# %% [markdown]
# # 🎮 Fantasy Football Projections - Control Panel
#
# **Scrape and manage player projections from multiple sources.**
#
# ## Quick Start:
# 1. **Update `WEEK` and `SEASON`** in the configuration
# 2. **Run All Cells** to scrape all sources
# 3. View database status and data quality metrics
#
# ## Sources:
# - 🔵 FanDuel
# - 💤 Sleeper
# - 🔴 ESPN
# - 📊 FantasyPros
# - 🎯 First Down Studio
#
# ---

# %% [markdown]
# ## 📦 Setup & Configuration

# %%
import os
import sqlite3
import subprocess
import sys
from datetime import datetime
from pathlib import Path

# Add scrapers directory to path FIRST (so local imports work)
NOTEBOOK_DIR = Path().absolute()
BACKEND_DIR = NOTEBOOK_DIR.parent
SCRAPERS_DIR = BACKEND_DIR / "scrapers"
sys.path.insert(0, str(SCRAPERS_DIR))

# Now import from scrapers (they use local imports like "from database import ProjectionsDB")
from database import ProjectionsDB
from scraper_sleeper import SleeperScraper
from scraper_espn import ESPNScraper
from scraper_fantasypros import FantasyProsScraper
from scraper_firstdown import FirstDownStudioScraper

# ==================== CONFIGURATION ====================
# Update these for each scraping session

WEEK = "Week 13"  # ⬅️ UPDATE THIS!
SEASON = "2025"
HEADLESS = True  # Set to False to see browser windows

# Database path
DB_PATH = str(BACKEND_DIR / "data" / "databases" / "projections.db")

print("✅ Setup Complete!")
print(f"📅 {WEEK}, Season {SEASON}")
print(f"👁️  Headless mode: {HEADLESS}")
print(f"💾 Database: {DB_PATH}")
print("\n" + "="*70 + "\n")
# Out:
# ✅ Setup Complete!
# 📅 Week 13, Season 2025
# 👁️  Headless mode: True
# 💾 Database: /Users/samerfaizi/Documents/Code/TNC-Model-2025/backend/data/databases/projections.db
#
# ======================================================================

# %% [markdown]
# ## 🤖 Run All Scrapers
#
# This will scrape projections from all sources for the configured week.

# %%
def run_all_scrapers():
    """Run all scrapers for the configured week."""
    print(f"{'='*70}")
    print(f"RUNNING ALL SCRAPERS - {WEEK}")
    print(f"{'='*70}\n")
    
    results = {}
    
    # 1. Sleeper (API-based, fast)
    print("💤 Sleeper...")
    try:
        with SleeperScraper(db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, season=SEASON)
        results['Sleeper'] = '✅'
        print("  ✓ Complete\n")
    except Exception as e:
        results['Sleeper'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
    
    # 2. ESPN
    print("🔴 ESPN...")
    try:
        with ESPNScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, season=SEASON)
        results['ESPN'] = '✅'
        print("  ✓ Complete\n")
    except Exception as e:
        results['ESPN'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
    
    # 3. FantasyPros
    print("📊 FantasyPros...")
    try:
        with FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK)
        results['FantasyPros'] = '✅'
        print("  ✓ Complete\n")
    except Exception as e:
        results['FantasyPros'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
    
    # 4. First Down Studio
    print("🎯 First Down Studio...")
    try:
        with FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, scoring="PPR")
        results['First Down'] = '✅'
        print("  ✓ Complete\n")
    except Exception as e:
        results['First Down'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
    
    # 5. FanDuel (via subprocess due to Playwright)
    print("🔵 FanDuel (subprocess)...")
    try:
        temp_script = NOTEBOOK_DIR / "_temp_fanduel.py"
        script_content = f'''
import sys
sys.path.insert(0, r"{SCRAPERS_DIR}")
from scraper_fanduel import FanDuelScraper

try:
    with FanDuelScraper(headless={HEADLESS}, db_path=r"{DB_PATH}") as scraper:
        scraper.scrape_and_save(week="{WEEK}")
    print("FanDuel complete")
except Exception as e:
    print(f"Error: {{e}}")
    raise
'''
        temp_script.write_text(script_content, encoding='utf-8')
        
        result = subprocess.run(
            [sys.executable, str(temp_script)],
            capture_output=True,
            text=True,
            cwd=str(SCRAPERS_DIR),
            timeout=300  # 5 minute timeout
        )
        
        if result.returncode == 0:
            results['FanDuel'] = '✅'
            print("  ✓ Complete\n")
        else:
            results['FanDuel'] = f'❌ {result.stderr[:50]}'
            print(f"  ✗ Error: {result.stderr}\n")
        
        temp_script.unlink(missing_ok=True)
    except Exception as e:
        results['FanDuel'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
        if temp_script.exists():
            temp_script.unlink()
    
    # Summary
    print(f"{'='*70}")
    print(f"SCRAPING SUMMARY")
    print(f"{'='*70}\n")
    for source, status in results.items():
        print(f"  {source:<15} {status}")
    print(f"\n{'='*70}\n")

# Run scrapers
run_all_scrapers()
# Out:
# ======================================================================
# RUNNING ALL SCRAPERS - Week 13
# ======================================================================
#
# 💤 Sleeper...
#
# Fetching Sleeper projections for 2025 Week 13...
# Fetching all players from Sleeper API...
#   ✓ Loaded 11401 players
# Fetching from: https://api.sleeper.app/v1/projections/nfl/regular/2025/13
#   ✓ Successfully fetched 8623 player projections
#
# Parsing 8623 projections...
#   Brandon Aubrey (K): 10.1 pts
#   CeeDee Lamb (WR): 18.4 pts
#   Bucky Irving (RB): 14.2 pts
#   Omarion Hampton (RB): 11.7 pts
#   Oronde Gadsden (TE): 12.1 pts
#   Dak Prescott (QB): 23.1 pts
#   Matthew Stafford (QB): 20.7 pts
#   Khalil Shakir (WR): 12.9 pts
#   James Cook (RB): 15.8 pts
#   Jauan Jennings (WR): 11.1 pts
#   Sam Darnold (QB): 19.2 pts
#   Jaxon Smith-Njigba (WR): 21.9 pts
#   Jaylen Waddle (WR): 14.0 pts
#   Daniel Jones (QB): 20.4 pts
#   TreVeyon Henderson (RB): 16.2 pts
#   D'Andre Swift (RB): 11.0 pts
#   Geno Smith (QB): 18.3 pts
#   Tua Tagovailoa (QB): 17.8 pts
#   Jalen Hurts (QB): 25.1 pts
#   Ladd McConkey (WR): 15.0 pts
#   Rome Odunze (WR): 10.9 pts
#   Michael Wilson (WR): 15.4 pts
#   Jordan Love (QB): 19.1 pts
#   Kirk Cousins (QB): 16.6 pts
#   Jake Ferguson (TE): 11.3 pts
#   Trey Benson (RB): 10.9 pts
#   Patrick Mahomes (QB): 26.3 pts
#   Shedeur Sanders (QB): 18.0 pts
#   Ja'Marr Chase (WR): 20.2 pts
#   Justin Herbert (QB): 22.3 pts
#   Lamar Jackson (QB): 24.6 pts
#   Davante Adams (WR): 15.8 pts
#   Aaron Rodgers (QB): 18.7 pts
#   Deebo Samuel (WR): 12.5 pts
#   Brenton Strange (TE): 10.1 pts
#   Tyler Shough (QB): 16.7 pts
#   Tyrod Taylor (QB): 17.1 pts
#   Baker Mayfield (QB): 21.4 pts
#   Tyler Warren (TE): 11.7 pts
#   Jakobi Meyers (WR): 10.7 pts
#   Emeka Egbuka (WR): 14.1 pts
#   Nico Collins (WR): 16.1 pts
#   Bryce Young (QB): 16.9 pts
#   Rico Dowdle (RB): 14.2 pts
#   George Pickens (WR): 17.2 pts
#   Woody Marks (RB): 12.4 pts
#   RJ Harvey (RB): 13.0 pts
#   Derrick Henry (RB): 18.1 pts
#   Cam Ward (QB): 15.2 pts
#   Puka Nacua (WR): 20.2 pts
#   A.J. Brown (WR): 15.4 pts
#   Christian McCaffrey (RB): 23.1 pts
#   Saquon Barkley (RB): 15.8 pts
#   Tre Tucker (WR): 10.5 pts
#   Trey McBride (TE): 19.6 pts
#   Alec Pierce (WR): 10.8 pts
#   Trevor Lawrence (QB): 20.8 pts
#   Jaxson Dart (QB): 21.0 pts
#   Ashton Jeanty (RB): 17.0 pts
#   Dallas Goedert (TE): 11.4 pts
#   Tyrone Tracy (RB): 10.4 pts
#   Max Brosmer (QB): 15.6 pts
#   Rashee Rice (WR): 18.5 pts
#   De'Von Achane (RB): 22.4 pts
#   Troy Franklin (WR): 10.3 pts
#   Bijan Robinson (RB): 20.8 pts
#   DeVonta Smith (WR): 15.2 pts
#   Devin Neal (RB): 12.2 pts
#   Drake London (WR): 17.0 pts
#   Joe Burrow (QB): 19.6 pts
#   Xavier Worthy (WR): 11.3 pts
#   Jahmyr Gibbs (RB): 22.6 pts
#   Jared Goff (QB): 18.7 pts
#   Jameson Williams (WR): 11.9 pts
#   George Kittle (TE): 13.6 pts
#   Keenan Allen (WR): 11.7 pts
#   Brock Purdy (QB): 20.9 pts
#   Quinshon Judkins (RB): 13.4 pts
#   Kenneth Walker (RB): 11.5 pts
#   Amon-Ra St. Brown (WR): 19.2 pts
#   Tetairoa McMillan (WR): 13.4 pts
#   Bo Nix (QB): 22.4 pts
#   Stefon Diggs (WR): 13.4 pts
#   Kenneth Gainwell (RB): 12.6 pts
#   Travis Etienne (RB): 14.3 pts
#   Brian Thomas (WR): 12.4 pts
#   Terry McLaurin (WR): 12.2 pts
#   Kyren Williams (RB): 14.4 pts
#   Romeo Doubs (WR): 10.4 pts
#   Jaylen Warren (RB): 14.0 pts
#   Chase Brown (RB): 14.5 pts
#   Mark Andrews (TE): 10.6 pts
#   Justin Jefferson (WR): 12.4 pts
#   Quentin Johnston (WR): 12.5 pts
#   Chris Olave (WR): 15.9 pts
#   Josh Allen (QB): 26.7 pts
#   Zay Flowers (WR): 15.8 pts
#   Wan'Dale Robinson (WR): 13.2 pts
#   Courtland Sutton (WR): 12.5 pts
#   Caleb Williams (QB): 17.8 pts
#   Jacoby Brissett (QB): 20.3 pts
#   C.J. Stroud (QB): 18.4 pts
#   Greg Dortch (WR): 11.1 pts
#   Marcus Mariota (QB): 19.8 pts
#   Travis Kelce (TE): 12.8 pts
#   Josh Jacobs (RB): 16.1 pts
#   Brock Bowers (TE): 15.1 pts
#   Michael Pittman (WR): 12.6 pts
#   Juwan Johnson (TE): 10.5 pts
#   DK Metcalf (WR): 12.0 pts
#   Breece Hall (RB): 14.2 pts
#   Jonathan Taylor (RB): 22.1 pts
#   Drake Maye (QB): 24.0 pts
#   Javonte Williams (RB): 16.4 pts
#
# ✓ Projections with data: 8623 out of 8623
# ✓ Total players with valid projections: 481
#
# Saving 481 projections to database...
# ✓ Successfully saved to database!
#   ✓ Complete
#
# 🔴 ESPN...
#
# Fetching ESPN projections for Week 13...
# Navigating to https://fantasy.espn.com/football/players/projections...
# Clicking 'Sortable Projections' view...
#   ✓ Switched to Sortable Projections view
# Setting scoring to Points PPR...
#   ✓ Set to Points PPR
# Setting to This Week projections...
#   ✓ Set to This Week
#
# Scraping 6 positions (up to 50 players each)...
#
#   Filtering to QB...
#     ✓ Filtered to QB
#     Found 50 players
#       Jalen Hurts (PHI): 23.3 pts
#       Drake Maye (NE): 22.4 pts
#       Patrick Mahomes (KC): 21.6 pts
#       Lamar Jackson (BAL): 21.3 pts
#       Josh Allen (BUF): 20.8 pts
#       Bo Nix (DEN): 20.3 pts
#       Dak Prescott (DAL): 19.4 pts
#       Matthew Stafford (LAR): 18.9 pts
#       Jaxson Dart (NYG): 18.8 pts
#       Justin Herbert (LAC): 18.2 pts
#       Joe Burrow (CIN): 17.9 pts
#       Caleb Williams (CHI): 17.4 pts
#       Jacoby Brissett (ARI): 17.3 pts
#       Daniel Jones (IND): 17.2 pts
#       C.J. Stroud (HOU): 17.2 pts
#       Trevor Lawrence (JAX): 16.5 pts
#       Jared Goff (DET): 15.9 pts
#       Tyrod Taylor (NYJ): 15.9 pts
#       Brock Purdy (SF): 15.8 pts
#       Jordan Love (GB): 15.7 pts
#       Baker Mayfield (TB): 15.5 pts
#       Sam Darnold (SEA): 15.2 pts
#       Marcus Mariota (WSH): 14.8 pts
#       Aaron Rodgers (PIT): 14.3 pts
#       Tyler Shough (NO): 13.5 pts
#       Cam Ward (TEN): 13.3 pts
#       Tua Tagovailoa (MIA): 12.6 pts
#       Kirk Cousins (ATL): 12.4 pts
#       Shedeur Sanders (CLE): 11.8 pts
#       Geno Smith (LV): 11.2 pts
#       Bryce Young (CAR): 10.6 pts
#     ✓ Scraped 32 QB projections
#
#   Filtering to RB...
#     ✓ Filtered to RB
#     Found 50 players
#       De'Von Achane (MIA): 24.5 pts
#       Christian McCaffrey (SF): 23.7 pts
#       Bijan Robinson (ATL): 20.7 pts
#       Jahmyr Gibbs (DET): 20.4 pts
#       Jonathan Taylor (IND): 20.3 pts
#       Derrick Henry (BAL): 20.2 pts
#       Josh Jacobs (GB): 19.1 pts
#       James Cook (BUF): 18.0 pts
#       Saquon Barkley (PHI): 17.7 pts
#       TreVeyon Henderson (NE): 16.7 pts
#       Breece Hall (NYJ): 16.3 pts
#       Chase Brown (CIN): 15.7 pts
#       Ashton Jeanty (LV): 15.5 pts
#       Rico Dowdle (CAR): 15.2 pts
#       Javonte Williams (DAL): 15.1 pts
#       Travis Etienne Jr. (JAX): 14.9 pts
#       RJ Harvey (DEN): 14.6 pts
#       Kyren Williams (LAR): 14.0 pts
#       Kenneth Walker (SEA): 13.9 pts
#       Jaylen Warren (PIT): 13.8 pts
#       Kenneth Gainwell (PIT): 13.1 pts
#       Aaron Jones Sr. (MIN): 12.5 pts
#       Quinshon Judkins (CLE): 12.5 pts
#       Tyrone Tracy Jr. (NYG): 12.5 pts
#       Omarion Hampton (LAC): 12.3 pts
#       Woody Marks (HOU): 11.8 pts
#       Bucky Irving (TB): 11.8 pts
#       Rhamondre Stevenson (NE): 11.7 pts
#       D'Andre Swift (CHI): 11.4 pts
#       Devin Neal (NO): 11.1 pts
#       Trey Benson (ARI): 10.8 pts
#       David Montgomery (DET): 10.5 pts
#       Tony Pollard (TEN): 10.3 pts
#     ✓ Scraped 50 RB projections
#
#   Filtering to WR...
#     ✓ Filtered to WR
#     Found 50 players
#       Jaxon Smith-Njigba (SEA): 21.9 pts
#       Ja'Marr Chase (CIN): 21.5 pts
#       Amon-Ra St. Brown (DET): 20.6 pts
#       Puka Nacua (LAR): 20.3 pts
#       CeeDee Lamb (DAL): 20.0 pts
#       George Pickens (DAL): 19.0 pts
#       Rashee Rice (KC): 18.1 pts
#       A.J. Brown (PHI): 16.8 pts
#       Davante Adams (LAR): 16.5 pts
#       Nico Collins (HOU): 16.4 pts
#       Chris Olave (NO): 15.9 pts
#       DeVonta Smith (PHI): 15.4 pts
#       Jaylen Waddle (MIA): 14.4 pts
#       Zay Flowers (BAL): 14.1 pts
#       Emeka Egbuka (TB): 14.0 pts
#       Justin Jefferson (MIN): 14.0 pts
#       Wan'Dale Robinson (NYG): 13.9 pts
#       Marvin Harrison Jr. (ARI): 13.7 pts
#       Courtland Sutton (DEN): 13.7 pts
#       Stefon Diggs (NE): 13.6 pts
#       Rome Odunze (CHI): 13.5 pts
#       Michael Pittman Jr. (IND): 13.3 pts
#       DK Metcalf (PIT): 13.3 pts
#       Tetairoa McMillan (CAR): 13.2 pts
#       Ladd McConkey (LAC): 13.2 pts
#       Troy Franklin (DEN): 12.9 pts
#       Khalil Shakir (BUF): 12.2 pts
#       Jauan Jennings (SF): 12.2 pts
#       Keenan Allen (LAC): 12.0 pts
#       Brian Thomas Jr. (JAX): 11.8 pts
#       Jameson Williams (DET): 11.8 pts
#       Deebo Samuel (WSH): 11.6 pts
#       Michael Wilson (ARI): 11.5 pts
#       Terry McLaurin (WSH): 11.0 pts
#       Xavier Worthy (KC): 11.0 pts
#       Christian Watson (GB): 10.9 pts
#       Jayden Higgins (HOU): 10.6 pts
#       Tre Tucker (LV): 10.5 pts
#       Darnell Mooney (ATL): 10.4 pts
#       Romeo Doubs (GB): 10.3 pts
#       Jakobi Meyers (JAX): 10.2 pts
#       Chimere Dike (TEN): 10.1 pts
#       Jerry Jeudy (CLE): 10.0 pts
#       Quentin Johnston (LAC): 10.0 pts
#     ✓ Scraped 50 WR projections
#
#   Filtering to TE...
#     ✓ Filtered to TE
#     Found 50 players
#       Trey McBride (ARI): 17.4 pts
#       Brock Bowers (LV): 14.6 pts
#       George Kittle (SF): 14.0 pts
#       Tyler Warren (IND): 13.3 pts
#       Mark Andrews (BAL): 12.0 pts
#       Travis Kelce (KC): 11.7 pts
#       Kyle Pitts Sr. (ATL): 11.4 pts
#       Hunter Henry (NE): 11.2 pts
#       Jake Ferguson (DAL): 10.9 pts
#       Dallas Goedert (PHI): 10.8 pts
#       Oronde Gadsden (LAC): 10.6 pts
#       Harold Fannin Jr. (CLE): 10.3 pts
#     ✓ Scraped 50 TE projections
#
#   Filtering to K...
#     ✓ Filtered to K
#     Found 50 players
#     ✓ Scraped 32 K projections
#
#   Filtering to D/ST...
#     ✓ Filtered to D/ST
#     Found 32 players
#     ✓ Scraped 32 D/ST projections
#
# ✓ Total players with valid projections: 246
#
# Saving 246 projections to database...
# ✓ Successfully saved to database!
#   ✓ Complete
#
# 📊 FantasyPros...
#
# Fetching FantasyPros consensus rankings for Week 13...
#
# Scraping QB from https://www.fantasypros.com/nfl/rankings/qb.php...
#   ⚠️  Page load timeout, retrying (1/2)...
#   Found 66 rows
#   Patrick Mahomes II (KC): 25.0 pts
#   Josh Allen (BUF): 24.5 pts
#   Lamar Jackson (BAL): 24.0 pts
#   Jalen Hurts (PHI): 23.5 pts
#   Drake Maye (NE): 23.0 pts
#   Matthew Stafford (LAR): 22.5 pts
#   Justin Herbert (LAC): 22.0 pts
#   Joe Burrow (CIN): 21.5 pts
#   Dak Prescott (DAL): 21.0 pts
#   Jacoby Brissett (ARI): 20.5 pts
#   Bo Nix (DEN): 20.0 pts
#   Jared Goff (DET): 19.5 pts
#   Caleb Williams (CHI): 19.0 pts
#   Sam Darnold (SEA): 18.5 pts
#   Jordan Love (GB): 18.0 pts
#   Trevor Lawrence (JAC): 17.5 pts
#   Brock Purdy (SF): 17.0 pts
#   Jaxson Dart (NYG): 16.5 pts
#   Daniel Jones (IND): 16.0 pts
#   Tua Tagovailoa (MIA): 15.5 pts
#   Tyrod Taylor (NYJ): 15.0 pts
#   Tyler Shough (NO): 14.5 pts
#   C.J. Stroud (HOU): 14.0 pts
#   Cam Ward (TEN): 13.5 pts
#   Kirk Cousins (ATL): 13.0 pts
#   Aaron Rodgers (PIT): 12.5 pts
#   Bryce Young (CAR): 12.0 pts
#   Marcus Mariota (WAS): 11.5 pts
#   Shedeur Sanders (CLE): 11.0 pts
#   Geno Smith (LV): 10.5 pts
#   Baker Mayfield (TB): 10.0 pts
#   ✓ Scraped 63 QB projections
#   ✓ Team data found: 63/63 (100.0%)
#
# Scraping RB from https://www.fantasypros.com/nfl/rankings/ppr-rb.php...
#   Found 27 rows
#   Jahmyr Gibbs (DET): 20.0 pts
#   Christian McCaffrey (SF): 19.6 pts
#   Jonathan Taylor (IND): 19.2 pts
#   De'Von Achane (MIA): 18.8 pts
#   Bijan Robinson (ATL): 18.4 pts
#   Chase Brown (CIN): 18.0 pts
#   James Cook III (BUF): 17.6 pts
#   Derrick Henry (BAL): 17.2 pts
#   TreVeyon Henderson (NE): 16.8 pts
#
#   DEBUG: Cleaned 'Saquon Barkley (PHI) Q' → 'Saquon Barkley (PHI)'
#   Saquon Barkley (PHI): 16.4 pts
#   Kyren Williams (LAR): 16.0 pts
#   Travis Etienne Jr. (JAC): 15.6 pts
#   Ashton Jeanty (LV): 15.2 pts
#   Breece Hall (NYJ): 14.8 pts
#   Rico Dowdle (CAR): 14.4 pts
#   Javonte Williams (DAL): 14.0 pts
#   Jaylen Warren (PIT): 13.6 pts
#
#   DEBUG: Cleaned 'Josh Jacobs (GB) Q' → 'Josh Jacobs (GB)'
#   Josh Jacobs (GB): 13.2 pts
#   RJ Harvey (DEN): 12.8 pts
#   Bucky Irving (TB): 12.4 pts
#   Woody Marks (HOU): 12.0 pts
#   Quinshon Judkins (CLE): 11.6 pts
#   Kenneth Walker III (SEA): 11.2 pts
#   Kareem Hunt (KC): 10.8 pts
#   Kenneth Gainwell (PIT): 10.4 pts
#   ✓ Scraped 25 RB projections
#   ✓ Team data found: 25/25 (100.0%)
#
# Scraping WR from https://www.fantasypros.com/nfl/rankings/ppr-wr.php...
#   Found 140 rows
#   Jaxon Smith-Njigba (SEA): 18.0 pts
#   Rashee Rice (KC): 17.6 pts
#   Ja'Marr Chase (CIN): 17.3 pts
#   Amon-Ra St. Brown (DET): 16.9 pts
#   Puka Nacua (LAR): 16.6 pts
#   Davante Adams (LAR): 16.2 pts
#   CeeDee Lamb (DAL): 15.9 pts
#
#   DEBUG: Cleaned 'George Pickens (DAL) Q' → 'George Pickens (DAL)'
#   George Pickens (DAL): 15.6 pts
#   Jaylen Waddle (MIA): 15.2 pts
#   Nico Collins (HOU): 14.8 pts
#   Chris Olave (NO): 14.5 pts
#   A.J. Brown (PHI): 14.2 pts
#   Tetairoa McMillan (CAR): 13.8 pts
#   Stefon Diggs (NE): 13.4 pts
#   Ladd McConkey (LAC): 13.1 pts
#
#   DEBUG: Cleaned 'DeVonta Smith (PHI) Q' → 'DeVonta Smith (PHI)'
#   DeVonta Smith (PHI): 12.8 pts
#   Wan'Dale Robinson (NYG): 12.4 pts
#   Emeka Egbuka (TB): 12.1 pts
#   Justin Jefferson (MIN): 11.7 pts
#   Michael Wilson (ARI): 11.4 pts
#   Zay Flowers (BAL): 11.0 pts
#   Khalil Shakir (BUF): 10.7 pts
#   Michael Pittman Jr. (IND): 10.3 pts
#
#   DEBUG: Cleaned 'Dontayvion Wicks (GB) Q' → 'Dontayvion Wicks (GB)'
#
#   DEBUG: Cleaned 'Isaac TeSlaa (DET) Q' → 'Isaac TeSlaa (DET)'
#
#   DEBUG: Cleaned 'KaVontae Turpin (DAL) Q' → 'KaVontae Turpin (DAL)'
#
#   DEBUG: Cleaned 'Matthew Golden (GB) Q' → 'Matthew Golden (GB)'
#
#   DEBUG: Cleaned 'Rashod Bateman (BAL) Q' → 'Rashod Bateman (BAL)'
#
#   DEBUG: Cleaned 'Savion Williams (GB) Q' → 'Savion Williams (GB)'
#   ✓ Scraped 136 WR projections
#   ✓ Team data found: 136/136 (100.0%)
#
# Scraping TE from https://www.fantasypros.com/nfl/rankings/ppr-te.php...
#   Found 77 rows
#   Trey McBride (ARI): 14.0 pts
#   George Kittle (SF): 13.7 pts
#   Brock Bowers (LV): 13.4 pts
#   Travis Kelce (KC): 13.1 pts
#   Tyler Warren (IND): 12.8 pts
#   Mark Andrews (BAL): 12.5 pts
#   Jake Ferguson (DAL): 12.2 pts
#   Oronde Gadsden II (LAC): 11.9 pts
#   Hunter Henry (NE): 11.6 pts
#   Dallas Goedert (PHI): 11.3 pts
#   Kyle Pitts Sr. (ATL): 11.0 pts
#   Juwan Johnson (NO): 10.7 pts
#   Theo Johnson (NYG): 10.4 pts
#   Brenton Strange (JAC): 10.1 pts
#
#   DEBUG: Cleaned 'Brock Wright (DET) Q' → 'Brock Wright (DET)'
#
#   DEBUG: Cleaned 'Noah Gray (KC) O' → 'Noah Gray (KC)'
#   ✓ Scraped 73 TE projections
#   ✓ Team data found: 73/73 (100.0%)
#
# Scraping K from https://www.fantasypros.com/nfl/rankings/k.php...
#   Found 36 rows
#   Brandon Aubrey (DAL): 10.0 pts
#   ✓ Scraped 33 K projections
#   ✓ Team data found: 33/33 (100.0%)
#
# Scraping DST from https://www.fantasypros.com/nfl/rankings/dst.php...
#   Found 35 rows
#   Seattle Seahawks Defense (SEA): 10.0 pts
#   ✓ Scraped 32 DST projections
#   ✓ Team data found: 32/32 (100.0%)
#
# ✓ Total players scraped: 362
#
# Saving 362 projections to database...
# ✓ Successfully saved to database!
#   ✓ Complete
#
# 🎯 First Down Studio...
# Navigating to https://www.firstdown.studio/rankings...
# Note: PPR points will be calculated from component stats for FLEX players
#
# Scraping QB tab...
# Error scraping QB tab: Message:
# Stacktrace:
# 0   chromedriver                        0x00000001028beecc cxxbridge1$str$ptr + 2941512
# 1   chromedriver                        0x00000001028b6b88 cxxbridge1$str$ptr + 2907908
# 2   chromedriver                        0x00000001023ce2b0 _RNvCsgXDX2mvAJAg_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 74020
# 3   chromedriver                        0x000000010241588c _RNvCsgXDX2mvAJAg_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 366336
# 4   chromedriver                        0x0000000102456d54 _RNvCsgXDX2mvAJAg_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 633800
# 5   chromedriver                        0x0000000102409ef0 _RNvCsgXDX2mvAJAg_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 318820
# 6   chromedriver                        0x00000001028820c8 cxxbridge1$str$ptr + 2692164
# 7   chromedriver                        0x00000001028858dc cxxbridge1$str$ptr + 2706520
# 8   chromedriver                        0x000000010286284c cxxbridge1$str$ptr + 2563016
# 9   chromedriver                        0x00000001028861b4 cxxbridge1$str$ptr + 2708784
# 10  chromedriver                        0x00000001028540f4 cxxbridge1$str$ptr + 2503792
# 11  chromedriver                        0x00000001028a5498 cxxbridge1$str$ptr + 2836500
# 12  chromedriver                        0x00000001028a561c cxxbridge1$str$ptr + 2836888
# 13  chromedriver                        0x00000001028b67d8 cxxbridge1$str$ptr + 2906964
# 14  libsystem_pthread.dylib             0x000000018f4b1f94 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x000000018f4acd34 thread_start + 8
#
#
# Scraping FLEX tab...
# Error scraping FLEX tab: Message:
# Stacktrace:
# 0   chromedriver                        0x00000001028beecc cxxbridge1$str$ptr + 2941512
# 1   chromedriver                        0x00000001028b6b88 cxxbridge1$str$ptr + 2907908
# 2   chromedriver                        0x00000001023ce2b0 _RNvCsgXDX2mvAJAg_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 74020
# 3   chromedriver                        0x000000010241588c _RNvCsgXDX2mvAJAg_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 366336
# 4   chromedriver                        0x0000000102456d54 _RNvCsgXDX2mvAJAg_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 633800
# 5   chromedriver                        0x0000000102409ef0 _RNvCsgXDX2mvAJAg_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 318820
# 6   chromedriver                        0x00000001028820c8 cxxbridge1$str$ptr + 2692164
# 7   chromedriver                        0x00000001028858dc cxxbridge1$str$ptr + 2706520
# 8   chromedriver                        0x000000010286284c cxxbridge1$str$ptr + 2563016
# 9   chromedriver                        0x00000001028861b4 cxxbridge1$str$ptr + 2708784
# 10  chromedriver                        0x00000001028540f4 cxxbridge1$str$ptr + 2503792
# 11  chromedriver                        0x00000001028a5498 cxxbridge1$str$ptr + 2836500
# 12  chromedriver                        0x00000001028a561c cxxbridge1$str$ptr + 2836888
# 13  chromedriver                        0x00000001028b67d8 cxxbridge1$str$ptr + 2906964
# 14  libsystem_pthread.dylib             0x000000018f4b1f94 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x000000018f4acd34 thread_start + 8
#
#
# Total unique players scraped: 0
# No projections found to save.
#   ✓ Complete
#
# 🔵 FanDuel (subprocess)...
#   ✓ Complete
#
# ======================================================================
# SCRAPING SUMMARY
# ======================================================================
#
#   Sleeper         ✅
#   ESPN            ✅
#   FantasyPros     ✅
#   First Down      ✅
#   FanDuel         ✅
#
# ======================================================================

# %% [markdown]
# ## 📊 Database Status & Data Quality

# %%
def show_database_status():
    """Display comprehensive database status and data quality metrics."""
    with ProjectionsDB(db_path=DB_PATH) as db:
        all_projs = db.get_projections()
        
        print(f"{'='*70}")
        print(f"DATABASE STATUS")
        print(f"{'='*70}\n")
        print(f"Total records: {len(all_projs)}\n")
        
        # Count by source
        print(f"📊 Records by Source:")
        print("-" * 70)
        sources = {}
        for p in all_projs:
            source = p['source_website']
            sources[source] = sources.get(source, 0) + 1
        
        for source, count in sorted(sources.items()):
            print(f"  {source:<25} {count:>5} records")
        
        # Count by week
        print(f"\n📅 Records by Week:")
        print("-" * 70)
        weeks = {}
        for p in all_projs:
            week = p['week']
            weeks[week] = weeks.get(week, 0) + 1
        
        for week, count in sorted(weeks.items()):
            print(f"  {week:<25} {count:>5} records")
        
        # Team coverage (data quality check)
        print(f"\n🏈 Team Data Coverage (Quality Check):")
        print("-" * 70)
        for source in sorted(sources.keys()):
            source_projs = [p for p in all_projs if p['source_website'] == source]
            with_team = sum(1 for p in source_projs if p.get('team'))
            total = len(source_projs)
            pct = (with_team / total * 100) if total > 0 else 0
            status = "✅" if pct >= 95 else "⚠️" if pct >= 75 else "❌"
            print(f"  {source:<25} {with_team:>4}/{total:<4} ({pct:>5.1f}%) {status}")
        
        print(f"\n{'='*70}\n")

# Show status
show_database_status()
# Out:
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 6428
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#   espn.com                    952 records
#   fanduel.com                1998 records
#   fantasypros.com            1508 records
#   firstdown.studio            337 records
#   sleeper.com                1633 records
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#   Week 10                    1625 records
#   Week 11                    1649 records
#   Week 12                    1519 records
#   Week 13                    1635 records
#
# 🏈 Team Data Coverage (Quality Check):
# ----------------------------------------------------------------------
#   espn.com                   952/952  (100.0%) ✅
#   fanduel.com               1998/1998 (100.0%) ✅
#   fantasypros.com           1508/1508 (100.0%) ✅
#   firstdown.studio           337/337  (100.0%) ✅
#   sleeper.com               1633/1633 (100.0%) ✅
#
# ======================================================================

# %% [markdown]
# ---
#
# ## 🛠️ Utility Functions
#
# **Use these as needed for database management**

# %%
# ============================================================================
# UTILITY FUNCTIONS - Uncomment to use
# ============================================================================

def clear_week(week_name):
    """Delete all records from a specific week."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    cursor.execute("DELETE FROM projections WHERE week = ?", (week_name,))
    deleted = cursor.rowcount
    conn.commit()
    conn.close()
    print(f"✓ Deleted {deleted} records from {week_name}")

def clear_source(source_name, week=None):
    """Delete records from a specific source."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    if week:
        cursor.execute("DELETE FROM projections WHERE source_website = ? AND week = ?", (source_name, week))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} for {week}")
    else:
        cursor.execute("DELETE FROM projections WHERE source_website = ?", (source_name,))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} (all weeks)")
    conn.commit()
    conn.close()

def clear_entire_database():
    """⚠️ DELETE ALL RECORDS - requires confirmation."""
    confirm = input("⚠️  Type 'DELETE ALL' to confirm: ")
    if confirm == "DELETE ALL":
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("DELETE FROM projections")
        conn.commit()
        deleted = cursor.rowcount
        conn.close()
        print(f"\n✓ Deleted {deleted} records from database")
    else:
        print("\n✗ Cancelled")

def show_week_source_matrix():
    """Display a matrix showing record counts by week and source."""
    import pandas as pd
    conn = sqlite3.connect(DB_PATH)
    query = """
        SELECT week, source_website, COUNT(*) as count
        FROM projections
        GROUP BY week, source_website
        ORDER BY week, source_website
    """
    df = pd.read_sql_query(query, conn)
    conn.close()
    
    if len(df) == 0:
        print("No data in database")
        return
    
    pivot = df.pivot(index='source_website', columns='week', values='count')
    pivot = pivot.fillna(0).astype(int)
    
    print(f"\n{'='*70}")
    print("WEEK × SOURCE MATRIX")
    print("="*70)
    print(pivot.to_string())
    print("="*70 + "\n")

def run_single_scraper(scraper_name):
    """Run a specific scraper by name."""
    scrapers = {
        'sleeper': lambda: SleeperScraper(db_path=DB_PATH),
        'espn': lambda: ESPNScraper(headless=HEADLESS, db_path=DB_PATH),
        'fantasypros': lambda: FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH),
        'firstdown': lambda: FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH)
    }
    
    name_lower = scraper_name.lower()
    if name_lower not in scrapers:
        print(f"Unknown scraper: {scraper_name}")
        print(f"Available: {', '.join(scrapers.keys())}")
        return
    
    print(f"Running {scraper_name}...")
    try:
        with scrapers[name_lower]() as scraper:
            if name_lower == 'sleeper':
                scraper.scrape_and_save(week=WEEK, season=SEASON)
            elif name_lower == 'espn':
                scraper.scrape_and_save(week=WEEK, season=SEASON)
            elif name_lower == 'firstdown':
                scraper.scrape_and_save(week=WEEK, scoring="PPR")
            else:
                scraper.scrape_and_save(week=WEEK)
        print(f"✓ {scraper_name} complete")
    except Exception as e:
        print(f"✗ Error: {e}")

# Uncomment to use:
# clear_week("Week 10")
# clear_source("fantasypros.com", WEEK)
# clear_entire_database()
show_week_source_matrix()
# run_single_scraper("sleeper")

print("✅ Utility functions loaded. Uncomment above to use.")
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# ======================================================================
# WEEK × SOURCE MATRIX
# ======================================================================
# week              Week 10  Week 11  Week 12  Week 13
# source_website
# espn.com              232      240      234      246
# fanduel.com           473      508      471      546
# fantasypros.com       388      321      437      362
# firstdown.studio      161      176        0        0
# sleeper.com           371      404      377      481
# ======================================================================
#
# ✅ Utility functions loaded. Uncomment above to use.

# %% [markdown]
# ---
#
# ## 📚 Quick Reference
#
# ### Weekly Workflow:
# 1. Update `WEEK` and `SEASON` in cell 2
# 2. **Kernel → Restart & Run All**
# 3. Wait for all scrapers to complete (~5-10 minutes)
# 4. Check database status for data quality
#
# ### Available Functions:
# - `run_all_scrapers()` - Scrape all sources *(runs automatically)*
# - `show_database_status()` - View database contents *(runs automatically)*
# - `run_single_scraper(name)` - Run one scraper
# - `clear_week(week)` - Delete all data for a week
# - `clear_source(source, week)` - Delete data from a source
# - `show_week_source_matrix()` - See week×source grid
# - `clear_entire_database()` - Delete everything ⚠️
#
# ### Source Names:
# - `"fanduel.com"`
# - `"sleeper.com"`
# - `"espn.com"`
# - `"fantasypros.com"`
# - `"firstdown.studio"`
#
# ### Tips:
# - FanDuel uses Playwright and runs in a subprocess (this is normal)
# - Set `HEADLESS = False` to see browser windows for debugging
# - Scrapers typically take 1-3 minutes each
# - Check "Team Data Coverage" to ensure quality (should be ≥95%)
#
# ---
#
# **✅ Ready to use! Update WEEK and run all cells.**
