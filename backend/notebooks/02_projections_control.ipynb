# %% [markdown]
# # 🎮 Fantasy Football Database - Master Control Panel
#
# This notebook provides complete control over your fantasy football projections database.
#
# **Features:**
# - 🗑️ Database management (view, clear, reset)
# - 📊 Run scrapers individually or all at once
# - 📈 View data quality metrics
# - 🔍 Check team coverage by source

# %% [markdown]
# ## 📦 Setup & Imports
#
# **Important Notes:**
# - The FanDuel scraper (Playwright-based) runs via subprocess to avoid conflicts with Jupyter's event loop. All other scrapers run directly in the notebook.
# - **⚠️ If you modify any scraper files (scraper_*.py), you MUST restart the Jupyter kernel to reload the changes!** Python caches imported modules.

# %%
import os
import sqlite3
import subprocess
import sys
from datetime import datetime
from pathlib import Path

# Add parent directory to path for imports
sys.path.append(str(Path().absolute().parent.parent))
sys.path.append(str(Path().absolute().parent / 'scrapers'))

from backend.scrapers.database import ProjectionsDB
from backend.scrapers.scraper_sleeper import SleeperScraper
from backend.scrapers.scraper_espn import ESPNScraper
from backend.scrapers.scraper_fantasypros import FantasyProsScraper
from backend.scrapers.scraper_firstdown import FirstDownStudioScraper

# Configuration
WEEK = "Week 10"
SEASON = "2025"
HEADLESS = True  # Set to False to see browser

# Get absolute path to database
NOTEBOOK_DIR = Path().absolute()
BACKEND_DIR = NOTEBOOK_DIR.parent
DB_PATH = str(BACKEND_DIR / "data" / "databases" / "projections.db")
SCRAPERS_DIR = str(BACKEND_DIR / "scrapers")

print(f"✓ Imports successful")
print(f"Configuration: {WEEK}, Season {SEASON}")
print(f"Headless mode: {HEADLESS}")
print(f"Database path: {DB_PATH}")
print(f"\n⚠️  Note: FanDuel scraper must be run via subprocess (Playwright limitation in Jupyter)")
# Out:
# ✓ Imports successful
# Configuration: Week 10, Season 2025
# Headless mode: True
# Database path: C:\Users\Samer Faizi\Documents\Claude Model\backend\data\databases\projections.db
#
# ⚠️  Note: FanDuel scraper must be run via subprocess (Playwright limitation in Jupyter)

# %% [markdown]
# ## 📊 Database Status & Overview

# %% [markdown]
# ## 📊 Week × Source Matrix View
#
# Quick diagnostic to see which sources have which weeks.

# %%
def show_week_source_matrix():
    """Display a matrix showing record counts by week and source."""
    import pandas as pd
    
    conn = sqlite3.connect(DB_PATH)
    
    query = """
        SELECT 
            week,
            source_website,
            COUNT(*) as count
        FROM projections
        GROUP BY week, source_website
        ORDER BY week, source_website
    """
    
    df = pd.read_sql_query(query, conn)
    conn.close()
    
    if len(df) == 0:
        print("No data in database")
        return
    
    # Create pivot table
    pivot = df.pivot(index='source_website', columns='week', values='count')
    pivot = pivot.fillna(0).astype(int)
    
    print("\n" + "="*70)
    print("WEEK × SOURCE MATRIX")
    print("="*70)
    print(pivot.to_string())
    print("="*70 + "\n")

show_week_source_matrix()
# Out:
# ======================================================================
# WEEK × SOURCE MATRIX
# ======================================================================
# week              Week 10
# source_website
# espn.com              232
# fanduel.com           473
# fantasypros.com       253
# firstdown.studio      161
# sleeper.com           371
# ======================================================================

# %%
def show_database_status():
    """Display current database status."""
    with ProjectionsDB(db_path=DB_PATH) as db:
        all_projs = db.get_projections()
        
        print(f"\n{'='*70}")
        print(f"DATABASE STATUS")
        print(f"{'='*70}\n")
        print(f"Total records: {len(all_projs)}")
        
        # Count by source
        print(f"\n📊 Records by Source:")
        print("-" * 70)
        sources = {}
        for p in all_projs:
            source = p['source_website']
            sources[source] = sources.get(source, 0) + 1
        
        for source, count in sorted(sources.items()):
            print(f"  {source:<25} {count:>5} records")
        
        # Count by week
        print(f"\n📅 Records by Week:")
        print("-" * 70)
        weeks = {}
        for p in all_projs:
            week = p['week']
            weeks[week] = weeks.get(week, 0) + 1
        
        for week, count in sorted(weeks.items()):
            print(f"  {week:<25} {count:>5} records")
        
        # Team coverage
        print(f"\n🏈 Team Data Coverage:")
        print("-" * 70)
        for source in sorted(sources.keys()):
            source_projs = [p for p in all_projs if p['source_website'] == source]
            with_team = sum(1 for p in source_projs if p.get('team'))
            total = len(source_projs)
            pct = (with_team / total * 100) if total > 0 else 0
            status = "✅" if pct >= 95 else "⚠️" if pct >= 75 else "❌"
            print(f"  {source:<25} {with_team:>4}/{total:<4} ({pct:>5.1f}%) {status}")

show_database_status()
# Out:
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 0
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#
# 🏈 Team Data Coverage:
# ----------------------------------------------------------------------

# %% [markdown]
# ## 🗑️ Database Management
#
# ### ⚠️ Clear Entire Database
# **WARNING:** This will delete ALL records from the database!

# %%
def clear_entire_database():
    """Delete all records from the database."""
    confirm = input("⚠️  Are you sure you want to delete ALL records? Type 'DELETE ALL' to confirm: ")
    
    if confirm == "DELETE ALL":
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("DELETE FROM projections")
        conn.commit()
        deleted = cursor.rowcount
        conn.close()
        print(f"\n✓ Deleted {deleted} records from database")
        print("Database is now empty.")
    else:
        print("\n✗ Cancelled. Database unchanged.")

# Uncomment to run:
clear_entire_database()
show_database_status()
# Out:
# ⚠️  Are you sure you want to delete ALL records? Type 'DELETE ALL' to confirm:  DELETE ALL
# ✓ Deleted 1490 records from database
# Database is now empty.
#
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 0
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#
# 🏈 Team Data Coverage:
# ----------------------------------------------------------------------

# %% [markdown]
# ### 🗑️ Clear Specific Source

# %%
def clear_source(source_name, week=None):
    """Delete records from a specific source."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    
    if week:
        cursor.execute("DELETE FROM projections WHERE source_website = ? AND week = ?", (source_name, week))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} for {week}")
    else:
        cursor.execute("DELETE FROM projections WHERE source_website = ?", (source_name,))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} (all weeks)")
    
    conn.commit()
    conn.close()

# Examples:
# clear_source("fantasypros.com", WEEK)
# clear_source("fantasypros.com")
# show_database_status()

# %% [markdown]
# ### 🗑️ Clear Specific Week
#
# Delete all records from a specific week across all sources.

# %%
def clear_week(week_name):
    """Delete all records from a specific week across all sources."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    
    cursor.execute("DELETE FROM projections WHERE week = ?", (week_name,))
    deleted = cursor.rowcount
    conn.commit()
    conn.close()
    
    print(f"✓ Deleted {deleted} records from {week_name}")

# Example: clear_week("Week 8")
# Uncomment to run:
clear_week("Week 8")
clear_week("Week 9")
show_database_status()

# %% [markdown]
# ## 🤖 Run Scrapers Individually
#
# **Note:** FanDuel uses Playwright which conflicts with Jupyter's event loop, so it runs via subprocess (separate process). The other scrapers run directly in the notebook.
#
# ### 1️⃣ FanDuel Scraper

# %%
print(f"\n{'='*70}")
print(f"🔵 FANDUEL SCRAPER (via subprocess)")
print(f"{'='*70}\n")
print(f"Using configuration: {WEEK}, Headless={HEADLESS}\n")

# FanDuel uses Playwright which doesn't work in Jupyter's event loop
# Run it as a subprocess instead
try:
    # Create a temporary script to run FanDuel scraper
    # Escape backslashes for Windows paths
    db_path_escaped = DB_PATH.replace("\\", "\\\\")
    scrapers_dir_escaped = SCRAPERS_DIR.replace("\\", "\\\\")
    
    script_content = f'''
import sys
from pathlib import Path

# Add scrapers directory to path
sys.path.insert(0, r"{scrapers_dir_escaped}")

from scraper_fanduel import FanDuelScraper

print("Starting FanDuel scraper...")
print(f"Week: {WEEK}")
print(f"Headless: {HEADLESS}")
print(f"DB Path: {db_path_escaped}")

try:
    with FanDuelScraper(headless={HEADLESS}, db_path=r"{db_path_escaped}") as scraper:
        scraper.scrape_and_save(week="{WEEK}")
    print("\\nFanDuel scraper completed successfully!")
except Exception as e:
    print(f"Error during scraping: {{e}}")
    import traceback
    traceback.print_exc()
'''
    
    # Write to temp file
    temp_script_path = NOTEBOOK_DIR / "_temp_fanduel.py"
    with open(temp_script_path, "w", encoding="utf-8") as f:
        f.write(script_content)
    
    print(f"Running FanDuel scraper for {WEEK}...\n")
    
    # Run as subprocess with proper working directory
    result = subprocess.run(
        [sys.executable, str(temp_script_path)],
        capture_output=True,
        text=True,
        cwd=str(SCRAPERS_DIR)  # Set working directory to scrapers
    )
    
    # Print output
    if result.stdout:
        print(result.stdout)
    
    if result.returncode == 0:
        print("\n✅ FanDuel scraping complete!")
    else:
        print(f"\n❌ Error: {result.stderr}")
    
    # Clean up temp file
    if temp_script_path.exists():
        temp_script_path.unlink()
        
except Exception as e:
    print(f"\n❌ Error: {e}")
    import traceback
    traceback.print_exc()
    # Clean up temp file if error
    temp_script_path = NOTEBOOK_DIR / "_temp_fanduel.py"
    if temp_script_path.exists():
        temp_script_path.unlink()

show_database_status()
# Out:
# ======================================================================
# 🔵 FANDUEL SCRAPER (via subprocess)
# ======================================================================
#
# Using configuration: Week 10, Headless=True
#
# Running FanDuel scraper for Week 10...
#
# Starting FanDuel scraper...
# Week: Week 10
# Headless: True
# DB Path: C:\Users\Samer Faizi\Documents\Claude Model\backend\data\databases\projections.db
# Navigating to https://www.fanduel.com/research/nfl/fantasy/ppr...
#   Intercepted data from https://fdresearch-api.fanduel.com/graphql
#   âœ“ Found 473 projections in response
#
# Parsing 473 projections...
#   Lamar Jackson (QB): 23.3 pts
#   Josh Allen (QB): 23.2 pts
#   Christian McCaffrey (RB): 22.3 pts
#   Bijan Robinson (RB): 22.1 pts
#   Jonathan Taylor (RB): 21.6 pts
#   De'Von Achane (RB): 21.3 pts
#   Puka Nacua (WR): 21.3 pts
#   James Cook (RB): 19.8 pts
#   Drake Maye (QB): 19.5 pts
#   Jahmyr Gibbs (RB): 19.5 pts
#   Baker Mayfield (QB): 18.9 pts
#   Jalen Hurts (QB): 18.9 pts
#   Caleb Williams (QB): 18.7 pts
#   Matthew Stafford (QB): 18.7 pts
#   Justin Herbert (QB): 18.7 pts
#   Bo Nix (QB): 18.6 pts
#   Amon-Ra St. Brown (WR): 18.6 pts
#   Brock Purdy (QB): 18.5 pts
#   Daniel Jones (QB): 18.5 pts
#   Justin Jefferson (WR): 18.4 pts
#   Jared Goff (QB): 18.1 pts
#   Jaxson Dart (QB): 18.0 pts
#   Zay Flowers (WR): 17.7 pts
#   J.J. McCarthy (QB): 17.6 pts
#   Jordan Love (QB): 17.4 pts
#   Marcus Mariota (QB): 17.1 pts
#   Jaxon Smith-Njigba (WR): 17.1 pts
#   Sam Darnold (QB): 16.9 pts
#   Davante Adams (WR): 16.6 pts
#   Drake London (WR): 16.6 pts
#   Josh Jacobs (RB): 16.3 pts
#   Emeka Egbuka (WR): 16.2 pts
#   Saquon Barkley (RB): 16.2 pts
#   Justin Fields (QB): 16.1 pts
#   Michael Penix Jr. (QB): 15.9 pts
#   Brock Bowers (TE): 15.7 pts
#   Aaron Rodgers (QB): 15.5 pts
#   Rico Dowdle (RB): 15.4 pts
#   Ashton Jeanty (RB): 15.4 pts
#   Kyren Williams (RB): 15.4 pts
#   Travis Etienne (RB): 15.3 pts
#   Breece Hall (RB): 15.2 pts
#   A.J. Brown (WR): 14.9 pts
#   Dillon Gabriel (QB): 14.8 pts
#   Michael Pittman Jr. (WR): 14.7 pts
#   Alvin Kamara (RB): 14.6 pts
#   Quinshon Judkins (RB): 14.6 pts
#   Bucky Irving (RB): 14.6 pts
#   Trevor Lawrence (QB): 14.5 pts
#   Trey McBride (TE): 14.3 pts
#   Omarion Hampton (RB): 14.3 pts
#   Bryce Young (QB): 14.0 pts
#   J.K. Dobbins (RB): 14.0 pts
#   Tyler Warren (TE): 13.9 pts
#   Deebo Samuel (WR): 13.9 pts
#   Courtland Sutton (WR): 13.9 pts
#   Ladd McConkey (WR): 13.7 pts
#   Stefon Diggs (WR): 13.7 pts
#   Jacoby Brissett (QB): 13.6 pts
#   Jaylen Waddle (WR): 13.6 pts
#   Derrick Henry (RB): 13.6 pts
#   Romeo Doubs (WR): 13.5 pts
#   Tua Tagovailoa (QB): 13.5 pts
#   Khalil Shakir (WR): 13.4 pts
#   Tetairoa McMillan (WR): 13.4 pts
#   Geno Smith (QB): 13.2 pts
#   Chris Olave (WR): 13.1 pts
#   Tyler Shough (QB): 13.1 pts
#   TreVeyon Henderson (RB): 13.1 pts
#   Marvin Harrison Jr. (WR): 12.9 pts
#   DeVonta Smith (WR): 12.9 pts
#   Nico Collins (WR): 12.8 pts
#   Davis Mills (QB): 12.7 pts
#   Jaylen Warren (RB): 12.7 pts
#   Harold Fannin Jr. (TE): 12.6 pts
#   Alec Pierce (WR): 12.5 pts
#   Rome Odunze (WR): 12.5 pts
#   Sam LaPorta (TE): 12.2 pts
#   Troy Franklin (WR): 12.2 pts
#   D.K. Metcalf (WR): 12.2 pts
#   Kenneth Walker III (RB): 11.9 pts
#   Jameson Williams (WR): 11.8 pts
#   Wan'Dale Robinson (WR): 11.8 pts
#   Oronde Gadsden (TE): 11.8 pts
#   Garrett Wilson (WR): 11.7 pts
#   Jauan Jennings (WR): 11.6 pts
#   Chris Godwin (WR): 11.4 pts
#   Tyrone Tracy Jr. (RB): 11.4 pts
#   Jordan Addison (WR): 11.3 pts
#   Jacory Croskey-Merritt (RB): 11.3 pts
#   Dalton Kincaid (TE): 11.3 pts
#   Tre Tucker (WR): 11.3 pts
#   Woody Marks (RB): 11.1 pts
#   Quentin Johnston (WR): 10.9 pts
#   Rashid Shaheed (WR): 10.9 pts
#   Keenan Allen (WR): 10.9 pts
#   Kenneth Gainwell (RB): 10.8 pts
#   David Montgomery (RB): 10.6 pts
#   Hunter Henry (TE): 10.6 pts
#   Josh Downs (WR): 10.4 pts
#   Theo Johnson (TE): 10.4 pts
#   Demarcus Robinson (WR): 10.4 pts
#   Zach Ertz (TE): 10.2 pts
#   Parker Washington (WR): 10.2 pts
#   Aaron Jones (RB): 9.9 pts
#   Juwan Johnson (TE): 9.9 pts
#   Dallas Goedert (TE): 9.8 pts
#   Jerry Jeudy (WR): 9.8 pts
#   D'Andre Swift (RB): 9.6 pts
#   Jakobi Meyers (WR): 9.5 pts
#   Kyle Pitts (TE): 9.5 pts
#   Christian Watson (WR): 9.3 pts
#   Keon Coleman (WR): 9.2 pts
#   Christian Kirk (WR): 9.1 pts
#   D.J. Moore (WR): 9.1 pts
#   Kyle Monangai (RB): 9.1 pts
#   Mason Taylor (TE): 9.0 pts
#   Rashod Bateman (WR): 9.0 pts
#   Malik Washington (WR): 8.9 pts
#   Calvin Austin III (WR): 8.9 pts
#   George Kittle (TE): 8.9 pts
#   Evan Engram (TE): 8.6 pts
#   Sterling Shepard (WR): 8.5 pts
#   Darius Slayton (WR): 8.5 pts
#   Chris Moore (WR): 8.4 pts
#   Luke Musgrave (TE): 8.4 pts
#   T.J. Hockenson (TE): 8.4 pts
#   Mark Andrews (TE): 8.3 pts
#   Michael Mayer (TE): 8.3 pts
#   Jordan Mason (RB): 8.2 pts
#   Matthew Golden (WR): 8.2 pts
#   David Njoku (TE): 8.2 pts
#   RJ Harvey (RB): 8.0 pts
#   Dalton Schultz (TE): 7.9 pts
#   Jalen Nailor (WR): 7.9 pts
#   Blake Corum (RB): 7.9 pts
#   Nick Chubb (RB): 7.6 pts
#   Isaiah Likely (TE): 7.6 pts
#   Zach Charbonnet (RB): 7.6 pts
#   Tyler Higbee (TE): 7.5 pts
#   Rachaad White (RB): 7.5 pts
#   Kayshon Boutte (WR): 7.4 pts
#   Xavier Legette (WR): 7.4 pts
#   AJ Barner (TE): 7.1 pts
#   Michael Wilson (WR): 7.1 pts
#   Emari Demercado (RB): 7.0 pts
#   Devin Singletary (RB): 7.0 pts
#   Kendrick Bourne (WR): 6.9 pts
#   Olamide Zaccheaus (WR): 6.9 pts
#   Brandin Cooks (WR): 6.8 pts
#   Pat Freiermuth (TE): 6.8 pts
#   Pat Bryant (WR): 6.8 pts
#   Ja'Tavion Sanders (TE): 6.8 pts
#   Josh Palmer (WR): 6.8 pts
#   Ollie Gordon II (RB): 6.8 pts
#   Zay Jones (WR): 6.6 pts
#   Mack Hollins (WR): 6.5 pts
#   Jerome Ford (RB): 6.4 pts
#   Jonnu Smith (TE): 6.4 pts
#   Darnell Mooney (WR): 6.3 pts
#   Cade Otton (TE): 6.2 pts
#   Justice Hill (RB): 6.0 pts
#   Colston Loveland (TE): 5.9 pts
#   Jaylin Lane (WR): 5.9 pts
#   Kalif Raymond (WR): 5.8 pts
#   Isaiah Bond (WR): 5.7 pts
#   Elijah Arroyo (TE): 5.7 pts
#   Nick Westbrook-Ikhine (WR): 5.5 pts
#   Darnell Washington (TE): 5.5 pts
#   Rhamondre Stevenson (RB): 5.4 pts
#   Ray-Ray McCloud (WR): 5.3 pts
#   Jalen Coker (WR): 5.3 pts
#   Brian Thomas Jr. (WR): 5.1 pts
#   Cooper Kupp (WR): 5.1 pts
#   Jordan Whittington (WR): 5.0 pts
#   Hunter Long (TE): 4.9 pts
#   Bhayshul Tuten (RB): 4.9 pts
#   Xavier Hutchinson (WR): 4.9 pts
#   Emanuel Wilson (RB): 4.9 pts
#   Greg Dulcich (TE): 4.8 pts
#   Zonovan Knight (RB): 4.7 pts
#   Trey Benson (RB): 4.7 pts
#   Cole Kmet (TE): 4.7 pts
#   Ricky Pearsall (WR): 4.7 pts
#   Chuba Hubbard (RB): 4.7 pts
#   Chris Rodriguez Jr. (RB): 4.6 pts
#   Kimani Vidal (RB): 4.6 pts
#   Dawson Knox (TE): 4.6 pts
#   Tez Johnson (WR): 4.5 pts
#   Isaiah Davis (RB): 4.5 pts
#   Luther Burden III (WR): 4.3 pts
#   Tory Horton (WR): 4.3 pts
#   Austin Hooper (TE): 4.1 pts
#   Terrance Ferguson (TE): 4.1 pts
#   Jeremy McNichols (RB): 4.0 pts
#   Brian Robinson (RB): 4.0 pts
#   Isaiah Williams (WR): 4.0 pts
#   Dyami Brown (WR): 4.0 pts
#   Johnny Mundt (TE): 3.9 pts
#   Greg Dortch (WR): 3.8 pts
#   Treylon Burks (WR): 3.8 pts
#   MarShawn Lloyd (RB): 3.7 pts
#   Tyler Lockett (WR): 3.7 pts
#   Tyler Allgeier (RB): 3.7 pts
#   Jimmy Horn Jr. (WR): 3.5 pts
#   Keaton Mitchell (RB): 3.5 pts
#   DeAndre Hopkins (WR): 3.5 pts
#   Allen Lazard (WR): 3.5 pts
#   Demario Douglas (WR): 3.5 pts
#   David Sills V (WR): 3.5 pts
#   Raheem Mostert (RB): 3.4 pts
#   Tanner Conner (TE): 3.3 pts
#   Taysom Hill (TE): 3.3 pts
#   Dontayvion Wicks (WR): 3.2 pts
#   Jahan Dotson (WR): 3.2 pts
#   Lil'Jordan Humphrey (WR): 3.0 pts
#   Dylan Sampson (RB): 3.0 pts
#   Will Shipley (RB): 3.0 pts
#   Daniel Bellinger (TE): 3.0 pts
#   Tre Harris (WR): 3.0 pts
#   Devin Neal (RB): 2.9 pts
#   Ty Johnson (RB): 2.9 pts
#   Tim Patrick (WR): 2.9 pts
#   Devaughn Vele (WR): 2.8 pts
#   Devin Duvernay (WR): 2.7 pts
#   Mason Tipton (WR): 2.6 pts
#   George Holani (RB): 2.6 pts
#   Curtis Samuel (WR): 2.6 pts
#   Roman Wilson (WR): 2.5 pts
#   Brittain Brown (RB): 2.5 pts
#   Chris Manhertz (TE): 2.5 pts
#   Terrell Jennings (RB): 2.4 pts
#   Elijah Higgins (TE): 2.4 pts
#   Charlie Kolar (TE): 2.4 pts
#   Sean Tucker (RB): 2.4 pts
#   Adonai Mitchell (WR): 2.3 pts
#   Tommy Tremble (TE): 2.3 pts
#   Isaac TeSlaa (WR): 2.2 pts
#   Savion Williams (WR): 2.1 pts
#   Kyle Williams (WR): 2.1 pts
#   Grant Calcaterra (TE): 2.0 pts
#   Casey Washington (WR): 2.0 pts
#   Andrew Beck (RB): 1.7 pts
#   Harrison Bryant (TE): 1.7 pts
#   Mitchell Evans (TE): 1.7 pts
#   Jack Bech (WR): 1.7 pts
#   Jake Bobo (WR): 1.6 pts
#   Jayden Higgins (WR): 1.5 pts
#   Trent Sherfield (WR): 1.5 pts
#   A.J. Dillon (RB): 1.5 pts
#   Isaac Guerendo (RB): 1.5 pts
#   Jamari Thrash (WR): 1.5 pts
#   Dylan Laube (RB): 1.4 pts
#   Kyle Juszczyk (RB): 1.4 pts
#   Ben Sinnott (TE): 1.4 pts
#   Colby Parkinson (TE): 1.3 pts
#   Brock Wright (TE): 1.2 pts
#   Jack Stoll (TE): 1.2 pts
#   Cedric Tillman (WR): 1.2 pts
#   Chris Brooks (RB): 1.2 pts
#   Nate Adkins (TE): 1.2 pts
#   Luke Farrell (TE): 1.1 pts
#   Foster Moreau (TE): 1.1 pts
#   Jackson Hawes (TE): 1.1 pts
#   Charlie Woerner (TE): 1.1 pts
#   Cedrick Wilson (WR): 1.1 pts
#   Tylan Wallace (WR): 1.1 pts
#   Tyler Conklin (TE): 1.1 pts
#   Kaleb Johnson (RB): 1.1 pts
#   Malik Heath (WR): 1.1 pts
#   Ray Davis (RB): 1.1 pts
#   Jaret Patterson (RB): 1.1 pts
#   Tyler Badie (RB): 1.0 pts
#   Skyy Moore (WR): 1.0 pts
#   Tyrell Shavers (WR): 1.0 pts
#   Jaylin Noel (WR): 1.0 pts
#   Trevor Etienne (RB): 1.0 pts
#   Xavier Smith (WR): 1.0 pts
#   Alec Ingold (RB): 1.0 pts
#   Will Dissly (TE): 1.0 pts
#   LeQuint Allen Jr. (RB): 1.0 pts
#   Ashton Dulin (WR): 0.9 pts
#   Ameer Abdullah (RB): 0.8 pts
#   Zavier Scott (RB): 0.8 pts
#   Zamir White (RB): 0.8 pts
#   Arian Smith (WR): 0.8 pts
#   Tay Martin (WR): 0.8 pts
#   D'Ernest Johnson (RB): 0.7 pts
#   Brycen Tremayne (WR): 0.7 pts
#   Riley Leonard (QB): 0.7 pts
#   Reggie Gilliam (RB): 0.7 pts
#   Payne Durham (TE): 0.7 pts
#   Jacob Saylors (RB): 0.7 pts
#   Jeff Wilson (RB): 0.6 pts
#   Jaylen Wright (RB): 0.6 pts
#   Cam Akers (RB): 0.6 pts
#   Audric Estime (RB): 0.6 pts
#   Davis Allen (TE): 0.6 pts
#   Roschon Johnson (RB): 0.6 pts
#   Mo Alie-Cox (TE): 0.6 pts
#   Andrew Ogletree (TE): 0.6 pts
#   Nathan Carter (RB): 0.6 pts
#   John FitzPatrick (TE): 0.6 pts
#   Ben Sims (TE): 0.6 pts
#   Adam Trautman (TE): 0.6 pts
#   Justin Shorter (TE): 0.6 pts
#   Adam Thielen (WR): 0.6 pts
#   Jake Tonges (TE): 0.6 pts
#   Teagan Quitoriano (TE): 0.6 pts
#   Feleipe Franks (TE): 0.6 pts
#   Josh Oliver (TE): 0.6 pts
#   Connor Heyward (TE): 0.6 pts
#   Dee Eskridge (WR): 0.6 pts
#   Ben Yurosek (TE): 0.6 pts
#   Kameron Johnson (WR): 0.6 pts
#   Ryan Miller (WR): 0.6 pts
#   Eric Saubert (TE): 0.5 pts
#   Dareke Young (WR): 0.5 pts
#   James Mitchell (TE): 0.5 pts
#   Michael Carter (RB): 0.5 pts
#   Marcedes Lewis (TE): 0.5 pts
#   Khadarel Hodge (WR): 0.5 pts
#   Tank Bigsby (RB): 0.5 pts
#   Jamal Agnew (WR): 0.5 pts
#   Kylen Granson (TE): 0.5 pts
#   Jalin Hyatt (WR): 0.5 pts
#   British Brooks (RB): 0.5 pts
#   Dare Ogunbowale (RB): 0.5 pts
#   Trey Palmer (WR): 0.4 pts
#   Irv Smith Jr. (TE): 0.4 pts
#   Hunter Renfrow (WR): 0.4 pts
#   Jared Wayne (WR): 0.4 pts
#   Jeremy Ruckert (TE): 0.4 pts
#   Braxton Berrios (WR): 0.4 pts
#   Jimmy Garoppolo (QB): 0.3 pts
#   Kirk Cousins (QB): 0.3 pts
#   Ian Thomas (TE): 0.3 pts
#   Russell Wilson (QB): 0.3 pts
#   Teddy Bridgewater (QB): 0.3 pts
#   Tucker Fisk (TE): 0.3 pts
#   Kedon Slovis (QB): 0.3 pts
#   KeAndre Lambert-Smith (WR): 0.3 pts
#   Andy Dalton (QB): 0.3 pts
#   Tyson Bagent (QB): 0.3 pts
#   Mitchell Trubisky (QB): 0.3 pts
#   Nick Mullens (QB): 0.3 pts
#   Mac Jones (QB): 0.2 pts
#   Trey Lance (QB): 0.2 pts
#   Jarrett Stidham (QB): 0.2 pts
#   Max Brosmer (QB): 0.2 pts
#   Kyle Allen (QB): 0.2 pts
#   Mason Rudolph (QB): 0.2 pts
#   DJ Giddens (RB): 0.2 pts
#   Spencer Rattler (QB): 0.2 pts
#   Shedeur Sanders (QB): 0.2 pts
#   Drew Lock (QB): 0.2 pts
#   Malik Willis (QB): 0.2 pts
#   Tyrod Taylor (QB): 0.2 pts
#   Joshua Dobbs (QB): 0.2 pts
#   Josh Johnson (QB): 0.2 pts
#   Tanner McKee (QB): 0.2 pts
#   Cooper Rush (QB): 0.2 pts
#   Kenny Pickett (QB): 0.2 pts
#   Zach Wilson (QB): 0.2 pts
#   Alex Bachman (WR): 0.0 pts
#   Marvin Mims (WR): 0.0 pts
#   Jaleel McLaughlin (RB): 0.0 pts
#   Aidan O'Connell (QB): 0.0 pts
#   Dont'e Thornton Jr. (WR): 0.0 pts
#   Carter Runyon (TE): 0.0 pts
#   Easton Stick (QB): 0.0 pts
#   Anthony Richardson (QB): 0.0 pts
#   Will Mallory (TE): 0.0 pts
#   Tyler Goodson (RB): 0.0 pts
#   Anthony Gould (WR): 0.0 pts
#   Dylan Drummond (WR): 0.0 pts
#   David Moore (WR): 0.0 pts
#   Zaire Mitchell-Paden (TE): 0.0 pts
#   Moliki Matavao (TE): 0.0 pts
#   Dalevon Campbell (WR): 0.0 pts
#   Case Keenum (QB): 0.0 pts
#   Jameis Winston (QB): 0.0 pts
#   Durham Smythe (TE): 0.0 pts
#   Travis Homer (RB): 0.0 pts
#   Eric Gray (RB): 0.0 pts
#   Cam Skattebo (RB): 0.0 pts
#   Beaux Collins (WR): 0.0 pts
#   Jahdae Walker (WR): 0.0 pts
#   Thomas Fidone II (TE): 0.0 pts
#   Darren Waller (TE): 0.0 pts
#   Elijah Moore (WR): 0.0 pts
#   Julian Hill (TE): 0.0 pts
#   Tahj Washington (WR): 0.0 pts
#   Quinn Ewers (QB): 0.0 pts
#   Hayden Rucci (TE): 0.0 pts
#   Patrick Ricard (RB): 0.0 pts
#   C.J. Ham (RB): 0.0 pts
#   Tyler Huntley (QB): 0.0 pts
#   Ty Chandler (RB): 0.0 pts
#   Devontez Walker (WR): 0.0 pts
#   Rasheen Ali (RB): 0.0 pts
#   Tai Felton (WR): 0.0 pts
#   LaJohntay Wester (WR): 0.0 pts
#   Myles Price (WR): 0.0 pts
#   Josh Reynolds (WR): 0.0 pts
#   Tyler Johnson (WR): 0.0 pts
#   Stone Smartt (TE): 0.0 pts
#   Irvin Charles (WR): 0.0 pts
#   Braelon Allen (RB): 0.0 pts
#   Blake Whiteheart (TE): 0.0 pts
#   Raheim Sanders (RB): 0.0 pts
#   Brady Cook (QB): 0.0 pts
#   Gage Larvadain (WR): 0.0 pts
#   Cade McDonald (WR): 0.0 pts
#   Joe Mixon (RB): 0.0 pts
#   Justin Watson (WR): 0.0 pts
#   Dameon Pierce (RB): 0.0 pts
#   C.J. Stroud (QB): 0.0 pts
#   Tank Dell (WR): 0.0 pts
#   Brenton Strange (TE): 0.0 pts
#   Cade Stover (TE): 0.0 pts
#   Travis Hunter (WR): 0.0 pts
#   Mike Evans (WR): 0.0 pts
#   Chase Edmonds (RB): 0.0 pts
#   Jalen McMillan (WR): 0.0 pts
#   Devin Culp (TE): 0.0 pts
#   Jack Westover (RB): 0.0 pts
#   Josh Williams (RB): 0.0 pts
#   Owen Wright (RB): 0.0 pts
#   Efton Chism III (WR): 0.0 pts
#   Kyler Murray (QB): 0.0 pts
#   Cody White (WR): 0.0 pts
#   Brady Russell (RB): 0.0 pts
#   Trishton Jackson (WR): 0.0 pts
#   Tip Reiman (TE): 0.0 pts
#   Xavier Weaver (WR): 0.0 pts
#   Robbie Ouzts (RB): 0.0 pts
#   Travis Vokolek (TE): 0.0 pts
#   Jalen Milroe (QB): 0.0 pts
#   Nick Kallerup (TE): 0.0 pts
#   Ricky White III (WR): 0.0 pts
#   Trent Taylor (WR): 0.0 pts
#   Brandon Aiyuk (WR): 0.0 pts
#   Tutu Atwell (WR): 0.0 pts
#   Jacob Cowing (WR): 0.0 pts
#   Konata Mumpfield (WR): 0.0 pts
#   Jarquez Hunter (RB): 0.0 pts
#   Adrian Martinez (QB): 0.0 pts
#   Jordan James (RB): 0.0 pts
#   Jordan Watkins (WR): 0.0 pts
#   Noah Brown (WR): 0.0 pts
#   Terry McLaurin (WR): 0.0 pts
#   Craig Reynolds (RB): 0.0 pts
#   John Bates (TE): 0.0 pts
#   Shane Zylstra (TE): 0.0 pts
#   Luke McCaffrey (WR): 0.0 pts
#   Jayden Daniels (QB): 0.0 pts
#   Sione Vaki (RB): 0.0 pts
#   Dominic Lovett (WR): 0.0 pts
#   Jackson Meeks (WR): 0.0 pts
#   Ja'Corey Brooks (WR): 0.0 pts
#   Marquez Valdes-Scantling (WR): 0.0 pts
#   Trayveon Williams (RB): 0.0 pts
#   Ben Skowronek (WR): 0.0 pts
#   Hassan Haskins (RB): 0.0 pts
#   Skylar Thompson (QB): 0.0 pts
#   Derius Davis (WR): 0.0 pts
#   Ke'Shawn Williams (WR): 0.0 pts
#   Amar Johnson (RB): 0.0 pts
#   Sam Howell (QB): 0.0 pts
#   Jayden Reed (WR): 0.0 pts
#   Darius Cooper (WR): 0.0 pts
#   Cameron Latu (TE): 0.0 pts
#
# Total players scraped: 473
#
# Saving 473 projections to database...
# Using database: C:\\Users\\Samer Faizi\\Documents\\Claude Model\\backend\\data\\databases\\projections.db
# âœ“ Successfully saved to database!
#
# FanDuel scraper completed successfully!
#
#
# ✅ FanDuel scraping complete!
#
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 473
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#   fanduel.com                 473 records
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#   Week 10                     473 records
#
# 🏈 Team Data Coverage:
# ----------------------------------------------------------------------
#   fanduel.com                473/473  (100.0%) ✅

# %% [markdown]
# ### 2️⃣ Sleeper Scraper

# %%
print(f"\n{'='*70}")
print(f"💤 SLEEPER SCRAPER")
print(f"{'='*70}\n")

try:
    with SleeperScraper(db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK, season=SEASON)
    print("\n✅ Sleeper scraping complete!")
except Exception as e:
    print(f"\n❌ Error: {e}")
    import traceback
    traceback.print_exc()

show_database_status()
# Out:
# ======================================================================
# 💤 SLEEPER SCRAPER
# ======================================================================
#
#
# Fetching Sleeper projections for 2025 Week 10...
# Fetching all players from Sleeper API...
#   ✓ Loaded 11400 players
# Fetching from: https://api.sleeper.app/v1/projections/nfl/regular/2025/10
#   ✓ Successfully fetched 8618 player projections
#
# Parsing 8618 projections...
#   Oronde Gadsden (TE): 12.1 pts
#   Davis Mills (QB): 14.8 pts
#   Matthew Stafford (QB): 19.6 pts
#   Khalil Shakir (WR): 12.3 pts
#   James Cook (RB): 16.9 pts
#   Jauan Jennings (WR): 11.9 pts
#   Rachaad White (RB): 16.6 pts
#   Sam Darnold (QB): 19.4 pts
#   Kimani Vidal (RB): 12.7 pts
#   Jaxon Smith-Njigba (WR): 23.1 pts
#   Jaylen Waddle (WR): 14.8 pts
#   Daniel Jones (QB): 21.4 pts
#   D'Andre Swift (RB): 12.9 pts
#   Geno Smith (QB): 18.8 pts
#   Tua Tagovailoa (QB): 18.5 pts
#   Jalen Hurts (QB): 22.6 pts
#   Ladd McConkey (WR): 13.7 pts
#   Rome Odunze (WR): 12.3 pts
#   Jordan Love (QB): 18.4 pts
#   Justin Herbert (QB): 20.9 pts
#   Sam LaPorta (TE): 13.0 pts
#   Lamar Jackson (QB): 25.1 pts
#   Davante Adams (WR): 15.1 pts
#   Aaron Rodgers (QB): 18.0 pts
#   Deebo Samuel (WR): 13.9 pts
#   Tyler Shough (QB): 16.5 pts
#   Baker Mayfield (QB): 21.9 pts
#   Tyler Warren (TE): 12.8 pts
#   Emeka Egbuka (WR): 14.7 pts
#   Nico Collins (WR): 14.7 pts
#   Bryce Young (QB): 17.6 pts
#   Rico Dowdle (RB): 16.7 pts
#   Garrett Wilson (WR): 16.4 pts
#   Woody Marks (RB): 11.6 pts
#   Derrick Henry (RB): 15.8 pts
#   Puka Nacua (WR): 23.7 pts
#   A.J. Brown (WR): 15.0 pts
#   Christian McCaffrey (RB): 24.2 pts
#   Justin Fields (QB): 19.9 pts
#   Saquon Barkley (RB): 16.4 pts
#   Tre Tucker (WR): 10.9 pts
#   Trey McBride (TE): 16.0 pts
#   Alec Pierce (WR): 10.4 pts
#   Hunter Henry (TE): 10.2 pts
#   Trevor Lawrence (QB): 18.7 pts
#   Jaxson Dart (QB): 24.1 pts
#   Jacory Croskey-Merritt (RB): 10.2 pts
#   J.J. McCarthy (QB): 17.6 pts
#   Ashton Jeanty (RB): 14.5 pts
#   DJ Moore (WR): 10.1 pts
#   Dallas Goedert (TE): 11.1 pts
#   Tyrone Tracy (RB): 11.3 pts
#   De'Von Achane (RB): 19.8 pts
#   Michael Penix (QB): 16.8 pts
#   Troy Franklin (WR): 10.4 pts
#   Bijan Robinson (RB): 19.8 pts
#   DeVonta Smith (WR): 14.7 pts
#   Drake London (WR): 16.3 pts
#   Jahmyr Gibbs (RB): 21.4 pts
#   Jared Goff (QB): 21.3 pts
#   Jameson Williams (WR): 10.7 pts
#   George Kittle (TE): 14.5 pts
#   Marvin Harrison (WR): 11.9 pts
#   Keenan Allen (WR): 12.9 pts
#   Brock Purdy (QB): 20.1 pts
#   Quinshon Judkins (RB): 13.8 pts
#   Kenneth Walker (RB): 10.6 pts
#   Amon-Ra St. Brown (WR): 21.5 pts
#   Tetairoa McMillan (WR): 12.6 pts
#   Bo Nix (QB): 21.1 pts
#   Stefon Diggs (WR): 14.4 pts
#   Kenneth Gainwell (RB): 10.2 pts
#   Travis Etienne (RB): 12.4 pts
#   David Montgomery (RB): 12.0 pts
#   Aaron Jones (RB): 10.2 pts
#   Rhamondre Stevenson (RB): 11.0 pts
#   Kyren Williams (RB): 16.3 pts
#   Romeo Doubs (WR): 11.0 pts
#   Emari Demercado (RB): 10.6 pts
#   Dillon Gabriel (QB): 16.1 pts
#   Jaylen Warren (RB): 15.5 pts
#   Justin Jefferson (WR): 16.9 pts
#   Quentin Johnston (WR): 10.9 pts
#   Chris Olave (WR): 15.2 pts
#   Josh Allen (QB): 25.6 pts
#   Josh Downs (WR): 10.0 pts
#   Zay Flowers (WR): 15.0 pts
#   Wan'Dale Robinson (WR): 14.4 pts
#   Courtland Sutton (WR): 13.0 pts
#   Caleb Williams (QB): 18.1 pts
#   Alvin Kamara (RB): 11.9 pts
#   Jacoby Brissett (QB): 15.3 pts
#   Marcus Mariota (QB): 19.8 pts
#   Darius Slayton (WR): 10.7 pts
#   Josh Jacobs (RB): 18.1 pts
#   Zach Charbonnet (RB): 10.1 pts
#   Brock Bowers (TE): 16.0 pts
#   Jordan Addison (WR): 12.4 pts
#   Michael Pittman (WR): 13.8 pts
#   Juwan Johnson (TE): 10.6 pts
#   DK Metcalf (WR): 12.6 pts
#   Breece Hall (RB): 14.3 pts
#   J.K. Dobbins (RB): 11.3 pts
#   Jonathan Taylor (RB): 22.7 pts
#   Drake Maye (QB): 22.2 pts
#
# ✓ Projections with data: 8618 out of 8618
# ✓ Total players with valid projections: 422
#
# Saving 422 projections to database...
# ✓ Successfully saved to database!
#
# ✅ Sleeper scraping complete!
#
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 895
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#   fanduel.com                 473 records
#   sleeper.com                 422 records
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#   Week 10                     895 records
#
# 🏈 Team Data Coverage:
# ----------------------------------------------------------------------
#   fanduel.com                473/473  (100.0%) ✅
#   sleeper.com                422/422  (100.0%) ✅

# %% [markdown]
# ### 3️⃣ ESPN Scraper

# %%
print(f"\n{'='*70}")
print(f"🔴 ESPN SCRAPER")
print(f"{'='*70}\n")

try:
    with ESPNScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK, season=SEASON)
    print("\n✅ ESPN scraping complete!")
except Exception as e:
    print(f"\n❌ Error: {e}")
    import traceback
    traceback.print_exc()

show_database_status()
# Out:
# ======================================================================
# 🔴 ESPN SCRAPER
# ======================================================================
#
#
# Fetching ESPN projections for Week 10...
# Navigating to https://fantasy.espn.com/football/players/projections...
# Clicking 'Sortable Projections' view...
#   ✓ Switched to Sortable Projections view
# Setting scoring to Points PPR...
#   ✓ Set to Points PPR
# Setting to This Week projections...
#   ✓ Set to This Week
#
# Scraping 6 positions (up to 50 players each)...
#
#   Filtering to QB...
#     ✓ Filtered to QB
#     Found 50 players
#       Lamar Jackson (BAL): 23.6 pts
#       Jaxson Dart (NYG): 23.4 pts
#       Josh Allen (BUF): 22.5 pts
#       Jalen Hurts (PHI): 21.4 pts
#       Drake Maye (NE): 20.8 pts
#       Justin Herbert (LAC): 20.1 pts
#       Daniel Jones (IND): 20.0 pts
#       Matthew Stafford (LAR): 19.6 pts
#       Caleb Williams (CHI): 19.5 pts
#       Bo Nix (DEN): 19.1 pts
#       Jared Goff (DET): 18.7 pts
#       J.J. McCarthy (MIN): 17.7 pts
#       Brock Purdy (SF): 17.1 pts
#       Jordan Love (GB): 17.0 pts
#       Justin Fields (NYJ): 16.7 pts
#       Sam Darnold (SEA): 16.6 pts
#       Marcus Mariota (WSH): 16.3 pts
#       Baker Mayfield (TB): 16.1 pts
#       Michael Penix Jr. (ATL): 16.0 pts
#       Davis Mills (HOU): 15.4 pts
#       Jacoby Brissett (ARI): 15.2 pts
#       Aaron Rodgers (PIT): 15.0 pts
#       Tua Tagovailoa (MIA): 13.8 pts
#       Trevor Lawrence (JAX): 13.3 pts
#       Bryce Young (CAR): 13.2 pts
#       Dillon Gabriel (CLE): 12.8 pts
#       Tyler Shough (NO): 12.4 pts
#       Geno Smith (LV): 12.1 pts
#     ✓ Scraped 28 QB projections
#
#   Filtering to RB...
#     ✓ Filtered to RB
#     Found 50 players
#       Christian McCaffrey (SF): 24.4 pts
#       De'Von Achane (MIA): 21.4 pts
#       Jonathan Taylor (IND): 21.3 pts
#       James Cook (BUF): 21.0 pts
#       Bijan Robinson (ATL): 20.6 pts
#       Jahmyr Gibbs (DET): 18.2 pts
#       Rico Dowdle (CAR): 18.2 pts
#       Josh Jacobs (GB): 18.1 pts
#       Rachaad White (TB): 16.2 pts
#       Saquon Barkley (PHI): 16.1 pts
#       Derrick Henry (BAL): 15.8 pts
#       Kyren Williams (LAR): 15.6 pts
#       Jaylen Warren (PIT): 15.3 pts
#       Quinshon Judkins (CLE): 15.1 pts
#       D'Andre Swift (CHI): 14.8 pts
#       Breece Hall (NYJ): 14.4 pts
#       David Montgomery (DET): 13.9 pts
#       Ashton Jeanty (LV): 13.9 pts
#       J.K. Dobbins (DEN): 13.2 pts
#       TreVeyon Henderson (NE): 13.2 pts
#       Tyrone Tracy Jr. (NYG): 12.8 pts
#       Travis Etienne Jr. (JAX): 12.7 pts
#       Kenneth Walker (SEA): 12.5 pts
#       Alvin Kamara (NO): 12.2 pts
#       Kimani Vidal (LAC): 11.7 pts
#       Aaron Jones Sr. (MIN): 11.4 pts
#       Kyle Monangai (CHI): 11.1 pts
#       Woody Marks (HOU): 10.2 pts
#       Devin Singletary (NYG): 10.0 pts
#     ✓ Scraped 50 RB projections
#
#   Filtering to WR...
#     ✓ Filtered to WR
#     Found 50 players
#       Puka Nacua (LAR): 23.1 pts
#       Amon-Ra St. Brown (DET): 22.3 pts
#       Jaxon Smith-Njigba (SEA): 21.9 pts
#       Justin Jefferson (MIN): 19.9 pts
#       Drake London (ATL): 19.8 pts
#       A.J. Brown (PHI): 17.2 pts
#       Davante Adams (LAR): 16.5 pts
#       Nico Collins (HOU): 15.7 pts
#       Zay Flowers (BAL): 15.6 pts
#       Emeka Egbuka (TB): 15.6 pts
#       Ladd McConkey (LAC): 15.3 pts
#       Michael Pittman Jr. (IND): 15.0 pts
#       DeVonta Smith (PHI): 14.9 pts
#       Chris Olave (NO): 14.6 pts
#       Wan'Dale Robinson (NYG): 14.5 pts
#       Jaylen Waddle (MIA): 14.1 pts
#       Deebo Samuel (WSH): 14.0 pts
#       Stefon Diggs (NE): 14.0 pts
#       Rome Odunze (CHI): 13.7 pts
#       Garrett Wilson (NYJ): 13.7 pts
#       Marvin Harrison Jr. (ARI): 13.3 pts
#       Courtland Sutton (DEN): 13.3 pts
#       DK Metcalf (PIT): 13.3 pts
#       Jauan Jennings (SF): 13.1 pts
#       Romeo Doubs (GB): 12.8 pts
#       Jordan Addison (MIN): 12.8 pts
#       Khalil Shakir (BUF): 12.7 pts
#       Keenan Allen (LAC): 12.5 pts
#       Troy Franklin (DEN): 12.4 pts
#       Tetairoa McMillan (CAR): 12.2 pts
#       Jameson Williams (DET): 12.1 pts
#       DJ Moore (CHI): 11.9 pts
#       Quentin Johnston (LAC): 11.7 pts
#       Brian Thomas Jr. (JAX): 11.5 pts
#       Darius Slayton (NYG): 11.4 pts
#       Josh Downs (IND): 11.2 pts
#       Rashid Shaheed (SEA): 10.9 pts
#       Alec Pierce (IND): 10.5 pts
#       Tre Tucker (LV): 10.2 pts
#     ✓ Scraped 50 WR projections
#
#   Filtering to TE...
#     ✓ Filtered to TE
#     Found 50 players
#       Trey McBride (ARI): 17.2 pts
#       Brock Bowers (LV): 15.8 pts
#       Sam LaPorta (DET): 13.1 pts
#       Tyler Warren (IND): 12.5 pts
#       George Kittle (SF): 12.1 pts
#       Kyle Pitts Sr. (ATL): 11.8 pts
#       Oronde Gadsden (LAC): 11.5 pts
#       Dallas Goedert (PHI): 10.8 pts
#       Hunter Henry (NE): 10.7 pts
#       Theo Johnson (NYG): 10.6 pts
#       Harold Fannin Jr. (CLE): 10.1 pts
#     ✓ Scraped 49 TE projections
#
#   Filtering to K...
#     ✓ Filtered to K
#     Found 50 players
#     ✓ Scraped 27 K projections
#
#   Filtering to D/ST...
#     ✓ Filtered to D/ST
#     Found 32 players
#     ✓ Scraped 28 D/ST projections
#
# ✓ Total players with valid projections: 232
#
# Saving 232 projections to database...
# ✓ Successfully saved to database!
#
# ✅ ESPN scraping complete!
#
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 1127
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#   espn.com                    232 records
#   fanduel.com                 473 records
#   sleeper.com                 422 records
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#   Week 10                    1127 records
#
# 🏈 Team Data Coverage:
# ----------------------------------------------------------------------
#   espn.com                   232/232  (100.0%) ✅
#   fanduel.com                473/473  (100.0%) ✅
#   sleeper.com                422/422  (100.0%) ✅

# %% [markdown]
# ### 4️⃣ FantasyPros Scraper

# %%
print(f"\n{'='*70}")
print(f"📊 FANTASYPROS SCRAPER")
print(f"{'='*70}\n")
print("⏳ Starting FantasyPros scraper (this may take a moment)...\n")

try:
    with FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
        print("Opening browser...")
        scraper.scrape_and_save(week=WEEK)
    print("\n✅ FantasyPros scraping complete!")
except Exception as e:
    print(f"\n❌ Error: {e}")
    import traceback
    traceback.print_exc()

show_database_status()
# Out:
# ======================================================================
# 📊 FANTASYPROS SCRAPER
# ======================================================================
#
# ⏳ Starting FantasyPros scraper (this may take a moment)...
#
# Opening browser...
#
# Fetching FantasyPros consensus rankings for Week 10...
#
# Scraping QB from https://www.fantasypros.com/nfl/rankings/qb.php...
#   Found 54 rows
#   Josh Allen (BUF): 24.1 pts
#   Lamar Jackson (BAL): 22.3 pts
#   Drake Maye (NE): 21.5 pts
#   Justin Herbert (LAC): 20.7 pts
#   Jalen Hurts (PHI): 20.5 pts
#   Jaxson Dart (NYG): 20.2 pts
#   Bo Nix (DEN): 19.9 pts
#   Baker Mayfield (TB): 19.6 pts
#   Caleb Williams (CHI): 19.2 pts
#   Daniel Jones (IND): 18.7 pts
#   Matthew Stafford (LAR): 18.1 pts
#   Jared Goff (DET): 17.5 pts
#   Sam Darnold (SEA): 17.1 pts
#   Jordan Love (GB): 16.7 pts
#   Marcus Mariota (WAS): 16.4 pts
#   J.J. McCarthy (MIN): 16.1 pts
#   Justin Fields (NYJ): 15.8 pts
#   Jacoby Brissett (ARI): 15.5 pts
#   Aaron Rodgers (PIT): 15.1 pts
#   Michael Penix Jr. (ATL): 14.8 pts
#   Mac Jones (SF): 14.5 pts
#   Bryce Young (CAR): 14.2 pts
#   Trevor Lawrence (JAC): 13.8 pts
#   Tua Tagovailoa (MIA): 13.4 pts
#   Geno Smith (LV): 13.1 pts
#   Davis Mills (HOU): 12.6 pts
#   Dillon Gabriel (CLE): 11.5 pts
#   Tyler Shough (NO): 10.6 pts
#
#   DEBUG: Cleaned 'Brock Purdy (SF) Q' → 'Brock Purdy (SF)'
#   ✓ Scraped 51 QB projections
#   ✓ Team data found: 51/51 (100.0%)
#
# Scraping RB from https://www.fantasypros.com/nfl/rankings/ppr-rb.php...
#   Found 106 rows
#   Christian McCaffrey (SF): 23.0 pts
#   Bijan Robinson (ATL): 20.6 pts
#   Jonathan Taylor (IND): 20.0 pts
#   De'Von Achane (MIA): 19.5 pts
#
#   DEBUG: Cleaned 'James Cook III (BUF) Q' → 'James Cook III (BUF)'
#   James Cook III (BUF): 18.6 pts
#
#   DEBUG: Cleaned 'Rico Dowdle (CAR) Q' → 'Rico Dowdle (CAR)'
#   Rico Dowdle (CAR): 17.8 pts
#   Jahmyr Gibbs (DET): 17.3 pts
#   Josh Jacobs (GB): 16.5 pts
#   Saquon Barkley (PHI): 15.2 pts
#   Jaylen Warren (PIT): 14.8 pts
#   Kyren Williams (LAR): 14.6 pts
#   Derrick Henry (BAL): 14.4 pts
#   Quinshon Judkins (CLE): 13.8 pts
#   Ashton Jeanty (LV): 13.7 pts
#   J.K. Dobbins (DEN): 13.6 pts
#   Breece Hall (NYJ): 13.4 pts
#   Kimani Vidal (LAC): 12.8 pts
#   Travis Etienne Jr. (JAC): 12.5 pts
#   TreVeyon Henderson (NE): 12.2 pts
#   Rachaad White (TB): 11.7 pts
#   Kyle Monangai (CHI): 11.2 pts
#   Kenneth Walker III (SEA): 10.8 pts
#   David Montgomery (DET): 10.7 pts
#   Tyrone Tracy Jr. (NYG): 10.3 pts
#   Zach Charbonnet (SEA): 10.3 pts
#
#   DEBUG: Cleaned 'Alvin Kamara (NO) Q' → 'Alvin Kamara (NO)'
#   Alvin Kamara (NO): 10.2 pts
#   RJ Harvey (DEN): 10.1 pts
#   Woody Marks (HOU): 10.0 pts
#
#   DEBUG: Cleaned 'Aaron Jones Sr. (MIN) Q' → 'Aaron Jones Sr. (MIN)'
#
#   DEBUG: Cleaned 'Nick Chubb (HOU) Q' → 'Nick Chubb (HOU)'
#
#   DEBUG: Cleaned 'Ollie Gordon II (MIA) Q' → 'Ollie Gordon II (MIA)'
#
#   DEBUG: Cleaned 'Bucky Irving (TB) Q' → 'Bucky Irving (TB)'
#
#   DEBUG: Cleaned 'Rhamondre Stevenson (NE) Q' → 'Rhamondre Stevenson (NE)'
#
#   DEBUG: Cleaned 'C.J. Ham (MIN) Q' → 'C.J. Ham (MIN)'
#
#   DEBUG: Cleaned 'Craig Reynolds (DET) Q' → 'Craig Reynolds (DET)'
#
#   DEBUG: Cleaned 'Trey Benson (ARI) IR' → 'Trey Benson (ARI)'
#
#   DEBUG: Cleaned 'Roschon Johnson (CHI) Q' → 'Roschon Johnson (CHI)'
#   ✓ Scraped 102 RB projections
#   ✓ Team data found: 102/102 (100.0%)
#
# Scraping WR from https://www.fantasypros.com/nfl/rankings/ppr-wr.php...
#   Found 164 rows
#   Jaxon Smith-Njigba (SEA): 21.1 pts
#   Puka Nacua (LAR): 20.7 pts
#   Amon-Ra St. Brown (DET): 20.6 pts
#   Drake London (ATL): 17.3 pts
#   Justin Jefferson (MIN): 16.3 pts
#   Emeka Egbuka (TB): 15.8 pts
#   Davante Adams (LAR): 15.4 pts
#   Nico Collins (HOU): 15.3 pts
#   Jaylen Waddle (MIA): 14.9 pts
#   Ladd McConkey (LAC): 14.6 pts
#   Zay Flowers (BAL): 14.6 pts
#   Michael Pittman Jr. (IND): 14.1 pts
#
#   DEBUG: Cleaned 'Rome Odunze (CHI) Q' → 'Rome Odunze (CHI)'
#   Rome Odunze (CHI): 14.0 pts
#   A.J. Brown (PHI): 14.0 pts
#   Stefon Diggs (NE): 13.9 pts
#   DeVonta Smith (PHI): 13.9 pts
#   Courtland Sutton (DEN): 13.5 pts
#   Chris Olave (NO): 13.5 pts
#
#   DEBUG: Cleaned 'Garrett Wilson (NYJ) Q' → 'Garrett Wilson (NYJ)'
#   Garrett Wilson (NYJ): 13.4 pts
#   Wan'Dale Robinson (NYG): 13.3 pts
#   Tetairoa McMillan (CAR): 13.2 pts
#   Marvin Harrison Jr. (ARI): 13.0 pts
#   Deebo Samuel Sr. (WAS): 12.7 pts
#   DK Metcalf (PIT): 12.7 pts
#   Romeo Doubs (GB): 12.4 pts
#
#   DEBUG: Cleaned 'DJ Moore (CHI) Q' → 'DJ Moore (CHI)'
#   DJ Moore (CHI): 12.3 pts
#   Jordan Addison (MIN): 12.2 pts
#   Khalil Shakir (BUF): 11.7 pts
#   Troy Franklin (DEN): 11.7 pts
#   Jameson Williams (DET): 11.6 pts
#   Quentin Johnston (LAC): 11.4 pts
#   Keenan Allen (LAC): 10.8 pts
#   Jauan Jennings (SF): 10.3 pts
#   Parker Washington (JAC): 10.1 pts
#   Tez Johnson (TB): 10.1 pts
#
#   DEBUG: Cleaned 'Christian Watson (GB) Q' → 'Christian Watson (GB)'
#
#   DEBUG: Cleaned 'Matthew Golden (GB) Q' → 'Matthew Golden (GB)'
#
#   DEBUG: Cleaned 'Jordan Whittington (LAR) Q' → 'Jordan Whittington (LAR)'
#
#   DEBUG: Cleaned 'Zay Jones (ARI) Q' → 'Zay Jones (ARI)'
#
#   DEBUG: Cleaned 'Isaiah Bond (CLE) Q' → 'Isaiah Bond (CLE)'
#
#   DEBUG: Cleaned 'Brian Thomas Jr. (JAC) Q' → 'Brian Thomas Jr. (JAC)'
#
#   DEBUG: Cleaned 'Cooper Kupp (SEA) Q' → 'Cooper Kupp (SEA)'
#
#   DEBUG: Cleaned 'Chris Godwin Jr. (TB) Q' → 'Chris Godwin Jr. (TB)'
#
#   DEBUG: Cleaned 'Savion Williams (GB) Q' → 'Savion Williams (GB)'
#
#   DEBUG: Cleaned 'Ricky Pearsall (SF) Q' → 'Ricky Pearsall (SF)'
#
#   DEBUG: Cleaned 'Kayshon Boutte (NE) Q' → 'Kayshon Boutte (NE)'
#
#   DEBUG: Cleaned 'Joshua Palmer (BUF) Q' → 'Joshua Palmer (BUF)'
#
#   DEBUG: Cleaned 'Beaux Collins (NYG) Q' → 'Beaux Collins (NYG)'
#
#   DEBUG: Cleaned 'Terry McLaurin (WAS) D' → 'Terry McLaurin (WAS)'
#
#   DEBUG: Cleaned 'Luke McCaffrey (WAS) IR' → 'Luke McCaffrey (WAS)'
#
#   DEBUG: Cleaned 'Dee Eskridge (MIA) Q' → 'Dee Eskridge (MIA)'
#
#   DEBUG: Cleaned 'Dontayvion Wicks (GB) Q' → 'Dontayvion Wicks (GB)'
#
#   DEBUG: Cleaned 'Brycen Tremayne (CAR) Q' → 'Brycen Tremayne (CAR)'
#
#   DEBUG: Cleaned 'KeAndre Lambert-Smith (LAC) Q' → 'KeAndre Lambert-Smith (LAC)'
#
#   DEBUG: Cleaned 'Jake Bobo (SEA) Q' → 'Jake Bobo (SEA)'
#
#   DEBUG: Cleaned 'Xavier Weaver (ARI) Q' → 'Xavier Weaver (ARI)'
#   ✓ Scraped 160 WR projections
#   ✓ Team data found: 160/160 (100.0%)
#
# Scraping TE from https://www.fantasypros.com/nfl/rankings/ppr-te.php...
#   Found 28 rows
#   Trey McBride (ARI): 15.6 pts
#   Brock Bowers (LV): 15.2 pts
#   Oronde Gadsden II (LAC): 12.2 pts
#   Tyler Warren (IND): 12.0 pts
#   George Kittle (SF): 11.9 pts
#   Sam LaPorta (DET): 11.8 pts
#   Dalton Kincaid (BUF): 11.2 pts
#   Dallas Goedert (PHI): 11.1 pts
#   Kyle Pitts Sr. (ATL): 10.9 pts
#   Colston Loveland (CHI): 10.6 pts
#   Hunter Henry (NE): 10.1 pts
#
#   DEBUG: Cleaned 'Harold Fannin Jr. (CLE) Q' → 'Harold Fannin Jr. (CLE)'
#
#   DEBUG: Cleaned 'AJ Barner (SEA) Q' → 'AJ Barner (SEA)'
#   ✓ Scraped 25 TE projections
#   ✓ Team data found: 25/25 (100.0%)
#
# Scraping K from https://www.fantasypros.com/nfl/rankings/k.php...
#   Found 28 rows
#   Cameron Dicker (LAC): 10.0 pts
#
#   DEBUG: Cleaned 'Ka'imi Fairbairn (HOU) Q' → 'Ka'imi Fairbairn (HOU)'
#
#   DEBUG: Cleaned 'Graham Gano (NYG) Q' → 'Graham Gano (NYG)'
#   ✓ Scraped 25 K projections
#   ✓ Team data found: 25/25 (100.0%)
#
# Scraping DST from https://www.fantasypros.com/nfl/rankings/dst.php...
#   Found 28 rows
#   Denver Broncos Defense (DEN): 10.0 pts
#   ✓ Scraped 25 DST projections
#   ✓ Team data found: 25/25 (100.0%)
#
# ✓ Total players scraped: 388
#
# Saving 388 projections to database...
# ✓ Successfully saved to database!
#
# ✅ FantasyPros scraping complete!
#
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 1515
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#   espn.com                    232 records
#   fanduel.com                 473 records
#   fantasypros.com             388 records
#   sleeper.com                 422 records
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#   Week 10                    1515 records
#
# 🏈 Team Data Coverage:
# ----------------------------------------------------------------------
#   espn.com                   232/232  (100.0%) ✅
#   fanduel.com                473/473  (100.0%) ✅
#   fantasypros.com            388/388  (100.0%) ✅
#   sleeper.com                422/422  (100.0%) ✅

# %% [markdown]
# ### 5️⃣ First Down Studio Scraper

# %%
print(f"\n{'='*70}")
print(f"🎯 FIRST DOWN STUDIO SCRAPER")
print(f"{'='*70}\n")

try:
    with FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK, scoring="PPR")
    print("\n✅ First Down Studio scraping complete!")
except Exception as e:
    print(f"\n❌ Error: {e}")
    import traceback
    traceback.print_exc()

show_database_status()
# Out:
# ======================================================================
# 🎯 FIRST DOWN STUDIO SCRAPER
# ======================================================================
#
# Navigating to https://www.firstdown.studio/rankings...
# Note: PPR points will be calculated from component stats for FLEX players
#
# Scraping QB tab...
#   Table headers: ['# (vs. ecr)', 'Player', 'Proj. Pts', 'Pass Yds', 'Pass TDs', 'INTs', 'Rush Yds', 'TDs']
#   Column indices found: {'proj_pts': 2, 'pass_yds': 3, 'pass_tds': 4, 'rush_yds': 6, 'tds': 7}
#   Josh Allen (): 23.0 pts
#   Lamar Jackson (.): 21.2 pts
#   Drake Maye (): 20.0 pts
#   Justin Herbert (.): 19.5 pts
#   Matthew Stafford (.): 18.9 pts
#   Jared Goff (.): 18.8 pts
#   Jaxson Dart (.): 18.8 pts
#   Baker Mayfield (.): 18.7 pts
#   Daniel Jones (.): 18.1 pts
#   Caleb Williams (.): 18.1 pts
#   Bo Nix (.): 18.1 pts
#   Sam Darnold (): 18.0 pts
#   Jalen Hurts (.): 17.7 pts
#   Jordan Love (.): 15.7 pts
#   Jacoby Brissett (.): 15.7 pts
#   J.J. McCarthy (.): 15.7 pts
#   Marcus Mariota (.): 15.6 pts
#   Justin Fields (.): 15.2 pts
#   Aaron Rodgers (.): 14.4 pts
#   Michael Penix (.): 14.3 pts
#   Trevor Lawrence (.): 13.8 pts
#   Tua Tagovailoa (.): 13.6 pts
#   Bryce Young (.): 12.9 pts
#   Davis Mills (.): 12.7 pts
#   Dillon Gabriel (.): 12.7 pts
#   Geno Smith (.): 12.3 pts
#   Tyler Shough (.): 11.3 pts
#
# Scraping FLEX tab...
#   Table headers: ['#', 'Player', 'Pos', 'Proj. Pts', 'Rush Yds', 'Rec', 'Rec Yds', 'TDs']
#   Column indices found: {'proj_pts': 3, 'rush_yds': 4, 'rec': 5, 'rec_yds': 6, 'tds': 7}
#   ✓ Will calculate PPR points from component stats for FLEX
#   C. McCaffrey (RB): 22.5 pts (calculated: 65.5 rush + 50.5 rec yds, 5.9 rec, 0.83 TDs)
#   Jonathan Taylor (RB): 20.5 pts (calculated: 93.5 rush + 16.5 rec yds, 2.9 rec, 1.1 TDs)
#   Bijan Robinson (RB): 20.4 pts (calculated: 67.5 rush + 43.5 rec yds, 5.2 rec, 0.69 TDs)
#   Puka Nacua (WR): 21.7 pts (calculated: 3.7 rush + 93.5 rec yds, 7.8 rec, 0.69 TDs)
#   J. Smith-Njigba (WR): 20.6 pts (calculated: 1.7 rush + 97.5 rec yds, 7.3 rec, 0.57 TDs)
#   Rico Dowdle (RB): 17.1 pts (calculated: 91.0 rush + 14.6 rec yds, 2.0 rec, 0.76 TDs)
#   De'Von Achane (RB): 18.5 pts (calculated: 60.5 rush + 31.5 rec yds, 5.0 rec, 0.71 TDs)
#   James Cook (RB): 16.6 pts (calculated: 88.5 rush + 10.0 rec yds, 1.8 rec, 0.83 TDs)
#   A. St. Brown (WR): 19.3 pts (calculated: 0.5 rush + 78.5 rec yds, 7.4 rec, 0.67 TDs)
#   Jahmyr Gibbs (RB): 16.9 pts (calculated: 71.0 rush + 20.5 rec yds, 2.9 rec, 0.81 TDs)
#   Josh Jacobs (RB): 16.1 pts (calculated: 68.0 rush + 16.5 rec yds, 2.8 rec, 0.81 TDs)
#   Quinshon Judkins (RB): 14.6 pts (calculated: 83.5 rush + 5.5 rec yds, 1.4 rec, 0.71 TDs)
#   Saquon Barkley (RB): 15.3 pts (calculated: 76.5 rush + 16.0 rec yds, 2.9 rec, 0.52 TDs)
#   Derrick Henry (RB): 13.8 pts (calculated: 77.0 rush + 6.5 rec yds, 1.0 rec, 0.75 TDs)
#   Justin Jefferson (WR): 16.6 pts (calculated: 0.1 rush + 74.5 rec yds, 6.3 rec, 0.47 TDs)
#   Emeka Egbuka (WR): 15.9 pts (calculated: 0.7 rush + 70.5 rec yds, 5.7 rec, 0.51 TDs)
#   Drake London (WR): 15.8 pts (calculated: 0.1 rush + 71.0 rec yds, 6.0 rec, 0.45 TDs)
#   Kyren Williams (RB): 13.7 pts (calculated: 63.5 rush + 14.5 rec yds, 2.5 rec, 0.57 TDs)
#   Rachaad White (RB): 14.1 pts (calculated: 48.0 rush + 20.5 rec yds, 3.4 rec, 0.64 TDs)
#   Brock Bowers (TE): 15.5 pts (calculated: 0.0 rush + 68.0 rec yds, 6.4 rec, 0.39 TDs)
#   D'Andre Swift (RB): 13.5 pts (calculated: 56.5 rush + 16.5 rec yds, 2.7 rec, 0.59 TDs)
#   Davante Adams (WR): 14.7 pts (calculated: 0.0 rush + 60.5 rec yds, 4.9 rec, 0.62 TDs)
#   Zay Flowers (WR): 14.8 pts (calculated: 2.5 rush + 65.0 rec yds, 5.3 rec, 0.45 TDs)
#   Breece Hall (RB): 13.2 pts (calculated: 62.0 rush + 15.5 rec yds, 2.6 rec, 0.47 TDs)
#   Ashton Jeanty (RB): 13.2 pts (calculated: 54.5 rush + 18.0 rec yds, 2.9 rec, 0.51 TDs)
#   Jaylen Warren (RB): 13.1 pts (calculated: 56.5 rush + 17.0 rec yds, 2.9 rec, 0.47 TDs)
#   Ladd McConkey (WR): 14.5 pts (calculated: 0.1 rush + 62.5 rec yds, 6.0 rec, 0.38 TDs)
#   Trey McBride (TE): 14.7 pts (calculated: 0.0 rush + 62.0 rec yds, 6.5 rec, 0.34 TDs)
#   Kimani Vidal (RB): 12.4 pts (calculated: 58.0 rush + 12.5 rec yds, 2.1 rec, 0.54 TDs)
#   Jaylen Waddle (WR): 13.9 pts (calculated: 0.4 rush + 63.5 rec yds, 5.2 rec, 0.39 TDs)
#   J.K. Dobbins (RB): 11.7 pts (calculated: 68.0 rush + 2.0 rec yds, 1.0 rec, 0.62 TDs)
#   Deebo Samuel (WR): 14.1 pts (calculated: 6.6 rush + 56.5 rec yds, 5.8 rec, 0.34 TDs)
#   DeVonta Smith (WR): 13.4 pts (calculated: 0.0 rush + 63.3 rec yds, 5.2 rec, 0.31 TDs)
#   Stefon Diggs (WR): 13.1 pts (calculated: 0.5 rush + 59.5 rec yds, 4.9 rec, 0.37 TDs)
#   W. Robinson (WR): 13.7 pts (calculated: 0.9 rush + 57.0 rec yds, 5.9 rec, 0.33 TDs)
#   Chris Olave (WR): 13.4 pts (calculated: 0.3 rush + 62.5 rec yds, 5.6 rec, 0.25 TDs)
#   Courtland Sutton (WR): 12.8 pts (calculated: 0.0 rush + 58.5 rec yds, 4.4 rec, 0.42 TDs)
#   Travis Etienne (RB): 11.8 pts (calculated: 49.0 rush + 14.5 rec yds, 2.6 rec, 0.47 TDs)
#   Nico Collins (WR): 13.1 pts (calculated: 0.2 rush + 56.5 rec yds, 5.2 rec, 0.37 TDs)
#   Michael Pittman (WR): 13.0 pts (calculated: 0.1 rush + 55.0 rec yds, 5.2 rec, 0.38 TDs)
#   David Montgomery (RB): 11.1 pts (calculated: 48.5 rush + 10.0 rec yds, 1.8 rec, 0.57 TDs)
#   Kenneth Walker (RB): 10.8 pts (calculated: 51.5 rush + 8.5 rec yds, 1.4 rec, 0.56 TDs)
#   A.J. Brown (WR): 12.3 pts (calculated: 0.0 rush + 58.0 rec yds, 4.6 rec, 0.32 TDs)
#   T. Henderson (RB): 11.2 pts (calculated: 41.9 rush + 19.1 rec yds, 2.5 rec, 0.44 TDs)
#   Tyrone Tracy (RB): 11.4 pts (calculated: 40.5 rush + 18.5 rec yds, 2.9 rec, 0.43 TDs)
#   Marvin Harrison (WR): 12.0 pts (calculated: 0.1 rush + 57.0 rec yds, 4.2 rec, 0.35 TDs)
#   Garrett Wilson (WR): 12.4 pts (calculated: 0.5 rush + 55.0 rec yds, 5.1 rec, 0.29 TDs)
#   Aaron Jones (RB): 11.0 pts (calculated: 44.1 rush + 18.1 rec yds, 2.4 rec, 0.4 TDs)
#   Oronde Gadsden (TE): 12.1 pts (calculated: 0.0 rush + 50.0 rec yds, 4.8 rec, 0.39 TDs)
#   Romeo Doubs (WR): 12.0 pts (calculated: 0.0 rush + 52.0 rec yds, 4.6 rec, 0.37 TDs)
#   Rome Odunze (WR): 11.7 pts (calculated: 0.1 rush + 51.5 rec yds, 4.1 rec, 0.4 TDs)
#   DK Metcalf (WR): 11.5 pts (calculated: 0.0 rush + 51.5 rec yds, 3.9 rec, 0.41 TDs)
#   George Kittle (TE): 11.5 pts (calculated: 0.0 rush + 48.0 rec yds, 4.5 rec, 0.37 TDs)
#   T. McMillan (WR): 11.7 pts (calculated: 0.2 rush + 49.5 rec yds, 4.7 rec, 0.34 TDs)
#   Alvin Kamara (RB): 10.7 pts (calculated: 32.0 rush + 15.5 rec yds, 3.1 rec, 0.48 TDs)
#   DJ Moore (WR): 11.2 pts (calculated: 6.5 rush + 45.5 rec yds, 4.0 rec, 0.34 TDs)
#   Khalil Shakir (WR): 11.7 pts (calculated: 0.4 rush + 46.5 rec yds, 4.9 rec, 0.35 TDs)
#   Woody Marks (RB): 10.3 pts (calculated: 42.6 rush + 19.2 rec yds, 2.1 rec, 0.33 TDs)
#   Sam LaPorta (TE): 11.1 pts (calculated: 0.0 rush + 46.0 rec yds, 4.3 rec, 0.37 TDs)
#   Tyler Warren (TE): 11.0 pts (calculated: 0.0 rush + 45.0 rec yds, 4.3 rec, 0.37 TDs)
#   Troy Franklin (WR): 11.2 pts (calculated: 1.0 rush + 43.0 rec yds, 4.6 rec, 0.37 TDs)
#   Jordan Addison (WR): 10.6 pts (calculated: 0.7 rush + 47.0 rec yds, 3.8 rec, 0.34 TDs)
#   Cade Otton (TE): 11.1 pts (calculated: 0.0 rush + 46.5 rec yds, 4.7 rec, 0.29 TDs)
#   Jameson Williams (WR): 10.3 pts (calculated: 1.7 rush + 42.5 rec yds, 3.2 rec, 0.44 TDs)
#   Keenan Allen (WR): 11.0 pts (calculated: 0.0 rush + 44.5 rec yds, 4.5 rec, 0.34 TDs)
#   Alec Pierce (WR): 10.3 pts (calculated: 0.0 rush + 53.5 rec yds, 3.3 rec, 0.27 TDs)
#   Jauan Jennings (WR): 10.7 pts (calculated: 0.0 rush + 46.5 rec yds, 4.2 rec, 0.3 TDs)
#   Kyle Pitts (TE): 10.9 pts (calculated: 0.0 rush + 43.5 rec yds, 4.9 rec, 0.27 TDs)
#   P. Washington (WR): 10.3 pts (calculated: 1.1 rush + 45.1 rec yds, 3.8 rec, 0.31 TDs)
#   J. Croskey-Merritt (RB): 8.9 pts (calculated: 45.0 rush + 9.5 rec yds, 1.2 rec, 0.38 TDs)
#   Bam Knight (RB): 9.4 pts (calculated: 36.0 rush + 12.0 rec yds, 2.3 rec, 0.38 TDs)
#   Kyle Monangai (RB): 8.8 pts (calculated: 36.5 rush + 11.6 rec yds, 1.5 rec, 0.41 TDs)
#   Zach Charbonnet (RB): 8.5 pts (calculated: 37.0 rush + 8.5 rec yds, 1.4 rec, 0.43 TDs)
#   Jordan Mason (RB): 8.4 pts (calculated: 44.4 rush + 5.4 rec yds, 1.0 rec, 0.4 TDs)
#   Dallas Goedert (TE): 10.0 pts (calculated: 0.0 rush + 40.7 rec yds, 4.1 rec, 0.3 TDs)
#   Tre Tucker (WR): 9.8 pts (calculated: 2.3 rush + 44.0 rec yds, 4.0 rec, 0.2 TDs)
#   Quentin Johnston (WR): 9.5 pts (calculated: 0.7 rush + 40.0 rec yds, 3.7 rec, 0.29 TDs)
#   Rashid Shaheed (WR): 9.1 pts (calculated: 2.5 rush + 43.7 rec yds, 2.9 rec, 0.27 TDs)
#   Tez Johnson (WR): 8.9 pts (calculated: 0.4 rush + 46.0 rec yds, 2.8 rec, 0.25 TDs)
#   Darius Slayton (WR): 9.1 pts (calculated: 0.3 rush + 41.5 rec yds, 3.2 rec, 0.28 TDs)
#   Dalton Kincaid (TE): 9.3 pts (calculated: 0.0 rush + 36.5 rec yds, 4.0 rec, 0.27 TDs)
#   Josh Downs (WR): 9.4 pts (calculated: 0.1 rush + 37.5 rec yds, 4.2 rec, 0.24 TDs)
#   Colston Loveland (TE): 9.0 pts (calculated: 0.0 rush + 39.0 rec yds, 3.5 rec, 0.27 TDs)
#   Nick Chubb (RB): 7.7 pts (calculated: 42.4 rush + 5.9 rec yds, 0.9 rec, 0.33 TDs)
#   Hunter Henry (TE): 9.1 pts (calculated: 0.0 rush + 35.0 rec yds, 3.8 rec, 0.3 TDs)
#   Devin Singletary (RB): 7.8 pts (calculated: 40.6 rush + 9.2 rec yds, 1.2 rec, 0.27 TDs)
#   Harold Fannin (TE): 9.3 pts (calculated: 0.0 rush + 36.0 rec yds, 4.3 rec, 0.24 TDs)
#   Dalton Schultz (TE): 9.1 pts (calculated: 0.0 rush + 36.0 rec yds, 4.0 rec, 0.25 TDs)
#   Zach Ertz (TE): 9.1 pts (calculated: 0.0 rush + 37.8 rec yds, 3.9 rec, 0.23 TDs)
#   RJ Harvey (RB): 8.3 pts (calculated: 22.0 rush + 15.0 rec yds, 2.6 rec, 0.33 TDs)
#   Mark Andrews (TE): 8.5 pts (calculated: 0.0 rush + 30.0 rec yds, 3.2 rec, 0.39 TDs)
#   Malik Washington (WR): 8.8 pts (calculated: 8.2 rush + 28.0 rec yds, 3.7 rec, 0.24 TDs)
#   Emari Demercado (RB): 7.5 pts (calculated: 40.5 rush + 7.7 rec yds, 1.2 rec, 0.25 TDs)
#   DeMario Douglas (WR): 8.0 pts (calculated: 1.2 rush + 46.0 rec yds, 2.3 rec, 0.16 TDs)
#   Juwan Johnson (TE): 8.7 pts (calculated: 0.0 rush + 38.0 rec yds, 3.8 rec, 0.18 TDs)
#   Theo Johnson (TE): 8.6 pts (calculated: 0.0 rush + 33.5 rec yds, 3.6 rec, 0.28 TDs)
#   Jakobi Meyers (WR): 8.4 pts (calculated: 0.6 rush + 37.3 rec yds, 3.2 rec, 0.24 TDs)
#   Jerry Jeudy (WR): 8.3 pts (calculated: 0.1 rush + 35.5 rec yds, 3.3 rec, 0.24 TDs)
#   Matthew Golden (WR): 8.0 pts (calculated: 2.2 rush + 35.4 rec yds, 2.9 rec, 0.23 TDs)
#   David Njoku (TE): 8.4 pts (calculated: 0.0 rush + 35.9 rec yds, 3.7 rec, 0.19 TDs)
#   Mason Taylor (TE): 8.3 pts (calculated: 0.0 rush + 33.5 rec yds, 3.6 rec, 0.23 TDs)
#   Keon Coleman (WR): 7.9 pts (calculated: 0.1 rush + 32.0 rec yds, 3.0 rec, 0.29 TDs)
#   Evan Engram (TE): 8.1 pts (calculated: 0.0 rush + 30.0 rec yds, 3.5 rec, 0.27 TDs)
#   T.J. Hockenson (TE): 8.0 pts (calculated: 0.0 rush + 30.0 rec yds, 3.5 rec, 0.25 TDs)
#   O. Zaccheaus (WR): 7.6 pts (calculated: 1.8 rush + 32.1 rec yds, 3.0 rec, 0.2 TDs)
#   Christian Watson (WR): 7.0 pts (calculated: 0.5 rush + 31.5 rec yds, 2.4 rec, 0.24 TDs)
#   Luke Musgrave (TE): 7.4 pts (calculated: 0.0 rush + 28.0 rec yds, 3.3 rec, 0.22 TDs)
#   Christian Kirk (WR): 7.3 pts (calculated: 0.1 rush + 30.5 rec yds, 3.1 rec, 0.19 TDs)
#   Calvin Austin (WR): 7.2 pts (calculated: 0.3 rush + 30.0 rec yds, 2.9 rec, 0.21 TDs)
#   Michael Wilson (WR): 6.9 pts (calculated: 3.0 rush + 27.0 rec yds, 2.6 rec, 0.22 TDs)
#   Sterling Shepard (WR): 6.9 pts (calculated: 0.7 rush + 28.2 rec yds, 2.6 rec, 0.24 TDs)
#   Isaiah Davis (RB): 6.3 pts (calculated: 26.2 rush + 12.9 rec yds, 1.5 rec, 0.15 TDs)
#   Darnell Mooney (WR): 6.9 pts (calculated: 0.1 rush + 29.5 rec yds, 2.7 rec, 0.2 TDs)
#   Jonnu Smith (TE): 7.2 pts (calculated: 0.0 rush + 24.5 rec yds, 3.4 rec, 0.22 TDs)
#   Chuba Hubbard (RB): 6.0 pts (calculated: 29.2 rush + 5.8 rec yds, 0.9 rec, 0.26 TDs)
#   Cedric Tillman (WR): 6.8 pts (calculated: 0.1 rush + 31.5 rec yds, 2.6 rec, 0.17 TDs)
#   Mack Hollins (WR): 6.5 pts (calculated: 0.1 rush + 30.0 rec yds, 2.3 rec, 0.2 TDs)
#   Jaylin Lane (WR): 6.7 pts (calculated: 0.2 rush + 32.3 rec yds, 2.5 rec, 0.15 TDs)
#   AJ Barner (TE): 6.7 pts (calculated: 0.0 rush + 24.5 rec yds, 2.7 rec, 0.25 TDs)
#   Chris Moore (WR): 6.4 pts (calculated: 0.3 rush + 31.8 rec yds, 2.2 rec, 0.17 TDs)
#   Kenneth Gainwell (RB): 6.4 pts (calculated: 18.0 rush + 12.0 rec yds, 2.4 rec, 0.17 TDs)
#   Xavier Legette (WR): 6.7 pts (calculated: 0.2 rush + 25.0 rec yds, 2.9 rec, 0.21 TDs)
#   Rashod Bateman (WR): 6.3 pts (calculated: 0.0 rush + 26.5 rec yds, 2.3 rec, 0.22 TDs)
#   Isaiah Likely (TE): 6.4 pts (calculated: 0.0 rush + 25.0 rec yds, 2.5 rec, 0.23 TDs)
#   Emanuel Wilson (RB): 5.7 pts (calculated: 24.5 rush + 7.5 rec yds, 1.2 rec, 0.21 TDs)
#   Cooper Kupp (WR): 6.0 pts (calculated: 0.1 rush + 24.5 rec yds, 2.0 rec, 0.25 TDs)
#   Brandin Cooks (WR): 6.4 pts (calculated: 0.2 rush + 29.5 rec yds, 2.6 rec, 0.13 TDs)
#   Blake Corum (RB): 5.0 pts (calculated: 30.5 rush + 4.1 rec yds, 0.6 rec, 0.16 TDs)
#   Tory Horton (WR): 5.6 pts (calculated: 0.4 rush + 23.8 rec yds, 1.8 rec, 0.23 TDs)
#   Bhayshul Tuten (RB): 5.1 pts (calculated: 22.5 rush + 6.9 rec yds, 0.9 rec, 0.21 TDs)
#   Ty Johnson (RB): 4.8 pts (calculated: 15.9 rush + 9.2 rec yds, 0.9 rec, 0.24 TDs)
#   Ollie Gordon (RB): 4.9 pts (calculated: 22.2 rush + 7.3 rec yds, 1.0 rec, 0.16 TDs)
#   Chris Rodriguez (RB): 4.1 pts (calculated: 28.8 rush + 1.3 rec yds, 0.1 rec, 0.17 TDs)
#   Tyler Allgeier (RB): 4.1 pts (calculated: 19.5 rush + 3.0 rec yds, 0.4 rec, 0.24 TDs)
#
# Total unique players scraped: 161
#
# Saving 161 projections to database...
# ✓ Successfully saved to database!
#
# ✅ First Down Studio scraping complete!
#
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 1676
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#   espn.com                    232 records
#   fanduel.com                 473 records
#   fantasypros.com             388 records
#   firstdown.studio            161 records
#   sleeper.com                 422 records
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#   Week 10                    1676 records
#
# 🏈 Team Data Coverage:
# ----------------------------------------------------------------------
#   espn.com                   232/232  (100.0%) ✅
#   fanduel.com                473/473  (100.0%) ✅
#   fantasypros.com            388/388  (100.0%) ✅
#   firstdown.studio           161/161  (100.0%) ✅
#   sleeper.com                422/422  (100.0%) ✅

# %% [markdown]
# ## 🎯 Quick Reference
#
# ### Useful Commands
#
# ```python
# # View current database status
# show_database_status()
#
# # Clear entire database (requires confirmation)
# clear_entire_database()
#
# # Clear specific source
# clear_source("fantasypros.com", WEEK)  # Clear specific week
# clear_source("fanduel.com")            # Clear all weeks
#
# # Change configuration
# WEEK = "Week 9"
# SEASON = "2024"
# HEADLESS = False  # Show browser
# ```
#
# ### Source Names
# - `"fanduel.com"`
# - `"sleeper.com"`
# - `"espn.com"`
# - `"fantasypros.com"`
# - `"firstdown.studio"`
