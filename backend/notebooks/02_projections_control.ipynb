# %% [markdown]
# # 🎮 Fantasy Football Projections - Control Panel
#
# **Scrape and manage player projections from multiple sources.**
#
# ## Quick Start:
# 1. **Update `WEEK` and `SEASON`** in the configuration
# 2. **Run All Cells** to scrape all sources
# 3. View database status and data quality metrics
#
# ## Sources:
# - 🔵 FanDuel
# - 💤 Sleeper
# - 🔴 ESPN
# - 📊 FantasyPros
# - 🎯 First Down Studio
#
# ---

# %% [markdown]
# ## 📦 Setup & Configuration

# %%
import os
import sqlite3
import subprocess
import sys
from datetime import datetime
from pathlib import Path

# Use absolute paths (this notebook is at backend/notebooks/)
NOTEBOOK_DIR = Path(r"C:\Users\Samer Faizi\Documents\Claude Model\backend\notebooks")
BACKEND_DIR = NOTEBOOK_DIR.parent
PROJECT_ROOT = BACKEND_DIR.parent
SCRAPERS_DIR = BACKEND_DIR / "scrapers"

# Add project root to path for package imports
sys.path.insert(0, str(PROJECT_ROOT))

# Import from the backend.scrapers package (uses relative imports internally)
from backend.scrapers.database import ProjectionsDB
from backend.scrapers.scraper_sleeper import SleeperScraper
from backend.scrapers.scraper_espn import ESPNScraper
from backend.scrapers.scraper_fantasypros import FantasyProsScraper
from backend.scrapers.scraper_firstdown import FirstDownStudioScraper

# ==================== CONFIGURATION ====================
# Update these for each scraping session

WEEK = "Week 16"  # ⬅️ UPDATE THIS!
SEASON = "2025"
HEADLESS = False  # Set to False to see browser windows

# Database path
DB_PATH = str(BACKEND_DIR / "data" / "databases" / "projections.db")

# Verify database exists
if not Path(DB_PATH).exists():
    print(f"⚠️ WARNING: Database not found at: {DB_PATH}")
else:
    print(f"✅ Database found: {DB_PATH}")

print("✅ Setup Complete!")
print(f"📅 {WEEK}, Season {SEASON}")
print(f"👁️  Headless mode: {HEADLESS}")
print("\n" + "="*70 + "\n")
# Out:
# ✅ Database found: C:\Users\Samer Faizi\Documents\Claude Model\backend\data\databases\projections.db
# ✅ Setup Complete!
# 📅 Week 16, Season 2025
# 👁️  Headless mode: False
#
# ======================================================================

# %% [markdown]
# ## 🤖 Individual Scrapers
#
# Run each scraper individually for easier debugging. Each cell is independent.

# %%
# 💤 SLEEPER SCRAPER (API-based, fast & reliable)
# ================================================
print(f"{'='*70}")
print(f"💤 SLEEPER SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    with SleeperScraper(db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK, season=SEASON)
    print("\n✅ Sleeper scraping complete!")
except Exception as e:
    print(f"\n❌ Sleeper error: {e}")
# Out:
# ======================================================================
# 💤 SLEEPER SCRAPER - Week 16
# ======================================================================
#
#
# Fetching Sleeper projections for 2025 Week 16...
# Fetching all players from Sleeper API...
#   ✓ Loaded 11402 players
# Fetching from: https://api.sleeper.app/v1/projections/nfl/regular/2025/16
#   ✓ Successfully fetched 8624 player projections
#
# Parsing 8624 projections...
#   Brandon Aubrey (K): 10.7 pts
#   CeeDee Lamb (WR): 17.5 pts
#   Bucky Irving (RB): 16.2 pts
#   Omarion Hampton (RB): 12.7 pts
#   Oronde Gadsden (TE): 10.9 pts
#   Kyle Pitts (TE): 12.7 pts
#   Dak Prescott (QB): 21.8 pts
#   Matthew Stafford (QB): 18.7 pts
#   Khalil Shakir (WR): 11.3 pts
#   James Cook (RB): 18.5 pts
#   Jauan Jennings (WR): 11.7 pts
#   Sam Darnold (QB): 18.3 pts
#   Jayden Reed (WR): 11.4 pts
#   Jaxon Smith-Njigba (WR): 20.6 pts
#   Jaylen Waddle (WR): 13.6 pts
#   TreVeyon Henderson (RB): 13.5 pts
#   D'Andre Swift (RB): 11.7 pts
#   Geno Smith (QB): 16.5 pts
#   Jalen Hurts (QB): 24.7 pts
#   Ladd McConkey (WR): 14.3 pts
#   Rome Odunze (WR): 11.1 pts
#   Michael Wilson (WR): 14.7 pts
#   Jordan Love (QB): 20.3 pts
#   Chris Godwin (WR): 11.5 pts
#   Kirk Cousins (QB): 18.0 pts
#   Shedeur Sanders (QB): 16.9 pts
#   Ja'Marr Chase (WR): 19.2 pts
#   Justin Herbert (QB): 23.4 pts
#   Tee Higgins (WR): 14.8 pts
#   Lamar Jackson (QB): 22.7 pts
#   Aaron Rodgers (QB): 20.3 pts
#   Deebo Samuel (WR): 11.4 pts
#   Tyler Shough (QB): 18.4 pts
#   Baker Mayfield (QB): 22.5 pts
#   Tyler Warren (TE): 10.8 pts
#   Jakobi Meyers (WR): 11.5 pts
#   Ricky Pearsall (WR): 10.2 pts
#   Nico Collins (WR): 15.6 pts
#   Bryce Young (QB): 19.3 pts
#   Rico Dowdle (RB): 11.8 pts
#   George Pickens (WR): 15.5 pts
#   Woody Marks (RB): 12.2 pts
#   Mike Evans (WR): 14.7 pts
#   Derrick Henry (RB): 16.2 pts
#   Cam Ward (QB): 13.9 pts
#   Puka Nacua (WR): 21.2 pts
#   A.J. Brown (WR): 15.9 pts
#   Christian McCaffrey (RB): 22.2 pts
#   Saquon Barkley (RB): 15.7 pts
#   Tony Pollard (RB): 10.3 pts
#   Trey McBride (TE): 18.9 pts
#   Trevor Lawrence (QB): 20.1 pts
#   Jaxson Dart (QB): 20.0 pts
#   J.J. McCarthy (QB): 20.4 pts
#   Ashton Jeanty (RB): 13.2 pts
#   Dallas Goedert (TE): 11.3 pts
#   Tyrone Tracy (RB): 12.1 pts
#   Rashee Rice (WR): 16.1 pts
#   De'Von Achane (RB): 19.8 pts
#   Bijan Robinson (RB): 22.4 pts
#   DeVonta Smith (WR): 14.0 pts
#   Drake London (WR): 16.4 pts
#   Joe Burrow (QB): 20.7 pts
#   Xavier Worthy (WR): 10.2 pts
#   Jahmyr Gibbs (RB): 22.7 pts
#   Jared Goff (QB): 19.5 pts
#   Jameson Williams (WR): 14.2 pts
#   George Kittle (TE): 14.9 pts
#   Marvin Harrison (WR): 12.2 pts
#   Keenan Allen (WR): 11.8 pts
#   Brock Purdy (QB): 22.1 pts
#   Quinshon Judkins (RB): 14.1 pts
#   Kenneth Walker (RB): 10.4 pts
#   Amon-Ra St. Brown (WR): 19.7 pts
#   Brady Cook (QB): 15.6 pts
#   Tetairoa McMillan (WR): 14.7 pts
#   Bo Nix (QB): 19.9 pts
#   Stefon Diggs (WR): 12.0 pts
#   Kenneth Gainwell (RB): 12.4 pts
#   Travis Etienne (RB): 13.9 pts
#   Brian Thomas (WR): 11.1 pts
#   Terry McLaurin (WR): 12.6 pts
#   Aaron Jones (RB): 11.3 pts
#   Jalen Coker (WR): 11.3 pts
#   Kyren Williams (RB): 13.2 pts
#   Philip Rivers (QB): 15.9 pts
#   Jaylen Warren (RB): 12.5 pts
#   Gardner Minshew (QB): 19.1 pts
#   Quinn Ewers (QB): 15.4 pts
#   Chase Brown (RB): 14.1 pts
#   Justin Jefferson (WR): 13.3 pts
#   Quentin Johnston (WR): 12.3 pts
#   Chris Olave (WR): 14.8 pts
#   Josh Allen (QB): 24.7 pts
#   Zay Flowers (WR): 14.7 pts
#   Harold Fannin (TE): 11.8 pts
#   Wan'Dale Robinson (WR): 12.2 pts
#   Courtland Sutton (WR): 11.3 pts
#   Caleb Williams (QB): 17.4 pts
#   Alvin Kamara (RB): 11.6 pts
#   Jacoby Brissett (QB): 20.6 pts
#   C.J. Stroud (QB): 17.3 pts
#   Marcus Mariota (QB): 20.7 pts
#   Jake Bates (K): 10.2 pts
#   Travis Kelce (TE): 11.1 pts
#   Josh Jacobs (RB): 17.1 pts
#   Brock Bowers (TE): 12.5 pts
#   Michael Pittman (WR): 11.4 pts
#   DK Metcalf (WR): 13.8 pts
#   Breece Hall (RB): 12.9 pts
#   Jonathan Taylor (RB): 18.9 pts
#   Drake Maye (QB): 21.9 pts
#   Javonte Williams (RB): 15.1 pts
#
# ✓ Projections with data: 8624 out of 8624
# ✓ Total players with valid projections: 495
#
# Saving 495 projections to database...
# ✓ Successfully saved to database!
#
# ✅ Sleeper scraping complete!

# %%
# # DELETE incorrect ESPN data for Week 14
# import sqlite3

# conn = sqlite3.connect(DB_PATH)
# cursor = conn.cursor()

# # See what we're deleting
# cursor.execute("""
#     SELECT COUNT(*) FROM projections 
#     WHERE source_website = 'espn.com' AND week = 'Week 14'
# """)
# count = cursor.fetchone()[0]
# print(f"Found {count} ESPN Week 14 records to delete")

# # Delete them
# cursor.execute("""
#     DELETE FROM projections 
#     WHERE source_website = 'espn.com' AND week = 'Week 14'
# """)
# conn.commit()
# print(f"✅ Deleted {cursor.rowcount} ESPN records for Week 14")
# conn.close()

# %%
# 🔴 ESPN SCRAPER
# ================================================
# Set HEADLESS = False in setup cell to debug visually
print(f"{'='*70}")
print(f"🔴 ESPN SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    with ESPNScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK, season=SEASON)
    print("\n✅ ESPN scraping complete!")
except Exception as e:
    print(f"\n❌ ESPN error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# 🔴 ESPN SCRAPER - Week 16
# ======================================================================
#
#
# Fetching ESPN projections for Week 16...
# Navigating to https://fantasy.espn.com/football/players/projections...
# Clicking 'Sortable Projections' view...
#   ✓ Switched to Sortable Projections view
# Setting scoring to Points PPR...
#   ✓ Set to Points PPR
# Setting to This Week projections...
#   ✓ Set to This Week
#
# Scraping 6 positions (up to 50 players each)...
#
#   [QB] Loading fresh page and applying filter...
#     → Filter attempt 1/5...
#     → Switched to Sortable Projections
#     ✗ Wrong positions: ['RB', 'RB', 'RB']
#     → Filter attempt 2/5...
#     → Switched to Sortable Projections
#     ✓ Filter verified: ['QB', 'QB', 'QB']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. Jalen Hurts (PHI): 22.7 pts
#         2. Josh Allen (BUF): 19.9 pts
#         3. Drake Maye (NE): 19.4 pts
#         4. Jacoby Brissett (ARI): 18.8 pts
#         5. Justin Herbert (LAC): 18.6 pts
#         6. Caleb Williams (CHI): 17.9 pts
#         7. Jaxson Dart (NYG): 17.8 pts
#         8. Jared Goff (DET): 17.5 pts
#         9. Brock Purdy (SF): 17.5 pts
#        10. C.J. Stroud (HOU): 17.5 pts
#        11. Jordan Love (GB): 17.4 pts
#        12. Joe Burrow (CIN): 17.1 pts
#        13. J.J. McCarthy (MIN): 17.0 pts
#        14. Tyler Shough (NO): 17.0 pts
#        15. Dak Prescott (DAL): 16.9 pts
#        16. Baker Mayfield (TB): 16.6 pts
#        17. Trevor Lawrence (JAX): 16.6 pts
#        18. Bryce Young (CAR): 16.3 pts
#        19. Bo Nix (DEN): 16.2 pts
#        20. Lamar Jackson (BAL): 16.0 pts
#        21. Matthew Stafford (LAR): 15.7 pts
#        22. Gardner Minshew (KC): 15.4 pts
#        23. Marcus Mariota (WAS): 14.9 pts
#        24. Sam Darnold (SEA): 14.9 pts
#        25. Aaron Rodgers (PIT): 14.8 pts
#        26. Kirk Cousins (ATL): 14.7 pts
#        27. Quinn Ewers (MIA): 14.2 pts
#        28. Tyrod Taylor (NYJ): 13.4 pts
#        29. Cam Ward (TEN): 13.4 pts
#        30. Shedeur Sanders (CLE): 12.9 pts
#        31. Philip Rivers (IND): 12.9 pts
#        32. Geno Smith (LV): 10.1 pts
#        33. Patrick Mahomes (KC): 0.0 pts
#        34. Jayden Daniels (WAS): 0.0 pts
#        35. Daniel Jones (IND): 0.0 pts
#        36. Kyler Murray (ARI): 0.0 pts
#        37. Justin Fields (NYJ): 0.0 pts
#        38. Tua Tagovailoa (MIA): 0.0 pts
#        39. Joe Flacco (CIN): 0.0 pts
#        40. Michael Penix Jr. (ATL): 0.0 pts
#        41. Davis Mills (HOU): 0.0 pts
#        42. Mac Jones (SF): 0.0 pts
#        43. Jameis Winston (NYG): 0.0 pts
#        44. Carson Wentz (MIN): 0.0 pts
#        45. Russell Wilson (NYG): 0.0 pts
#        46. Anthony Richardson Sr. (IND): 0.0 pts
#        47. Dillon Gabriel (CLE): 0.0 pts
#        48. Spencer Rattler (NO): 0.0 pts
#        49. Mason Rudolph (PIT): 0.0 pts
#        50. Jake Browning (CIN): 0.0 pts
#     ✓ Total 50 QB projections
#     ✓ Scraped 50 QB projections
#
#   [RB] Loading fresh page and applying filter...
#     → Filter attempt 1/5...
#     → Switched to Sortable Projections
#     ✓ Filter verified: ['RB', 'RB', 'RB']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. De'Von Achane (MIA): 24.8 pts
#         2. Jonathan Taylor (IND): 24.0 pts
#         3. Jahmyr Gibbs (DET): 23.8 pts
#         4. Bijan Robinson (ATL): 23.7 pts
#         5. Jalen Hurts (PHI): 22.7 pts
#         6. Christian McCaffrey (SF): 22.1 pts
#         7. Amon-Ra St. Brown (DET): 21.3 pts
#         8. Jaxon Smith-Njigba (SEA): 21.0 pts
#         9. Puka Nacua (LAR): 20.9 pts
#        10. Josh Allen (BUF): 19.9 pts
#        11. Drake Maye (NE): 19.4 pts
#        12. Saquon Barkley (PHI): 19.1 pts
#        13. Josh Jacobs (GB): 19.0 pts
#        14. Ja'Marr Chase (CIN): 18.8 pts
#        15. Jacoby Brissett (ARI): 18.8 pts
#        16. Justin Herbert (LAC): 18.6 pts
#        17. Drake London (ATL): 18.0 pts
#        18. James Cook (BUF): 18.0 pts
#        19. Caleb Williams (CHI): 17.9 pts
#        20. Jaxson Dart (NYG): 17.8 pts
#        21. Rashee Rice (KC): 17.8 pts
#        22. Jared Goff (DET): 17.5 pts
#        23. Brock Purdy (SF): 17.5 pts
#        24. C.J. Stroud (HOU): 17.5 pts
#        25. A.J. Brown (PHI): 17.4 pts
#        26. Jordan Love (GB): 17.4 pts
#        27. Joe Burrow (CIN): 17.1 pts
#        28. J.J. McCarthy (MIN): 17.0 pts
#        29. Tyler Shough (NO): 17.0 pts
#        30. Dak Prescott (DAL): 16.9 pts
#        31. CeeDee Lamb (DAL): 16.9 pts
#        32. Trey McBride (ARI): 16.8 pts
#        33. Baker Mayfield (TB): 16.6 pts
#        34. Nico Collins (HOU): 16.6 pts
#        35. Trevor Lawrence (JAX): 16.6 pts
#        36. Bryce Young (CAR): 16.3 pts
#        37. Bo Nix (DEN): 16.2 pts
#        38. Lamar Jackson (BAL): 16.0 pts
#        39. Jameson Williams (DET): 15.9 pts
#        40. Matthew Stafford (LAR): 15.7 pts
#        41. Gardner Minshew (KC): 15.4 pts
#        42. Rico Dowdle (CAR): 15.2 pts
#        43. Bucky Irving (TB): 15.2 pts
#        44. George Kittle (SF): 15.1 pts
#        45. Javonte Williams (DAL): 15.1 pts
#        46. Ashton Jeanty (LV): 15.1 pts
#        47. Quinshon Judkins (CLE): 14.9 pts
#        48. Marcus Mariota (WAS): 14.9 pts
#        49. Sam Darnold (SEA): 14.9 pts
#        50. Chase Brown (CIN): 14.9 pts
#     ✓ Total 50 RB projections
#     ✓ Scraped 50 RB projections
#
#   [WR] Loading fresh page and applying filter...
#     → Filter attempt 1/5...
#     → Switched to Sortable Projections
#     ✗ Wrong positions: ['RB', 'RB', 'RB']
#     → Filter attempt 2/5...
#     → Switched to Sortable Projections
#     ✓ Filter verified: ['WR', 'WR', 'WR']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. Amon-Ra St. Brown (DET): 21.3 pts
#         2. Jaxon Smith-Njigba (SEA): 21.0 pts
#         3. Puka Nacua (LAR): 20.9 pts
#         4. Ja'Marr Chase (CIN): 18.8 pts
#         5. Drake London (ATL): 18.0 pts
#         6. Rashee Rice (KC): 17.8 pts
#         7. A.J. Brown (PHI): 17.4 pts
#         8. CeeDee Lamb (DAL): 16.9 pts
#         9. Nico Collins (HOU): 16.6 pts
#        10. Jameson Williams (DET): 15.9 pts
#        11. Justin Jefferson (MIN): 14.8 pts
#        12. Marvin Harrison Jr. (ARI): 14.2 pts
#        13. George Pickens (DAL): 14.0 pts
#        14. Tee Higgins (CIN): 13.9 pts
#        15. Zay Flowers (BAL): 13.8 pts
#        16. Chris Olave (NO): 13.5 pts
#        17. DK Metcalf (PIT): 13.5 pts
#        18. Wan'Dale Robinson (NYG): 13.5 pts
#        19. Michael Wilson (ARI): 13.4 pts
#        20. DeVonta Smith (PHI): 13.1 pts
#        21. Tetairoa McMillan (CAR): 13.1 pts
#        22. Courtland Sutton (DEN): 13.1 pts
#        23. Jauan Jennings (SF): 12.9 pts
#        24. Mike Evans (TB): 12.8 pts
#        25. Jakobi Meyers (JAX): 12.6 pts
#        26. Terry McLaurin (WAS): 12.6 pts
#        27. Ladd McConkey (LAC): 12.6 pts
#        28. Michael Pittman Jr. (IND): 12.6 pts
#        29. Jaylen Waddle (MIA): 12.6 pts
#        30. Rome Odunze (CHI): 12.5 pts
#        31. Deebo Samuel (WAS): 12.4 pts
#        32. Christian Watson (GB): 11.8 pts
#        33. Brian Thomas Jr. (JAX): 11.8 pts
#        34. Stefon Diggs (NE): 11.2 pts
#        35. Jayden Reed (GB): 11.2 pts
#        36. Emeka Egbuka (TB): 10.9 pts
#        37. Chris Godwin Jr. (TB): 10.7 pts
#        38. Keenan Allen (LAC): 10.6 pts
#        39. Jordan Addison (MIN): 10.5 pts
#        40. Adonai Mitchell (NYJ): 10.5 pts
#        41. Ricky Pearsall (SF): 10.5 pts
#        42. Chimere Dike (TEN): 10.3 pts
#        43. Jalen Coker (CAR): 10.2 pts
#        44. Rashid Shaheed (SEA): 10.2 pts
#        45. Luther Burden (CHI): 9.8 pts
#        46. Romeo Doubs (GB): 9.6 pts
#        47. Devaughn Vele (NO): 9.6 pts
#        48. Khalil Shakir (BUF): 9.5 pts
#        49. Cooper Kupp (SEA): 9.3 pts
#        50. Xavier Worthy (KC): 9.2 pts
#     ✓ Total 50 WR projections
#     ✓ Scraped 50 WR projections
#
#   [TE] Loading fresh page and applying filter...
#     → Filter attempt 1/5...
#     → Switched to Sortable Projections
#     ✗ Wrong positions: ['RB', 'RB', 'RB']
#     → Filter attempt 2/5...
#     → Switched to Sortable Projections
#     ✓ Filter verified: ['TE', 'TE', 'TE']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. Trey McBride (ARI): 16.8 pts
#         2. George Kittle (SF): 15.1 pts
#         3. Brock Bowers (LV): 13.6 pts
#         4. Harold Fannin Jr. (CLE): 12.3 pts
#         5. Kyle Pitts Sr. (ATL): 12.1 pts
#         6. Dallas Goedert (PHI): 11.9 pts
#         7. Tyler Warren (IND): 11.6 pts
#         8. Travis Kelce (KC): 10.9 pts
#         9. Hunter Henry (NE): 10.4 pts
#        10. Dalton Schultz (HOU): 10.0 pts
#        11. Colby Parkinson (LAR): 10.0 pts
#        12. Jake Ferguson (DAL): 9.8 pts
#        13. Oronde Gadsden (LAC): 9.8 pts
#        14. Darren Waller (MIA): 9.3 pts
#        15. AJ Barner (SEA): 9.2 pts
#        16. Colston Loveland (CHI): 9.2 pts
#        17. Juwan Johnson (NO): 9.0 pts
#        18. Theo Johnson (NYG): 8.8 pts
#        19. T.J. Hockenson (MIN): 8.7 pts
#        20. Mark Andrews (BAL): 8.6 pts
#        21. Brenton Strange (JAX): 8.2 pts
#        22. Dalton Kincaid (BUF): 8.1 pts
#        23. Gunnar Helm (TEN): 7.8 pts
#        24. Mason Taylor (NYJ): 7.2 pts
#        25. Mike Gesicki (CIN): 6.9 pts
#        26. Isaiah Likely (BAL): 6.9 pts
#        27. Luke Musgrave (GB): 6.8 pts
#        28. Chig Okonkwo (TEN): 6.7 pts
#        29. Evan Engram (DEN): 6.7 pts
#        30. Darnell Washington (PIT): 6.5 pts
#        31. Pat Freiermuth (PIT): 6.3 pts
#        32. Dawson Knox (BUF): 6.2 pts
#        33. Jonnu Smith (PIT): 6.0 pts
#        34. Cade Otton (TB): 5.5 pts
#        35. Greg Dulcich (MIA): 4.7 pts
#        36. Davis Allen (LAR): 4.7 pts
#        37. Ja'Tavion Sanders (CAR): 4.6 pts
#        38. David Njoku (CLE): 4.1 pts
#        39. John FitzPatrick (GB): 3.9 pts
#        40. Michael Mayer (LV): 3.8 pts
#        41. Noah Gray (KC): 3.7 pts
#        42. Cole Kmet (CHI): 3.7 pts
#        43. Shane Zylstra (DET): 3.6 pts
#        44. Taysom Hill (NO): 3.5 pts
#        45. Cade Stover (HOU): 3.5 pts
#        46. Josh Oliver (MIN): 3.4 pts
#        47. John Bates (WAS): 3.4 pts
#        48. Daniel Bellinger (NYG): 3.4 pts
#        49. Tommy Tremble (CAR): 3.2 pts
#        50. Terrance Ferguson (LAR): 3.0 pts
#     ✓ Total 50 TE projections
#     ✓ Scraped 50 TE projections
#
#   [K] Loading fresh page and applying filter...
#     → Filter attempt 1/5...
#     → Switched to Sortable Projections
#     ✗ Wrong positions: ['RB', 'RB', 'RB']
#     → Filter attempt 2/5...
#     → Switched to Sortable Projections
#     ✓ Filter verified: ['K', 'K', 'K']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. Cameron Dicker (LAC): 8.8 pts
#         2. Jake Bates (DET): 8.8 pts
#         3. Brandon Aubrey (DAL): 8.6 pts
#         4. Chris Boswell (PIT): 8.6 pts
#         5. Eddy Pineiro (SF): 8.4 pts
#         6. Harrison Mevis (LAR): 8.4 pts
#         7. Cairo Santos (CHI): 8.3 pts
#         8. Jason Myers (SEA): 8.3 pts
#         9. Ka'imi Fairbairn (HOU): 8.3 pts
#        10. Jake Elliott (PHI): 8.2 pts
#        11. Will Reichard (MIN): 8.2 pts
#        12. Brandon McManus (GB): 8.2 pts
#        13. Cam Little (JAX): 8.1 pts
#        14. Andy Borregales (NE): 8.1 pts
#        15. Zane Gonzalez (ATL): 8.0 pts
#        16. Riley Patterson (MIA): 8.0 pts
#        17. Chase McLaughlin (TB): 8.0 pts
#        18. Harrison Butker (KC): 8.0 pts
#        19. Wil Lutz (DEN): 8.0 pts
#        20. Tyler Loop (BAL): 8.0 pts
#        21. Evan McPherson (CIN): 8.0 pts
#        22. Charlie Smyth (NO): 7.9 pts
#        23. Ryan Fitzgerald (CAR): 7.9 pts
#        24. Blake Grupe (IND): 7.5 pts
#        25. Nick Folk (NYJ): 7.5 pts
#        26. Chad Ryland (ARI): 7.5 pts
#        27. Joey Slye (TEN): 7.4 pts
#        28. Andre Szmyt (CLE): 7.2 pts
#        29. Jake Moody (WAS): 6.9 pts
#        30. Daniel Carlson (LV): 6.6 pts
#        31. Matt Prater (BUF): 0.0 pts
#        32. Tyler Bass (BUF): 0.0 pts
#        33. Jason Sanders (MIA): 0.0 pts
#        34. Spencer Shrader (IND): 0.0 pts
#        35. Lucas Havrisik (GB): 0.0 pts
#        36. Graham Gano (NYG): 0.0 pts
#     ✓ Total 36 K projections
#     ✓ Scraped 36 K projections
#
#   [D/ST] Loading fresh page and applying filter...
#     → Filter attempt 1/5...
#     → Switched to Sortable Projections
#     ✗ Wrong positions: ['RB', 'RB', 'RB']
#     → Filter attempt 2/5...
#     → Switched to Sortable Projections
#     ✓ Filter verified: ['D/ST', 'D/ST', 'D/ST']
#     Found 3 tables
#     Found 32 player rows
#     Found 32 FPTS rows
#         1. Texans Defense (HOU): 9.8 pts
#         2. Saints Defense (NO): 7.4 pts
#         3. Bills Defense (BUF): 7.2 pts
#         4. Eagles Defense (PHI): 7.0 pts
#         5. Broncos Defense (DEN): 7.0 pts
#         6. Chiefs Defense (KC): 6.5 pts
#         7. Vikings Defense (MIN): 6.3 pts
#         8. Dolphins Defense (MIA): 6.3 pts
#         9. Patriots Defense (NE): 6.1 pts
#        10. Giants Defense (NYG): 5.8 pts
#        11. Jaguars Defense (JAX): 5.7 pts
#        12. Falcons Defense (ATL): 5.6 pts
#        13. Titans Defense (TEN): 5.5 pts
#        14. Jets Defense (NYJ): 5.4 pts
#        15. Lions Defense (DET): 5.3 pts
#        16. Buccaneers Defense (TB): 5.2 pts
#        17. Rams Defense (LAR): 5.2 pts
#        18. Bengals Defense (CIN): 4.9 pts
#        19. 49ers Defense (SF): 4.9 pts
#        20. Cowboys Defense (DAL): 4.8 pts
#        21. Panthers Defense (CAR): 4.8 pts
#        22. Ravens Defense (BAL): 4.7 pts
#        23. Seahawks Defense (SEA): 4.6 pts
#        24. Browns Defense (CLE): 4.4 pts
#        25. Chargers Defense (LAC): 4.3 pts
#        26. Colts Defense (IND): 4.3 pts
#        27. Raiders Defense (LV): 3.9 pts
#        28. Cardinals Defense (ARI): 3.5 pts
#        29. Packers Defense (GB): 3.2 pts
#        30. Commanders Defense (WAS): 2.9 pts
#        31. Steelers Defense (PIT): 2.8 pts
#        32. Bears Defense (CHI): 2.7 pts
#     ✓ Total 32 D/ST projections
#     ✓ Scraped 32 D/ST projections
#
# ✓ Total players with valid projections: 268
#
# Saving 268 projections to database...
# ✓ Successfully saved to database!
#
# ✅ ESPN scraping complete!

# %%
# 📊 FANTASYPROS SCRAPER  
# ================================================
# Set HEADLESS = False in setup cell to debug visually
print(f"{'='*70}")
print(f"📊 FANTASYPROS SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    with FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK)
    print("\n✅ FantasyPros scraping complete!")
except Exception as e:
    print(f"\n❌ FantasyPros error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# 📊 FANTASYPROS SCRAPER - Week 16
# ======================================================================
#
#
# ============================================================
# FANTASYPROS SCRAPER - Week 16
# ============================================================
#
#   [QB] Loading https://www.fantasypros.com/nfl/rankings/qb.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 89 rows
#     → Parsing players...
#         1. Josh Allen (BUF): 22.7
#         2. Jalen Hurts (PHI): 21.0
#         3. Drake Maye (NE): 20.3
#         4. Joe Burrow (CIN): 19.4
#         5. Brock Purdy (SF): 18.9
#         6. Dak Prescott (DAL): 18.7
#         7. Lamar Jackson (BAL): 18.5
#         8. Jacoby Brissett (ARI): 18.3
#         9. Jared Goff (DET): 18.2
#        10. Matthew Stafford (LAR): 18.1
#        11. Justin Herbert (LAC): 17.9
#        12. Jordan Love (GB): 17.7
#        13. C.J. Stroud (HOU): 17.8
#        14. Bo Nix (DEN): 17.5
#        15. Jaxson Dart (NYG): 17.4
#        16. Caleb Williams (CHI): 17.2
#        17. Trevor Lawrence (JAC): 16.9
#        18. Baker Mayfield (TB): 16.6
#        19. J.J. McCarthy (MIN): 16.4
#        20. Tyler Shough (NO): 16.1
#        21. Bryce Young (CAR): 15.9
#        22. Kirk Cousins (ATL): 15.7
#        23. Aaron Rodgers (PIT): 15.6
#        24. Sam Darnold (SEA): 15.4
#        25. Marcus Mariota (WAS): 15.2
#        26. Gardner Minshew II (KC): 14.8
#        27. Shedeur Sanders (CLE): 14.3
#        28. Philip Rivers (IND): 13.8
#        29. Cam Ward (TEN): 13.0
#        30. Brady Cook (NYJ): 12.3
#        31. Kenny Pickett (LV): 11.5
#        32. Tua Tagovailoa (MIA): 10.9
#        33. Geno Smith (LV): 2.0
#        34. Tyrod Taylor (NYJ): 1.6
#        35. Quinn Ewers (MIA): 0.5
#        36. Joe Milton III (DAL): 0.5
#        37. Riley Leonard (IND): 0.5
#        38. Trey Lance (LAC): 0.5
#        39. Teddy Bridgewater (TB): 0.5
#        40. Tyler Huntley (BAL): 0.5
#        41. Davis Mills (HOU): 0.5
#        42. Joe Flacco (CIN): 0.5
#        43. Tyson Bagent (CHI): 0.5
#        44. Collin Hill (FA): 0.4
#        45. Mason Rudolph (PIT): 0.4
#        46. Jameis Winston (NYG): 0.4
#        47. Justin Fields (NYJ): 0.4
#        48. Max Brosmer (MIN): 0.4
#        49. Malik Willis (GB): 0.4
#        50. Mitchell Trubisky (BUF): 0.4
#        51. Jalen Milroe (SEA): 0.4
#        52. Joshua Dobbs (NE): 0.4
#        53. Spencer Rattler (NO): 0.4
#        54. Mac Jones (SF): 0.4
#        55. Hendon Hooker (FA): 0.4
#        56. Jimmy Garoppolo (LAR): 0.3
#        57. Brett Rypien (IND): 0.3
#        58. Tanner McKee (PHI): 0.2
#        59. Nick Mullens (JAC): 0.2
#        60. Jarrett Stidham (DEN): 0.2
#        61. Zach Wilson (MIA): 0.2
#        62. Andy Dalton (CAR): 0.2
#        63. Shane Buechele (BUF): 0.1
#        64. Brandon Allen (TEN): 0.1
#        65. Taylor Heinicke (FA): 0.1
#     ✓ QB: 65 players scraped
#
#   [RB] Loading https://www.fantasypros.com/nfl/rankings/ppr-rb.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 117 rows
#     → Parsing players...
#         1. De'Von Achane (MIA): 25.9
#         2. Bijan Robinson (ATL): 23.2
#         3. Christian McCaffrey (SF): 22.5
#         4. Jahmyr Gibbs (DET): 22.4
#         5. James Cook III (BUF): 21.0
#         6. Travis Etienne Jr. (JAC): 18.3
#         7. Saquon Barkley (PHI): 18.0
#         8. Jonathan Taylor (IND): 16.4
#         9. Josh Jacobs (GB): 15.6
#        10. Bucky Irving (TB): 15.0
#        11. Javonte Williams (DAL): 14.9
#        12. TreVeyon Henderson (NE): 14.8
#        13. Chase Brown (CIN): 14.1
#        14. Woody Marks (HOU): 14.0
#        15. Derrick Henry (BAL): 13.9
#        16. Kyren Williams (LAR): 13.8
#        17. D'Andre Swift (CHI): 13.8
#        18. Quinshon Judkins (CLE): 13.6
#        19. RJ Harvey (DEN): 13.5
#        20. Tyrone Tracy Jr. (NYG): 12.8
#        21. Breece Hall (NYJ): 12.6
#        22. Aaron Jones Sr. (MIN): 12.3
#        23. Rico Dowdle (CAR): 12.0
#        24. Omarion Hampton (LAC): 11.8
#        25. Ashton Jeanty (LV): 11.8
#        26. Jaylen Warren (PIT): 11.6
#        27. Tony Pollard (TEN): 11.0
#        28. Michael Carter (ARI): 11.0
#        29. Kenneth Walker III (SEA): 10.3
#        30. Kenneth Gainwell (PIT): 10.2
#        31. Kyle Monangai (CHI): 9.9
#        32. Blake Corum (LAR): 9.8
#        33. Chuba Hubbard (CAR): 9.6
#        34. Kareem Hunt (KC): 9.4
#        35. Jacory Croskey-Merritt (WAS): 9.2
#        36. David Montgomery (DET): 9.2
#        37. Kimani Vidal (LAC): 9.1
#        38. Rhamondre Stevenson (NE): 8.6
#        39. Audric Estime (NO): 8.6
#        40. Zach Charbonnet (SEA): 8.4
#        41. Tyler Allgeier (ATL): 8.2
#        42. Jordan Mason (MIN): 8.1
#        43. Samaje Perine (CIN): 8.0
#        44. Devin Singletary (NYG): 7.9
#        45. Isiah Pacheco (KC): 7.8
#        46. Tyjae Spears (TEN): 7.2
#        47. Emari Demercado (ARI): 6.6
#        48. Rachaad White (TB): 6.6
#        49. Sean Tucker (TB): 6.5
#        50. Jeremy McNichols (WAS): 6.5
#        51. Ty Johnson (BUF): 6.2
#        52. Jaleel McLaughlin (DEN): 6.1
#        53. Brian Robinson Jr. (SF): 5.8
#        54. Keaton Mitchell (BAL): 5.7
#        55. Emanuel Wilson (GB): 5.0
#        56. Malik Davis (DAL): 5.3
#        57. Jaylen Wright (MIA): 5.1
#        58. Chris Rodriguez Jr. (WAS): 4.5
#        59. Isaiah Davis (NYJ): 4.3
#        60. Ollie Gordon II (MIA): 4.2
#        61. Dare Ogunbowale (HOU): 4.1
#        62. Rasheen Ali (BAL): 4.1
#        63. Tank Bigsby (PHI): 3.7
#        64. Brashard Smith (KC): 3.8
#        65. Tyler Badie (DEN): 3.1
#        66. LeQuint Allen Jr. (JAC): 3.0
#        67. Jawhar Jordan (HOU): 3.0
#        68. Evan Hull (NO): 2.8
#        69. Ray Davis (BUF): 2.7
#        70. Ameer Abdullah (IND): 2.6
#        71. Raheem Mostert (LV): 1.9
#        72. Alvin Kamara (NO): 2.5
#        73. Nick Chubb (HOU): 2.4
#        74. Trayveon Williams (CLE): 1.8
#        75. Bhayshul Tuten (JAC): 2.3
#        76. Devin Neal (NO): 2.2
#        77. Dylan Sampson (CLE): 1.8
#        78. Chris Brooks (GB): 1.7
#        79. Will Shipley (PHI): 1.4
#        80. DJ Giddens (IND): 1.4
#        81. Kyle Juszczyk (SF): 1.3
#        82. Hunter Luepke (DAL): 1.1
#        83. Raheim Sanders (CLE): 1.1
#        84. Kaleb Johnson (PIT): 1.0
#        85. Trevor Etienne (CAR): 0.9
#        86. Tahj Brooks (CIN): 0.9
#        87. Tyler Goodson (IND): 0.8
#        88. Corey Kiner (ARI): 0.8
#        89. Alec Ingold (MIA): 0.7
#        90. Patrick Ricard (BAL): 0.7
#        91. Dylan Laube (LV): 0.7
#        92. Justice Hill (BAL): 0.6
#        93. Zavier Scott (MIN): 0.5
#        94. Adam Prentice (DEN): 0.5
#        95. D'Ernest Johnson (NE): 0.5
#        96. Kendall Milton (CIN): 0.5
#        97. C.J. Ham (MIN): 0.5
#        98. Clyde Edwards-Helaire (KC): 0.4
#        99. MarShawn Lloyd (GB): 0.4
#       100. Braelon Allen (NYJ): 0.4
#       101. Travis Homer (CHI): 0.3
#       102. Reggie Gilliam (BUF): 0.3
#       103. Ty Chandler (MIN): 0.2
#       104. Khalil Herbert (NYJ): 0.2
#       105. Julius Chestnut (TEN): 0.1
#     ✓ RB: 105 players scraped
#
#   [WR] Loading https://www.fantasypros.com/nfl/rankings/ppr-wr.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 153 rows
#     → Parsing players...
#         1. Puka Nacua (LAR): 20.4
#         2. Jaxon Smith-Njigba (SEA): 20.1
#         3. Ja'Marr Chase (CIN): 19.8
#         4. Amon-Ra St. Brown (DET): 19.4
#         5. CeeDee Lamb (DAL): 18.0
#         6. Nico Collins (HOU): 17.3
#         7. Michael Wilson (ARI): 16.7
#         8. A.J. Brown (PHI): 16.6
#         9. Mike Evans (TB): 16.5
#        10. Chris Olave (NO): 16.5
#        11. Jameson Williams (DET): 14.7
#        12. Rashee Rice (KC): 14.3
#        13. Jaylen Waddle (MIA): 14.2
#        14. George Pickens (DAL): 14.2
#        15. DK Metcalf (PIT): 13.9
#        16. Tetairoa McMillan (CAR): 13.8
#        17. Jauan Jennings (SF): 13.5
#        18. Courtland Sutton (DEN): 13.1
#        19. Wan'Dale Robinson (NYG): 13.1
#        20. Zay Flowers (BAL): 13.0
#        21. DeVonta Smith (PHI): 12.9
#        22. Terry McLaurin (WAS): 12.8
#        23. Jakobi Meyers (JAC): 12.8
#        24. Ladd McConkey (LAC): 12.7
#        25. Justin Jefferson (MIN): 12.6
#        26. Michael Pittman Jr. (IND): 12.5
#        27. Chris Godwin Jr. (TB): 12.3
#        28. Jayden Reed (GB): 12.1
#        29. Stefon Diggs (NE): 11.9
#        30. Emeka Egbuka (TB): 11.4
#        31. Brian Thomas Jr. (JAC): 11.4
#        32. DJ Moore (CHI): 11.4
#        33. Deebo Samuel Sr. (WAS): 11.3
#        34. Khalil Shakir (BUF): 11.1
#        35. Luther Burden III (CHI): 11.1
#        36. Adonai Mitchell (NYJ): 10.7
#        37. Jordan Addison (MIN): 10.4
#        38. Keenan Allen (LAC): 10.3
#        39. Troy Franklin (DEN): 10.3
#        40. Romeo Doubs (GB): 10.3
#        41. Jayden Higgins (HOU): 10.2
#        42. Jalen Coker (CAR): 9.7
#        43. Jerry Jeudy (CLE): 9.7
#        44. Xavier Worthy (KC): 9.5
#        45. Rashid Shaheed (SEA): 9.5
#        46. Kayshon Boutte (NE): 9.3
#        47. Darnell Mooney (ATL): 9.4
#        48. Chimere Dike (TEN): 9.0
#        49. Darius Slayton (NYG): 8.9
#        50. Josh Downs (IND): 8.9
#        51. John Metchie III (NYJ): 8.8
#        52. Alec Pierce (IND): 8.7
#        53. Tre Tucker (LV): 8.7
#        54. Drake London (ATL): 7.4
#        55. Cooper Kupp (SEA): 8.5
#        56. Andrei Iosivas (CIN): 8.5
#        57. Elic Ayomanor (TEN): 8.4
#        58. Mack Hollins (NE): 8.4
#        59. David Sills V (ATL): 8.3
#        60. Dontayvion Wicks (GB): 8.2
#        61. Xavier Legette (CAR): 7.9
#        62. Malik Washington (MIA): 7.8
#        63. Parker Washington (JAC): 7.7
#        64. Tre Harris (LAC): 7.8
#        65. Ryan Flournoy (DAL): 7.4
#        66. Tee Higgins (CIN): 7.1
#        67. Devaughn Vele (NO): 6.9
#        68. Matthew Golden (GB): 6.9
#        69. Marvin Mims Jr. (DEN): 6.8
#        70. Christian Kirk (HOU): 6.8
#        71. Olamide Zaccheaus (CHI): 6.4
#        72. Keon Coleman (BUF): 6.3
#        73. Jack Bech (LV): 6.2
#        74. DeMario Douglas (NE): 5.9
#        75. Isaac TeSlaa (DET): 5.9
#        76. Calvin Austin III (PIT): 5.8
#        77. Jalen Nailor (MIN): 5.6
#        78. Ricky Pearsall (SF): 5.6
#        79. Isaiah Hodgins (NYG): 5.3
#        80. DeAndre Hopkins (BAL): 5.2
#        81. Mitch Tinsley (CIN): 5.0
#        82. Van Jefferson (TEN): 5.0
#        83. Isaiah Bond (CLE): 5.0
#        84. Jalen McMillan (TB): 5.0
#        85. Joshua Palmer (BUF): 5.0
#        86. Kendrick Bourne (SF): 5.0
#        87. Quentin Johnston (LAC): 4.9
#        88. Pat Bryant (DEN): 4.9
#        89. Lil'Jordan Humphrey (DEN): 4.8
#        90. Marvin Harrison Jr. (ARI): 4.7
#        91. Cedric Tillman (CLE): 4.6
#        92. Christian Watson (GB): 4.5
#        93. Tyquan Thornton (KC): 4.5
#        94. Tyler Lockett (LV): 4.5
#        95. Tutu Atwell (LAR): 4.3
#        96. Konata Mumpfield (LAR): 4.2
#        97. KaVontae Turpin (DAL): 4.1
#        98. Demarcus Robinson (SF): 4.1
#        99. Jordan Whittington (LAR): 4.0
#       100. Tim Patrick (JAC): 4.0
#       101. Jahan Dotson (PHI): 4.0
#       102. Jaylin Noel (HOU): 3.8
#       103. Davante Adams (LAR): 3.7
#       104. Brandin Cooks (BUF): 3.6
#       105. Rashod Bateman (BAL): 3.3
#       106. Xavier Hutchinson (HOU): 3.4
#       107. Isaiah Williams (NYJ): 3.3
#       108. Marquise Brown (KC): 3.3
#       109. Adam Thielen (PIT): 3.2
#       110. Mason Tipton (NO): 3.2
#       111. Jalen Brooks (ARI): 3.1
#       112. Rome Odunze (CHI): 3.0
#       113. Kevin Austin Jr. (NO): 3.1
#       114. Treylon Burks (WAS): 2.8
#       115. Tyrell Shavers (BUF): 2.8
#       116. Marquez Valdes-Scantling (PIT): 2.7
#       117. JuJu Smith-Schuster (KC): 2.7
#       118. Jaylin Lane (WAS): 2.6
#       119. Xavier Smith (LAR): 2.4
#       120. Casey Washington (ATL): 2.4
#       121. Gage Larvadain (CLE): 2.3
#       122. Dylan Drummond (ATL): 2.3
#       123. Kalif Raymond (DET): 2.1
#       124. Devin Duvernay (CHI): 2.2
#       125. Devontez Walker (BAL): 1.8
#       126. Tez Johnson (TB): 1.8
#       127. Bo Melton (GB): 1.8
#       128. KeAndre Lambert-Smith (LAC): 1.8
#       129. Kyle Williams (NE): 1.7
#       130. Cedrick Wilson Jr. (MIA): 1.7
#       131. Trent Sherfield Sr. (ARI): 1.3
#       132. Dont'e Thornton Jr. (LV): 1.6
#       133. Malachi Corley (CLE): 1.2
#       134. Sterling Shepard (TB): 1.1
#       135. James Proche II (TEN): 1.1
#       136. Gabe Davis (BUF): 1.0
#       137. Jimmy Horn Jr. (CAR): 1.0
#       138. Ben Skowronek (PIT): 0.9
#       139. Arian Smith (NYJ): 0.8
#       140. Nick Westbrook-Ikhine (MIA): 0.5
#       141. Chris Moore (WAS): 0.5
#       142. Shedrick Jackson (LV): 0.5
#       143. Charlie Jones (CIN): 0.5
#       144. Darius Cooper (PHI): 0.4
#       145. Dyami Brown (JAC): 0.5
#     ✓ WR: 145 players scraped
#
#   [TE] Loading https://www.fantasypros.com/nfl/rankings/ppr-te.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 87 rows
#     → Parsing players...
#         1. Trey McBride (ARI): 17.0
#         2. George Kittle (SF): 15.2
#         3. Kyle Pitts Sr. (ATL): 13.9
#         4. Brock Bowers (LV): 13.4
#         5. Dallas Goedert (PHI): 11.9
#         6. Harold Fannin Jr. (CLE): 11.7
#         7. Colby Parkinson (LAR): 11.1
#         8. Travis Kelce (KC): 11.0
#         9. Dalton Schultz (HOU): 10.7
#        10. Darren Waller (MIA): 10.3
#        11. Tyler Warren (IND): 10.0
#        12. Dalton Kincaid (BUF): 9.9
#        13. Jake Ferguson (DAL): 9.9
#        14. Oronde Gadsden II (LAC): 9.7
#        15. Theo Johnson (NYG): 9.3
#        16. Colston Loveland (CHI): 9.2
#        17. Hunter Henry (NE): 8.9
#        18. Brenton Strange (JAC): 8.7
#        19. Juwan Johnson (NO): 8.5
#        20. Mike Gesicki (CIN): 8.4
#        21. AJ Barner (SEA): 8.2
#        22. Mark Andrews (BAL): 8.0
#        23. Gunnar Helm (TEN): 7.9
#        24. T.J. Hockenson (MIN): 7.3
#        25. Evan Engram (DEN): 7.1
#        26. Isaiah Likely (BAL): 7.0
#        27. Pat Freiermuth (PIT): 7.0
#        28. Dawson Knox (BUF): 7.0
#        29. Chig Okonkwo (TEN): 6.6
#        30. Cole Kmet (CHI): 5.7
#        31. Jonnu Smith (PIT): 5.6
#        32. Luke Musgrave (GB): 5.6
#        33. Ja'Tavion Sanders (CAR): 5.6
#        34. Greg Dulcich (MIA): 4.8
#        35. Ben Sinnott (WAS): 4.7
#        36. Darnell Washington (PIT): 4.7
#        37. John Bates (WAS): 4.4
#        38. Davis Allen (LAR): 4.0
#        39. Taysom Hill (NO): 3.9
#        40. Terrance Ferguson (LAR): 3.7
#        41. Jeremy Ruckert (NYJ): 3.7
#        42. Tommy Tremble (CAR): 3.7
#        43. Noah Fant (CIN): 3.6
#        44. Cade Otton (TB): 3.6
#        45. Adam Trautman (DEN): 3.6
#        46. John FitzPatrick (GB): 3.6
#        47. Tanner Hudson (CIN): 3.5
#        48. Michael Mayer (LV): 3.3
#        49. Noah Gray (KC): 3.2
#        50. Elijah Higgins (ARI): 3.1
#        51. Mason Taylor (NYJ): 3.1
#        52. David Njoku (CLE): 2.9
#        53. Josh Oliver (MIN): 2.8
#        54. Cade Stover (HOU): 2.7
#        55. Shane Zylstra (DET): 2.6
#        56. Anthony Firkser (DET): 2.6
#        57. Austin Hooper (NE): 2.6
#        58. Daniel Bellinger (NYG): 2.5
#        59. Devin Culp (TB): 2.4
#        60. Grant Calcaterra (PHI): 2.3
#        61. Jackson Hawes (BUF): 2.2
#        62. Brevyn Spann-Ford (DAL): 2.1
#        63. Charlie Kolar (BAL): 2.1
#        64. Luke Schoonmaker (DAL): 2.1
#        65. Pharaoh Brown (ARI): 2.1
#        66. Charlie Woerner (ATL): 2.0
#        67. Payne Durham (TB): 2.0
#        68. Mitchell Evans (CAR): 1.9
#        69. Foster Moreau (NO): 1.9
#        70. Eric Saubert (SEA): 1.9
#        71. Colson Yankoff (WAS): 1.8
#        72. Drew Sample (CIN): 1.8
#        73. Quintin Morris (JAC): 1.7
#        74. Jack Stoll (NO): 1.7
#        75. Blake Whiteheart (CLE): 1.6
#        76. Connor Heyward (PIT): 1.5
#        77. Julian Hill (MIA): 1.5
#        78. Stone Smartt (NYJ): 1.4
#        79. Hunter Long (JAC): 1.3
#        80. Will Dissly (LAC): 1.1
#        81. Kylen Granson (PHI): 1.1
#        82. Mo Alie-Cox (IND): 1.0
#        83. Ian Thomas (LV): 1.0
#        84. Jared Wiley (KC): 1.0
#        85. Drew Ogletree (IND): 1.0
#     ✓ TE: 85 players scraped
#
#   [K] Loading https://www.fantasypros.com/nfl/rankings/k.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 34 rows
#     → Parsing players...
#         1. Ka'imi Fairbairn (HOU): 8.8
#         2. Brandon Aubrey (DAL): 8.5
#         3. Cameron Dicker (LAC): 8.3
#         4. Eddy Pineiro (SF): 8.3
#         5. Jason Myers (SEA): 8.1
#         6. Chase McLaughlin (TB): 8.0
#         7. Jake Bates (DET): 8.0
#         8. Andy Borregales (NE): 8.0
#         9. Tyler Loop (BAL): 7.9
#        10. Riley Patterson (MIA): 7.8
#        11. Evan McPherson (CIN): 7.8
#        12. Jake Elliott (PHI): 7.7
#        13. Cam Little (JAC): 7.7
#        14. Chris Boswell (PIT): 7.6
#        15. Will Reichard (MIN): 7.6
#        16. Zane Gonzalez (ATL): 7.3
#        17. Harrison Mevis (LAR): 7.3
#        18. Brandon McManus (GB): 7.2
#        19. Cairo Santos (CHI): 7.2
#        20. Charlie Smyth (NO): 7.2
#        21. Wil Lutz (DEN): 7.2
#        22. Harrison Butker (KC): 7.1
#        23. Chad Ryland (ARI): 6.9
#        24. Ryan Fitzgerald (CAR): 6.9
#        25. Nick Folk (NYJ): 6.7
#        26. Jake Moody (WAS): 6.7
#        27. Blake Grupe (IND): 6.6
#        28. Joey Slye (TEN): 6.4
#        29. Michael Badgley (BUF): 6.1
#        30. Andre Szmyt (CLE): 5.5
#        31. Younghoe Koo (FA): 5.3
#        32. Daniel Carlson (LV): 3.5
#     ✓ K: 32 players scraped
#
#   [DST] Loading https://www.fantasypros.com/nfl/rankings/dst.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 33 rows
#     → Parsing players...
#         1. Houston Texans Defense (HOU): 12.7
#         2. Buffalo Bills Defense (BUF): 8.7
#         3. Kansas City Chiefs Defense (KC): 8.6
#         4. Philadelphia Eagles Defense (PHI): 8.2
#         5. New Orleans Saints Defense (NO): 8.0
#         6. Denver Broncos Defense (DEN): 7.5
#         7. Minnesota Vikings Defense (MIN): 7.1
#         8. Seattle Seahawks Defense (SEA): 7.0
#         9. Los Angeles Rams Defense (LAR): 6.6
#        10. Detroit Lions Defense (DET): 6.6
#        11. San Francisco 49ers Defense (SF): 6.6
#        12. Jacksonville Jaguars Defense (JAC): 6.5
#        13. Tampa Bay Buccaneers Defense (TB): 6.5
#        14. Dallas Cowboys Defense (DAL): 6.4
#        15. New York Giants Defense (NYG): 6.4
#        16. Green Bay Packers Defense (GB): 6.2
#        17. New England Patriots Defense (NE): 6.1
#        18. Tennessee Titans Defense (TEN): 6.0
#        19. Atlanta Falcons Defense (ATL): 6.0
#        20. Carolina Panthers Defense (CAR): 5.9
#        21. Los Angeles Chargers Defense (LAC): 5.9
#        22. Chicago Bears Defense (CHI): 5.8
#        23. New York Jets Defense (NYJ): 5.6
#        24. Miami Dolphins Defense (MIA): 5.4
#        25. Baltimore Ravens Defense (BAL): 5.4
#        26. Cleveland Browns Defense (CLE): 5.3
#        27. Pittsburgh Steelers Defense (PIT): 5.2
#        28. Arizona Cardinals Defense (ARI): 5.2
#        29. Indianapolis Colts Defense (IND): 5.0
#        30. Cincinnati Bengals Defense (CIN): 4.9
#        31. Las Vegas Raiders Defense (LV): 4.9
#        32. Washington Commanders Defense (WAS): 4.8
#     ✓ DST: 32 players scraped
#
# ============================================================
# Total: 464 players scraped
# ============================================================
#
# Saving 464 projections to database...
# ✓ Successfully saved to database!
#
# ✅ FantasyPros scraping complete!

# %%
# 🎯 FIRST DOWN STUDIO SCRAPER
# ================================================
# Set HEADLESS = False in setup cell to debug visually
print(f"{'='*70}")
print(f"🎯 FIRST DOWN STUDIO SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    with FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK, scoring="PPR")
    print("\n✅ First Down Studio scraping complete!")
except Exception as e:
    print(f"\n❌ First Down Studio error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# 🎯 FIRST DOWN STUDIO SCRAPER - Week 16
# ======================================================================
#
#
# Scraping QB from https://www.firstdown.studio/rankings/qb...
#   Headers: ['# (vs. ecr)', 'Player', 'Proj. Pts', 'Pass Yds', 'Pass TDs', 'INTs', 'Rush Yds']
#   Found points column at index 2
#   Found 31 player rows
#     Josh Allen (BUF): 21.2 pts
#     Jalen Hurts (PHI): 20.6 pts
#     Joe Burrow (CIN): 18.9 pts
#     Jared Goff (DET): 18.7 pts
#     Lamar Jackson (BAL): 18.4 pts
#     Brock Purdy (SF): 18.1 pts
#     Justin Herbert (LAC): 18.1 pts
#     Drake Maye (NE): 17.9 pts
#     Bo Nix (DEN): 17.9 pts
#     Jacoby Brissett (ARI): 17.7 pts
#     C.J. Stroud (HOU): 17.6 pts
#     Baker Mayfield (TB): 17.6 pts
#     Dak Prescott (DAL): 17.5 pts
#     Tyler Shough (NO): 16.9 pts
#     Jaxson Dart (NYG): 16.7 pts
#     Marcus Mariota (WAS): 16.3 pts
#     Jordan Love (GB): 16.2 pts
#     Caleb Williams (CHI): 16.2 pts
#     Trevor Lawrence (JAC): 16.1 pts
#     J.J. McCarthy (MIN): 15.2 pts
#     Bryce Young (CAR): 14.8 pts
#     Matthew Stafford (LA): 14.7 pts
#     Aaron Rodgers (PIT): 14.6 pts
#     Tua Tagovailoa (MIA): 14.4 pts
#     Sam Darnold (SEA): 14.4 pts
#     Kirk Cousins (ATL): 14.4 pts
#     Gardner Minshew (KC): 13.2 pts
#     Cam Ward (TEN): 11.1 pts
#     Shedeur Sanders (CLE): 10.7 pts
#     Geno Smith (LV): 10.4 pts
#     Philip Rivers (IND): 8.9 pts
#   ✓ Scraped 31 QB projections
#
# Scraping RB from https://www.firstdown.studio/rankings/rb...
#   Headers: ['# (vs. ecr)', 'Player', 'Proj. Pts', 'Rush Yds', 'Rec', 'Rec Yds', 'TDs']
#   Found points column at index 2
#   Found 54 player rows
#     Bijan Robinson (ATL): 20.5 pts
#     Jahmyr Gibbs (DET): 19.0 pts
#     De'Von Achane (MIA): 18.8 pts
#     C. McCaffrey (SF): 18.1 pts
#     Jonathan Taylor (IND): 17.3 pts
#     James Cook (BUF): 15.3 pts
#     Saquon Barkley (PHI): 14.2 pts
#     Chase Brown (CIN): 14.1 pts
#     Javonte Williams (DAL): 13.9 pts
#     Josh Jacobs (GB): 13.5 pts
#     Derrick Henry (BAL): 13.2 pts
#     Quinshon Judkins (CLE): 12.8 pts
#     Breece Hall (NYJ): 12.8 pts
#     Bucky Irving (TB): 12.4 pts
#     Travis Etienne (JAC): 12.2 pts
#     T. Henderson (NE): 12.2 pts
#     Aaron Jones (MIN): 11.9 pts
#     Jaylen Warren (PIT): 11.5 pts
#     RJ Harvey (DEN): 11.4 pts
#     Ashton Jeanty (LV): 11.1 pts
#     Rico Dowdle (CAR): 11.0 pts
#     Kyren Williams (LA): 10.7 pts
#     D'Andre Swift (CHI): 10.4 pts
#     Woody Marks (HOU): 10.4 pts
#     Kenneth Gainwell (PIT): 10.1 pts
#     Michael Carter (ARI): 10.0 pts
#     Omarion Hampton (LAC): 9.6 pts
#     Tyrone Tracy (NYG): 9.5 pts
#     Tony Pollard (TEN): 9.3 pts
#     Kenneth Walker (SEA): 9.1 pts
#     David Montgomery (DET): 8.7 pts
#     Kyle Monangai (CHI): 8.2 pts
#     Jordan Mason (MIN): 8.2 pts
#     Kareem Hunt (KC): 8.1 pts
#     Kimani Vidal (LAC): 8.0 pts
#     J. Croskey-Merritt (WAS): 7.5 pts
#     R. Stevenson (NE): 7.4 pts
#     Chuba Hubbard (CAR): 7.3 pts
#     Tyjae Spears (TEN): 7.2 pts
#     Isiah Pacheco (KC): 7.0 pts
#     Blake Corum (LA): 6.5 pts
#     Devin Singletary (NYG): 6.5 pts
#     Samaje Perine (CIN): 6.4 pts
#     Tyler Allgeier (ATL): 6.2 pts
#     Chris Rodriguez (WAS): 6.2 pts
#     Zach Charbonnet (SEA): 6.1 pts
#     Dylan Sampson (CLE): 5.5 pts
#     Emanuel Wilson (GB): 5.1 pts
#     Rachaad White (TB): 4.9 pts
#     Keaton Mitchell (BAL): 4.7 pts
#     J. McLaughlin (DEN): 4.6 pts
#     Jeremy McNichols (WAS): 4.5 pts
#     Brian Robinson (SF): 4.2 pts
#     Malik Davis (DAL): 3.9 pts
#   ✓ Scraped 54 RB projections
#
# Scraping WR from https://www.firstdown.studio/rankings/wr...
#   Headers: ['# (vs. ecr)', 'Player', 'Proj. Pts', 'Rec', 'Rec Yds', 'TDs']
#   Found points column at index 2
#   Found 71 player rows
#     Puka Nacua (LA): 17.2 pts
#     Ja'Marr Chase (CIN): 16.9 pts
#     J. Smith-Njigba (SEA): 16.0 pts
#     A. St. Brown (DET): 14.7 pts
#     CeeDee Lamb (DAL): 13.8 pts
#     Nico Collins (HOU): 13.7 pts
#     Chris Olave (NO): 12.1 pts
#     Michael Wilson (ARI): 11.9 pts
#     Jameson Williams (DET): 11.7 pts
#     A.J. Brown (PHI): 11.5 pts
#     Tee Higgins (CIN): 11.5 pts
#     Zay Flowers (BAL): 11.3 pts
#     Drake London (ATL): 11.3 pts
#     George Pickens (DAL): 11.0 pts
#     Jaylen Waddle (MIA): 10.9 pts
#     Mike Evans (TB): 10.6 pts
#     T. McMillan (CAR): 10.6 pts
#     DK Metcalf (PIT): 10.6 pts
#     Rashee Rice (KC): 10.5 pts
#     Terry McLaurin (WAS): 10.3 pts
#     W. Robinson (NYG): 10.3 pts
#     DeVonta Smith (PHI): 10.3 pts
#     Justin Jefferson (MIN): 10.2 pts
#     Courtland Sutton (DEN): 9.9 pts
#     Jakobi Meyers (JAC): 9.8 pts
#     Christian Watson (GB): 9.6 pts
#     Jauan Jennings (SF): 9.5 pts
#     Jayden Reed (GB): 9.3 pts
#     DJ Moore (CHI): 9.1 pts
#     Ricky Pearsall (SF): 9.1 pts
#     Ladd McConkey (LAC): 8.8 pts
#     Deebo Samuel (WAS): 8.8 pts
#     Emeka Egbuka (TB): 8.6 pts
#     Rome Odunze (CHI): 8.4 pts
#     Brian Thomas (JAC): 8.3 pts
#     Khalil Shakir (BUF): 8.1 pts
#     Jordan Addison (MIN): 8.1 pts
#     Adonai Mitchell (NYJ): 7.9 pts
#     Stefon Diggs (NE): 7.7 pts
#     Alec Pierce (IND): 7.2 pts
#     Michael Pittman (IND): 7.1 pts
#     Troy Franklin (DEN): 7.1 pts
#     Jayden Higgins (HOU): 7.1 pts
#     Romeo Doubs (GB): 7.0 pts
#     Keenan Allen (LAC): 7.0 pts
#     Quentin Johnston (LAC): 7.0 pts
#     Jalen Coker (CAR): 6.9 pts
#     Chris Godwin (TB): 6.7 pts
#     Xavier Worthy (KC): 6.7 pts
#     Tre Tucker (LV): 6.6 pts
#     Jerry Jeudy (CLE): 6.5 pts
#     John Metchie (NYJ): 6.5 pts
#     Rashid Shaheed (SEA): 6.4 pts
#     Mack Hollins (NE): 6.3 pts
#     Darius Slayton (NYG): 6.2 pts
#     Luther Burden (CHI): 6.2 pts
#     Chimere Dike (TEN): 6.1 pts
#     Darnell Mooney (ATL): 6.1 pts
#     Josh Downs (IND): 6.1 pts
#     Pat Bryant (DEN): 5.9 pts
#     Cooper Kupp (SEA): 5.8 pts
#     Kayshon Boutte (NE): 5.5 pts
#     Malik Washington (MIA): 5.5 pts
#     Jalen Nailor (MIN): 5.3 pts
#     Xavier Legette (CAR): 5.2 pts
#     Ryan Flournoy (DAL): 5.2 pts
#     Andrei Iosivas (CIN): 5.2 pts
#     Isaiah Bond (CLE): 5.2 pts
#     Van Jefferson (TEN): 5.1 pts
#     Rashod Bateman (BAL): 4.7 pts
#     Matthew Golden (GB): 4.6 pts
#   ✓ Scraped 71 WR projections
#
# Scraping TE from https://www.firstdown.studio/rankings/te...
#   Headers: ['# (vs. ecr)', 'Player', 'Proj. Pts', 'Rec', 'Rec Yds', 'TDs']
#   Found points column at index 2
#   Found 26 player rows
#     Trey McBride (ARI): 14.2 pts
#     George Kittle (SF): 11.2 pts
#     Kyle Pitts (ATL): 10.2 pts
#     Brock Bowers (LV): 9.5 pts
#     Harold Fannin (CLE): 8.6 pts
#     Darren Waller (MIA): 8.6 pts
#     Dallas Goedert (PHI): 8.5 pts
#     Colston Loveland (CHI): 8.1 pts
#     Travis Kelce (KC): 8.0 pts
#     Juwan Johnson (NO): 8.0 pts
#     Hunter Henry (NE): 7.7 pts
#     Dalton Schultz (HOU): 7.6 pts
#     Jake Ferguson (DAL): 7.5 pts
#     Oronde Gadsden (LAC): 7.4 pts
#     Dalton Kincaid (BUF): 7.2 pts
#     Mark Andrews (BAL): 7.2 pts
#     Tyler Warren (IND): 7.2 pts
#     Colby Parkinson (LA): 6.9 pts
#     AJ Barner (SEA): 6.8 pts
#     Brenton Strange (JAC): 6.5 pts
#     Theo Johnson (NYG): 6.4 pts
#     T.J. Hockenson (MIN): 5.9 pts
#     Isaiah Likely (BAL): 5.7 pts
#     Mike Gesicki (CIN): 5.6 pts
#     Cade Otton (TB): 5.2 pts
#     D. Washington (PIT): 5.0 pts
#   ✓ Scraped 26 TE projections
#
# Scraping K from https://www.firstdown.studio/rankings/k...
#   Headers: ['#', 'Player', 'Kicking Pts']
#   Found points column at index 2
#   Found 20 player rows
#     Brandon Aubrey (DAL): 8.4 pts
#     Evan McPherson (CIN): 7.8 pts
#     Wil Lutz (DEN): 7.7 pts
#     Chase McLaughlin (TB): 7.7 pts
#     Jason Myers (SEA): 7.7 pts
#     Will Reichard (MIN): 7.7 pts
#     Harrison Mevis (LA): 7.6 pts
#     Cameron Dicker (LAC): 7.6 pts
#     Cam Little (JAC): 7.6 pts
#     Brandon McManus (GB): 7.4 pts
#     Jake Elliott (PHI): 7.4 pts
#     Tyler Loop (BAL): 7.4 pts
#     Cairo Santos (CHI): 6.9 pts
#     Harrison Butker (KC): 6.9 pts
#     Ryan Fitzgerald (CAR): 6.8 pts
#     Andy Borregales (NE): 6.7 pts
#     Blake Grupe (IND): 6.7 pts
#     Jake Moody (WAS): 6.5 pts
#     Younghoe Koo (NYG): 6.0 pts
#     Joey Slye (TEN): 5.8 pts
#   ✓ Scraped 20 K projections
#
# Total unique players scraped: 202
#
# Saving 202 projections to database...
# ✓ Successfully saved to database!
#
# ✅ First Down Studio scraping complete!

# %%
# 🔵 FANDUEL SCRAPER (runs in subprocess due to Playwright)
# ================================================
print(f"{'='*70}")
print(f"🔵 FANDUEL SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    temp_script = NOTEBOOK_DIR / "_temp_fanduel.py"
    script_content = f'''
import sys
sys.path.insert(0, r"{PROJECT_ROOT}")
from backend.scrapers.scraper_fanduel import FanDuelScraper

try:
    with FanDuelScraper(headless={HEADLESS}, db_path=r"{DB_PATH}") as scraper:
        scraper.scrape_and_save(week="{WEEK}")
    print("FanDuel complete")
except Exception as e:
    print(f"Error: {{e}}")
    import traceback
    traceback.print_exc()
    raise
'''
    temp_script.write_text(script_content, encoding='utf-8')
    
    result = subprocess.run(
        [sys.executable, str(temp_script)],
        capture_output=True,
        text=True,
        cwd=str(PROJECT_ROOT),
        timeout=300
    )
    
    print(result.stdout)
    if result.stderr:
        print("STDERR:", result.stderr)
    
    if result.returncode == 0:
        print("\n✅ FanDuel scraping complete!")
    else:
        print(f"\n❌ FanDuel failed with code {result.returncode}")
    
    temp_script.unlink(missing_ok=True)
except Exception as e:
    print(f"\n❌ FanDuel error: {e}")
    import traceback
    traceback.print_exc()
    if temp_script.exists():
        temp_script.unlink()
# Out:
# ======================================================================
# 🔵 FANDUEL SCRAPER - Week 16
# ======================================================================
#
# Navigating to https://www.fanduel.com/research/nfl/fantasy/ppr...
#   Intercepted data from https://fdresearch-api.fanduel.com/graphql
#   âœ“ Found 555 projections in response
#
# Parsing 555 projections...
#   Christian McCaffrey (RB): 23.4 pts
#   Bijan Robinson (RB): 22.4 pts
#   Ja'Marr Chase (WR): 22.2 pts
#   Jahmyr Gibbs (RB): 21.9 pts
#   De'Von Achane (RB): 20.9 pts
#   Dak Prescott (QB): 20.8 pts
#   Jonathan Taylor (RB): 20.7 pts
#   Josh Allen (QB): 20.6 pts
#   Amon-Ra St. Brown (WR): 20.4 pts
#   Jalen Hurts (QB): 20.3 pts
#   Puka Nacua (WR): 19.7 pts
#   Brock Purdy (QB): 19.6 pts
#   Jaxon Smith-Njigba (WR): 19.3 pts
#   Jared Goff (QB): 19.2 pts
#   Lamar Jackson (QB): 19.1 pts
#   Joe Burrow (QB): 19.0 pts
#   Justin Herbert (QB): 18.9 pts
#   Drake Maye (QB): 18.8 pts
#   Chase Brown (RB): 18.8 pts
#   Bo Nix (QB): 17.8 pts
#   C.J. Stroud (QB): 17.8 pts
#   Jacoby Brissett (QB): 17.7 pts
#   Saquon Barkley (RB): 17.5 pts
#   Caleb Williams (QB): 17.4 pts
#   CeeDee Lamb (WR): 17.3 pts
#   Baker Mayfield (QB): 17.1 pts
#   Trey McBride (TE): 17.0 pts
#   Trevor Lawrence (QB): 16.7 pts
#   Tyler Shough (QB): 16.7 pts
#   Jordan Love (QB): 16.6 pts
#   Josh Jacobs (RB): 16.5 pts
#   James Cook (RB): 16.3 pts
#   Marcus Mariota (QB): 16.2 pts
#   J.J. McCarthy (QB): 15.8 pts
#   Chris Olave (WR): 15.8 pts
#   Kirk Cousins (QB): 15.8 pts
#   Jaxson Dart (QB): 15.7 pts
#   Aaron Rodgers (QB): 15.5 pts
#   Nico Collins (WR): 15.5 pts
#   Mike Evans (WR): 15.4 pts
#   Zay Flowers (WR): 15.2 pts
#   George Pickens (WR): 15.0 pts
#   Sam Darnold (QB): 14.9 pts
#   Derrick Henry (RB): 14.9 pts
#   Matthew Stafford (QB): 14.8 pts
#   Rashee Rice (WR): 14.7 pts
#   A.J. Brown (WR): 14.6 pts
#   Jameson Williams (WR): 14.5 pts
#   Bucky Irving (RB): 14.5 pts
#   Kyren Williams (RB): 14.3 pts
#   Quinshon Judkins (RB): 14.3 pts
#   Justin Jefferson (WR): 14.3 pts
#   Bryce Young (QB): 14.2 pts
#   TreVeyon Henderson (RB): 14.2 pts
#   George Kittle (TE): 14.1 pts
#   Tetairoa McMillan (WR): 14.0 pts
#   Breece Hall (RB): 13.8 pts
#   Brady Cook (QB): 13.8 pts
#   Javonte Williams (RB): 13.7 pts
#   Ashton Jeanty (RB): 13.6 pts
#   Rico Dowdle (RB): 13.6 pts
#   Gardner Minshew (QB): 13.6 pts
#   DeVonta Smith (WR): 13.5 pts
#   Kenneth Gainwell (RB): 13.5 pts
#   D.K. Metcalf (WR): 13.5 pts
#   Travis Etienne (RB): 13.5 pts
#   Michael Wilson (WR): 13.3 pts
#   Wan'Dale Robinson (WR): 13.2 pts
#   RJ Harvey (RB): 13.1 pts
#   Jakobi Meyers (WR): 12.4 pts
#   Jaylen Waddle (WR): 12.2 pts
#   Brian Thomas Jr. (WR): 12.0 pts
#   Michael Carter (RB): 12.0 pts
#   Courtland Sutton (WR): 11.9 pts
#   Shedeur Sanders (QB): 11.9 pts
#   Ladd McConkey (WR): 11.9 pts
#   Terry McLaurin (WR): 11.9 pts
#   Kyle Pitts (TE): 11.9 pts
#   Stefon Diggs (WR): 11.8 pts
#   Brock Bowers (TE): 11.8 pts
#   Tyrone Tracy Jr. (RB): 11.7 pts
#   Troy Franklin (WR): 11.7 pts
#   Juwan Johnson (TE): 11.6 pts
#   Cameron Ward (QB): 11.6 pts
#   Kenneth Walker III (RB): 11.6 pts
#   Romeo Doubs (WR): 11.5 pts
#   Geno Smith (QB): 11.4 pts
#   Quinn Ewers (QB): 11.2 pts
#   Jaylen Warren (RB): 11.2 pts
#   D'Andre Swift (RB): 11.2 pts
#   Khalil Shakir (WR): 11.1 pts
#   Jayden Reed (WR): 10.9 pts
#   Aaron Jones (RB): 10.9 pts
#   Mark Andrews (TE): 10.8 pts
#   Deebo Samuel (WR): 10.8 pts
#   Harold Fannin Jr. (TE): 10.8 pts
#   David Montgomery (RB): 10.7 pts
#   Hunter Henry (TE): 10.7 pts
#   Chris Godwin (WR): 10.6 pts
#   Brenton Strange (TE): 10.5 pts
#   Emeka Egbuka (WR): 10.5 pts
#   Jordan Addison (WR): 10.4 pts
#   Jacory Croskey-Merritt (RB): 10.2 pts
#   Dallas Goedert (TE): 9.9 pts
#   Oronde Gadsden (TE): 9.8 pts
#   Ricky Pearsall (WR): 9.8 pts
#   Tony Pollard (RB): 9.8 pts
#   AJ Barner (TE): 9.7 pts
#   Philip Rivers (QB): 9.7 pts
#   Omarion Hampton (RB): 9.6 pts
#   Kareem Hunt (RB): 9.6 pts
#   Kimani Vidal (RB): 9.6 pts
#   Travis Kelce (TE): 9.6 pts
#   D.J. Moore (WR): 9.5 pts
#   Keenan Allen (WR): 9.5 pts
#   Michael Pittman Jr. (WR): 9.5 pts
#   Jauan Jennings (WR): 9.5 pts
#   Darius Slayton (WR): 9.4 pts
#   Jalen Coker (WR): 9.4 pts
#   Dalton Schultz (TE): 9.4 pts
#   Dalton Kincaid (TE): 9.3 pts
#   Blake Corum (RB): 9.1 pts
#   Tyjae Spears (RB): 9.1 pts
#   Jayden Higgins (WR): 9.1 pts
#   Kyle Monangai (RB): 9.0 pts
#   Tyler Warren (TE): 9.0 pts
#   Rashid Shaheed (WR): 8.8 pts
#   Cooper Kupp (WR): 8.8 pts
#   Drake London (WR): 8.8 pts
#   Jake Ferguson (TE): 8.8 pts
#   Alec Pierce (WR): 8.8 pts
#   Parker Washington (WR): 8.7 pts
#   Darren Waller (TE): 8.7 pts
#   Xavier Worthy (WR): 8.7 pts
#   Theo Johnson (TE): 8.6 pts
#   David Sills V (WR): 8.6 pts
#   Mason Taylor (TE): 8.5 pts
#   Jordan Mason (RB): 8.4 pts
#   Quentin Johnston (WR): 8.3 pts
#   Chuba Hubbard (RB): 8.3 pts
#   Kayshon Boutte (WR): 8.1 pts
#   Rhamondre Stevenson (RB): 8.0 pts
#   Devin Singletary (RB): 7.9 pts
#   Josh Downs (WR): 7.9 pts
#   T.J. Hockenson (TE): 7.9 pts
#   Mike Gesicki (TE): 7.8 pts
#   Zach Charbonnet (RB): 7.7 pts
#   Tre Tucker (WR): 7.6 pts
#   Woody Marks (RB): 7.6 pts
#   Colston Loveland (TE): 7.5 pts
#   Colby Parkinson (TE): 7.5 pts
#   Adonai Mitchell (WR): 7.5 pts
#   Mack Hollins (WR): 7.5 pts
#   Rome Odunze (WR): 7.4 pts
#   Isaiah Likely (TE): 7.4 pts
#   Keon Coleman (WR): 7.3 pts
#   Olamide Zaccheaus (WR): 7.3 pts
#   Xavier Legette (WR): 7.2 pts
#   Elic Ayomanor (WR): 7.1 pts
#   John Metchie III (WR): 6.9 pts
#   Darnell Washington (TE): 6.9 pts
#   Chimere Dike (WR): 6.8 pts
#   Marvin Mims (WR): 6.8 pts
#   Darnell Mooney (WR): 6.8 pts
#   Evan Engram (TE): 6.8 pts
#   Jeremy McNichols (RB): 6.8 pts
#   Jerry Jeudy (WR): 6.8 pts
#   Andrei Iosivas (WR): 6.8 pts
#   Chigoziem Okonkwo (TE): 6.7 pts
#   Matthew Golden (WR): 6.6 pts
#   Emanuel Wilson (RB): 6.5 pts
#   Taysom Hill (TE): 6.5 pts
#   Emari Demercado (RB): 6.5 pts
#   Jalen Nailor (WR): 6.4 pts
#   Isaiah Bond (WR): 6.3 pts
#   Jack Bech (WR): 6.0 pts
#   Pat Freiermuth (TE): 5.9 pts
#   Dontayvion Wicks (WR): 5.8 pts
#   Malik Washington (WR): 5.8 pts
#   Marvin Harrison Jr. (WR): 5.8 pts
#   Ryan Flournoy (WR): 5.7 pts
#   Isiah Pacheco (RB): 5.7 pts
#   Cedric Tillman (WR): 5.7 pts
#   Luke Musgrave (TE): 5.6 pts
#   Jaylin Lane (WR): 5.6 pts
#   Brian Robinson (RB): 5.6 pts
#   Isaac TeSlaa (WR): 5.6 pts
#   Tyler Allgeier (RB): 5.6 pts
#   Isaiah Davis (RB): 5.5 pts
#   Christian Kirk (WR): 5.4 pts
#   Konata Mumpfield (WR): 5.4 pts
#   Devin Neal (RB): 5.4 pts
#   Jalen McMillan (WR): 5.3 pts
#   Calvin Austin III (WR): 5.3 pts
#   Elijah Higgins (TE): 5.2 pts
#   Demario Douglas (WR): 5.2 pts
#   Alvin Kamara (RB): 5.2 pts
#   Gunnar Helm (TE): 5.2 pts
#   Cole Kmet (TE): 5.1 pts
#   Nick Chubb (RB): 5.1 pts
#   Lil'Jordan Humphrey (WR): 5.1 pts
#   Tutu Atwell (WR): 5.1 pts
#   Kalif Raymond (WR): 5.0 pts
#   Brandin Cooks (WR): 4.8 pts
#   Terrance Ferguson (TE): 4.7 pts
#   Demarcus Robinson (WR): 4.7 pts
#   Mason Tipton (WR): 4.6 pts
#   Mitchell Tinsley (WR): 4.6 pts
#   Keaton Mitchell (RB): 4.6 pts
#   Van Jefferson (WR): 4.5 pts
#   KaVontae Turpin (WR): 4.5 pts
#   Isaiah Williams (WR): 4.5 pts
#   Dare Ogunbowale (RB): 4.5 pts
#   Rachaad White (RB): 4.4 pts
#   Michael Mayer (TE): 4.3 pts
#   Treylon Burks (WR): 4.2 pts
#   Samaje Perine (RB): 4.2 pts
#   Jaleel McLaughlin (RB): 4.2 pts
#   Isaiah Hodgins (WR): 4.2 pts
#   Daniel Bellinger (TE): 4.1 pts
#   Noah Gray (TE): 4.1 pts
#   Chris Moore (WR): 4.0 pts
#   Devaughn Vele (WR): 4.0 pts
#   Ty Johnson (RB): 4.0 pts
#   Xavier Hutchinson (WR): 4.0 pts
#   Tank Bigsby (RB): 3.8 pts
#   Jalen Brooks (WR): 3.8 pts
#   JuJu Smith-Schuster (WR): 3.8 pts
#   Tommy Tremble (TE): 3.8 pts
#   Tre Harris (WR): 3.8 pts
#   Dawson Knox (TE): 3.7 pts
#   Greg Dulcich (TE): 3.7 pts
#   Tanner Hudson (TE): 3.7 pts
#   Davis Allen (TE): 3.6 pts
#   Malachi Corley (WR): 3.6 pts
#   LeQuint Allen Jr. (RB): 3.6 pts
#   Jahan Dotson (WR): 3.6 pts
#   Marquise Brown (WR): 3.5 pts
#   Gage Larvadain (WR): 3.5 pts
#   John FitzPatrick (TE): 3.4 pts
#   Josh Palmer (WR): 3.3 pts
#   Jonnu Smith (TE): 3.3 pts
#   Malik Davis (RB): 3.3 pts
#   Xavier Restrepo (WR): 3.3 pts
#   Tyler Lockett (WR): 3.2 pts
#   Evan Hull (RB): 3.2 pts
#   Noah Fant (TE): 3.2 pts
#   Ameer Abdullah (RB): 3.2 pts
#   Tyler Badie (RB): 3.2 pts
#   Jackson Hawes (TE): 3.1 pts
#   Luther Burden III (WR): 3.1 pts
#   Ben Sinnott (TE): 3.1 pts
#   Jack Stoll (TE): 3.0 pts
#   Trayveon Williams (RB): 3.0 pts
#   Kyle Juszczyk (RB): 3.0 pts
#   Luke Schoonmaker (TE): 3.0 pts
#   Foster Moreau (TE): 3.0 pts
#   Jaylin Noel (WR): 2.9 pts
#   Ray Davis (RB): 2.9 pts
#   Jeremy Ruckert (TE): 2.9 pts
#   Devontez Walker (WR): 2.9 pts
#   Jimmy Horn Jr. (WR): 2.9 pts
#   Ja'Tavion Sanders (TE): 2.9 pts
#   Ollie Gordon II (RB): 2.9 pts
#   DeAndre Hopkins (WR): 2.8 pts
#   Drew Sample (TE): 2.8 pts
#   Austin Hooper (TE): 2.8 pts
#   Cade Stover (TE): 2.7 pts
#   Charlie Woerner (TE): 2.7 pts
#   Charlie Kolar (TE): 2.7 pts
#   Rasheen Ali (RB): 2.7 pts
#   Dylan Drummond (WR): 2.6 pts
#   Marquez Valdes-Scantling (WR): 2.6 pts
#   Cade Otton (TE): 2.6 pts
#   Brashard Smith (RB): 2.6 pts
#   Adam Thielen (WR): 2.5 pts
#   Kendrick Bourne (WR): 2.5 pts
#   John Bates (TE): 2.5 pts
#   Jonathan Mingo (WR): 2.5 pts
#   Dyami Brown (WR): 2.4 pts
#   Chris Brooks (RB): 2.4 pts
#   Arian Smith (WR): 2.4 pts
#   Adam Trautman (TE): 2.4 pts
#   Tylan Wallace (WR): 2.4 pts
#   Jaylen Wright (RB): 2.4 pts
#   Anthony Firkser (TE): 2.4 pts
#   Shane Zylstra (TE): 2.3 pts
#   Chris Rodriguez Jr. (RB): 2.2 pts
#   Devin Duvernay (WR): 2.2 pts
#   Malik Heath (WR): 2.1 pts
#   Adam Prentice (RB): 2.1 pts
#   Dont'e Thornton Jr. (WR): 2.1 pts
#   Tyrell Shavers (WR): 2.1 pts
#   Durham Smythe (TE): 2.0 pts
#   Dylan Laube (RB): 2.0 pts
#   Sean Tucker (RB): 1.9 pts
#   Will Dissly (TE): 1.9 pts
#   Kaleb Johnson (RB): 1.9 pts
#   Elijah Moore (WR): 1.8 pts
#   Mo Alie-Cox (TE): 1.8 pts
#   Josiah Deguara (TE): 1.7 pts
#   Jalin Hyatt (WR): 1.7 pts
#   Corey Kiner (RB): 1.6 pts
#   Jawhar Jordan (RB): 1.6 pts
#   Audric Estime (RB): 1.6 pts
#   Tyquan Thornton (WR): 1.6 pts
#   Trent Sherfield (WR): 1.6 pts
#   Tim Patrick (WR): 1.6 pts
#   Patrick Ricard (RB): 1.5 pts
#   Ben Skowronek (WR): 1.5 pts
#   Tahj Brooks (RB): 1.5 pts
#   Will Shipley (RB): 1.4 pts
#   Stone Smartt (TE): 1.4 pts
#   Tai Felton (WR): 1.3 pts
#   Raheem Mostert (RB): 1.3 pts
#   Andrew Beck (RB): 1.3 pts
#   Ian Thomas (TE): 1.3 pts
#   Brevyn Spann-Ford (TE): 1.2 pts
#   Deven Thompkins (WR): 1.2 pts
#   Isaac Guerendo (RB): 1.1 pts
#   British Brooks (RB): 1.1 pts
#   Luke Farrell (TE): 1.1 pts
#   KeAndre Lambert-Smith (WR): 1.1 pts
#   Trevor Etienne (RB): 1.1 pts
#   Tyler Conklin (TE): 1.1 pts
#   Grant Calcaterra (TE): 1.0 pts
#   Tez Johnson (WR): 1.0 pts
#   Josh Oliver (TE): 1.0 pts
#   Brady Russell (RB): 1.0 pts
#   Eric Saubert (TE): 1.0 pts
#   Sterling Shepard (WR): 0.9 pts
#   Reggie Gilliam (RB): 0.9 pts
#   Kylen Granson (TE): 0.9 pts
#   Feleipe Franks (TE): 0.9 pts
#   Andrew Ogletree (TE): 0.9 pts
#   Connor Heyward (TE): 0.9 pts
#   Alec Ingold (RB): 0.9 pts
#   Blake Whiteheart (TE): 0.9 pts
#   David Martin-Robinson (TE): 0.9 pts
#   Nick Westbrook-Ikhine (WR): 0.8 pts
#   Julian Hill (TE): 0.8 pts
#   Brittain Brown (RB): 0.8 pts
#   Jaret Patterson (RB): 0.7 pts
#   Hassan Haskins (RB): 0.6 pts
#   Amar Johnson (RB): 0.6 pts
#   Ben Sims (TE): 0.6 pts
#   Kyle Williams (WR): 0.6 pts
#   Devin Culp (TE): 0.5 pts
#   Derius Davis (WR): 0.5 pts
#   Skyy Moore (WR): 0.5 pts
#   Jordan Watkins (WR): 0.5 pts
#   Tyler Goodson (RB): 0.5 pts
#   Kameron Johnson (WR): 0.5 pts
#   Julius Chestnut (RB): 0.5 pts
#   Zaire Mitchell-Paden (TE): 0.5 pts
#   Xavier Smith (WR): 0.5 pts
#   Tay Martin (WR): 0.5 pts
#   Zamir White (RB): 0.5 pts
#   Carter Runyon (TE): 0.5 pts
#   Darius Cooper (WR): 0.4 pts
#   Tyler Johnson (WR): 0.4 pts
#   Alex Bachman (WR): 0.4 pts
#   DJ Turner (WR): 0.4 pts
#   Zavier Scott (RB): 0.4 pts
#   Cedrick Wilson (WR): 0.4 pts
#   Xavier Gipson (WR): 0.4 pts
#   Jeff Wilson (RB): 0.4 pts
#   Nick Mullens (QB): 0.3 pts
#   Joe Milton III (QB): 0.3 pts
#   Jarrett Stidham (QB): 0.3 pts
#   Kedon Slovis (QB): 0.3 pts
#   Mason Rudolph (QB): 0.3 pts
#   Jameis Winston (QB): 0.3 pts
#   Andy Dalton (QB): 0.3 pts
#   Joe Flacco (QB): 0.3 pts
#   Tua Tagovailoa (QB): 0.3 pts
#   Max Brosmer (QB): 0.3 pts
#   Davis Mills (QB): 0.2 pts
#   Case Keenum (QB): 0.2 pts
#   Malik Willis (QB): 0.2 pts
#   Chris Oladokun (QB): 0.2 pts
#   Easton Stick (QB): 0.2 pts
#   Joshua Dobbs (QB): 0.2 pts
#   Mitchell Trubisky (QB): 0.2 pts
#   Riley Leonard (QB): 0.2 pts
#   Spencer Rattler (QB): 0.2 pts
#   Adrian Martinez (QB): 0.2 pts
#   Tyler Huntley (QB): 0.2 pts
#   Owen Wright (RB): 0.2 pts
#   Kalel Mullings (RB): 0.2 pts
#   Dillon Gabriel (QB): 0.2 pts
#   Travis Homer (RB): 0.0 pts
#   Christian Watson (WR): 0.0 pts
#   Roschon Johnson (RB): 0.0 pts
#   Tyson Bagent (QB): 0.0 pts
#   MarShawn Lloyd (RB): 0.0 pts
#   Savion Williams (WR): 0.0 pts
#   Jahdae Walker (WR): 0.0 pts
#   Josh Johnson (QB): 0.0 pts
#   Noah Brown (WR): 0.0 pts
#   A.J. Dillon (RB): 0.0 pts
#   Sam Howell (QB): 0.0 pts
#   Jayden Daniels (QB): 0.0 pts
#   Tanner McKee (QB): 0.0 pts
#   Cameron Latu (TE): 0.0 pts
#   Ja'Corey Brooks (WR): 0.0 pts
#   Davante Adams (WR): 0.0 pts
#   Jimmy Garoppolo (QB): 0.0 pts
#   Drew Lock (QB): 0.0 pts
#   Cody White (WR): 0.0 pts
#   Dareke Young (WR): 0.0 pts
#   Jake Bobo (WR): 0.0 pts
#   Jordan Whittington (WR): 0.0 pts
#   George Holani (RB): 0.0 pts
#   Tory Horton (WR): 0.0 pts
#   Robbie Ouzts (RB): 0.0 pts
#   Jalen Milroe (QB): 0.0 pts
#   Elijah Arroyo (TE): 0.0 pts
#   Jarquez Hunter (RB): 0.0 pts
#   Nick Kallerup (TE): 0.0 pts
#   Ricky White III (WR): 0.0 pts
#   Stetson Bennett (QB): 0.0 pts
#   Brennan Presley (WR): 0.0 pts
#   Cooper Rush (QB): 0.0 pts
#   Justice Hill (RB): 0.0 pts
#   D'Ernest Johnson (RB): 0.0 pts
#   Rashod Bateman (WR): 0.0 pts
#   Tommy DeVito (QB): 0.0 pts
#   Terrell Jennings (RB): 0.0 pts
#   LaJohntay Wester (WR): 0.0 pts
#   Jack Westover (RB): 0.0 pts
#   Efton Chism III (WR): 0.0 pts
#   Teddy Bridgewater (QB): 0.0 pts
#   David Moore (WR): 0.0 pts
#   Hunter Renfrow (WR): 0.0 pts
#   James Mitchell (TE): 0.0 pts
#   Payne Durham (TE): 0.0 pts
#   Brycen Tremayne (WR): 0.0 pts
#   Ryan Miller (WR): 0.0 pts
#   Mitchell Evans (TE): 0.0 pts
#   Josh Williams (RB): 0.0 pts
#   David Njoku (TE): 0.0 pts
#   Mecole Hardman (WR): 0.0 pts
#   Gabriel Davis (WR): 0.0 pts
#   Jerome Ford (RB): 0.0 pts
#   Bailey Zappe (QB): 0.0 pts
#   Jamari Thrash (WR): 0.0 pts
#   Dylan Sampson (RB): 0.0 pts
#   Raheim Sanders (RB): 0.0 pts
#   Cade McDonald (WR): 0.0 pts
#   Keleki Latu (TE): 0.0 pts
#   Nyheim Hines (RB): 0.0 pts
#   Trey Lance (QB): 0.0 pts
#   Jalen Tolbert (WR): 0.0 pts
#   Hunter Luepke (RB): 0.0 pts
#   Tucker Fisk (TE): 0.0 pts
#   Jaydon Blue (RB): 0.0 pts
#   Dalevon Campbell (WR): 0.0 pts
#   Jalen Cropper (WR): 0.0 pts
#   Tyrod Taylor (QB): 0.0 pts
#   Josh Reynolds (WR): 0.0 pts
#   Justin Fields (QB): 0.0 pts
#   Khalil Herbert (RB): 0.0 pts
#   Garrett Wilson (WR): 0.0 pts
#   Jelani Woods (TE): 0.0 pts
#   Trey Palmer (WR): 0.0 pts
#   Irvin Charles (WR): 0.0 pts
#   Braelon Allen (RB): 0.0 pts
#   Moliki Matavao (TE): 0.0 pts
#   Russell Wilson (QB): 0.0 pts
#   Chris Manhertz (TE): 0.0 pts
#   C.J. Ham (RB): 0.0 pts
#   Ray-Ray McCloud (WR): 0.0 pts
#   Gunner Olszewski (WR): 0.0 pts
#   Ty Chandler (RB): 0.0 pts
#   Eric Gray (RB): 0.0 pts
#   Cam Skattebo (RB): 0.0 pts
#   Beaux Collins (WR): 0.0 pts
#   Ben Yurosek (TE): 0.0 pts
#   Myles Price (WR): 0.0 pts
#   Thomas Fidone II (TE): 0.0 pts
#   Brandon Allen (QB): 0.0 pts
#   Clyde Edwards-Helaire (RB): 0.0 pts
#   Elijah Mitchell (RB): 0.0 pts
#   Jason Brownlee (WR): 0.0 pts
#   Jared Wiley (TE): 0.0 pts
#   Bryce Oliver (WR): 0.0 pts
#   Nikko Remigio (WR): 0.0 pts
#   Jalen Royals (WR): 0.0 pts
#   Johnny Mundt (TE): 0.0 pts
#   J.K. Dobbins (RB): 0.0 pts
#   Hunter Long (TE): 0.0 pts
#   Quintin Morris (TE): 0.0 pts
#   Nate Adkins (TE): 0.0 pts
#   Lucas Krull (TE): 0.0 pts
#   Bhayshul Tuten (RB): 0.0 pts
#   Pat Bryant (WR): 0.0 pts
#   Jamal Agnew (WR): 0.0 pts
#   Khadarel Hodge (WR): 0.0 pts
#   Kyler Murray (QB): 0.0 pts
#   Greg Dortch (WR): 0.0 pts
#   Simi Fehoko (WR): 0.0 pts
#   Teagan Quitoriano (TE): 0.0 pts
#   Zonovan Knight (RB): 0.0 pts
#   Trishton Jackson (WR): 0.0 pts
#   Xavier Weaver (WR): 0.0 pts
#   Casey Washington (WR): 0.0 pts
#   Travis Vokolek (TE): 0.0 pts
#   Nathan Carter (RB): 0.0 pts
#   Joe Mixon (RB): 0.0 pts
#   Justin Watson (WR): 0.0 pts
#   Irv Smith Jr. (TE): 0.0 pts
#   Braxton Berrios (WR): 0.0 pts
#   Jakob Johnson (RB): 0.0 pts
#   Harrison Bryant (TE): 0.0 pts
#   Kenny Pickett (QB): 0.0 pts
#   Tank Dell (WR): 0.0 pts
#   Aidan O'Connell (QB): 0.0 pts
#   Justin Shorter (TE): 0.0 pts
#   Jared Wayne (WR): 0.0 pts
#   Kyle Allen (QB): 0.0 pts
#   Scotty Miller (WR): 0.0 pts
#   Craig Reynolds (RB): 0.0 pts
#   Brock Wright (TE): 0.0 pts
#   Skylar Thompson (QB): 0.0 pts
#   Sam LaPorta (TE): 0.0 pts
#   Roman Wilson (WR): 0.0 pts
#   Sione Vaki (RB): 0.0 pts
#   Dominic Lovett (WR): 0.0 pts
#   Jacob Saylors (RB): 0.0 pts
#   Jackson Meeks (WR): 0.0 pts
#   Ke'Shawn Williams (WR): 0.0 pts
#   Hayden Rucci (TE): 0.0 pts
#   Zach Horton (TE): 0.0 pts
#   Tee Higgins (WR): 0.0 pts
#   Zach Wilson (QB): 0.0 pts
#   Dee Eskridge (WR): 0.0 pts
#   Tanner Conner (TE): 0.0 pts
#   Charlie Jones (WR): 0.0 pts
#   Jake Browning (QB): 0.0 pts
#   Erick All Jr. (TE): 0.0 pts
#   Cam Grandy (TE): 0.0 pts
#   Tahj Washington (WR): 0.0 pts
#   Kendall Milton (RB): 0.0 pts
#   Trent Taylor (WR): 0.0 pts
#   Ashton Dulin (WR): 0.0 pts
#   Brett Rypien (QB): 0.0 pts
#   Mac Jones (QB): 0.0 pts
#   Jake Tonges (TE): 0.0 pts
#   Anthony Richardson (QB): 0.0 pts
#   Will Mallory (TE): 0.0 pts
#   Anthony Gould (WR): 0.0 pts
#   Jacob Cowing (WR): 0.0 pts
#   DJ Giddens (RB): 0.0 pts
#   Jordan James (RB): 0.0 pts
#
# Total players scraped: 555
#
# Saving 555 projections to database...
# Using database: C:\Users\Samer Faizi\Documents\Claude Model\backend\data\databases\projections.db
# âœ“ Successfully saved to database!
# FanDuel complete
#
#
# ✅ FanDuel scraping complete!

# %% [markdown]
# ### 🚀 Run All Scrapers (Convenience Cell)
#
# Run this cell to execute all scrapers in sequence:

# %%
# 🚀 RUN ALL SCRAPERS
# ================================================
def run_all_scrapers():
    """Run all scrapers for the configured week."""
    print(f"{'='*70}")
    print(f"RUNNING ALL SCRAPERS - {WEEK}")
    print(f"{'='*70}\n")
    
    results = {}
    
    # 1. Sleeper
    print("💤 Sleeper...")
    try:
        with SleeperScraper(db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, season=SEASON)
        results['Sleeper'] = '✅'
    except Exception as e:
        results['Sleeper'] = f'❌ {str(e)[:40]}'
        print(f"  Error: {e}")
    
    # 2. ESPN
    print("\n🔴 ESPN...")
    try:
        with ESPNScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, season=SEASON)
        results['ESPN'] = '✅'
    except Exception as e:
        results['ESPN'] = f'❌ {str(e)[:40]}'
        print(f"  Error: {e}")
    
    # 3. FantasyPros
    print("\n📊 FantasyPros...")
    try:
        with FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK)
        results['FantasyPros'] = '✅'
    except Exception as e:
        results['FantasyPros'] = f'❌ {str(e)[:40]}'
        print(f"  Error: {e}")
    
    # 4. First Down Studio
    print("\n🎯 First Down Studio...")
    try:
        with FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, scoring="PPR")
        results['First Down'] = '✅'
    except Exception as e:
        results['First Down'] = f'❌ {str(e)[:40]}'
        print(f"  Error: {e}")
    
    # 5. FanDuel (subprocess)
    print("\n🔵 FanDuel...")
    try:
        temp_script = NOTEBOOK_DIR / "_temp_fanduel.py"
        script_content = f'''
import sys
sys.path.insert(0, r"{PROJECT_ROOT}")
from backend.scrapers.scraper_fanduel import FanDuelScraper
with FanDuelScraper(headless={HEADLESS}, db_path=r"{DB_PATH}") as scraper:
    scraper.scrape_and_save(week="{WEEK}")
'''
        temp_script.write_text(script_content, encoding='utf-8')
        result = subprocess.run([sys.executable, str(temp_script)], capture_output=True, text=True, cwd=str(PROJECT_ROOT), timeout=300)
        temp_script.unlink(missing_ok=True)
        results['FanDuel'] = '✅' if result.returncode == 0 else f'❌ Exit {result.returncode}'
    except Exception as e:
        results['FanDuel'] = f'❌ {str(e)[:40]}'
    
    # Summary
    print(f"\n{'='*70}")
    print("SCRAPING SUMMARY")
    print(f"{'='*70}")
    for source, status in results.items():
        print(f"  {source:<15} {status}")
    print(f"{'='*70}\n")

# Uncomment to run all:
# run_all_scrapers()

# %% [markdown]
# ## 📊 Database Status & Data Quality

# %%
def show_database_status():
    """Display comprehensive database status and data quality metrics."""
    with ProjectionsDB(db_path=DB_PATH) as db:
        all_projs = db.get_projections()
        
        print(f"{'='*70}")
        print(f"DATABASE STATUS")
        print(f"{'='*70}\n")
        print(f"Total records: {len(all_projs)}\n")
        
        # Count by source
        print(f"📊 Records by Source:")
        print("-" * 70)
        sources = {}
        for p in all_projs:
            source = p['source_website']
            sources[source] = sources.get(source, 0) + 1
        
        for source, count in sorted(sources.items()):
            print(f"  {source:<25} {count:>5} records")
        
        # Count by week
        print(f"\n📅 Records by Week:")
        print("-" * 70)
        weeks = {}
        for p in all_projs:
            week = p['week']
            weeks[week] = weeks.get(week, 0) + 1
        
        for week, count in sorted(weeks.items()):
            print(f"  {week:<25} {count:>5} records")
        
        # Team coverage (data quality check)
        print(f"\n🏈 Team Data Coverage (Quality Check):")
        print("-" * 70)
        for source in sorted(sources.keys()):
            source_projs = [p for p in all_projs if p['source_website'] == source]
            with_team = sum(1 for p in source_projs if p.get('team'))
            total = len(source_projs)
            pct = (with_team / total * 100) if total > 0 else 0
            status = "✅" if pct >= 95 else "⚠️" if pct >= 75 else "❌"
            print(f"  {source:<25} {with_team:>4}/{total:<4} ({pct:>5.1f}%) {status}")
        
        print(f"\n{'='*70}\n")

# Show status
show_database_status()
# Out:
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 11693
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#   espn.com                   1710 records
#   fanduel.com                3585 records
#   fantasypros.com            2768 records
#   firstdown.studio            746 records
#   sleeper.com                2884 records
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#   Week 10                    1625 records
#   Week 11                    1649 records
#   Week 12                    1519 records
#   Week 13                    1578 records
#   Week 14                    1424 records
#   Week 15                    1914 records
#   Week 16                    1984 records
#
# 🏈 Team Data Coverage (Quality Check):
# ----------------------------------------------------------------------
#   espn.com                  1710/1710 (100.0%) ✅
#   fanduel.com               3585/3585 (100.0%) ✅
#   fantasypros.com           2768/2768 (100.0%) ✅
#   firstdown.studio           746/746  (100.0%) ✅
#   sleeper.com               2884/2884 (100.0%) ✅
#
# ======================================================================

# %% [markdown]
# ---
#
# ## 🛠️ Utility Functions
#
# **Use these as needed for database management**

# %%
# ============================================================================
# UTILITY FUNCTIONS - Uncomment to use
# ============================================================================

def clear_week(week_name):
    """Delete all records from a specific week."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    cursor.execute("DELETE FROM projections WHERE week = ?", (week_name,))
    deleted = cursor.rowcount
    conn.commit()
    conn.close()
    print(f"✓ Deleted {deleted} records from {week_name}")

def clear_source(source_name, week=None):
    """Delete records from a specific source."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    if week:
        cursor.execute("DELETE FROM projections WHERE source_website = ? AND week = ?", (source_name, week))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} for {week}")
    else:
        cursor.execute("DELETE FROM projections WHERE source_website = ?", (source_name,))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} (all weeks)")
    conn.commit()
    conn.close()

def clear_entire_database():
    """⚠️ DELETE ALL RECORDS - requires confirmation."""
    confirm = input("⚠️  Type 'DELETE ALL' to confirm: ")
    if confirm == "DELETE ALL":
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("DELETE FROM projections")
        conn.commit()
        deleted = cursor.rowcount
        conn.close()
        print(f"\n✓ Deleted {deleted} records from database")
    else:
        print("\n✗ Cancelled")

def show_week_source_matrix():
    """Display a matrix showing record counts by week and source."""
    import pandas as pd
    conn = sqlite3.connect(DB_PATH)
    query = """
        SELECT week, source_website, COUNT(*) as count
        FROM projections
        GROUP BY week, source_website
        ORDER BY week, source_website
    """
    df = pd.read_sql_query(query, conn)
    conn.close()
    
    if len(df) == 0:
        print("No data in database")
        return
    
    pivot = df.pivot(index='source_website', columns='week', values='count')
    pivot = pivot.fillna(0).astype(int)
    
    print(f"\n{'='*70}")
    print("WEEK × SOURCE MATRIX")
    print("="*70)
    print(pivot.to_string())
    print("="*70 + "\n")

def run_single_scraper(scraper_name):
    """Run a specific scraper by name."""
    scrapers = {
        'sleeper': lambda: SleeperScraper(db_path=DB_PATH),
        'espn': lambda: ESPNScraper(headless=HEADLESS, db_path=DB_PATH),
        'fantasypros': lambda: FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH),
        'firstdown': lambda: FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH)
    }
    
    name_lower = scraper_name.lower()
    if name_lower not in scrapers:
        print(f"Unknown scraper: {scraper_name}")
        print(f"Available: {', '.join(scrapers.keys())}")
        return
    
    print(f"Running {scraper_name}...")
    try:
        with scrapers[name_lower]() as scraper:
            if name_lower == 'sleeper':
                scraper.scrape_and_save(week=WEEK, season=SEASON)
            elif name_lower == 'espn':
                scraper.scrape_and_save(week=WEEK, season=SEASON)
            elif name_lower == 'firstdown':
                scraper.scrape_and_save(week=WEEK, scoring="PPR")
            else:
                scraper.scrape_and_save(week=WEEK)
        print(f"✓ {scraper_name} complete")
    except Exception as e:
        print(f"✗ Error: {e}")

# Uncomment to use:
# clear_week("Week 10")
# clear_source("fantasypros.com", WEEK)
# clear_entire_database()
show_week_source_matrix()
# run_single_scraper("sleeper")

print("✅ Utility functions loaded. Uncomment above to use.")
# Out:
# ======================================================================
# WEEK × SOURCE MATRIX
# ======================================================================
# week              Week 10  Week 11  Week 12  Week 13  Week 14  Week 15  Week 16
# source_website
# espn.com              232      240      234      246      216      274      268
# fanduel.com           473      508      471      546      480      552      555
# fantasypros.com       388      321      437      362      347      449      464
# firstdown.studio      161      176        0        0        0      207      202
# sleeper.com           371      404      377      424      381      432      495
# ======================================================================
#
# ✅ Utility functions loaded. Uncomment above to use.

# %% [markdown]
# ---
#
# ## 📚 Quick Reference
#
# ### Weekly Workflow:
# 1. Update `WEEK` and `SEASON` in cell 2
# 2. **Kernel → Restart & Run All**
# 3. Wait for all scrapers to complete (~5-10 minutes)
# 4. Check database status for data quality
#
# ### Available Functions:
# - `run_all_scrapers()` - Scrape all sources *(runs automatically)*
# - `show_database_status()` - View database contents *(runs automatically)*
# - `run_single_scraper(name)` - Run one scraper
# - `clear_week(week)` - Delete all data for a week
# - `clear_source(source, week)` - Delete data from a source
# - `show_week_source_matrix()` - See week×source grid
# - `clear_entire_database()` - Delete everything ⚠️
#
# ### Source Names:
# - `"fanduel.com"`
# - `"sleeper.com"`
# - `"espn.com"`
# - `"fantasypros.com"`
# - `"firstdown.studio"`
#
# ### Tips:
# - FanDuel uses Playwright and runs in a subprocess (this is normal)
# - Set `HEADLESS = False` to see browser windows for debugging
# - Scrapers typically take 1-3 minutes each
# - Check "Team Data Coverage" to ensure quality (should be ≥95%)
#
# ---
#
# **✅ Ready to use! Update WEEK and run all cells.**
