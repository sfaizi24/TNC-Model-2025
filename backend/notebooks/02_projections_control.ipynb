# %% [markdown]
# # 🎮 Fantasy Football Projections - Control Panel
#
# **Scrape and manage player projections from multiple sources.**
#
# ## Quick Start:
# 1. **Update `WEEK` and `SEASON`** in the configuration
# 2. **Run All Cells** to scrape all sources
# 3. View database status and data quality metrics
#
# ## Sources:
# - 🔵 FanDuel
# - 💤 Sleeper
# - 🔴 ESPN
# - 📊 FantasyPros
# - 🎯 First Down Studio
#
# ---

# %% [markdown]
# ## 📦 Setup & Configuration

# %%
import os
import sqlite3
import subprocess
import sys
from datetime import datetime
from pathlib import Path

# Use absolute paths (this notebook is at backend/notebooks/)
NOTEBOOK_DIR = Path(r"C:\Users\Samer Faizi\Documents\Claude Model\backend\notebooks")
BACKEND_DIR = NOTEBOOK_DIR.parent
PROJECT_ROOT = BACKEND_DIR.parent
SCRAPERS_DIR = BACKEND_DIR / "scrapers"

# Add project root to path for package imports
sys.path.insert(0, str(PROJECT_ROOT))

# Import from the backend.scrapers package (uses relative imports internally)
from backend.scrapers.database import ProjectionsDB
from backend.scrapers.scraper_sleeper import SleeperScraper
from backend.scrapers.scraper_espn import ESPNScraper
from backend.scrapers.scraper_fantasypros import FantasyProsScraper
from backend.scrapers.scraper_firstdown import FirstDownStudioScraper

# ==================== CONFIGURATION ====================
# Update these for each scraping session

WEEK = "Week 14"  # ⬅️ UPDATE THIS!
SEASON = "2025"
HEADLESS = True  # Set to False to see browser windows

# Database path
DB_PATH = str(BACKEND_DIR / "data" / "databases" / "projections.db")

# Verify database exists
if not Path(DB_PATH).exists():
    print(f"⚠️ WARNING: Database not found at: {DB_PATH}")
else:
    print(f"✅ Database found: {DB_PATH}")

print("✅ Setup Complete!")
print(f"📅 {WEEK}, Season {SEASON}")
print(f"👁️  Headless mode: {HEADLESS}")
print("\n" + "="*70 + "\n")
# Out:
# ✅ Database found: C:\Users\Samer Faizi\Documents\Claude Model\backend\data\databases\projections.db
# ✅ Setup Complete!
# 📅 Week 14, Season 2025
# 👁️  Headless mode: True
#
# ======================================================================

# %% [markdown]
# ## 🤖 Individual Scrapers
#
# Run each scraper individually for easier debugging. Each cell is independent.

# %%
# 💤 SLEEPER SCRAPER (API-based, fast & reliable)
# ================================================
print(f"{'='*70}")
print(f"💤 SLEEPER SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    with SleeperScraper(db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK, season=SEASON)
    print("\n✅ Sleeper scraping complete!")
except Exception as e:
    print(f"\n❌ Sleeper error: {e}")

# %%
# DELETE incorrect ESPN data for Week 14
import sqlite3

conn = sqlite3.connect(DB_PATH)
cursor = conn.cursor()

# See what we're deleting
cursor.execute("""
    SELECT COUNT(*) FROM projections 
    WHERE source_website = 'espn.com' AND week = 'Week 14'
""")
count = cursor.fetchone()[0]
print(f"Found {count} ESPN Week 14 records to delete")

# Delete them
cursor.execute("""
    DELETE FROM projections 
    WHERE source_website = 'espn.com' AND week = 'Week 14'
""")
conn.commit()
print(f"✅ Deleted {cursor.rowcount} ESPN records for Week 14")
conn.close()
# Out:
# Found 393 ESPN Week 14 records to delete
# ✅ Deleted 393 ESPN records for Week 14

# %%
# 🔴 ESPN SCRAPER
# ================================================
# Set HEADLESS = False in setup cell to debug visually
print(f"{'='*70}")
print(f"🔴 ESPN SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    with ESPNScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK, season=SEASON)
    print("\n✅ ESPN scraping complete!")
except Exception as e:
    print(f"\n❌ ESPN error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# 🔴 ESPN SCRAPER - Week 14
# ======================================================================
#
#
# Fetching ESPN projections for Week 14...
# Navigating to https://fantasy.espn.com/football/players/projections...
# Clicking 'Sortable Projections' view...
#   ✓ Switched to Sortable Projections view
# Setting scoring to Points PPR...
#   ✓ Set to Points PPR
# Setting to This Week projections...
#   ✓ Set to This Week
#
# Scraping 6 positions (up to 50 players each)...
#
#   [QB] Loading fresh page and applying filter...
#     → Switched to Sortable Projections
#     → Filter attempt 1/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Filter attempt 2/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Filter attempt 3/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Trying Full Projections workaround...
#     → Filter attempt 4/5...
#     ✓ Filter verified: ['QB', 'QB', 'QB']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. Josh Allen (BUF): 24.0 pts
#         2. Dak Prescott (DAL): 20.3 pts
#         3. Jalen Hurts (PHI): 19.4 pts
#         4. Jared Goff (DET): 18.5 pts
#         5. Matthew Stafford (LAR): 18.5 pts
#         6. Joe Burrow (CIN): 18.0 pts
#         7. Patrick Mahomes (KC): 17.9 pts
#         8. Bo Nix (DEN): 17.8 pts
#         9. Jordan Love (GB): 17.6 pts
#        10. Daniel Jones (IND): 17.2 pts
#        11. Caleb Williams (CHI): 16.9 pts
#        12. Lamar Jackson (BAL): 16.8 pts
#        13. C.J. Stroud (HOU): 16.7 pts
#        14. Marcus Mariota (WAS): 16.4 pts
#        15. Justin Herbert (LAC): 16.2 pts
#        16. Trevor Lawrence (JAX): 16.1 pts
#        17. Tyrod Taylor (NYJ): 15.9 pts
#        18. Baker Mayfield (TB): 15.4 pts
#        19. Jacoby Brissett (ARI): 15.4 pts
#        20. J.J. McCarthy (MIN): 14.6 pts
#        21. Sam Darnold (SEA): 14.3 pts
#        22. Tyler Shough (NO): 14.0 pts
#        23. Aaron Rodgers (PIT): 12.2 pts
#        24. Shedeur Sanders (CLE): 12.0 pts
#        25. Tua Tagovailoa (MIA): 11.9 pts
#        26. Cam Ward (TEN): 10.9 pts
#        27. Kirk Cousins (ATL): 10.6 pts
#        28. Geno Smith (LV): 10.0 pts
#        29. Jayden Daniels (WAS): 0.0 pts
#        30. Kyler Murray (ARI): 0.0 pts
#        31. Justin Fields (NYJ): 0.0 pts
#        32. Joe Flacco (CIN): 0.0 pts
#        33. Michael Penix Jr. (ATL): 0.0 pts
#        34. Davis Mills (HOU): 0.0 pts
#        35. Carson Wentz (MIN): 0.0 pts
#        36. Mason Rudolph (PIT): 0.0 pts
#        37. Dillon Gabriel (CLE): 0.0 pts
#        38. Spencer Rattler (NO): 0.0 pts
#        39. Max Brosmer (MIN): 0.0 pts
#        40. Anthony Richardson Sr. (IND): 0.0 pts
#        41. Jake Browning (CIN): 0.0 pts
#        42. Jalen Milroe (SEA): 0.0 pts
#     ✓ Total 42 QB projections
#     ✓ Scraped 42 QB projections
#
#   [RB] Loading fresh page and applying filter...
#     → Switched to Sortable Projections
#     → Filter attempt 1/5...
#     ✓ Filter verified: ['QB', 'RB', 'RB']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. Jahmyr Gibbs (DET): 23.7 pts
#         2. De'Von Achane (MIA): 23.5 pts
#         3. Josh Jacobs (GB): 21.3 pts
#         4. James Cook (BUF): 21.3 pts
#         5. Jonathan Taylor (IND): 20.9 pts
#         6. Bijan Robinson (ATL): 20.0 pts
#         7. Breece Hall (NYJ): 16.6 pts
#         8. Derrick Henry (BAL): 16.4 pts
#         9. Bucky Irving (TB): 16.4 pts
#        10. Ashton Jeanty (LV): 15.9 pts
#        11. Quinshon Judkins (CLE): 14.8 pts
#        12. Saquon Barkley (PHI): 14.5 pts
#        13. Chase Brown (CIN): 14.3 pts
#        14. Javonte Williams (DAL): 14.1 pts
#     ✓ Total 14 RB projections
#     ✓ Scraped 14 RB projections
#
#   [WR] Loading fresh page and applying filter...
#     → Switched to Sortable Projections
#     → Filter attempt 1/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Filter attempt 2/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Filter attempt 3/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Trying Full Projections workaround...
#     → Filter attempt 4/5...
#     ✓ Filter verified: ['WR', 'WR', 'WR']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. Jaxon Smith-Njigba (SEA): 20.9 pts
#         2. Puka Nacua (LAR): 20.9 pts
#         3. CeeDee Lamb (DAL): 19.5 pts
#         4. Ja'Marr Chase (CIN): 19.1 pts
#         5. George Pickens (DAL): 18.9 pts
#         6. Rashee Rice (KC): 17.1 pts
#         7. Nico Collins (HOU): 16.9 pts
#         8. Davante Adams (LAR): 16.7 pts
#         9. A.J. Brown (PHI): 16.3 pts
#        10. Drake London (ATL): 16.1 pts
#        11. Jameson Williams (DET): 16.0 pts
#        12. Justin Jefferson (MIN): 15.2 pts
#        13. Chris Olave (NO): 15.0 pts
#        14. Jaylen Waddle (MIA): 14.0 pts
#        15. Marvin Harrison Jr. (ARI): 13.8 pts
#        16. Emeka Egbuka (TB): 13.6 pts
#        17. DeVonta Smith (PHI): 13.5 pts
#        18. Tee Higgins (CIN): 13.3 pts
#        19. Rome Odunze (CHI): 13.0 pts
#        20. Michael Pittman Jr. (IND): 12.8 pts
#        21. Zay Flowers (BAL): 12.3 pts
#        22. Ladd McConkey (LAC): 12.3 pts
#        23. DK Metcalf (PIT): 12.2 pts
#        24. Khalil Shakir (BUF): 12.1 pts
#        25. Terry McLaurin (WAS): 11.9 pts
#        26. Christian Watson (GB): 11.8 pts
#        27. Courtland Sutton (DEN): 11.8 pts
#        28. Michael Wilson (ARI): 11.7 pts
#        29. Deebo Samuel (WAS): 11.2 pts
#        30. Keenan Allen (LAC): 11.0 pts
#        31. Chris Godwin Jr. (TB): 11.0 pts
#        32. Brian Thomas Jr. (JAX): 10.9 pts
#        33. Jakobi Meyers (JAX): 10.9 pts
#        34. Adonai Mitchell (NYJ): 10.8 pts
#        35. Alec Pierce (IND): 10.7 pts
#        36. John Metchie (NYJ): 10.5 pts
#        37. Jordan Addison (MIN): 10.4 pts
#        38. Romeo Doubs (GB): 10.4 pts
#        39. Jayden Higgins (HOU): 10.1 pts
#        40. Xavier Worthy (KC): 10.1 pts
#        41. Devaughn Vele (NO): 9.7 pts
#        42. Troy Franklin (DEN): 9.5 pts
#        43. Chimere Dike (TEN): 9.5 pts
#        44. Josh Downs (IND): 9.5 pts
#        45. Tre Tucker (LV): 9.3 pts
#        46. Kalif Raymond (DET): 9.2 pts
#        47. DJ Moore (CHI): 9.1 pts
#        48. Jerry Jeudy (CLE): 8.9 pts
#        49. Quentin Johnston (LAC): 8.7 pts
#        50. Cooper Kupp (SEA): 8.6 pts
#     ✓ Total 50 WR projections
#     ✓ Scraped 50 WR projections
#
#   [TE] Loading fresh page and applying filter...
#     → Switched to Sortable Projections
#     → Filter attempt 1/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Filter attempt 2/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Filter attempt 3/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Trying Full Projections workaround...
#     → Filter attempt 4/5...
#     ✓ Filter verified: ['TE', 'TE', 'TE']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. Trey McBride (ARI): 15.5 pts
#         2. Brock Bowers (LV): 13.2 pts
#         3. Tyler Warren (IND): 12.9 pts
#         4. Jake Ferguson (DAL): 11.0 pts
#         5. Travis Kelce (KC): 10.1 pts
#         6. Dalton Kincaid (BUF): 10.0 pts
#         7. Juwan Johnson (NO): 9.7 pts
#         8. Dalton Schultz (HOU): 9.7 pts
#         9. Kyle Pitts Sr. (ATL): 9.6 pts
#        10. Harold Fannin Jr. (CLE): 9.6 pts
#        11. Zach Ertz (WAS): 9.4 pts
#        12. Dallas Goedert (PHI): 9.4 pts
#        13. Oronde Gadsden (LAC): 9.3 pts
#        14. AJ Barner (SEA): 9.1 pts
#        15. Mark Andrews (BAL): 9.1 pts
#        16. Brenton Strange (JAX): 9.0 pts
#        17. T.J. Hockenson (MIN): 8.7 pts
#        18. Colston Loveland (CHI): 8.5 pts
#        19. Colby Parkinson (LAR): 8.5 pts
#        20. Mason Taylor (NYJ): 8.4 pts
#        21. Evan Engram (DEN): 7.8 pts
#        22. Isaiah Likely (BAL): 7.4 pts
#        23. Darren Waller (MIA): 7.3 pts
#        24. Gunnar Helm (TEN): 7.2 pts
#        25. Ross Dwelley (DET): 6.9 pts
#        26. Cade Otton (TB): 6.5 pts
#        27. Darnell Washington (PIT): 6.3 pts
#        28. Chig Okonkwo (TEN): 6.3 pts
#        29. Mike Gesicki (CIN): 6.1 pts
#        30. Michael Mayer (LV): 5.6 pts
#        31. Jonnu Smith (PIT): 5.0 pts
#        32. Pat Freiermuth (PIT): 4.5 pts
#        33. Cade Stover (HOU): 4.5 pts
#        34. David Njoku (CLE): 4.3 pts
#        35. Cole Kmet (CHI): 3.7 pts
#        36. Elijah Arroyo (SEA): 3.6 pts
#        37. Anthony Firkser (DET): 3.6 pts
#        38. Taysom Hill (NO): 3.5 pts
#        39. Noah Gray (KC): 3.4 pts
#        40. Dawson Knox (BUF): 3.4 pts
#        41. Davis Allen (LAR): 3.2 pts
#        42. Luke Musgrave (GB): 3.1 pts
#        43. Noah Fant (CIN): 3.0 pts
#        44. Foster Moreau (NO): 3.0 pts
#        45. Elijah Higgins (ARI): 2.9 pts
#        46. Adam Trautman (DEN): 2.9 pts
#        47. Josh Oliver (MIN): 2.9 pts
#        48. Drew Sample (CIN): 2.8 pts
#        49. Jeremy Ruckert (NYJ): 2.8 pts
#        50. Josh Whyle (GB): 2.8 pts
#     ✓ Total 50 TE projections
#     ✓ Scraped 50 TE projections
#
#   [K] Loading fresh page and applying filter...
#     → Switched to Sortable Projections
#     → Filter attempt 1/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Filter attempt 2/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Filter attempt 3/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Trying Full Projections workaround...
#     → Filter attempt 4/5...
#     ✓ Filter verified: ['K', 'K', 'K']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. Jake Bates (DET): 9.0 pts
#         2. Brandon Aubrey (DAL): 8.9 pts
#         3. Matt Prater (BUF): 8.8 pts
#         4. Harrison Mevis (LAR): 8.5 pts
#         5. Brandon McManus (GB): 8.3 pts
#         6. Jason Myers (SEA): 8.3 pts
#         7. Cameron Dicker (LAC): 8.3 pts
#         8. Harrison Butker (KC): 8.2 pts
#         9. Tyler Loop (BAL): 8.1 pts
#        10. Wil Lutz (DEN): 8.1 pts
#        11. Evan McPherson (CIN): 8.0 pts
#        12. Cairo Santos (CHI): 8.0 pts
#        13. Chase McLaughlin (TB): 8.0 pts
#        14. Cam Little (JAX): 8.0 pts
#        15. Riley Patterson (MIA): 8.0 pts
#        16. Chris Boswell (PIT): 7.9 pts
#        17. Nick Folk (NYJ): 7.7 pts
#        18. Ka'imi Fairbairn (HOU): 7.7 pts
#        19. Jake Elliott (PHI): 7.6 pts
#        20. Zane Gonzalez (ATL): 7.6 pts
#        21. Will Reichard (MIN): 7.6 pts
#        22. Andre Szmyt (CLE): 7.4 pts
#        23. Jake Moody (WAS): 7.1 pts
#        24. Chad Ryland (ARI): 7.1 pts
#        25. Charlie Smyth (NO): 6.9 pts
#        26. Joey Slye (TEN): 6.7 pts
#        27. Daniel Carlson (LV): 6.6 pts
#        28. Tyler Bass (BUF): 0.0 pts
#        29. Jason Sanders (MIA): 0.0 pts
#        30. Spencer Shrader (IND): 0.0 pts
#        31. Lucas Havrisik (GB): 0.0 pts
#        32. Blake Grupe (NO): 0.0 pts
#     ✓ Total 32 K projections
#     ✓ Scraped 32 K projections
#
#   [D/ST] Loading fresh page and applying filter...
#     → Switched to Sortable Projections
#     → Filter attempt 1/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Filter attempt 2/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Filter attempt 3/5...
#     ✗ Wrong positions: ['QB', 'RB', 'RB']
#     → Trying Full Projections workaround...
#     → Filter attempt 4/5...
#     ✓ Filter verified: ['D/ST', 'D/ST', 'D/ST']
#     Found 3 tables
#     Found 32 player rows
#     Found 32 FPTS rows
#         1. Broncos Defense (DEN): 9.0 pts
#         2. Browns Defense (CLE): 6.8 pts
#         3. Rams Defense (LAR): 6.8 pts
#         4. Titans Defense (TEN): 6.4 pts
#         5. Commanders Defense (WAS): 6.3 pts
#         6. Seahawks Defense (SEA): 6.1 pts
#         7. Colts Defense (IND): 6.1 pts
#         8. Dolphins Defense (MIA): 6.0 pts
#         9. Ravens Defense (BAL): 5.9 pts
#        10. Buccaneers Defense (TB): 5.9 pts
#        11. Eagles Defense (PHI): 5.8 pts
#        12. Vikings Defense (MIN): 5.5 pts
#        13. Jets Defense (NYJ): 5.3 pts
#        14. Chargers Defense (LAC): 5.3 pts
#        15. Bills Defense (BUF): 4.9 pts
#        16. Texans Defense (HOU): 4.8 pts
#        17. Chiefs Defense (KC): 4.7 pts
#        18. Steelers Defense (PIT): 4.7 pts
#        19. Saints Defense (NO): 4.3 pts
#        20. Jaguars Defense (JAX): 4.3 pts
#        21. Falcons Defense (ATL): 4.1 pts
#        22. Lions Defense (DET): 3.5 pts
#        23. Packers Defense (GB): 3.4 pts
#        24. Raiders Defense (LV): 3.3 pts
#        25. Cowboys Defense (DAL): 3.0 pts
#        26. Bengals Defense (CIN): 2.9 pts
#        27. Cardinals Defense (ARI): 2.7 pts
#        28. Bears Defense (CHI): 2.6 pts
#     ✓ Total 28 D/ST projections
#     ✓ Scraped 28 D/ST projections
#
# ✓ Total players with valid projections: 216
#
# Saving 216 projections to database...
# ✓ Successfully saved to database!
#
# ✅ ESPN scraping complete!

# %%
# 📊 FANTASYPROS SCRAPER  
# ================================================
# Set HEADLESS = False in setup cell to debug visually
print(f"{'='*70}")
print(f"📊 FANTASYPROS SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    with FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK)
    print("\n✅ FantasyPros scraping complete!")
except Exception as e:
    print(f"\n❌ FantasyPros error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# 📊 FANTASYPROS SCRAPER - Week 14
# ======================================================================
#
#
# ============================================================
# FANTASYPROS SCRAPER - Week 14
# ============================================================
#
#   [QB] Loading https://www.fantasypros.com/nfl/rankings/qb.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 36 rows
#     → Parsing players...
#         1. Josh Allen (BUF): 24.6
#         2. Dak Prescott (DAL): 21.3
#         3. Jalen Hurts (PHI): 20.3
#         4. Matthew Stafford (LAR): 19.0
#         5. Jared Goff (DET): 18.7
#         6. Joe Burrow (CIN): 18.5
#         7. Patrick Mahomes II (KC): 18.3
#         8. Lamar Jackson (BAL): 18.2
#         9. Baker Mayfield (TB): 18.0
#        10. Jacoby Brissett (ARI): 17.8
#        11. Jordan Love (GB): 17.6
#        12. Bo Nix (DEN): 17.3
#        13. Justin Herbert (LAC): 17.0
#        14. Daniel Jones (IND): 16.6
#        15. Sam Darnold (SEA): 16.3
#        16. Trevor Lawrence (JAC): 15.9
#        17. Caleb Williams (CHI): 15.6
#        18. Tyrod Taylor (NYJ): 15.3
#        19. Tyler Shough (NO): 14.9
#        20. Marcus Mariota (WAS): 14.6
#        21. C.J. Stroud (HOU): 14.1
#        22. Tua Tagovailoa (MIA): 13.6
#        23. Aaron Rodgers (PIT): 13.1
#        24. Shedeur Sanders (CLE): 12.5
#        25. J.J. McCarthy (MIN): 12.0
#        26. Cam Ward (TEN): 11.4
#        27. Kirk Cousins (ATL): 10.2
#        28. Geno Smith (LV): 9.3
#        29. Jayden Daniels (WAS): 6.8
#        30. Max Brosmer (MIN): 0.6
#        31. Mason Rudolph (PIT): 0.5
#        32. Davis Mills (HOU): 0.5
#        33. Teddy Bridgewater (TB): 0.5
#        34. Justin Fields (NYJ): 0.5
#        35. Joe Flacco (CIN): 0.5
#     ✓ QB: 35 players scraped
#
#   [RB] Loading https://www.fantasypros.com/nfl/rankings/ppr-rb.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 85 rows
#     → Parsing players...
#         1. De'Von Achane (MIA): 22.5
#         2. Jahmyr Gibbs (DET): 21.1
#         3. Jonathan Taylor (IND): 20.8
#         4. James Cook III (BUF): 19.6
#         5. Bijan Robinson (ATL): 19.6
#         6. Chase Brown (CIN): 19.2
#         7. Bucky Irving (TB): 15.6
#         8. Breece Hall (NYJ): 15.5
#         9. Josh Jacobs (GB): 15.2
#        10. Kyren Williams (LAR): 15.1
#        11. Derrick Henry (BAL): 14.9
#        12. Quinshon Judkins (CLE): 14.7
#        13. RJ Harvey (DEN): 14.7
#        14. Javonte Williams (DAL): 14.4
#        15. Saquon Barkley (PHI): 14.1
#        16. Jaylen Warren (PIT): 14.0
#        17. Travis Etienne Jr. (JAC): 12.2
#        18. Ashton Jeanty (LV): 12.1
#        19. Kenneth Walker III (SEA): 12.1
#        20. D'Andre Swift (CHI): 11.4
#        21. Woody Marks (HOU): 10.8
#        22. Kareem Hunt (KC): 10.7
#        23. Jordan Mason (MIN): 10.5
#        24. Kyle Monangai (CHI): 10.2
#        25. Devin Neal (NO): 10.2
#        26. Kimani Vidal (LAC): 9.3
#        27. Kenneth Gainwell (PIT): 9.2
#        28. Zach Charbonnet (SEA): 9.0
#        29. David Montgomery (DET): 9.0
#        30. Zonovan Knight (ARI): 8.8
#        31. Chris Rodriguez Jr. (WAS): 8.7
#        32. Blake Corum (LAR): 7.9
#        33. Bhayshul Tuten (JAC): 7.9
#        34. Tyjae Spears (TEN): 7.6
#        35. Tony Pollard (TEN): 7.6
#        36. Omarion Hampton (LAC): 7.3
#        37. Isiah Pacheco (KC): 7.2
#        38. Tyler Allgeier (ATL): 7.1
#        39. Samaje Perine (CIN): 6.6
#        40. Aaron Jones Sr. (MIN): 6.6
#        41. Jaleel McLaughlin (DEN): 6.2
#        42. Michael Carter (ARI): 6.2
#        43. Emanuel Wilson (GB): 6.2
#        44. Rachaad White (TB): 5.9
#        45. Ty Johnson (BUF): 5.7
#        46. Sean Tucker (TB): 5.5
#        47. Keaton Mitchell (BAL): 5.3
#        48. Jeremy McNichols (WAS): 5.2
#        49. Ollie Gordon II (MIA): 4.9
#        50. Dylan Sampson (CLE): 4.9
#        51. Brashard Smith (KC): 4.7
#        52. Ray Davis (BUF): 4.6
#        53. Nick Chubb (HOU): 4.5
#        54. Jacory Croskey-Merritt (WAS): 3.7
#        55. Isaiah Davis (NYJ): 3.4
#        56. Malik Davis (DAL): 3.1
#        57. Jerome Ford (CLE): 3.0
#        58. Chris Brooks (GB): 2.9
#        59. Raheem Mostert (LV): 2.9
#        60. Tank Bigsby (PHI): 2.8
#        61. Kaleb Johnson (PIT): 2.4
#        62. Tyler Badie (DEN): 2.4
#        63. LeQuint Allen Jr. (JAC): 2.0
#        64. Zavier Scott (MIN): 1.8
#        65. Will Shipley (PHI): 1.8
#        66. Trey Benson (ARI): 1.5
#        67. Jaylen Wright (MIA): 1.5
#        68. Evan Hull (NO): 1.4
#        69. Jaydon Blue (DAL): 1.4
#        70. Alvin Kamara (NO): 1.3
#        71. Dylan Laube (LV): 1.2
#        72. Dare Ogunbowale (HOU): 1.2
#        73. Clyde Edwards-Helaire (KC): 1.1
#        74. Rasheen Ali (BAL): 1.1
#        75. Ameer Abdullah (IND): 0.9
#        76. Audric Estime (NO): 0.9
#        77. Emari Demercado (ARI): 0.9
#        78. Alec Ingold (MIA): 0.8
#        79. Trey Sermon (PIT): 0.8
#        80. C.J. Ham (MIN): 0.8
#        81. DJ Giddens (IND): 0.8
#        82. Jaret Patterson (LAC): 0.7
#        83. Chase Edmonds (WAS): 0.6
#     ✓ RB: 83 players scraped
#
#   [WR] Loading https://www.fantasypros.com/nfl/rankings/ppr-wr.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 115 rows
#     → Parsing players...
#         1. Jaxon Smith-Njigba (SEA): 20.6
#         2. CeeDee Lamb (DAL): 19.9
#         3. Ja'Marr Chase (CIN): 18.3
#         4. Rashee Rice (KC): 18.2
#         5. George Pickens (DAL): 18.2
#         6. Puka Nacua (LAR): 16.7
#         7. Davante Adams (LAR): 16.4
#         8. Jameson Williams (DET): 15.9
#         9. Chris Olave (NO): 15.8
#        10. Nico Collins (HOU): 15.2
#        11. Jaylen Waddle (MIA): 15.1
#        12. A.J. Brown (PHI): 14.5
#        13. Ladd McConkey (LAC): 13.7
#        14. Emeka Egbuka (TB): 13.4
#        15. Zay Flowers (BAL): 12.8
#        16. Justin Jefferson (MIN): 12.8
#        17. DeVonta Smith (PHI): 12.7
#        18. Michael Pittman Jr. (IND): 12.7
#        19. Terry McLaurin (WAS): 12.6
#        20. Khalil Shakir (BUF): 12.4
#        21. Christian Watson (GB): 12.3
#        22. Jakobi Meyers (JAC): 11.7
#        23. Courtland Sutton (DEN): 11.6
#        24. Michael Wilson (ARI): 11.6
#        25. Troy Franklin (DEN): 11.5
#        26. Deebo Samuel Sr. (WAS): 11.5
#        27. Rome Odunze (CHI): 11.4
#        28. DK Metcalf (PIT): 11.3
#        29. Marvin Harrison Jr. (ARI): 11.3
#        30. Chris Godwin Jr. (TB): 11.2
#        31. Alec Pierce (IND): 10.6
#        32. Brian Thomas Jr. (JAC): 10.4
#        33. Quentin Johnston (LAC): 10.2
#        34. Romeo Doubs (GB): 10.0
#        35. Jayden Higgins (HOU): 10.0
#        36. Keenan Allen (LAC): 10.0
#        37. Xavier Worthy (KC): 9.8
#        38. Adonai Mitchell (NYJ): 9.7
#        39. DJ Moore (CHI): 9.6
#        40. Darnell Mooney (ATL): 9.6
#        41. Jordan Addison (MIN): 9.3
#        42. John Metchie III (NYJ): 9.0
#        43. Tre Tucker (LV): 9.0
#        44. Luther Burden III (CHI): 9.0
#        45. Josh Downs (IND): 8.9
#        46. Devaughn Vele (NO): 8.8
#        47. Isaac TeSlaa (DET): 8.7
#        48. Jerry Jeudy (CLE): 8.6
#        49. Dontayvion Wicks (GB): 8.1
#        50. Chimere Dike (TEN): 8.1
#        51. Pat Bryant (DEN): 7.8
#        52. Malik Washington (MIA): 7.7
#        53. Rashid Shaheed (SEA): 7.4
#        54. Parker Washington (JAC): 7.3
#        55. Cooper Kupp (SEA): 7.2
#        56. Tez Johnson (TB): 7.1
#        57. Elic Ayomanor (TEN): 6.9
#        58. Keon Coleman (BUF): 6.9
#        59. Marquise Brown (KC): 6.8
#        60. Andrei Iosivas (CIN): 6.7
#        61. Greg Dortch (ARI): 6.6
#        62. Rashod Bateman (BAL): 6.5
#        63. Christian Kirk (HOU): 6.4
#        64. Cedric Tillman (CLE): 6.2
#        65. Tyler Lockett (LV): 6.1
#        66. Calvin Austin III (PIT): 6.1
#        67. Gabe Davis (BUF): 5.9
#        68. DeAndre Hopkins (BAL): 5.8
#        69. David Sills V (ATL): 5.6
#        70. Marvin Mims Jr. (DEN): 5.4
#        71. Van Jefferson (TEN): 5.2
#        72. Xavier Hutchinson (HOU): 5.0
#        73. Sterling Shepard (TB): 5.0
#        74. Ryan Flournoy (DAL): 4.8
#        75. Olamide Zaccheaus (CHI): 4.8
#        76. Jaylin Noel (HOU): 4.8
#        77. KaVontae Turpin (DAL): 4.8
#        78. Mitch Tinsley (CIN): 4.8
#        79. Tyquan Thornton (KC): 4.7
#        80. Tyrell Shavers (BUF): 4.6
#        81. Roman Wilson (PIT): 4.5
#        82. Tee Higgins (CIN): 4.3
#        83. Joshua Palmer (BUF): 4.3
#        84. Jalen Nailor (MIN): 4.2
#        85. Tre Harris (LAC): 4.1
#        86. Isaiah Bond (CLE): 4.0
#        87. JuJu Smith-Schuster (KC): 3.8
#        88. Jack Bech (LV): 3.7
#        89. Mason Tipton (NO): 3.6
#        90. Jahan Dotson (PHI): 3.5
#        91. Matthew Golden (GB): 3.3
#        92. Tim Patrick (JAC): 3.3
#        93. Tom Kennedy (DET): 3.2
#        94. Jaylin Lane (WAS): 3.2
#        95. Xavier Weaver (ARI): 3.2
#        96. Jordan Whittington (LAR): 3.2
#        97. Treylon Burks (WAS): 3.2
#        98. Brandin Cooks (BUF): 2.6
#        99. Tutu Atwell (LAR): 2.6
#       100. Konata Mumpfield (LAR): 2.5
#       101. Chris Moore (WAS): 2.4
#       102. Xavier Smith (LAR): 2.4
#       103. Jayden Reed (GB): 2.4
#       104. Jalen Tolbert (DAL): 2.4
#       105. Drake London (ATL): 2.2
#       106. Malachi Corley (CLE): 2.2
#       107. Nick Westbrook-Ikhine (MIA): 2.2
#       108. Allen Lazard (NYJ): 2.0
#       109. Devontez Walker (BAL): 2.0
#       110. Tyler Johnson (NYJ): 1.9
#       111. Dyami Brown (JAC): 1.8
#       112. Kameron Johnson (TB): 1.8
#       113. Casey Washington (ATL): 1.7
#     ✓ WR: 113 players scraped
#
#   [TE] Loading https://www.fantasypros.com/nfl/rankings/ppr-te.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 61 rows
#     → Parsing players...
#         1. Trey McBride (ARI): 15.0
#         2. Brock Bowers (LV): 13.6
#         3. Tyler Warren (IND): 12.4
#         4. Travis Kelce (KC): 10.8
#         5. Brenton Strange (JAC): 10.4
#         6. Jake Ferguson (DAL): 10.2
#         7. Kyle Pitts Sr. (ATL): 10.1
#         8. Oronde Gadsden II (LAC): 9.5
#         9. Juwan Johnson (NO): 9.5
#        10. Harold Fannin Jr. (CLE): 9.5
#        11. Mark Andrews (BAL): 9.4
#        12. Colston Loveland (CHI): 9.3
#        13. Zach Ertz (WAS): 8.9
#        14. Darren Waller (MIA): 8.9
#        15. Dallas Goedert (PHI): 8.9
#        16. Dalton Schultz (HOU): 8.7
#        17. Evan Engram (DEN): 8.7
#        18. Mason Taylor (NYJ): 8.7
#        19. Isaiah Likely (BAL): 8.3
#        20. Cade Otton (TB): 8.2
#        21. T.J. Hockenson (MIN): 8.1
#        22. AJ Barner (SEA): 7.9
#        23. Mike Gesicki (CIN): 7.6
#        24. Taysom Hill (NO): 7.0
#        25. Colby Parkinson (LAR): 6.1
#        26. Gunnar Helm (TEN): 6.1
#        27. Dawson Knox (BUF): 5.7
#        28. Darnell Washington (PIT): 5.5
#        29. Chig Okonkwo (TEN): 5.4
#        30. David Njoku (CLE): 5.3
#        31. Pat Freiermuth (PIT): 4.7
#        32. Dalton Kincaid (BUF): 4.7
#        33. Noah Fant (CIN): 4.6
#        34. Jonnu Smith (PIT): 4.2
#        35. Luke Musgrave (GB): 3.8
#        36. Jackson Hawes (BUF): 3.8
#        37. Cole Kmet (CHI): 3.7
#        38. Terrance Ferguson (LAR): 3.7
#        39. Elijah Higgins (ARI): 3.6
#        40. Ross Dwelley (DET): 3.5
#        41. Greg Dulcich (MIA): 3.4
#        42. Davis Allen (LAR): 3.3
#        43. Elijah Arroyo (SEA): 3.2
#        44. Charlie Kolar (BAL): 3.1
#        45. Tanner Hudson (CIN): 2.9
#        46. Adam Trautman (DEN): 2.9
#        47. John FitzPatrick (GB): 2.8
#        48. Noah Gray (KC): 2.8
#        49. Brock Wright (DET): 2.5
#        50. Foster Moreau (NO): 2.5
#        51. Michael Mayer (LV): 2.5
#        52. Johnny Mundt (JAC): 2.5
#        53. Jeremy Ruckert (NYJ): 2.4
#        54. Luke Schoonmaker (DAL): 2.4
#        55. Charlie Woerner (ATL): 2.3
#        56. Grant Calcaterra (PHI): 2.1
#        57. Drew Sample (CIN): 1.9
#        58. Josh Oliver (MIN): 1.9
#        59. Julian Hill (MIA): 1.8
#        60. Hunter Long (JAC): 1.4
#     ✓ TE: 60 players scraped
#
#   [K] Loading https://www.fantasypros.com/nfl/rankings/k.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 29 rows
#     → Parsing players...
#         1. Jason Myers (SEA): 8.3
#         2. Brandon Aubrey (DAL): 8.2
#         3. Tyler Loop (BAL): 8.2
#         4. Jake Bates (DET): 8.2
#         5. Wil Lutz (DEN): 8.1
#         6. Chris Boswell (PIT): 7.9
#         7. Chase McLaughlin (TB): 7.9
#         8. Ka'imi Fairbairn (HOU): 7.7
#         9. Harrison Mevis (LAR): 7.6
#        10. Matt Prater (BUF): 7.5
#        11. Cameron Dicker (LAC): 7.4
#        12. Evan McPherson (CIN): 7.3
#        13. Cam Little (JAC): 7.3
#        14. Brandon McManus (GB): 7.3
#        15. Riley Patterson (MIA): 7.2
#        16. Harrison Butker (KC): 7.2
#        17. Michael Badgley (FA): 7.0
#        18. Cairo Santos (CHI): 7.0
#        19. Nick Folk (NYJ): 6.8
#        20. Will Reichard (MIN): 6.8
#        21. Jake Moody (WAS): 6.6
#        22. Jake Elliott (PHI): 6.5
#        23. Chad Ryland (ARI): 6.5
#        24. Zane Gonzalez (ATL): 6.5
#        25. Joey Slye (TEN): 6.5
#        26. Charlie Smyth (NO): 6.1
#        27. Andre Szmyt (CLE): 5.6
#     ✓ K: 27 players scraped
#
#   [DST] Loading https://www.fantasypros.com/nfl/rankings/dst.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 29 rows
#     → Parsing players...
#         1. Denver Broncos Defense (DEN): 12.0
#         2. Cleveland Browns Defense (CLE): 9.7
#         3. Seattle Seahawks Defense (SEA): 9.6
#         4. Los Angeles Rams Defense (LAR): 7.8
#         5. Tampa Bay Buccaneers Defense (TB): 7.5
#         6. Houston Texans Defense (HOU): 7.3
#         7. Baltimore Ravens Defense (BAL): 7.2
#         8. Miami Dolphins Defense (MIA): 7.0
#         9. Philadelphia Eagles Defense (PHI): 6.9
#        10. Washington Commanders Defense (WAS): 6.9
#        11. Kansas City Chiefs Defense (KC): 6.8
#        12. Tennessee Titans Defense (TEN): 6.7
#        13. Green Bay Packers Defense (GB): 6.6
#        14. Pittsburgh Steelers Defense (PIT): 6.4
#        15. Indianapolis Colts Defense (IND): 6.4
#        16. Jacksonville Jaguars Defense (JAC): 6.3
#        17. Los Angeles Chargers Defense (LAC): 6.3
#        18. Minnesota Vikings Defense (MIN): 6.3
#        19. Buffalo Bills Defense (BUF): 6.1
#        20. Atlanta Falcons Defense (ATL): 5.7
#        21. New York Jets Defense (NYJ): 5.7
#        22. Detroit Lions Defense (DET): 5.6
#        23. Chicago Bears Defense (CHI): 5.6
#        24. Dallas Cowboys Defense (DAL): 5.6
#        25. New Orleans Saints Defense (NO): 5.3
#        26. Arizona Cardinals Defense (ARI): 5.0
#        27. Las Vegas Raiders Defense (LV): 4.7
#        28. Cincinnati Bengals Defense (CIN): 4.4
#     ✓ DST: 28 players scraped
#
# ============================================================
# Total: 346 players scraped
# ============================================================
#
# Saving 346 projections to database...
# ✓ Successfully saved to database!
#
# ✅ FantasyPros scraping complete!

# %%
# 🎯 FIRST DOWN STUDIO SCRAPER
# ================================================
# Set HEADLESS = False in setup cell to debug visually
print(f"{'='*70}")
print(f"🎯 FIRST DOWN STUDIO SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    with FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK, scoring="PPR")
    print("\n✅ First Down Studio scraping complete!")
except Exception as e:
    print(f"\n❌ First Down Studio error: {e}")
    import traceback
    traceback.print_exc()

# %%
# 🔵 FANDUEL SCRAPER (runs in subprocess due to Playwright)
# ================================================
print(f"{'='*70}")
print(f"🔵 FANDUEL SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    temp_script = NOTEBOOK_DIR / "_temp_fanduel.py"
    script_content = f'''
import sys
sys.path.insert(0, r"{PROJECT_ROOT}")
from backend.scrapers.scraper_fanduel import FanDuelScraper

try:
    with FanDuelScraper(headless={HEADLESS}, db_path=r"{DB_PATH}") as scraper:
        scraper.scrape_and_save(week="{WEEK}")
    print("FanDuel complete")
except Exception as e:
    print(f"Error: {{e}}")
    import traceback
    traceback.print_exc()
    raise
'''
    temp_script.write_text(script_content, encoding='utf-8')
    
    result = subprocess.run(
        [sys.executable, str(temp_script)],
        capture_output=True,
        text=True,
        cwd=str(PROJECT_ROOT),
        timeout=300
    )
    
    print(result.stdout)
    if result.stderr:
        print("STDERR:", result.stderr)
    
    if result.returncode == 0:
        print("\n✅ FanDuel scraping complete!")
    else:
        print(f"\n❌ FanDuel failed with code {result.returncode}")
    
    temp_script.unlink(missing_ok=True)
except Exception as e:
    print(f"\n❌ FanDuel error: {e}")
    import traceback
    traceback.print_exc()
    if temp_script.exists():
        temp_script.unlink()
# Out:
# ======================================================================
# 🔵 FANDUEL SCRAPER - Week 14
# ======================================================================
#
# Navigating to https://www.fanduel.com/research/nfl/fantasy/ppr...
#   Intercepted data from https://fdresearch-api.fanduel.com/graphql
#   âœ“ Found 478 projections in response
#
# Parsing 478 projections...
#   Josh Allen (QB): 21.5 pts
#   Jahmyr Gibbs (RB): 21.5 pts
#   De'Von Achane (RB): 21.5 pts
#   Dak Prescott (QB): 21.0 pts
#   Jaxon Smith-Njigba (WR): 20.0 pts
#   Ja'Marr Chase (WR): 19.9 pts
#   Josh Jacobs (RB): 19.6 pts
#   Jonathan Taylor (RB): 19.3 pts
#   CeeDee Lamb (WR): 19.3 pts
#   Bijan Robinson (RB): 19.2 pts
#   Puka Nacua (WR): 19.1 pts
#   Matthew Stafford (QB): 19.0 pts
#   Jalen Hurts (QB): 18.7 pts
#   Patrick Mahomes (QB): 18.5 pts
#   Lamar Jackson (QB): 18.5 pts
#   Jared Goff (QB): 18.3 pts
#   James Cook (RB): 17.9 pts
#   Joe Burrow (QB): 17.9 pts
#   Bo Nix (QB): 17.6 pts
#   Breece Hall (RB): 17.5 pts
#   George Pickens (WR): 17.5 pts
#   Baker Mayfield (QB): 17.3 pts
#   Trevor Lawrence (QB): 17.3 pts
#   Marcus Mariota (QB): 17.0 pts
#   Daniel Jones (QB): 16.7 pts
#   Jordan Love (QB): 16.7 pts
#   Sam Darnold (QB): 16.5 pts
#   Jameson Williams (WR): 16.3 pts
#   Ashton Jeanty (RB): 16.3 pts
#   Justin Jefferson (WR): 16.2 pts
#   Trey McBride (TE): 16.0 pts
#   Chase Brown (RB): 15.5 pts
#   Saquon Barkley (RB): 15.5 pts
#   Davante Adams (WR): 15.2 pts
#   Kyren Williams (RB): 15.2 pts
#   Caleb Williams (QB): 15.2 pts
#   Chris Olave (WR): 15.1 pts
#   C.J. Stroud (QB): 15.0 pts
#   Emeka Egbuka (WR): 15.0 pts
#   Tyrod Taylor (QB): 15.0 pts
#   Quinshon Judkins (RB): 14.8 pts
#   Rashee Rice (WR): 14.5 pts
#   Derrick Henry (RB): 14.5 pts
#   Jacoby Brissett (QB): 14.5 pts
#   Devin Neal (RB): 14.4 pts
#   Nico Collins (WR): 14.3 pts
#   Zay Flowers (WR): 14.1 pts
#   Tyler Shough (QB): 14.1 pts
#   Travis Etienne (RB): 14.0 pts
#   Tyler Warren (TE): 14.0 pts
#   Tua Tagovailoa (QB): 13.7 pts
#   Aaron Rodgers (QB): 13.7 pts
#   Kirk Cousins (QB): 13.6 pts
#   Bucky Irving (RB): 13.6 pts
#   A.J. Brown (WR): 13.5 pts
#   David Montgomery (RB): 13.4 pts
#   Shedeur Sanders (QB): 13.3 pts
#   Khalil Shakir (WR): 13.3 pts
#   Romeo Doubs (WR): 13.1 pts
#   DeVonta Smith (WR): 12.9 pts
#   Kenneth Walker III (RB): 12.7 pts
#   Brian Thomas Jr. (WR): 12.7 pts
#   Jordan Addison (WR): 12.7 pts
#   Woody Marks (RB): 12.6 pts
#   Jaylen Waddle (WR): 12.6 pts
#   Javonte Williams (RB): 12.5 pts
#   Geno Smith (QB): 12.4 pts
#   Terry McLaurin (WR): 12.2 pts
#   Marvin Harrison Jr. (WR): 12.1 pts
#   Omarion Hampton (RB): 12.1 pts
#   Christian Watson (WR): 11.6 pts
#   Zonovan Knight (RB): 11.5 pts
#   Amon-Ra St. Brown (WR): 11.4 pts
#   Ladd McConkey (WR): 11.4 pts
#   Cameron Ward (QB): 11.4 pts
#   RJ Harvey (RB): 11.3 pts
#   Jaylen Warren (RB): 11.3 pts
#   Chris Godwin (WR): 11.2 pts
#   Kenneth Gainwell (RB): 11.2 pts
#   D'Andre Swift (RB): 11.1 pts
#   D.K. Metcalf (WR): 11.0 pts
#   Kyle Pitts (TE): 10.8 pts
#   Jordan Mason (RB): 10.8 pts
#   Courtland Sutton (WR): 10.5 pts
#   Tyjae Spears (RB): 10.5 pts
#   Harold Fannin Jr. (TE): 10.5 pts
#   Brock Bowers (TE): 10.4 pts
#   Michael Pittman Jr. (WR): 10.3 pts
#   T.J. Hockenson (TE): 10.2 pts
#   Alec Pierce (WR): 10.1 pts
#   Travis Kelce (TE): 10.1 pts
#   Rome Odunze (WR): 10.1 pts
#   Xavier Worthy (WR): 10.1 pts
#   Juwan Johnson (TE): 10.0 pts
#   Keenan Allen (WR): 9.9 pts
#   D.J. Moore (WR): 9.7 pts
#   Dontayvion Wicks (WR): 9.6 pts
#   Tony Pollard (RB): 9.6 pts
#   Jake Ferguson (TE): 9.5 pts
#   Isaac TeSlaa (WR): 9.3 pts
#   Jakobi Meyers (WR): 9.3 pts
#   Dalton Schultz (TE): 9.3 pts
#   Mark Andrews (TE): 9.2 pts
#   Jerry Jeudy (WR): 9.2 pts
#   Oronde Gadsden (TE): 9.1 pts
#   Justin Herbert (QB): 9.0 pts
#   Deebo Samuel (WR): 9.0 pts
#   Cooper Kupp (WR): 8.8 pts
#   Troy Franklin (WR): 8.8 pts
#   Mason Taylor (TE): 8.8 pts
#   Quentin Johnston (WR): 8.6 pts
#   J.J. McCarthy (QB): 8.6 pts
#   Ross Dwelley (TE): 8.6 pts
#   Dalton Kincaid (TE): 8.5 pts
#   John Metchie III (WR): 8.4 pts
#   Zach Charbonnet (RB): 8.4 pts
#   Max Brosmer (QB): 8.3 pts
#   Pat Bryant (WR): 8.2 pts
#   Rashid Shaheed (WR): 8.2 pts
#   Darren Waller (TE): 8.1 pts
#   Michael Wilson (WR): 8.1 pts
#   Kyle Monangai (RB): 8.0 pts
#   Dallas Goedert (TE): 8.0 pts
#   Jalen Nailor (WR): 7.8 pts
#   Josh Downs (WR): 7.8 pts
#   Kareem Hunt (RB): 7.8 pts
#   Jayden Higgins (WR): 7.7 pts
#   Brenton Strange (TE): 7.7 pts
#   Chigoziem Okonkwo (TE): 7.6 pts
#   Tre Tucker (WR): 7.6 pts
#   Zach Ertz (TE): 7.5 pts
#   Colston Loveland (TE): 7.4 pts
#   Nick Chubb (RB): 7.4 pts
#   Elic Ayomanor (WR): 7.4 pts
#   Chris Rodriguez Jr. (RB): 7.3 pts
#   Malik Washington (WR): 7.2 pts
#   Cade Otton (TE): 7.2 pts
#   Evan Engram (TE): 7.2 pts
#   Emanuel Wilson (RB): 7.2 pts
#   AJ Barner (TE): 7.0 pts
#   Michael Carter (RB): 7.0 pts
#   Cedric Tillman (WR): 7.0 pts
#   Isaiah Likely (TE): 6.9 pts
#   Trey Lance (QB): 6.9 pts
#   Keon Coleman (WR): 6.9 pts
#   Mike Gesicki (TE): 6.9 pts
#   Dylan Drummond (WR): 6.8 pts
#   Luther Burden III (WR): 6.8 pts
#   Blake Corum (RB): 6.7 pts
#   Darnell Mooney (WR): 6.6 pts
#   Jonnu Smith (TE): 6.6 pts
#   Isiah Pacheco (RB): 6.5 pts
#   Marvin Mims (WR): 6.5 pts
#   Calvin Austin III (WR): 6.4 pts
#   Chimere Dike (WR): 6.3 pts
#   David Njoku (TE): 6.3 pts
#   Rashod Bateman (WR): 6.3 pts
#   Adonai Mitchell (WR): 6.2 pts
#   Van Jefferson (WR): 6.1 pts
#   Aaron Jones (RB): 6.0 pts
#   Treylon Burks (WR): 6.0 pts
#   Drake London (WR): 5.9 pts
#   Marquise Brown (WR): 5.9 pts
#   Andrei Iosivas (WR): 5.9 pts
#   Darnell Washington (TE): 5.8 pts
#   David Sills V (WR): 5.6 pts
#   Jaleel McLaughlin (RB): 5.5 pts
#   Jeremy McNichols (RB): 5.5 pts
#   Colby Parkinson (TE): 5.5 pts
#   Taysom Hill (TE): 5.5 pts
#   Pat Freiermuth (TE): 5.4 pts
#   Christian Kirk (WR): 5.4 pts
#   Gabriel Davis (WR): 5.3 pts
#   Gunnar Helm (TE): 5.3 pts
#   Jaylin Noel (WR): 5.2 pts
#   KaVontae Turpin (WR): 5.1 pts
#   Jalen McMillan (WR): 5.1 pts
#   Isaiah Davis (RB): 5.1 pts
#   Luke Musgrave (TE): 5.0 pts
#   Foster Moreau (TE): 4.9 pts
#   Tee Higgins (WR): 4.9 pts
#   Bhayshul Tuten (RB): 4.8 pts
#   Sterling Shepard (WR): 4.8 pts
#   Devaughn Vele (WR): 4.8 pts
#   Raheem Mostert (RB): 4.8 pts
#   Lil'Jordan Humphrey (WR): 4.7 pts
#   Rachaad White (RB): 4.7 pts
#   Tyler Lockett (WR): 4.7 pts
#   Tyler Allgeier (RB): 4.6 pts
#   Michael Mayer (TE): 4.5 pts
#   Jerome Ford (RB): 4.5 pts
#   Jordan Whittington (WR): 4.3 pts
#   Elijah Arroyo (TE): 4.2 pts
#   Cole Kmet (TE): 4.2 pts
#   Quintin Morris (TE): 4.1 pts
#   Isaiah Bond (WR): 4.1 pts
#   Tim Patrick (WR): 4.0 pts
#   Parker Washington (WR): 3.9 pts
#   Mitchell Tinsley (WR): 3.9 pts
#   Ollie Gordon II (RB): 3.9 pts
#   Emari Demercado (RB): 3.8 pts
#   Brandin Cooks (WR): 3.8 pts
#   Jaylin Lane (WR): 3.8 pts
#   Olamide Zaccheaus (WR): 3.7 pts
#   Mason Tipton (WR): 3.7 pts
#   Dawson Knox (TE): 3.7 pts
#   Nick Westbrook-Ikhine (WR): 3.7 pts
#   Jeremy Ruckert (TE): 3.7 pts
#   Tanner Hudson (TE): 3.6 pts
#   Tutu Atwell (WR): 3.5 pts
#   Tyquan Thornton (WR): 3.5 pts
#   Samaje Perine (RB): 3.5 pts
#   Jack Bech (WR): 3.4 pts
#   Allen Lazard (WR): 3.3 pts
#   JuJu Smith-Schuster (WR): 3.3 pts
#   Dont'e Thornton Jr. (WR): 3.3 pts
#   Mo Alie-Cox (TE): 3.3 pts
#   John FitzPatrick (TE): 3.3 pts
#   Kimani Vidal (RB): 3.2 pts
#   Greg Dortch (WR): 3.2 pts
#   DeAndre Hopkins (WR): 3.1 pts
#   Ray Davis (RB): 3.1 pts
#   Terrance Ferguson (TE): 3.1 pts
#   Charlie Kolar (TE): 3.1 pts
#   Luke Schoonmaker (TE): 3.1 pts
#   Davis Allen (TE): 3.0 pts
#   Tez Johnson (WR): 3.0 pts
#   Chris Brooks (RB): 3.0 pts
#   Jahan Dotson (WR): 2.9 pts
#   Brashard Smith (RB): 2.9 pts
#   Tyrell Shavers (WR): 2.9 pts
#   Noah Brown (WR): 2.8 pts
#   Drew Sample (TE): 2.8 pts
#   Elijah Higgins (TE): 2.8 pts
#   Devontez Walker (WR): 2.8 pts
#   Jacory Croskey-Merritt (RB): 2.7 pts
#   Khadarel Hodge (WR): 2.7 pts
#   Ty Johnson (RB): 2.7 pts
#   Keaton Mitchell (RB): 2.7 pts
#   Dylan Sampson (RB): 2.6 pts
#   Greg Dulcich (TE): 2.6 pts
#   Evan Hull (RB): 2.5 pts
#   Xavier Hutchinson (WR): 2.5 pts
#   Ryan Flournoy (WR): 2.5 pts
#   Tre Harris (WR): 2.5 pts
#   Noah Fant (TE): 2.4 pts
#   Roman Wilson (WR): 2.4 pts
#   Josh Palmer (WR): 2.4 pts
#   Xavier Smith (WR): 2.4 pts
#   Clyde Edwards-Helaire (RB): 2.3 pts
#   Adam Trautman (TE): 2.3 pts
#   Ameer Abdullah (RB): 2.2 pts
#   Dyami Brown (WR): 2.2 pts
#   Cody White (WR): 2.2 pts
#   Isaiah Williams (WR): 2.1 pts
#   Rasheen Ali (RB): 2.1 pts
#   Cade Stover (TE): 2.1 pts
#   Chris Moore (WR): 2.1 pts
#   Zavier Scott (RB): 2.1 pts
#   Malik Davis (RB): 2.0 pts
#   Malachi Corley (WR): 1.9 pts
#   Jaylen Wright (RB): 1.9 pts
#   Kyler Murray (QB): 1.9 pts
#   Jackson Hawes (TE): 1.8 pts
#   Keleki Latu (TE): 1.8 pts
#   Charlie Jones (WR): 1.8 pts
#   Tank Bigsby (RB): 1.7 pts
#   Gage Larvadain (WR): 1.7 pts
#   Tyler Goodson (RB): 1.7 pts
#   Reggie Gilliam (RB): 1.7 pts
#   Kaleb Johnson (RB): 1.7 pts
#   Will Shipley (RB): 1.7 pts
#   Andrew Ogletree (TE): 1.6 pts
#   Xavier Weaver (WR): 1.6 pts
#   Tyler Badie (RB): 1.5 pts
#   Julian Hill (TE): 1.5 pts
#   Durham Smythe (TE): 1.5 pts
#   John Bates (TE): 1.4 pts
#   Nathan Carter (RB): 1.4 pts
#   LeQuint Allen Jr. (RB): 1.4 pts
#   Grant Calcaterra (TE): 1.4 pts
#   Tahj Brooks (RB): 1.3 pts
#   Ian Thomas (TE): 1.3 pts
#   Adam Prentice (RB): 1.2 pts
#   Jalen Tolbert (WR): 1.2 pts
#   Kendall Milton (RB): 1.2 pts
#   Audric Estime (RB): 1.2 pts
#   Jaret Patterson (RB): 1.2 pts
#   Jaydon Blue (RB): 1.1 pts
#   Charlie Woerner (TE): 1.1 pts
#   Cedrick Wilson (WR): 1.1 pts
#   Tanner Conner (TE): 1.0 pts
#   Anthony Gould (WR): 1.0 pts
#   Sean Tucker (RB): 1.0 pts
#   Jamari Thrash (WR): 1.0 pts
#   Hunter Luepke (RB): 0.9 pts
#   Ben Skowronek (WR): 0.9 pts
#   Xavier Restrepo (WR): 0.9 pts
#   Jeff Wilson (RB): 0.8 pts
#   Craig Reynolds (RB): 0.7 pts
#   Sione Vaki (RB): 0.7 pts
#   Alec Ingold (RB): 0.7 pts
#   Trayveon Williams (RB): 0.7 pts
#   Connor Heyward (TE): 0.6 pts
#   Travis Homer (RB): 0.6 pts
#   Dare Ogunbowale (RB): 0.6 pts
#   Nyheim Hines (RB): 0.6 pts
#   Hassan Haskins (RB): 0.6 pts
#   Derius Davis (WR): 0.6 pts
#   Brevyn Spann-Ford (TE): 0.6 pts
#   Amar Johnson (RB): 0.6 pts
#   A.J. Dillon (RB): 0.6 pts
#   Patrick Ricard (RB): 0.6 pts
#   Dylan Laube (RB): 0.6 pts
#   Zamir White (RB): 0.6 pts
#   Konata Mumpfield (WR): 0.6 pts
#   Devin Culp (TE): 0.6 pts
#   Dareke Young (WR): 0.5 pts
#   Nick Kallerup (TE): 0.5 pts
#   Payne Durham (TE): 0.5 pts
#   Johnny Mundt (TE): 0.5 pts
#   Eric Saubert (TE): 0.5 pts
#   Jake Bobo (WR): 0.5 pts
#   Kameron Johnson (WR): 0.5 pts
#   Ryan Miller (WR): 0.5 pts
#   Will Dissly (TE): 0.5 pts
#   Trishton Jackson (WR): 0.5 pts
#   Casey Washington (WR): 0.5 pts
#   KeAndre Lambert-Smith (WR): 0.5 pts
#   Scotty Miller (WR): 0.5 pts
#   Tucker Fisk (TE): 0.5 pts
#   Dee Eskridge (WR): 0.5 pts
#   Tay Martin (WR): 0.5 pts
#   Ben Sinnott (TE): 0.5 pts
#   Tyler Conklin (TE): 0.5 pts
#   Marquez Valdes-Scantling (WR): 0.5 pts
#   Bryce Oliver (WR): 0.5 pts
#   Carter Runyon (TE): 0.5 pts
#   David Martin-Robinson (TE): 0.5 pts
#   Stone Smartt (TE): 0.5 pts
#   Alex Bachman (WR): 0.5 pts
#   Josh Reynolds (WR): 0.4 pts
#   Kylen Granson (TE): 0.4 pts
#   Tylan Wallace (WR): 0.4 pts
#   Deven Thompkins (WR): 0.4 pts
#   Tyler Johnson (WR): 0.4 pts
#   Irvin Charles (WR): 0.4 pts
#   Arian Smith (WR): 0.4 pts
#   Darius Cooper (WR): 0.4 pts
#   Xavier Gipson (WR): 0.4 pts
#   Joe Milton III (QB): 0.3 pts
#   Nick Mullens (QB): 0.3 pts
#   Kyle Allen (QB): 0.3 pts
#   Joe Flacco (QB): 0.3 pts
#   Mitchell Trubisky (QB): 0.3 pts
#   Kedon Slovis (QB): 0.3 pts
#   Drew Lock (QB): 0.3 pts
#   Riley Leonard (QB): 0.3 pts
#   Gardner Minshew (QB): 0.2 pts
#   Easton Stick (QB): 0.2 pts
#   Spencer Rattler (QB): 0.2 pts
#   Malik Willis (QB): 0.2 pts
#   Dillon Gabriel (QB): 0.2 pts
#   Quinn Ewers (QB): 0.2 pts
#   Davis Mills (QB): 0.2 pts
#   Josh Johnson (QB): 0.2 pts
#   Tyler Huntley (QB): 0.2 pts
#   Andrew Beck (RB): 0.2 pts
#   Chase Edmonds (RB): 0.2 pts
#   Josh Williams (RB): 0.2 pts
#   Owen Wright (RB): 0.2 pts
#   George Holani (RB): 0.2 pts
#   Jacob Saylors (RB): 0.2 pts
#   Julius Chestnut (RB): 0.2 pts
#   British Brooks (RB): 0.2 pts
#   Kalif Raymond (WR): 0.0 pts
#   Brock Wright (TE): 0.0 pts
#   Shane Zylstra (TE): 0.0 pts
#   Jonathan Mingo (WR): 0.0 pts
#   Sam LaPorta (TE): 0.0 pts
#   Dominic Lovett (WR): 0.0 pts
#   Jalen Cropper (WR): 0.0 pts
#   Jackson Meeks (WR): 0.0 pts
#   Cooper Rush (QB): 0.0 pts
#   Mason Rudolph (QB): 0.0 pts
#   Skylar Thompson (QB): 0.0 pts
#   LaJohntay Wester (WR): 0.0 pts
#   Ke'Shawn Williams (WR): 0.0 pts
#   Jamal Agnew (WR): 0.0 pts
#   Feleipe Franks (TE): 0.0 pts
#   Teagan Quitoriano (TE): 0.0 pts
#   Brady Russell (RB): 0.0 pts
#   Tory Horton (WR): 0.0 pts
#   Robbie Ouzts (RB): 0.0 pts
#   Jalen Milroe (QB): 0.0 pts
#   Ricky White III (WR): 0.0 pts
#   Brandon Allen (QB): 0.0 pts
#   Bailey Zappe (QB): 0.0 pts
#   Blake Whiteheart (TE): 0.0 pts
#   Raheim Sanders (RB): 0.0 pts
#   Kalel Mullings (RB): 0.0 pts
#   Cade McDonald (WR): 0.0 pts
#   Justin Fields (QB): 0.0 pts
#   Zach Wilson (QB): 0.0 pts
#   Garrett Wilson (WR): 0.0 pts
#   Braelon Allen (RB): 0.0 pts
#   Brady Cook (QB): 0.0 pts
#   Tahj Washington (WR): 0.0 pts
#   Hayden Rucci (TE): 0.0 pts
#   Mike Evans (WR): 0.0 pts
#   Teddy Bridgewater (QB): 0.0 pts
#   Alvin Kamara (RB): 0.0 pts
#   Jack Stoll (TE): 0.0 pts
#   Trey Palmer (WR): 0.0 pts
#   Zaire Mitchell-Paden (TE): 0.0 pts
#   Moliki Matavao (TE): 0.0 pts
#   Ashton Dulin (WR): 0.0 pts
#   Hunter Long (TE): 0.0 pts
#   Anthony Richardson (QB): 0.0 pts
#   Will Mallory (TE): 0.0 pts
#   DJ Giddens (RB): 0.0 pts
#   Case Keenum (QB): 0.0 pts
#   Devin Duvernay (WR): 0.0 pts
#   Brittain Brown (RB): 0.0 pts
#   Jayden Reed (WR): 0.0 pts
#   Roschon Johnson (RB): 0.0 pts
#   Malik Heath (WR): 0.0 pts
#   Ben Sims (TE): 0.0 pts
#   Tyson Bagent (QB): 0.0 pts
#   MarShawn Lloyd (RB): 0.0 pts
#   Matthew Golden (WR): 0.0 pts
#   Savion Williams (WR): 0.0 pts
#   Jahdae Walker (WR): 0.0 pts
#   C.J. Ham (RB): 0.0 pts
#   Josh Oliver (TE): 0.0 pts
#   Cam Akers (RB): 0.0 pts
#   Ty Chandler (RB): 0.0 pts
#   Jayden Daniels (QB): 0.0 pts
#   Tai Felton (WR): 0.0 pts
#   Ben Yurosek (TE): 0.0 pts
#   Myles Price (WR): 0.0 pts
#   Ja'Corey Brooks (WR): 0.0 pts
#   Trent Sherfield (WR): 0.0 pts
#   Jarrett Stidham (QB): 0.0 pts
#   Kenny Pickett (QB): 0.0 pts
#   Nate Adkins (TE): 0.0 pts
#   Aidan O'Connell (QB): 0.0 pts
#   Lucas Krull (TE): 0.0 pts
#   Justin Shorter (TE): 0.0 pts
#   Jake Browning (QB): 0.0 pts
#   Jermaine Burton (WR): 0.0 pts
#   Erick All Jr. (TE): 0.0 pts
#   Cam Grandy (TE): 0.0 pts
#   Jimmy Garoppolo (QB): 0.0 pts
#   Simi Fehoko (WR): 0.0 pts
#   Andre Baccellia (WR): 0.0 pts
#   Trey Benson (RB): 0.0 pts
#   Travis Vokolek (TE): 0.0 pts
#   Jarquez Hunter (RB): 0.0 pts
#   Stetson Bennett (QB): 0.0 pts
#   Brennan Presley (WR): 0.0 pts
#   Joe Mixon (RB): 0.0 pts
#   Justin Watson (WR): 0.0 pts
#   Irv Smith Jr. (TE): 0.0 pts
#   Braxton Berrios (WR): 0.0 pts
#   Jakob Johnson (RB): 0.0 pts
#   Harrison Bryant (TE): 0.0 pts
#   Elijah Mitchell (RB): 0.0 pts
#   Noah Gray (TE): 0.0 pts
#   Tank Dell (WR): 0.0 pts
#   Jason Brownlee (WR): 0.0 pts
#   Jared Wiley (TE): 0.0 pts
#   Nikko Remigio (WR): 0.0 pts
#   Jared Wayne (WR): 0.0 pts
#   Jalen Royals (WR): 0.0 pts
#   Sam Howell (QB): 0.0 pts
#   Tanner McKee (QB): 0.0 pts
#   Cameron Latu (TE): 0.0 pts
#
# Total players scraped: 478
#
# Saving 478 projections to database...
# Using database: C:\Users\Samer Faizi\Documents\Claude Model\backend\data\databases\projections.db
# âœ“ Successfully saved to database!
# FanDuel complete
#
#
# ✅ FanDuel scraping complete!

# %% [markdown]
# ### 🚀 Run All Scrapers (Convenience Cell)
#
# Run this cell to execute all scrapers in sequence:

# %%
# 🚀 RUN ALL SCRAPERS
# ================================================
def run_all_scrapers():
    """Run all scrapers for the configured week."""
    print(f"{'='*70}")
    print(f"RUNNING ALL SCRAPERS - {WEEK}")
    print(f"{'='*70}\n")
    
    results = {}
    
    # 1. Sleeper
    print("💤 Sleeper...")
    try:
        with SleeperScraper(db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, season=SEASON)
        results['Sleeper'] = '✅'
    except Exception as e:
        results['Sleeper'] = f'❌ {str(e)[:40]}'
        print(f"  Error: {e}")
    
    # 2. ESPN
    print("\n🔴 ESPN...")
    try:
        with ESPNScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, season=SEASON)
        results['ESPN'] = '✅'
    except Exception as e:
        results['ESPN'] = f'❌ {str(e)[:40]}'
        print(f"  Error: {e}")
    
    # 3. FantasyPros
    print("\n📊 FantasyPros...")
    try:
        with FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK)
        results['FantasyPros'] = '✅'
    except Exception as e:
        results['FantasyPros'] = f'❌ {str(e)[:40]}'
        print(f"  Error: {e}")
    
    # 4. First Down Studio
    print("\n🎯 First Down Studio...")
    try:
        with FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, scoring="PPR")
        results['First Down'] = '✅'
    except Exception as e:
        results['First Down'] = f'❌ {str(e)[:40]}'
        print(f"  Error: {e}")
    
    # 5. FanDuel (subprocess)
    print("\n🔵 FanDuel...")
    try:
        temp_script = NOTEBOOK_DIR / "_temp_fanduel.py"
        script_content = f'''
import sys
sys.path.insert(0, r"{PROJECT_ROOT}")
from backend.scrapers.scraper_fanduel import FanDuelScraper
with FanDuelScraper(headless={HEADLESS}, db_path=r"{DB_PATH}") as scraper:
    scraper.scrape_and_save(week="{WEEK}")
'''
        temp_script.write_text(script_content, encoding='utf-8')
        result = subprocess.run([sys.executable, str(temp_script)], capture_output=True, text=True, cwd=str(PROJECT_ROOT), timeout=300)
        temp_script.unlink(missing_ok=True)
        results['FanDuel'] = '✅' if result.returncode == 0 else f'❌ Exit {result.returncode}'
    except Exception as e:
        results['FanDuel'] = f'❌ {str(e)[:40]}'
    
    # Summary
    print(f"\n{'='*70}")
    print("SCRAPING SUMMARY")
    print(f"{'='*70}")
    for source, status in results.items():
        print(f"  {source:<15} {status}")
    print(f"{'='*70}\n")

# Uncomment to run all:
# run_all_scrapers()

# %% [markdown]
# ## 📊 Database Status & Data Quality

# %%
def show_database_status():
    """Display comprehensive database status and data quality metrics."""
    with ProjectionsDB(db_path=DB_PATH) as db:
        all_projs = db.get_projections()
        
        print(f"{'='*70}")
        print(f"DATABASE STATUS")
        print(f"{'='*70}\n")
        print(f"Total records: {len(all_projs)}\n")
        
        # Count by source
        print(f"📊 Records by Source:")
        print("-" * 70)
        sources = {}
        for p in all_projs:
            source = p['source_website']
            sources[source] = sources.get(source, 0) + 1
        
        for source, count in sorted(sources.items()):
            print(f"  {source:<25} {count:>5} records")
        
        # Count by week
        print(f"\n📅 Records by Week:")
        print("-" * 70)
        weeks = {}
        for p in all_projs:
            week = p['week']
            weeks[week] = weeks.get(week, 0) + 1
        
        for week, count in sorted(weeks.items()):
            print(f"  {week:<25} {count:>5} records")
        
        # Team coverage (data quality check)
        print(f"\n🏈 Team Data Coverage (Quality Check):")
        print("-" * 70)
        for source in sorted(sources.keys()):
            source_projs = [p for p in all_projs if p['source_website'] == source]
            with_team = sum(1 for p in source_projs if p.get('team'))
            total = len(source_projs)
            pct = (with_team / total * 100) if total > 0 else 0
            status = "✅" if pct >= 95 else "⚠️" if pct >= 75 else "❌"
            print(f"  {source:<25} {with_team:>4}/{total:<4} ({pct:>5.1f}%) {status}")
        
        print(f"\n{'='*70}\n")

# Show status
show_database_status()
# Out:
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 7902
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#   espn.com                   1224 records
#   fanduel.com                2477 records
#   fantasypros.com            1855 records
#   firstdown.studio            337 records
#   sleeper.com                2009 records
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#   Week 10                    1625 records
#   Week 11                    1649 records
#   Week 12                    1519 records
#   Week 13                    1578 records
#   Week 14                    1531 records
#
# 🏈 Team Data Coverage (Quality Check):
# ----------------------------------------------------------------------
#   espn.com                  1224/1224 (100.0%) ✅
#   fanduel.com               2477/2477 (100.0%) ✅
#   fantasypros.com           1855/1855 (100.0%) ✅
#   firstdown.studio           337/337  (100.0%) ✅
#   sleeper.com               2009/2009 (100.0%) ✅
#
# ======================================================================

# %% [markdown]
# ---
#
# ## 🛠️ Utility Functions
#
# **Use these as needed for database management**

# %%
# ============================================================================
# UTILITY FUNCTIONS - Uncomment to use
# ============================================================================

def clear_week(week_name):
    """Delete all records from a specific week."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    cursor.execute("DELETE FROM projections WHERE week = ?", (week_name,))
    deleted = cursor.rowcount
    conn.commit()
    conn.close()
    print(f"✓ Deleted {deleted} records from {week_name}")

def clear_source(source_name, week=None):
    """Delete records from a specific source."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    if week:
        cursor.execute("DELETE FROM projections WHERE source_website = ? AND week = ?", (source_name, week))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} for {week}")
    else:
        cursor.execute("DELETE FROM projections WHERE source_website = ?", (source_name,))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} (all weeks)")
    conn.commit()
    conn.close()

def clear_entire_database():
    """⚠️ DELETE ALL RECORDS - requires confirmation."""
    confirm = input("⚠️  Type 'DELETE ALL' to confirm: ")
    if confirm == "DELETE ALL":
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("DELETE FROM projections")
        conn.commit()
        deleted = cursor.rowcount
        conn.close()
        print(f"\n✓ Deleted {deleted} records from database")
    else:
        print("\n✗ Cancelled")

def show_week_source_matrix():
    """Display a matrix showing record counts by week and source."""
    import pandas as pd
    conn = sqlite3.connect(DB_PATH)
    query = """
        SELECT week, source_website, COUNT(*) as count
        FROM projections
        GROUP BY week, source_website
        ORDER BY week, source_website
    """
    df = pd.read_sql_query(query, conn)
    conn.close()
    
    if len(df) == 0:
        print("No data in database")
        return
    
    pivot = df.pivot(index='source_website', columns='week', values='count')
    pivot = pivot.fillna(0).astype(int)
    
    print(f"\n{'='*70}")
    print("WEEK × SOURCE MATRIX")
    print("="*70)
    print(pivot.to_string())
    print("="*70 + "\n")

def run_single_scraper(scraper_name):
    """Run a specific scraper by name."""
    scrapers = {
        'sleeper': lambda: SleeperScraper(db_path=DB_PATH),
        'espn': lambda: ESPNScraper(headless=HEADLESS, db_path=DB_PATH),
        'fantasypros': lambda: FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH),
        'firstdown': lambda: FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH)
    }
    
    name_lower = scraper_name.lower()
    if name_lower not in scrapers:
        print(f"Unknown scraper: {scraper_name}")
        print(f"Available: {', '.join(scrapers.keys())}")
        return
    
    print(f"Running {scraper_name}...")
    try:
        with scrapers[name_lower]() as scraper:
            if name_lower == 'sleeper':
                scraper.scrape_and_save(week=WEEK, season=SEASON)
            elif name_lower == 'espn':
                scraper.scrape_and_save(week=WEEK, season=SEASON)
            elif name_lower == 'firstdown':
                scraper.scrape_and_save(week=WEEK, scoring="PPR")
            else:
                scraper.scrape_and_save(week=WEEK)
        print(f"✓ {scraper_name} complete")
    except Exception as e:
        print(f"✗ Error: {e}")

# Uncomment to use:
# clear_week("Week 10")
# clear_source("fantasypros.com", WEEK)
# clear_entire_database()
show_week_source_matrix()
# run_single_scraper("sleeper")

print("✅ Utility functions loaded. Uncomment above to use.")
# Out:
# ======================================================================
# WEEK × SOURCE MATRIX
# ======================================================================
# week              Week 10  Week 11  Week 12  Week 13  Week 14
# source_website
# espn.com              232      240      234      246      272
# fanduel.com           473      508      471      546      479
# fantasypros.com       388      321      437      362      347
# firstdown.studio      161      176        0        0        0
# sleeper.com           371      404      377      424      433
# ======================================================================
#
# ✅ Utility functions loaded. Uncomment above to use.

# %% [markdown]
# ---
#
# ## 📚 Quick Reference
#
# ### Weekly Workflow:
# 1. Update `WEEK` and `SEASON` in cell 2
# 2. **Kernel → Restart & Run All**
# 3. Wait for all scrapers to complete (~5-10 minutes)
# 4. Check database status for data quality
#
# ### Available Functions:
# - `run_all_scrapers()` - Scrape all sources *(runs automatically)*
# - `show_database_status()` - View database contents *(runs automatically)*
# - `run_single_scraper(name)` - Run one scraper
# - `clear_week(week)` - Delete all data for a week
# - `clear_source(source, week)` - Delete data from a source
# - `show_week_source_matrix()` - See week×source grid
# - `clear_entire_database()` - Delete everything ⚠️
#
# ### Source Names:
# - `"fanduel.com"`
# - `"sleeper.com"`
# - `"espn.com"`
# - `"fantasypros.com"`
# - `"firstdown.studio"`
#
# ### Tips:
# - FanDuel uses Playwright and runs in a subprocess (this is normal)
# - Set `HEADLESS = False` to see browser windows for debugging
# - Scrapers typically take 1-3 minutes each
# - Check "Team Data Coverage" to ensure quality (should be ≥95%)
#
# ---
#
# **✅ Ready to use! Update WEEK and run all cells.**
