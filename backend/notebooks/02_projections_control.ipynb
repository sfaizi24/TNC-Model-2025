# %% [markdown]
# # 🎮 Fantasy Football Projections - Control Panel
#
# **Scrape and manage player projections from multiple sources.**
#
# ## Quick Start:
# 1. **Update `WEEK` and `SEASON`** in the configuration
# 2. **Run All Cells** to scrape all sources
# 3. View database status and data quality metrics
#
# ## Sources:
# - 🔵 FanDuel
# - 💤 Sleeper
# - 🔴 ESPN
# - 📊 FantasyPros
# - 🎯 First Down Studio
#
# ---

# %% [markdown]
# ## 📦 Setup & Configuration

# %%
import os
import sqlite3
import subprocess
import sys
from datetime import datetime
from pathlib import Path

# Add scrapers directory to path FIRST (so local imports work)
NOTEBOOK_DIR = Path().absolute()
BACKEND_DIR = NOTEBOOK_DIR.parent
SCRAPERS_DIR = BACKEND_DIR / "scrapers"
sys.path.insert(0, str(SCRAPERS_DIR))

# Now import from scrapers (they use local imports like "from database import ProjectionsDB")
from database import ProjectionsDB
from scraper_sleeper import SleeperScraper
from scraper_espn import ESPNScraper
from scraper_fantasypros import FantasyProsScraper
from scraper_firstdown import FirstDownStudioScraper

# ==================== CONFIGURATION ====================
# Update these for each scraping session

WEEK = "Week 12"  # ⬅️ UPDATE THIS!
SEASON = "2025"
HEADLESS = True  # Set to False to see browser windows

# Database path
DB_PATH = str(BACKEND_DIR / "data" / "databases" / "projections.db")

print("✅ Setup Complete!")
print(f"📅 {WEEK}, Season {SEASON}")
print(f"👁️  Headless mode: {HEADLESS}")
print(f"💾 Database: {DB_PATH}")
print("\n" + "="*70 + "\n")
# Out:
# ✅ Setup Complete!
# 📅 Week 12, Season 2025
# 👁️  Headless mode: True
# 💾 Database: C:\Users\Samer Faizi\Documents\Claude Model\backend\data\databases\projections.db
#
# ======================================================================

# %% [markdown]
# ## 🤖 Run All Scrapers
#
# This will scrape projections from all sources for the configured week.

# %%
def run_all_scrapers():
    """Run all scrapers for the configured week."""
    print(f"{'='*70}")
    print(f"RUNNING ALL SCRAPERS - {WEEK}")
    print(f"{'='*70}\n")
    
    results = {}
    
    # 1. Sleeper (API-based, fast)
    print("💤 Sleeper...")
    try:
        with SleeperScraper(db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, season=SEASON)
        results['Sleeper'] = '✅'
        print("  ✓ Complete\n")
    except Exception as e:
        results['Sleeper'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
    
    # 2. ESPN
    print("🔴 ESPN...")
    try:
        with ESPNScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, season=SEASON)
        results['ESPN'] = '✅'
        print("  ✓ Complete\n")
    except Exception as e:
        results['ESPN'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
    
    # 3. FantasyPros
    print("📊 FantasyPros...")
    try:
        with FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK)
        results['FantasyPros'] = '✅'
        print("  ✓ Complete\n")
    except Exception as e:
        results['FantasyPros'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
    
    # 4. First Down Studio
    print("🎯 First Down Studio...")
    try:
        with FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, scoring="PPR")
        results['First Down'] = '✅'
        print("  ✓ Complete\n")
    except Exception as e:
        results['First Down'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
    
    # 5. FanDuel (via subprocess due to Playwright)
    print("🔵 FanDuel (subprocess)...")
    try:
        temp_script = NOTEBOOK_DIR / "_temp_fanduel.py"
        script_content = f'''
import sys
sys.path.insert(0, r"{SCRAPERS_DIR}")
from scraper_fanduel import FanDuelScraper

try:
    with FanDuelScraper(headless={HEADLESS}, db_path=r"{DB_PATH}") as scraper:
        scraper.scrape_and_save(week="{WEEK}")
    print("FanDuel complete")
except Exception as e:
    print(f"Error: {{e}}")
    raise
'''
        temp_script.write_text(script_content, encoding='utf-8')
        
        result = subprocess.run(
            [sys.executable, str(temp_script)],
            capture_output=True,
            text=True,
            cwd=str(SCRAPERS_DIR),
            timeout=300  # 5 minute timeout
        )
        
        if result.returncode == 0:
            results['FanDuel'] = '✅'
            print("  ✓ Complete\n")
        else:
            results['FanDuel'] = f'❌ {result.stderr[:50]}'
            print(f"  ✗ Error: {result.stderr}\n")
        
        temp_script.unlink(missing_ok=True)
    except Exception as e:
        results['FanDuel'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
        if temp_script.exists():
            temp_script.unlink()
    
    # Summary
    print(f"{'='*70}")
    print(f"SCRAPING SUMMARY")
    print(f"{'='*70}\n")
    for source, status in results.items():
        print(f"  {source:<15} {status}")
    print(f"\n{'='*70}\n")

# Run scrapers
run_all_scrapers()
# Out:
# ======================================================================
# RUNNING ALL SCRAPERS - Week 12
# ======================================================================
#
# 💤 Sleeper...
#
# Fetching Sleeper projections for 2025 Week 12...
# Fetching all players from Sleeper API...
#   ✓ Loaded 11401 players
# Fetching from: https://api.sleeper.app/v1/projections/nfl/regular/2025/12
#   ✓ Successfully fetched 8619 player projections
#
# Parsing 8619 projections...
#   Brandon Aubrey (K): 10.1 pts
#   CeeDee Lamb (WR): 18.6 pts
#   Bucky Irving (RB): 12.4 pts
#   Kyle Pitts (TE): 10.9 pts
#   Joe Flacco (QB): 17.9 pts
#   Davis Mills (QB): 16.2 pts
#   Dak Prescott (QB): 21.7 pts
#   Matthew Stafford (QB): 20.7 pts
#   Khalil Shakir (WR): 11.8 pts
#   James Cook (RB): 16.7 pts
#   Jauan Jennings (WR): 11.9 pts
#   Sam Darnold (QB): 19.8 pts
#   Jaxon Smith-Njigba (WR): 20.5 pts
#   Daniel Jones (QB): 20.1 pts
#   TreVeyon Henderson (RB): 16.0 pts
#   D'Andre Swift (RB): 12.6 pts
#   Geno Smith (QB): 18.1 pts
#   Jalen Hurts (QB): 25.7 pts
#   Rome Odunze (WR): 11.8 pts
#   Michael Wilson (WR): 12.5 pts
#   Jordan Love (QB): 18.1 pts
#   Kirk Cousins (QB): 17.0 pts
#   Jake Ferguson (TE): 10.5 pts
#   Patrick Mahomes (QB): 24.9 pts
#   Shedeur Sanders (QB): 14.0 pts
#   Tee Higgins (WR): 16.3 pts
#   Lamar Jackson (QB): 25.1 pts
#   Davante Adams (WR): 15.8 pts
#   Aaron Rodgers (QB): 20.7 pts
#   Tyler Shough (QB): 18.9 pts
#   Tyrod Taylor (QB): 16.2 pts
#   Baker Mayfield (QB): 20.4 pts
#   Tyler Warren (TE): 12.1 pts
#   Jakobi Meyers (WR): 10.3 pts
#   Ricky Pearsall (WR): 11.3 pts
#   Emeka Egbuka (WR): 13.6 pts
#   Nico Collins (WR): 14.6 pts
#   Bryce Young (QB): 18.6 pts
#   Rico Dowdle (RB): 16.7 pts
#   George Pickens (WR): 15.0 pts
#   Woody Marks (RB): 14.4 pts
#   Derrick Henry (RB): 16.8 pts
#   Cam Ward (QB): 14.6 pts
#   Puka Nacua (WR): 19.8 pts
#   A.J. Brown (WR): 15.9 pts
#   Christian McCaffrey (RB): 25.2 pts
#   Saquon Barkley (RB): 16.9 pts
#   Tre Tucker (WR): 10.7 pts
#   Trey McBride (TE): 18.5 pts
#   Alec Pierce (WR): 10.9 pts
#   Hunter Henry (TE): 10.2 pts
#   Trevor Lawrence (QB): 19.8 pts
#   Jaxson Dart (QB): 21.6 pts
#   J.J. McCarthy (QB): 17.4 pts
#   Ashton Jeanty (RB): 14.3 pts
#   Dallas Goedert (TE): 11.7 pts
#   Rashee Rice (WR): 17.5 pts
#   Bijan Robinson (RB): 20.9 pts
#   DeVonta Smith (WR): 15.9 pts
#   Xavier Worthy (WR): 10.5 pts
#   Jahmyr Gibbs (RB): 22.4 pts
#   Jared Goff (QB): 20.3 pts
#   Jameson Williams (WR): 13.7 pts
#   Darnell Mooney (WR): 10.4 pts
#   George Kittle (TE): 15.1 pts
#   Brock Purdy (QB): 23.0 pts
#   Quinshon Judkins (RB): 13.6 pts
#   Kenneth Walker (RB): 11.6 pts
#   Amon-Ra St. Brown (WR): 19.4 pts
#   Tetairoa McMillan (WR): 14.8 pts
#   Stefon Diggs (WR): 16.0 pts
#   Kenneth Gainwell (RB): 12.1 pts
#   Travis Etienne (RB): 12.9 pts
#   Brian Thomas (WR): 11.5 pts
#   David Montgomery (RB): 11.7 pts
#   Aaron Jones (RB): 11.6 pts
#   Kyren Williams (RB): 13.4 pts
#   Romeo Doubs (WR): 10.8 pts
#   Jaylen Warren (RB): 13.0 pts
#   Chase Brown (RB): 16.2 pts
#   Justin Jefferson (WR): 15.5 pts
#   Chris Olave (WR): 16.8 pts
#   Josh Allen (QB): 25.9 pts
#   Zay Flowers (WR): 15.0 pts
#   Wan'Dale Robinson (WR): 12.8 pts
#   Caleb Williams (QB): 18.1 pts
#   Alvin Kamara (RB): 12.9 pts
#   Jacoby Brissett (QB): 19.8 pts
#   Jake Bates (K): 10.3 pts
#   Travis Kelce (TE): 12.2 pts
#   Josh Jacobs (RB): 14.7 pts
#   Zach Charbonnet (RB): 11.0 pts
#   Brock Bowers (TE): 15.1 pts
#   Jordan Addison (WR): 10.4 pts
#   Michael Pittman (WR): 12.7 pts
#   Juwan Johnson (TE): 10.9 pts
#   DK Metcalf (WR): 13.3 pts
#   Breece Hall (RB): 12.4 pts
#   Jonathan Taylor (RB): 23.9 pts
#   Drake Maye (QB): 25.3 pts
#   Javonte Williams (RB): 16.9 pts
#
# ✓ Projections with data: 8619 out of 8619
# ✓ Total players with valid projections: 430
#
# Saving 430 projections to database...
# ✓ Successfully saved to database!
#   ✓ Complete
#
# 🔴 ESPN...
#
# Fetching ESPN projections for Week 12...
# Navigating to https://fantasy.espn.com/football/players/projections...
# Clicking 'Sortable Projections' view...
#   ✓ Switched to Sortable Projections view
# Setting scoring to Points PPR...
#   ✓ Set to Points PPR
# Setting to This Week projections...
#   ✓ Set to This Week
#
# Scraping 6 positions (up to 50 players each)...
#
#   Filtering to QB...
#     ✓ Filtered to QB
#     Found 50 players
#       Drake Maye (NE): 25.1 pts
#       Jalen Hurts (PHI): 22.4 pts
#       Patrick Mahomes (KC): 21.4 pts
#       Lamar Jackson (BAL): 21.2 pts
#       Brock Purdy (SF): 20.3 pts
#       Daniel Jones (IND): 19.9 pts
#       Matthew Stafford (LAR): 19.6 pts
#       Jaxson Dart (NYG): 19.5 pts
#       Josh Allen (BUF): 19.1 pts
#       Jared Goff (DET): 17.8 pts
#       Dak Prescott (DAL): 17.7 pts
#       Caleb Williams (CHI): 17.5 pts
#       Jordan Love (GB): 17.4 pts
#       Jacoby Brissett (ARI): 16.8 pts
#       Davis Mills (HOU): 16.5 pts
#       Tyler Shough (NO): 16.0 pts
#       Joe Flacco (CIN): 15.9 pts
#       Tyrod Taylor (NYJ): 15.5 pts
#       Trevor Lawrence (JAX): 15.4 pts
#       Sam Darnold (SEA): 15.2 pts
#       Mason Rudolph (PIT): 14.8 pts
#       Baker Mayfield (TB): 14.7 pts
#       Bryce Young (CAR): 14.5 pts
#       J.J. McCarthy (MIN): 14.2 pts
#       Geno Smith (LV): 12.6 pts
#       Kirk Cousins (ATL): 12.4 pts
#       Cam Ward (TEN): 10.8 pts
#       Shedeur Sanders (CLE): 10.5 pts
#     ✓ Scraped 28 QB projections
#
#   Filtering to RB...
#     ✓ Filtered to RB
#     Found 50 players
#       Christian McCaffrey (SF): 26.1 pts
#       Bijan Robinson (ATL): 21.7 pts
#       Jahmyr Gibbs (DET): 21.0 pts
#       Jonathan Taylor (IND): 20.5 pts
#       Rico Dowdle (CAR): 18.7 pts
#       Derrick Henry (BAL): 17.1 pts
#       Saquon Barkley (PHI): 16.8 pts
#       Chase Brown (CIN): 15.8 pts
#       James Cook (BUF): 15.8 pts
#       Ashton Jeanty (LV): 15.3 pts
#       Kyren Williams (LAR): 15.0 pts
#       D'Andre Swift (CHI): 14.9 pts
#       Jaylen Warren (PIT): 14.6 pts
#       Emanuel Wilson (GB): 14.5 pts
#       TreVeyon Henderson (NE): 14.4 pts
#       Breece Hall (NYJ): 14.2 pts
#       Javonte Williams (DAL): 14.2 pts
#       Rhamondre Stevenson (NE): 14.0 pts
#       Quinshon Judkins (CLE): 13.9 pts
#       Kenneth Walker (SEA): 13.8 pts
#       Alvin Kamara (NO): 13.7 pts
#       Woody Marks (HOU): 13.6 pts
#       Travis Etienne Jr. (JAX): 13.6 pts
#       Aaron Jones Sr. (MIN): 13.5 pts
#       David Montgomery (DET): 13.0 pts
#       Bucky Irving (TB): 12.2 pts
#       Tyrone Tracy Jr. (NYG): 11.1 pts
#       Trey Benson (ARI): 11.1 pts
#       Kenneth Gainwell (PIT): 10.2 pts
#       Tony Pollard (TEN): 10.0 pts
#     ✓ Scraped 50 RB projections
#
#   Filtering to WR...
#     ✓ Filtered to WR
#     Found 50 players
#       Jaxon Smith-Njigba (SEA): 21.3 pts
#       Puka Nacua (LAR): 20.8 pts
#       Amon-Ra St. Brown (DET): 20.2 pts
#       CeeDee Lamb (DAL): 18.2 pts
#       Rashee Rice (KC): 17.7 pts
#       Justin Jefferson (MIN): 17.5 pts
#       Chris Olave (NO): 17.0 pts
#       Davante Adams (LAR): 16.9 pts
#       Emeka Egbuka (TB): 16.7 pts
#       Stefon Diggs (NE): 16.7 pts
#       Tee Higgins (CIN): 16.6 pts
#       George Pickens (DAL): 16.6 pts
#       Nico Collins (HOU): 16.4 pts
#       Tetairoa McMillan (CAR): 16.4 pts
#       A.J. Brown (PHI): 16.3 pts
#       Michael Pittman Jr. (IND): 15.6 pts
#       DeVonta Smith (PHI): 14.8 pts
#       Jauan Jennings (SF): 14.0 pts
#       Wan'Dale Robinson (NYG): 13.4 pts
#       Zay Flowers (BAL): 13.2 pts
#       Rome Odunze (CHI): 13.1 pts
#       Michael Wilson (ARI): 13.0 pts
#       Jameson Williams (DET): 12.9 pts
#       DK Metcalf (PIT): 12.8 pts
#       Romeo Doubs (GB): 12.3 pts
#       Jordan Addison (MIN): 11.9 pts
#       Khalil Shakir (BUF): 11.5 pts
#       Alec Pierce (IND): 11.4 pts
#       Xavier Worthy (KC): 11.4 pts
#       Christian Watson (GB): 11.3 pts
#       Darnell Mooney (ATL): 11.2 pts
#       Brian Thomas Jr. (JAX): 11.2 pts
#       Josh Downs (IND): 10.7 pts
#       Ricky Pearsall (SF): 10.3 pts
#     ✓ Scraped 50 WR projections
#
#   Filtering to TE...
#     ✓ Filtered to TE
#     Found 50 players
#       Trey McBride (ARI): 17.9 pts
#       Brock Bowers (LV): 15.1 pts
#       George Kittle (SF): 15.1 pts
#       Tyler Warren (IND): 14.8 pts
#       Travis Kelce (KC): 11.9 pts
#       Hunter Henry (NE): 11.5 pts
#       Dallas Goedert (PHI): 11.3 pts
#       Kyle Pitts Sr. (ATL): 10.9 pts
#       Dalton Schultz (HOU): 10.2 pts
#       Mark Andrews (BAL): 10.0 pts
#     ✓ Scraped 50 TE projections
#
#   Filtering to K...
#     ✓ Filtered to K
#     Found 50 players
#     ✓ Scraped 28 K projections
#
#   Filtering to D/ST...
#     ✓ Filtered to D/ST
#     Found 32 players
#     ✓ Scraped 28 D/ST projections
#
# ✓ Total players with valid projections: 234
#
# Saving 234 projections to database...
# ✓ Successfully saved to database!
#   ✓ Complete
#
# 📊 FantasyPros...
#
# Fetching FantasyPros consensus rankings for Week 12...
#
# Scraping QB from https://www.fantasypros.com/nfl/rankings/qb.php...
#   ⚠️  Page load timeout, retrying (1/2)...
#   Found 69 rows
#   Drake Maye (NE): 23.5 pts
#
#   DEBUG: Cleaned 'Lamar Jackson (BAL) Q' → 'Lamar Jackson (BAL)'
#   Lamar Jackson (BAL): 22.1 pts
#   Josh Allen (BUF): 21.6 pts
#   Jalen Hurts (PHI): 20.8 pts
#   Patrick Mahomes II (KC): 20.4 pts
#   Matthew Stafford (LAR): 19.9 pts
#   Jared Goff (DET): 19.4 pts
#   Brock Purdy (SF): 18.9 pts
#   Jacoby Brissett (ARI): 18.6 pts
#
#   DEBUG: Cleaned 'Dak Prescott (DAL) Q' → 'Dak Prescott (DAL)'
#   Dak Prescott (DAL): 18.1 pts
#   Caleb Williams (CHI): 17.7 pts
#   Daniel Jones (IND): 17.4 pts
#
#   DEBUG: Cleaned 'Jaxson Dart (NYG) Q' → 'Jaxson Dart (NYG)'
#   Jaxson Dart (NYG): 17.1 pts
#
#   DEBUG: Cleaned 'Baker Mayfield (TB) Q' → 'Baker Mayfield (TB)'
#   Baker Mayfield (TB): 16.8 pts
#   Sam Darnold (SEA): 16.6 pts
#   Jordan Love (GB): 16.3 pts
#   Trevor Lawrence (JAC): 16.0 pts
#
#   DEBUG: Cleaned 'Joe Flacco (CIN) Q' → 'Joe Flacco (CIN)'
#   Joe Flacco (CIN): 15.8 pts
#   Bryce Young (CAR): 15.5 pts
#   Tyler Shough (NO): 15.1 pts
#   J.J. McCarthy (MIN): 14.8 pts
#   Davis Mills (HOU): 14.4 pts
#   Mason Rudolph (PIT): 14.0 pts
#   Kirk Cousins (ATL): 13.5 pts
#   Tyrod Taylor (NYJ): 13.0 pts
#   Geno Smith (LV): 12.3 pts
#   Shedeur Sanders (CLE): 11.2 pts
#
#   DEBUG: Cleaned 'Aaron Rodgers (PIT) Q' → 'Aaron Rodgers (PIT)'
#
#   DEBUG: Cleaned 'Dillon Gabriel (CLE) Q' → 'Dillon Gabriel (CLE)'
#   ✓ Scraped 66 QB projections
#   ✓ Team data found: 66/66 (100.0%)
#
# Scraping RB from https://www.fantasypros.com/nfl/rankings/ppr-rb.php...
#   Found 109 rows
#   Christian McCaffrey (SF): 25.1 pts
#   Jahmyr Gibbs (DET): 21.8 pts
#   Jonathan Taylor (IND): 21.0 pts
#   Bijan Robinson (ATL): 20.8 pts
#   Rico Dowdle (CAR): 16.5 pts
#   Saquon Barkley (PHI): 16.3 pts
#   Javonte Williams (DAL): 15.9 pts
#   TreVeyon Henderson (NE): 15.9 pts
#   Derrick Henry (BAL): 15.4 pts
#   Chase Brown (CIN): 15.3 pts
#   James Cook III (BUF): 14.4 pts
#   Kyren Williams (LAR): 14.3 pts
#
#   DEBUG: Cleaned 'Travis Etienne Jr. (JAC) Q' → 'Travis Etienne Jr. (JAC)'
#   Travis Etienne Jr. (JAC): 14.2 pts
#   Woody Marks (HOU): 14.1 pts
#   Ashton Jeanty (LV): 13.5 pts
#   Quinshon Judkins (CLE): 13.3 pts
#   Breece Hall (NYJ): 13.3 pts
#
#   DEBUG: Cleaned 'D'Andre Swift (CHI) Q' → 'D'Andre Swift (CHI)'
#   D'Andre Swift (CHI): 13.1 pts
#   Aaron Jones Sr. (MIN): 13.1 pts
#   Kenneth Walker III (SEA): 12.3 pts
#   Emanuel Wilson (GB): 11.8 pts
#   David Montgomery (DET): 11.7 pts
#
#   DEBUG: Cleaned 'Alvin Kamara (NO) Q' → 'Alvin Kamara (NO)'
#   Alvin Kamara (NO): 11.4 pts
#   Kareem Hunt (KC): 11.2 pts
#
#   DEBUG: Cleaned 'Jaylen Warren (PIT) Q' → 'Jaylen Warren (PIT)'
#   Jaylen Warren (PIT): 11.0 pts
#   Tyrone Tracy Jr. (NYG): 10.6 pts
#   Zach Charbonnet (SEA): 10.4 pts
#
#   DEBUG: Cleaned 'Zonovan Knight (ARI) Q' → 'Zonovan Knight (ARI)'
#
#   DEBUG: Cleaned 'Bhayshul Tuten (JAC) Q' → 'Bhayshul Tuten (JAC)'
#
#   DEBUG: Cleaned 'Rhamondre Stevenson (NE) Q' → 'Rhamondre Stevenson (NE)'
#
#   DEBUG: Cleaned 'Bucky Irving (TB) Q' → 'Bucky Irving (TB)'
#
#   DEBUG: Cleaned 'Trey Benson (ARI) Q' → 'Trey Benson (ARI)'
#
#   DEBUG: Cleaned 'Josh Jacobs (GB) Q' → 'Josh Jacobs (GB)'
#
#   DEBUG: Cleaned 'Emari Demercado (ARI) Q' → 'Emari Demercado (ARI)'
#
#   DEBUG: Cleaned 'Travis Homer (CHI) Q' → 'Travis Homer (CHI)'
#
#   DEBUG: Cleaned 'Samaje Perine (CIN) Q' → 'Samaje Perine (CIN)'
#
#   DEBUG: Cleaned 'Phil Mafah (DAL) IR' → 'Phil Mafah (DAL)'
#
#   DEBUG: Cleaned 'Sione Vaki (DET) Q' → 'Sione Vaki (DET)'
#   ✓ Scraped 105 RB projections
#   ✓ Team data found: 105/105 (100.0%)
#
# Scraping WR from https://www.fantasypros.com/nfl/rankings/ppr-wr.php...
#   Found 144 rows
#   Puka Nacua (LAR): 21.0 pts
#   Jaxon Smith-Njigba (SEA): 19.9 pts
#   Amon-Ra St. Brown (DET): 19.9 pts
#   Rashee Rice (KC): 17.5 pts
#   CeeDee Lamb (DAL): 16.7 pts
#
#   DEBUG: Cleaned 'Emeka Egbuka (TB) Q' → 'Emeka Egbuka (TB)'
#   Emeka Egbuka (TB): 16.4 pts
#   Davante Adams (LAR): 16.2 pts
#   Nico Collins (HOU): 16.1 pts
#   Stefon Diggs (NE): 15.7 pts
#   Tee Higgins (CIN): 15.6 pts
#   Chris Olave (NO): 15.5 pts
#   Justin Jefferson (MIN): 15.4 pts
#   Tetairoa McMillan (CAR): 14.6 pts
#   DeVonta Smith (PHI): 14.5 pts
#   George Pickens (DAL): 14.2 pts
#   Wan'Dale Robinson (NYG): 14.2 pts
#   A.J. Brown (PHI): 14.1 pts
#   Michael Pittman Jr. (IND): 13.5 pts
#   Jameson Williams (DET): 13.4 pts
#   Rome Odunze (CHI): 13.3 pts
#   Zay Flowers (BAL): 12.8 pts
#   Michael Wilson (ARI): 12.6 pts
#   DK Metcalf (PIT): 12.5 pts
#   Jauan Jennings (SF): 11.9 pts
#   Khalil Shakir (BUF): 11.8 pts
#
#   DEBUG: Cleaned 'Romeo Doubs (GB) Q' → 'Romeo Doubs (GB)'
#   Romeo Doubs (GB): 11.2 pts
#   Alec Pierce (IND): 10.9 pts
#   Jordan Addison (MIN): 10.6 pts
#
#   DEBUG: Cleaned 'Christian Watson (GB) Q' → 'Christian Watson (GB)'
#   Christian Watson (GB): 10.5 pts
#   Ricky Pearsall (SF): 10.3 pts
#
#   DEBUG: Cleaned 'Xavier Worthy (KC) Q' → 'Xavier Worthy (KC)'
#   Xavier Worthy (KC): 10.2 pts
#   Tez Johnson (TB): 10.1 pts
#   Darnell Mooney (ATL): 10.0 pts
#   Jakobi Meyers (JAC): 10.0 pts
#
#   DEBUG: Cleaned 'Brian Thomas Jr. (JAC) Q' → 'Brian Thomas Jr. (JAC)'
#
#   DEBUG: Cleaned 'Elic Ayomanor (TEN) Q' → 'Elic Ayomanor (TEN)'
#
#   DEBUG: Cleaned 'Matthew Golden (GB) Q' → 'Matthew Golden (GB)'
#
#   DEBUG: Cleaned 'Sterling Shepard (TB) Q' → 'Sterling Shepard (TB)'
#
#   DEBUG: Cleaned 'Dontayvion Wicks (GB) Q' → 'Dontayvion Wicks (GB)'
#
#   DEBUG: Cleaned 'Isaac TeSlaa (DET) Q' → 'Isaac TeSlaa (DET)'
#
#   DEBUG: Cleaned 'Chris Godwin Jr. (TB) Q' → 'Chris Godwin Jr. (TB)'
#
#   DEBUG: Cleaned 'Darius Slayton (NYG) Q' → 'Darius Slayton (NYG)'
#
#   DEBUG: Cleaned 'Rashod Bateman (BAL) Q' → 'Rashod Bateman (BAL)'
#
#   DEBUG: Cleaned 'Marvin Harrison Jr. (ARI) Q' → 'Marvin Harrison Jr. (ARI)'
#
#   DEBUG: Cleaned 'Tory Horton (SEA) Q' → 'Tory Horton (SEA)'
#
#   DEBUG: Cleaned 'Savion Williams (GB) Q' → 'Savion Williams (GB)'
#
#   DEBUG: Cleaned 'Drake London (ATL) Q' → 'Drake London (ATL)'
#
#   DEBUG: Cleaned 'Curtis Samuel (BUF) O' → 'Curtis Samuel (BUF)'
#
#   DEBUG: Cleaned 'Xavier Smith (LAR) Q' → 'Xavier Smith (LAR)'
#   ✓ Scraped 140 WR projections
#   ✓ Team data found: 140/140 (100.0%)
#
# Scraping TE from https://www.fantasypros.com/nfl/rankings/ppr-te.php...
#   Found 73 rows
#   Trey McBride (ARI): 18.3 pts
#   George Kittle (SF): 15.1 pts
#   Brock Bowers (LV): 15.1 pts
#   Tyler Warren (IND): 13.0 pts
#   Travis Kelce (KC): 12.9 pts
#   Hunter Henry (NE): 11.7 pts
#   Dallas Goedert (PHI): 11.2 pts
#   Jake Ferguson (DAL): 10.8 pts
#   Kyle Pitts Sr. (ATL): 10.6 pts
#   Theo Johnson (NYG): 10.2 pts
#   Mark Andrews (BAL): 10.0 pts
#   Cade Otton (TB): 10.0 pts
#
#   DEBUG: Cleaned 'David Njoku (CLE) Q' → 'David Njoku (CLE)'
#
#   DEBUG: Cleaned 'Isaiah Likely (BAL) Q' → 'Isaiah Likely (BAL)'
#
#   DEBUG: Cleaned 'Chig Okonkwo (TEN) Q' → 'Chig Okonkwo (TEN)'
#
#   DEBUG: Cleaned 'Brock Wright (DET) Q' → 'Brock Wright (DET)'
#
#   DEBUG: Cleaned 'Tyler Higbee (LAR) IR' → 'Tyler Higbee (LAR)'
#
#   DEBUG: Cleaned 'Brenton Strange (JAC) Q' → 'Brenton Strange (JAC)'
#
#   DEBUG: Cleaned 'Hunter Long (JAC) Q' → 'Hunter Long (JAC)'
#
#   DEBUG: Cleaned 'Austin Hooper (NE) Q' → 'Austin Hooper (NE)'
#
#   DEBUG: Cleaned 'Thomas Fidone II (NYG) Q' → 'Thomas Fidone II (NYG)'
#   ✓ Scraped 70 TE projections
#   ✓ Team data found: 70/70 (100.0%)
#
# Scraping K from https://www.fantasypros.com/nfl/rankings/k.php...
#   Found 34 rows
#   Brandon Aubrey (DAL): 10.0 pts
#
#   DEBUG: Cleaned 'Chase McLaughlin (TB) Q' → 'Chase McLaughlin (TB)'
#   ✓ Scraped 31 K projections
#   ✓ Team data found: 31/31 (100.0%)
#
# Scraping DST from https://www.fantasypros.com/nfl/rankings/dst.php...
#   Found 28 rows
#   Seattle Seahawks Defense (SEA): 10.0 pts
#   ✓ Scraped 25 DST projections
#   ✓ Team data found: 25/25 (100.0%)
#
# ✓ Total players scraped: 437
#
# Saving 437 projections to database...
# ✓ Successfully saved to database!
#   ✓ Complete
#
# 🎯 First Down Studio...
# Navigating to https://www.firstdown.studio/rankings...
# Note: PPR points will be calculated from component stats for FLEX players
#
# Scraping QB tab...
# Error scraping QB tab: Message:
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff641dca235
# 	0x7ff641b22630
# 	0x7ff6418b16dd
# 	0x7ff64190a27e
# 	0x7ff64190a58c
# 	0x7ff64195ed77
# 	0x7ff64195baba
# 	0x7ff6418fb0ed
# 	0x7ff6418fbf63
# 	0x7ff641df5d60
# 	0x7ff641defe8a
# 	0x7ff641e11005
# 	0x7ff641b3d71e
# 	0x7ff641b44e1f
# 	0x7ff641b2b7c4
# 	0x7ff641b2b97f
# 	0x7ff641b118e8
# 	0x7ffba74be8d7
# 	0x7ffba840c53c
#
#
# Scraping FLEX tab...
# Error scraping FLEX tab: Message:
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff641dca235
# 	0x7ff641b22630
# 	0x7ff6418b16dd
# 	0x7ff64190a27e
# 	0x7ff64190a58c
# 	0x7ff64195ed77
# 	0x7ff64195baba
# 	0x7ff6418fb0ed
# 	0x7ff6418fbf63
# 	0x7ff641df5d60
# 	0x7ff641defe8a
# 	0x7ff641e11005
# 	0x7ff641b3d71e
# 	0x7ff641b44e1f
# 	0x7ff641b2b7c4
# 	0x7ff641b2b97f
# 	0x7ff641b118e8
# 	0x7ffba74be8d7
# 	0x7ffba840c53c
#
#
# Total unique players scraped: 0
# No projections found to save.
#   ✓ Complete
#
# 🔵 FanDuel (subprocess)...
#   ✓ Complete
#
# ======================================================================
# SCRAPING SUMMARY
# ======================================================================
#
#   Sleeper         ✅
#   ESPN            ✅
#   FantasyPros     ✅
#   First Down      ✅
#   FanDuel         ✅
#
# ======================================================================

# %% [markdown]
# ## 📊 Database Status & Data Quality

# %%
def show_database_status():
    """Display comprehensive database status and data quality metrics."""
    with ProjectionsDB(db_path=DB_PATH) as db:
        all_projs = db.get_projections()
        
        print(f"{'='*70}")
        print(f"DATABASE STATUS")
        print(f"{'='*70}\n")
        print(f"Total records: {len(all_projs)}\n")
        
        # Count by source
        print(f"📊 Records by Source:")
        print("-" * 70)
        sources = {}
        for p in all_projs:
            source = p['source_website']
            sources[source] = sources.get(source, 0) + 1
        
        for source, count in sorted(sources.items()):
            print(f"  {source:<25} {count:>5} records")
        
        # Count by week
        print(f"\n📅 Records by Week:")
        print("-" * 70)
        weeks = {}
        for p in all_projs:
            week = p['week']
            weeks[week] = weeks.get(week, 0) + 1
        
        for week, count in sorted(weeks.items()):
            print(f"  {week:<25} {count:>5} records")
        
        # Team coverage (data quality check)
        print(f"\n🏈 Team Data Coverage (Quality Check):")
        print("-" * 70)
        for source in sorted(sources.keys()):
            source_projs = [p for p in all_projs if p['source_website'] == source]
            with_team = sum(1 for p in source_projs if p.get('team'))
            total = len(source_projs)
            pct = (with_team / total * 100) if total > 0 else 0
            status = "✅" if pct >= 95 else "⚠️" if pct >= 75 else "❌"
            print(f"  {source:<25} {with_team:>4}/{total:<4} ({pct:>5.1f}%) {status}")
        
        print(f"\n{'='*70}\n")

# Show status
show_database_status()
# Out:
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 4846
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#   espn.com                    706 records
#   fanduel.com                1452 records
#   fantasypros.com            1146 records
#   firstdown.studio            337 records
#   sleeper.com                1205 records
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#   Week 10                    1625 records
#   Week 11                    1649 records
#   Week 12                    1572 records
#
# 🏈 Team Data Coverage (Quality Check):
# ----------------------------------------------------------------------
#   espn.com                   706/706  (100.0%) ✅
#   fanduel.com               1452/1452 (100.0%) ✅
#   fantasypros.com           1146/1146 (100.0%) ✅
#   firstdown.studio           337/337  (100.0%) ✅
#   sleeper.com               1205/1205 (100.0%) ✅
#
# ======================================================================

# %% [markdown]
# ---
#
# ## 🛠️ Utility Functions
#
# **Use these as needed for database management**

# %%
# ============================================================================
# UTILITY FUNCTIONS - Uncomment to use
# ============================================================================

def clear_week(week_name):
    """Delete all records from a specific week."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    cursor.execute("DELETE FROM projections WHERE week = ?", (week_name,))
    deleted = cursor.rowcount
    conn.commit()
    conn.close()
    print(f"✓ Deleted {deleted} records from {week_name}")

def clear_source(source_name, week=None):
    """Delete records from a specific source."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    if week:
        cursor.execute("DELETE FROM projections WHERE source_website = ? AND week = ?", (source_name, week))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} for {week}")
    else:
        cursor.execute("DELETE FROM projections WHERE source_website = ?", (source_name,))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} (all weeks)")
    conn.commit()
    conn.close()

def clear_entire_database():
    """⚠️ DELETE ALL RECORDS - requires confirmation."""
    confirm = input("⚠️  Type 'DELETE ALL' to confirm: ")
    if confirm == "DELETE ALL":
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("DELETE FROM projections")
        conn.commit()
        deleted = cursor.rowcount
        conn.close()
        print(f"\n✓ Deleted {deleted} records from database")
    else:
        print("\n✗ Cancelled")

def show_week_source_matrix():
    """Display a matrix showing record counts by week and source."""
    import pandas as pd
    conn = sqlite3.connect(DB_PATH)
    query = """
        SELECT week, source_website, COUNT(*) as count
        FROM projections
        GROUP BY week, source_website
        ORDER BY week, source_website
    """
    df = pd.read_sql_query(query, conn)
    conn.close()
    
    if len(df) == 0:
        print("No data in database")
        return
    
    pivot = df.pivot(index='source_website', columns='week', values='count')
    pivot = pivot.fillna(0).astype(int)
    
    print(f"\n{'='*70}")
    print("WEEK × SOURCE MATRIX")
    print("="*70)
    print(pivot.to_string())
    print("="*70 + "\n")

def run_single_scraper(scraper_name):
    """Run a specific scraper by name."""
    scrapers = {
        'sleeper': lambda: SleeperScraper(db_path=DB_PATH),
        'espn': lambda: ESPNScraper(headless=HEADLESS, db_path=DB_PATH),
        'fantasypros': lambda: FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH),
        'firstdown': lambda: FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH)
    }
    
    name_lower = scraper_name.lower()
    if name_lower not in scrapers:
        print(f"Unknown scraper: {scraper_name}")
        print(f"Available: {', '.join(scrapers.keys())}")
        return
    
    print(f"Running {scraper_name}...")
    try:
        with scrapers[name_lower]() as scraper:
            if name_lower == 'sleeper':
                scraper.scrape_and_save(week=WEEK, season=SEASON)
            elif name_lower == 'espn':
                scraper.scrape_and_save(week=WEEK, season=SEASON)
            elif name_lower == 'firstdown':
                scraper.scrape_and_save(week=WEEK, scoring="PPR")
            else:
                scraper.scrape_and_save(week=WEEK)
        print(f"✓ {scraper_name} complete")
    except Exception as e:
        print(f"✗ Error: {e}")

# Uncomment to use:
# clear_week("Week 10")
# clear_source("fantasypros.com", WEEK)
# clear_entire_database()
show_week_source_matrix()
# run_single_scraper("sleeper")

print("✅ Utility functions loaded. Uncomment above to use.")
# Out:
# ======================================================================
# WEEK × SOURCE MATRIX
# ======================================================================
# week              Week 10  Week 11  Week 12
# source_website
# espn.com              232      240      234
# fanduel.com           473      508      471
# fantasypros.com       388      321      437
# firstdown.studio      161      176        0
# sleeper.com           371      404      430
# ======================================================================
#
# ✅ Utility functions loaded. Uncomment above to use.

# %% [markdown]
# ---
#
# ## 📚 Quick Reference
#
# ### Weekly Workflow:
# 1. Update `WEEK` and `SEASON` in cell 2
# 2. **Kernel → Restart & Run All**
# 3. Wait for all scrapers to complete (~5-10 minutes)
# 4. Check database status for data quality
#
# ### Available Functions:
# - `run_all_scrapers()` - Scrape all sources *(runs automatically)*
# - `show_database_status()` - View database contents *(runs automatically)*
# - `run_single_scraper(name)` - Run one scraper
# - `clear_week(week)` - Delete all data for a week
# - `clear_source(source, week)` - Delete data from a source
# - `show_week_source_matrix()` - See week×source grid
# - `clear_entire_database()` - Delete everything ⚠️
#
# ### Source Names:
# - `"fanduel.com"`
# - `"sleeper.com"`
# - `"espn.com"`
# - `"fantasypros.com"`
# - `"firstdown.studio"`
#
# ### Tips:
# - FanDuel uses Playwright and runs in a subprocess (this is normal)
# - Set `HEADLESS = False` to see browser windows for debugging
# - Scrapers typically take 1-3 minutes each
# - Check "Team Data Coverage" to ensure quality (should be ≥95%)
#
# ---
#
# **✅ Ready to use! Update WEEK and run all cells.**
