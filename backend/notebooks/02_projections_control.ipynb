# %% [markdown]
# # 🎮 Fantasy Football Projections - Control Panel
#
# **Scrape and manage player projections from multiple sources.**
#
# ## Quick Start:
# 1. **Update `WEEK` and `SEASON`** in the configuration
# 2. **Run All Cells** to scrape all sources
# 3. View database status and data quality metrics
#
# ## Sources:
# - 🔵 FanDuel
# - 💤 Sleeper
# - 🔴 ESPN
# - 📊 FantasyPros
# - 🎯 First Down Studio
#
# ---

# %% [markdown]
# ## 📦 Setup & Configuration

# %%
import os
import sqlite3
import subprocess
import sys
from datetime import datetime
from pathlib import Path

# Add scrapers directory to path FIRST (so local imports work)
NOTEBOOK_DIR = Path().absolute()
BACKEND_DIR = NOTEBOOK_DIR.parent
SCRAPERS_DIR = BACKEND_DIR / "scrapers"
sys.path.insert(0, str(SCRAPERS_DIR))

# Now import from scrapers (they use local imports like "from database import ProjectionsDB")
from database import ProjectionsDB
from scraper_sleeper import SleeperScraper
from scraper_espn import ESPNScraper
from scraper_fantasypros import FantasyProsScraper
from scraper_firstdown import FirstDownStudioScraper

# ==================== CONFIGURATION ====================
# Update these for each scraping session

WEEK = "Week 11"  # ⬅️ UPDATE THIS!
SEASON = "2025"
HEADLESS = True  # Set to False to see browser windows

# Database path
DB_PATH = str(BACKEND_DIR / "data" / "databases" / "projections.db")

print("✅ Setup Complete!")
print(f"📅 {WEEK}, Season {SEASON}")
print(f"👁️  Headless mode: {HEADLESS}")
print(f"💾 Database: {DB_PATH}")
print("\n" + "="*70 + "\n")
# Out:
# ✅ Setup Complete!
# 📅 Week 11, Season 2025
# 👁️  Headless mode: True
# 💾 Database: C:\Users\Samer Faizi\Documents\Claude Model\backend\data\databases\projections.db
#
# ======================================================================

# %% [markdown]
# ## 🤖 Run All Scrapers
#
# This will scrape projections from all sources for the configured week.

# %%
def run_all_scrapers():
    """Run all scrapers for the configured week."""
    print(f"{'='*70}")
    print(f"RUNNING ALL SCRAPERS - {WEEK}")
    print(f"{'='*70}\n")
    
    results = {}
    
    # 1. Sleeper (API-based, fast)
    print("💤 Sleeper...")
    try:
        with SleeperScraper(db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, season=SEASON)
        results['Sleeper'] = '✅'
        print("  ✓ Complete\n")
    except Exception as e:
        results['Sleeper'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
    
    # 2. ESPN
    print("🔴 ESPN...")
    try:
        with ESPNScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, season=SEASON)
        results['ESPN'] = '✅'
        print("  ✓ Complete\n")
    except Exception as e:
        results['ESPN'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
    
    # 3. FantasyPros
    print("📊 FantasyPros...")
    try:
        with FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK)
        results['FantasyPros'] = '✅'
        print("  ✓ Complete\n")
    except Exception as e:
        results['FantasyPros'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
    
    # 4. First Down Studio
    print("🎯 First Down Studio...")
    try:
        with FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, scoring="PPR")
        results['First Down'] = '✅'
        print("  ✓ Complete\n")
    except Exception as e:
        results['First Down'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
    
    # 5. FanDuel (via subprocess due to Playwright)
    print("🔵 FanDuel (subprocess)...")
    try:
        temp_script = NOTEBOOK_DIR / "_temp_fanduel.py"
        script_content = f'''
import sys
sys.path.insert(0, r"{SCRAPERS_DIR}")
from scraper_fanduel import FanDuelScraper

try:
    with FanDuelScraper(headless={HEADLESS}, db_path=r"{DB_PATH}") as scraper:
        scraper.scrape_and_save(week="{WEEK}")
    print("FanDuel complete")
except Exception as e:
    print(f"Error: {{e}}")
    raise
'''
        temp_script.write_text(script_content, encoding='utf-8')
        
        result = subprocess.run(
            [sys.executable, str(temp_script)],
            capture_output=True,
            text=True,
            cwd=str(SCRAPERS_DIR),
            timeout=300  # 5 minute timeout
        )
        
        if result.returncode == 0:
            results['FanDuel'] = '✅'
            print("  ✓ Complete\n")
        else:
            results['FanDuel'] = f'❌ {result.stderr[:50]}'
            print(f"  ✗ Error: {result.stderr}\n")
        
        temp_script.unlink(missing_ok=True)
    except Exception as e:
        results['FanDuel'] = f'❌ {str(e)[:50]}'
        print(f"  ✗ Error: {e}\n")
        if temp_script.exists():
            temp_script.unlink()
    
    # Summary
    print(f"{'='*70}")
    print(f"SCRAPING SUMMARY")
    print(f"{'='*70}\n")
    for source, status in results.items():
        print(f"  {source:<15} {status}")
    print(f"\n{'='*70}\n")

# Run scrapers
run_all_scrapers()
# Out:
# ======================================================================
# RUNNING ALL SCRAPERS - Week 11
# ======================================================================
#
# 💤 Sleeper...
#
# Fetching Sleeper projections for 2025 Week 11...
# Fetching all players from Sleeper API...
#   ✓ Loaded 11401 players
# Fetching from: https://api.sleeper.app/v1/projections/nfl/regular/2025/11
#   ✓ Successfully fetched 8621 player projections
#
# Parsing 8621 projections...
#   Brandon Aubrey (K): 10.9 pts
#   CeeDee Lamb (WR): 20.7 pts
#   Oronde Gadsden (TE): 11.3 pts
#   Kyle Pitts (TE): 10.3 pts
#   Joe Flacco (QB): 17.7 pts
#   Dak Prescott (QB): 22.1 pts
#   Matthew Stafford (QB): 19.3 pts
#   Khalil Shakir (WR): 13.4 pts
#   James Cook (RB): 15.1 pts
#   Jauan Jennings (WR): 10.7 pts
#   Rachaad White (RB): 14.9 pts
#   Sam Darnold (QB): 19.1 pts
#   Kimani Vidal (RB): 15.3 pts
#   Jaxon Smith-Njigba (WR): 22.0 pts
#   Jaylen Waddle (WR): 15.6 pts
#   TreVeyon Henderson (RB): 16.3 pts
#   D'Andre Swift (RB): 12.8 pts
#   Geno Smith (QB): 21.5 pts
#   Tua Tagovailoa (QB): 19.6 pts
#   Jalen Hurts (QB): 24.1 pts
#   Ladd McConkey (WR): 14.5 pts
#   Rome Odunze (WR): 12.8 pts
#   Jordan Love (QB): 18.7 pts
#   Jake Ferguson (TE): 11.2 pts
#   Zach Ertz (TE): 10.5 pts
#   Patrick Mahomes (QB): 22.4 pts
#   Ja'Marr Chase (WR): 18.8 pts
#   Justin Herbert (QB): 22.9 pts
#   Tee Higgins (WR): 13.2 pts
#   Sam LaPorta (TE): 12.3 pts
#   Lamar Jackson (QB): 24.6 pts
#   Davante Adams (WR): 15.2 pts
#   Aaron Rodgers (QB): 20.8 pts
#   Deebo Samuel (WR): 13.4 pts
#   Baker Mayfield (QB): 21.5 pts
#   Ricky Pearsall (WR): 12.5 pts
#   Emeka Egbuka (WR): 14.3 pts
#   Nico Collins (WR): 16.5 pts
#   Bryce Young (QB): 18.4 pts
#   Rico Dowdle (RB): 16.4 pts
#   George Pickens (WR): 14.3 pts
#   Woody Marks (RB): 13.9 pts
#   RJ Harvey (RB): 13.1 pts
#   Derrick Henry (RB): 15.8 pts
#   Cam Ward (QB): 14.7 pts
#   Puka Nacua (WR): 22.2 pts
#   A.J. Brown (WR): 15.2 pts
#   Christian McCaffrey (RB): 23.9 pts
#   Justin Fields (QB): 19.0 pts
#   Saquon Barkley (RB): 15.6 pts
#   Tre Tucker (WR): 12.5 pts
#   Trey McBride (TE): 17.3 pts
#   Trevor Lawrence (QB): 18.8 pts
#   J.J. McCarthy (QB): 20.5 pts
#   Ashton Jeanty (RB): 17.3 pts
#   Dallas Goedert (TE): 10.7 pts
#   Rashee Rice (WR): 16.6 pts
#   De'Von Achane (RB): 23.5 pts
#   Michael Penix (QB): 17.5 pts
#   Bijan Robinson (RB): 21.8 pts
#   DeVonta Smith (WR): 15.0 pts
#   Chris Boswell (K): 10.1 pts
#   Drake London (WR): 17.2 pts
#   Xavier Worthy (WR): 10.2 pts
#   Jahmyr Gibbs (RB): 20.9 pts
#   Jared Goff (QB): 19.9 pts
#   Jameson Williams (WR): 10.9 pts
#   George Kittle (TE): 14.1 pts
#   Jameis Winston (QB): 18.6 pts
#   Keenan Allen (WR): 11.2 pts
#   Brock Purdy (QB): 21.2 pts
#   Quinshon Judkins (RB): 13.7 pts
#   Amon-Ra St. Brown (WR): 19.3 pts
#   Tetairoa McMillan (WR): 13.4 pts
#   Bo Nix (QB): 20.5 pts
#   Stefon Diggs (WR): 13.8 pts
#   Kenneth Gainwell (RB): 10.5 pts
#   Travis Etienne (RB): 13.9 pts
#   Brian Thomas (WR): 11.5 pts
#   David Montgomery (RB): 10.6 pts
#   Aaron Jones (RB): 14.3 pts
#   Kyren Williams (RB): 13.5 pts
#   Romeo Doubs (WR): 11.0 pts
#   Dillon Gabriel (QB): 15.8 pts
#   Jaylen Warren (RB): 14.9 pts
#   Chase Brown (RB): 15.6 pts
#   Justin Jefferson (WR): 17.4 pts
#   Quentin Johnston (WR): 12.3 pts
#   Josh Allen (QB): 26.0 pts
#   Zay Flowers (WR): 14.6 pts
#   Wan'Dale Robinson (WR): 13.4 pts
#   Courtland Sutton (WR): 12.4 pts
#   Caleb Williams (QB): 18.4 pts
#   Jacoby Brissett (QB): 18.6 pts
#   C.J. Stroud (QB): 19.4 pts
#   Marcus Mariota (QB): 20.8 pts
#   Travis Kelce (TE): 11.0 pts
#   Darius Slayton (WR): 10.4 pts
#   Josh Jacobs (RB): 20.1 pts
#   Brock Bowers (TE): 17.2 pts
#   Jordan Addison (WR): 12.0 pts
#   DK Metcalf (WR): 14.1 pts
#   Breece Hall (RB): 12.3 pts
#   Drake Maye (QB): 23.1 pts
#   Javonte Williams (RB): 18.5 pts
#
# ✓ Projections with data: 8621 out of 8621
# ✓ Total players with valid projections: 461
#
# Saving 461 projections to database...
# ✓ Successfully saved to database!
#   ✓ Complete
#
# 🔴 ESPN...
#
# Fetching ESPN projections for Week 11...
# Navigating to https://fantasy.espn.com/football/players/projections...
# Clicking 'Sortable Projections' view...
#   ✓ Switched to Sortable Projections view
# Setting scoring to Points PPR...
#   ✓ Set to Points PPR
# Setting to This Week projections...
#   ✓ Set to This Week
#
# Scraping 6 positions (up to 50 players each)...
#
#   Filtering to QB...
#     ✓ Filtered to QB
#     Found 50 players
#       Drake Maye (NE): 22.4 pts
#       Jalen Hurts (PHI): 21.6 pts
#       Josh Allen (BUF): 20.7 pts
#       Lamar Jackson (BAL): 20.4 pts
#       Justin Herbert (LAC): 19.6 pts
#       Caleb Williams (CHI): 19.5 pts
#       Aaron Rodgers (PIT): 18.9 pts
#       J.J. McCarthy (MIN): 18.4 pts
#       Marcus Mariota (WSH): 18.2 pts
#       Matthew Stafford (LAR): 18.1 pts
#       Patrick Mahomes (KC): 18.0 pts
#       Jacoby Brissett (ARI): 17.9 pts
#       Dak Prescott (DAL): 17.9 pts
#       Davis Mills (HOU): 17.7 pts
#       Tua Tagovailoa (MIA): 17.6 pts
#       Baker Mayfield (TB): 17.4 pts
#       Bo Nix (DEN): 17.3 pts
#       Jordan Love (GB): 17.0 pts
#       Joe Flacco (CIN): 16.7 pts
#       Geno Smith (LV): 16.6 pts
#       Mac Jones (SF): 16.6 pts
#       Justin Fields (NYJ): 16.3 pts
#       Jared Goff (DET): 16.2 pts
#       Michael Penix Jr. (ATL): 15.7 pts
#       Trevor Lawrence (JAX): 15.3 pts
#       Sam Darnold (SEA): 15.0 pts
#       Jameis Winston (NYG): 13.7 pts
#       Dillon Gabriel (CLE): 13.5 pts
#       Bryce Young (CAR): 11.6 pts
#     ✓ Scraped 30 QB projections
#
#   Filtering to RB...
#     ✓ Filtered to RB
#     Found 50 players
#       De'Von Achane (MIA): 27.9 pts
#       Christian McCaffrey (SF): 26.6 pts
#       Josh Jacobs (GB): 22.5 pts
#       Bijan Robinson (ATL): 20.6 pts
#       Rico Dowdle (CAR): 19.4 pts
#       Jaylen Warren (PIT): 19.0 pts
#       Ashton Jeanty (LV): 18.8 pts
#       James Cook (BUF): 18.5 pts
#       Jahmyr Gibbs (DET): 17.4 pts
#       Javonte Williams (DAL): 16.1 pts
#       Saquon Barkley (PHI): 15.5 pts
#       D'Andre Swift (CHI): 14.7 pts
#       Quinshon Judkins (CLE): 14.6 pts
#       Travis Etienne Jr. (JAX): 14.5 pts
#       Derrick Henry (BAL): 14.3 pts
#       Rachaad White (TB): 14.2 pts
#       Aaron Jones Sr. (MIN): 14.1 pts
#       TreVeyon Henderson (NE): 14.0 pts
#       Kyren Williams (LAR): 13.9 pts
#       Woody Marks (HOU): 13.9 pts
#       Breece Hall (NYJ): 13.8 pts
#       Chase Brown (CIN): 13.2 pts
#       Tyrone Tracy Jr. (NYG): 12.9 pts
#       Kimani Vidal (LAC): 12.8 pts
#       RJ Harvey (DEN): 12.3 pts
#       Bam Knight (ARI): 11.2 pts
#       Kareem Hunt (KC): 10.9 pts
#       Kenneth Walker (SEA): 10.7 pts
#       David Montgomery (DET): 10.3 pts
#       Sean Tucker (TB): 10.2 pts
#     ✓ Scraped 50 RB projections
#
#   Filtering to WR...
#     ✓ Filtered to WR
#     Found 50 players
#       Jaxon Smith-Njigba (SEA): 22.9 pts
#       Ja'Marr Chase (CIN): 22.3 pts
#       Puka Nacua (LAR): 20.5 pts
#       Amon-Ra St. Brown (DET): 20.2 pts
#       Justin Jefferson (MIN): 19.5 pts
#       CeeDee Lamb (DAL): 19.4 pts
#       Drake London (ATL): 18.8 pts
#       Jaylen Waddle (MIA): 16.8 pts
#       Emeka Egbuka (TB): 16.6 pts
#       Rashee Rice (KC): 16.4 pts
#       Nico Collins (HOU): 16.3 pts
#       Davante Adams (LAR): 15.7 pts
#       A.J. Brown (PHI): 15.7 pts
#       DeVonta Smith (PHI): 15.3 pts
#       Ladd McConkey (LAC): 15.2 pts
#       George Pickens (DAL): 14.7 pts
#       Rome Odunze (CHI): 14.6 pts
#       Wan'Dale Robinson (NYG): 14.5 pts
#       Stefon Diggs (NE): 13.9 pts
#       Deebo Samuel (WSH): 13.9 pts
#       Tee Higgins (CIN): 13.6 pts
#       Tetairoa McMillan (CAR): 13.5 pts
#       Zay Flowers (BAL): 13.4 pts
#       Jauan Jennings (SF): 13.4 pts
#       Courtland Sutton (DEN): 12.9 pts
#       Khalil Shakir (BUF): 12.9 pts
#       Jordan Addison (MIN): 12.8 pts
#       Troy Franklin (DEN): 12.6 pts
#       DK Metcalf (PIT): 12.5 pts
#       Quentin Johnston (LAC): 12.5 pts
#       Romeo Doubs (GB): 12.1 pts
#       Keenan Allen (LAC): 12.1 pts
#       Jameson Williams (DET): 11.9 pts
#       Brian Thomas Jr. (JAX): 11.9 pts
#       Calvin Austin (PIT): 11.5 pts
#       Xavier Worthy (KC): 11.4 pts
#       Tre Tucker (LV): 11.0 pts
#       Jerry Jeudy (CLE): 10.8 pts
#       Darius Slayton (NYG): 10.8 pts
#       Michael Wilson (ARI): 10.6 pts
#       Malik Washington (MIA): 10.6 pts
#       Greg Dortch (ARI): 10.5 pts
#       Mack Hollins (NE): 10.3 pts
#       DJ Moore (CHI): 10.2 pts
#     ✓ Scraped 50 WR projections
#
#   Filtering to TE...
#     ✓ Filtered to TE
#     Found 50 players
#       Trey McBride (ARI): 18.9 pts
#       Brock Bowers (LV): 17.2 pts
#       George Kittle (SF): 13.6 pts
#       Sam LaPorta (DET): 11.3 pts
#       Dallas Goedert (PHI): 11.1 pts
#       Jake Ferguson (DAL): 10.8 pts
#       Theo Johnson (NYG): 10.6 pts
#       Oronde Gadsden (LAC): 10.5 pts
#       Kyle Pitts Sr. (ATL): 10.3 pts
#       Dalton Schultz (HOU): 10.2 pts
#       Travis Kelce (KC): 10.0 pts
#       Hunter Henry (NE): 10.0 pts
#       Zach Ertz (WSH): 10.0 pts
#     ✓ Scraped 50 TE projections
#
#   Filtering to K...
#     ✓ Filtered to K
#     Found 50 players
#     ✓ Scraped 30 K projections
#
#   Filtering to D/ST...
#     ✓ Filtered to D/ST
#     Found 32 players
#     ✓ Scraped 30 D/ST projections
#
# ✓ Total players with valid projections: 240
#
# Saving 240 projections to database...
# ✓ Successfully saved to database!
#   ✓ Complete
#
# 📊 FantasyPros...
#
# Fetching FantasyPros consensus rankings for Week 11...
#
# Scraping QB from https://www.fantasypros.com/nfl/rankings/qb.php...
#   Found 68 rows
#   Josh Allen (BUF): 25.0 pts
#   Drake Maye (NE): 24.5 pts
#   Jalen Hurts (PHI): 24.0 pts
#
#   DEBUG: Cleaned 'Lamar Jackson (BAL) Q' → 'Lamar Jackson (BAL)'
#   Lamar Jackson (BAL): 23.5 pts
#   Justin Herbert (LAC): 23.0 pts
#   Dak Prescott (DAL): 22.5 pts
#   Patrick Mahomes II (KC): 22.0 pts
#   Matthew Stafford (LAR): 21.5 pts
#   Baker Mayfield (TB): 21.0 pts
#
#   DEBUG: Cleaned 'Joe Flacco (CIN) Q' → 'Joe Flacco (CIN)'
#   Joe Flacco (CIN): 20.5 pts
#   Caleb Williams (CHI): 20.0 pts
#   Jordan Love (GB): 19.5 pts
#   Marcus Mariota (WAS): 19.0 pts
#   Sam Darnold (SEA): 18.5 pts
#   Aaron Rodgers (PIT): 18.0 pts
#
#   DEBUG: Cleaned 'J.J. McCarthy (MIN) Q' → 'J.J. McCarthy (MIN)'
#   J.J. McCarthy (MIN): 17.5 pts
#   Jared Goff (DET): 17.0 pts
#   Jacoby Brissett (ARI): 16.5 pts
#   Geno Smith (LV): 16.0 pts
#   Bo Nix (DEN): 15.5 pts
#   Tua Tagovailoa (MIA): 15.0 pts
#   Mac Jones (SF): 14.5 pts
#   Michael Penix Jr. (ATL): 14.0 pts
#   Justin Fields (NYJ): 13.5 pts
#   Trevor Lawrence (JAC): 13.0 pts
#   Bryce Young (CAR): 12.5 pts
#   Jameis Winston (NYG): 12.0 pts
#   Dillon Gabriel (CLE): 11.5 pts
#   Cam Ward (TEN): 11.0 pts
#   Davis Mills (HOU): 10.5 pts
#
#   DEBUG: Cleaned 'C.J. Stroud (HOU) Q' → 'C.J. Stroud (HOU)'
#   C.J. Stroud (HOU): 10.0 pts
#
#   DEBUG: Cleaned 'Jaxson Dart (NYG) Q' → 'Jaxson Dart (NYG)'
#
#   DEBUG: Cleaned 'Brock Purdy (SF) Q' → 'Brock Purdy (SF)'
#
#   DEBUG: Cleaned 'Jayden Daniels (WAS) O' → 'Jayden Daniels (WAS)'
#
#   DEBUG: Cleaned 'Joe Burrow (CIN) Q' → 'Joe Burrow (CIN)'
#   ✓ Scraped 65 QB projections
#   ✓ Team data found: 65/65 (100.0%)
#
# Scraping RB from https://www.fantasypros.com/nfl/rankings/ppr-rb.php...
#   Found 118 rows
#   Christian McCaffrey (SF): 20.0 pts
#   De'Von Achane (MIA): 19.6 pts
#   Bijan Robinson (ATL): 19.2 pts
#   Josh Jacobs (GB): 18.8 pts
#   Jahmyr Gibbs (DET): 18.4 pts
#
#   DEBUG: Cleaned 'Rico Dowdle (CAR) Q' → 'Rico Dowdle (CAR)'
#   Rico Dowdle (CAR): 18.0 pts
#   Javonte Williams (DAL): 17.6 pts
#   Ashton Jeanty (LV): 17.2 pts
#   James Cook III (BUF): 16.8 pts
#   Jaylen Warren (PIT): 16.4 pts
#   Saquon Barkley (PHI): 16.0 pts
#   Chase Brown (CIN): 15.6 pts
#   Kyren Williams (LAR): 15.2 pts
#   TreVeyon Henderson (NE): 14.8 pts
#   Quinshon Judkins (CLE): 14.4 pts
#   Travis Etienne Jr. (JAC): 14.0 pts
#   Derrick Henry (BAL): 13.6 pts
#   Breece Hall (NYJ): 13.2 pts
#
#   DEBUG: Cleaned 'Aaron Jones Sr. (MIN) Q' → 'Aaron Jones Sr. (MIN)'
#   Aaron Jones Sr. (MIN): 12.8 pts
#   Kimani Vidal (LAC): 12.4 pts
#
#   DEBUG: Cleaned 'D'Andre Swift (CHI) Q' → 'D'Andre Swift (CHI)'
#   D'Andre Swift (CHI): 12.0 pts
#   Rachaad White (TB): 11.6 pts
#   Woody Marks (HOU): 11.2 pts
#   David Montgomery (DET): 10.8 pts
#   Zach Charbonnet (SEA): 10.4 pts
#   RJ Harvey (DEN): 10.0 pts
#
#   DEBUG: Cleaned 'Ollie Gordon II (MIA) Q' → 'Ollie Gordon II (MIA)'
#
#   DEBUG: Cleaned 'Zonovan Knight (ARI) Q' → 'Zonovan Knight (ARI)'
#
#   DEBUG: Cleaned 'Justice Hill (BAL) Q' → 'Justice Hill (BAL)'
#
#   DEBUG: Cleaned 'Keaton Mitchell (BAL) Q' → 'Keaton Mitchell (BAL)'
#
#   DEBUG: Cleaned 'Terrell Jennings (NE) Q' → 'Terrell Jennings (NE)'
#
#   DEBUG: Cleaned 'J.K. Dobbins (DEN) Q' → 'J.K. Dobbins (DEN)'
#
#   DEBUG: Cleaned 'Isiah Pacheco (KC) Q' → 'Isiah Pacheco (KC)'
#
#   DEBUG: Cleaned 'Phil Mafah (DAL) IR' → 'Phil Mafah (DAL)'
#
#   DEBUG: Cleaned 'Trey Benson (ARI) IR' → 'Trey Benson (ARI)'
#
#   DEBUG: Cleaned 'Bucky Irving (TB) Q' → 'Bucky Irving (TB)'
#
#   DEBUG: Cleaned 'Sione Vaki (DET) Q' → 'Sione Vaki (DET)'
#
#   DEBUG: Cleaned 'Samaje Perine (CIN) Q' → 'Samaje Perine (CIN)'
#
#   DEBUG: Cleaned 'Rhamondre Stevenson (NE) O' → 'Rhamondre Stevenson (NE)'
#   ✓ Scraped 114 RB projections
#   ✓ Team data found: 114/114 (100.0%)
#
# Scraping WR from https://www.fantasypros.com/nfl/rankings/ppr-wr.php...
#   Found 27 rows
#   Ja'Marr Chase (CIN): 18.0 pts
#   Jaxon Smith-Njigba (SEA): 17.6 pts
#   Puka Nacua (LAR): 17.3 pts
#   CeeDee Lamb (DAL): 16.9 pts
#   Amon-Ra St. Brown (DET): 16.6 pts
#
#   DEBUG: Cleaned 'Drake London (ATL) Q' → 'Drake London (ATL)'
#   Drake London (ATL): 16.2 pts
#   Rashee Rice (KC): 15.9 pts
#   Justin Jefferson (MIN): 15.6 pts
#   Emeka Egbuka (TB): 15.2 pts
#   Jaylen Waddle (MIA): 14.8 pts
#   Nico Collins (HOU): 14.5 pts
#
#   DEBUG: Cleaned 'Davante Adams (LAR) Q' → 'Davante Adams (LAR)'
#   Davante Adams (LAR): 14.2 pts
#
#   DEBUG: Cleaned 'Ladd McConkey (LAC) Q' → 'Ladd McConkey (LAC)'
#   Ladd McConkey (LAC): 13.8 pts
#   George Pickens (DAL): 13.4 pts
#   Tee Higgins (CIN): 13.1 pts
#
#   DEBUG: Cleaned 'Rome Odunze (CHI) Q' → 'Rome Odunze (CHI)'
#   Rome Odunze (CHI): 12.8 pts
#   A.J. Brown (PHI): 12.4 pts
#   DeVonta Smith (PHI): 12.1 pts
#   Stefon Diggs (NE): 11.7 pts
#   Zay Flowers (BAL): 11.4 pts
#   DK Metcalf (PIT): 11.0 pts
#   Jauan Jennings (SF): 10.7 pts
#   Romeo Doubs (GB): 10.3 pts
#   ✓ Scraped 25 WR projections
#   ✓ Team data found: 25/25 (100.0%)
#
# Scraping TE from https://www.fantasypros.com/nfl/rankings/ppr-te.php...
#   Found 70 rows
#   Trey McBride (ARI): 14.0 pts
#   Brock Bowers (LV): 13.7 pts
#   George Kittle (SF): 13.4 pts
#   Jake Ferguson (DAL): 13.1 pts
#   Oronde Gadsden II (LAC): 12.8 pts
#
#   DEBUG: Cleaned 'Sam LaPorta (DET) Q' → 'Sam LaPorta (DET)'
#   Sam LaPorta (DET): 12.5 pts
#   Dallas Goedert (PHI): 12.2 pts
#   Travis Kelce (KC): 11.9 pts
#   Cade Otton (TB): 11.6 pts
#   Kyle Pitts Sr. (ATL): 11.3 pts
#
#   DEBUG: Cleaned 'Dalton Schultz (HOU) Q' → 'Dalton Schultz (HOU)'
#   Dalton Schultz (HOU): 11.0 pts
#   Theo Johnson (NYG): 10.7 pts
#   Hunter Henry (NE): 10.4 pts
#
#   DEBUG: Cleaned 'Harold Fannin Jr. (CLE) Q' → 'Harold Fannin Jr. (CLE)'
#   Harold Fannin Jr. (CLE): 10.1 pts
#
#   DEBUG: Cleaned 'David Njoku (CLE) Q' → 'David Njoku (CLE)'
#
#   DEBUG: Cleaned 'Chig Okonkwo (TEN) Q' → 'Chig Okonkwo (TEN)'
#
#   DEBUG: Cleaned 'Isaiah Likely (BAL) Q' → 'Isaiah Likely (BAL)'
#
#   DEBUG: Cleaned 'Cole Kmet (CHI) Q' → 'Cole Kmet (CHI)'
#
#   DEBUG: Cleaned 'Daniel Bellinger (NYG) Q' → 'Daniel Bellinger (NYG)'
#
#   DEBUG: Cleaned 'Austin Hooper (NE) O' → 'Austin Hooper (NE)'
#
#   DEBUG: Cleaned 'Brenton Strange (JAC) Q' → 'Brenton Strange (JAC)'
#
#   DEBUG: Cleaned 'Dalton Kincaid (BUF) Q' → 'Dalton Kincaid (BUF)'
#
#   DEBUG: Cleaned 'Harrison Bryant (HOU) Q' → 'Harrison Bryant (HOU)'
#
#   DEBUG: Cleaned 'Brock Wright (DET) Q' → 'Brock Wright (DET)'
#   ✓ Scraped 67 TE projections
#   ✓ Team data found: 67/67 (100.0%)
#
# Scraping K from https://www.fantasypros.com/nfl/rankings/k.php...
#   Found 28 rows
#   Brandon Aubrey (DAL): 10.0 pts
#
#   DEBUG: Cleaned 'Ka'imi Fairbairn (HOU) Q' → 'Ka'imi Fairbairn (HOU)'
#   ✓ Scraped 25 K projections
#   ✓ Team data found: 25/25 (100.0%)
#
# Scraping DST from https://www.fantasypros.com/nfl/rankings/dst.php...
#   Found 28 rows
#   Houston Texans Defense (HOU): 10.0 pts
#   ✓ Scraped 25 DST projections
#   ✓ Team data found: 25/25 (100.0%)
#
# ✓ Total players scraped: 321
#
# Saving 321 projections to database...
# ✓ Successfully saved to database!
#   ✓ Complete
#
# 🎯 First Down Studio...
# Navigating to https://www.firstdown.studio/rankings...
# Note: PPR points will be calculated from component stats for FLEX players
#
# Scraping QB tab...
#   Table headers: ['# (vs. ecr)', 'Player', 'Proj. Pts', 'Pass Yds', 'Pass TDs', 'INTs', 'Rush Yds', 'TDs']
#   Column indices found: {'proj_pts': 2, 'pass_yds': 3, 'pass_tds': 4, 'rush_yds': 6, 'tds': 7}
#   Josh Allen (.): 21.7 pts
#   Drake Maye (.): 21.3 pts
#   Jalen Hurts (.): 20.4 pts
#   Patrick Mahomes (): 20.0 pts
#   Justin Herbert (.): 19.9 pts
#   Matthew Stafford (.): 19.2 pts
#   Dak Prescott (): 19.0 pts
#   Lamar Jackson (.): 18.6 pts
#   J.J. McCarthy (.): 17.8 pts
#   Jacoby Brissett (.): 17.5 pts
#   Caleb Williams (.): 17.5 pts
#   Joe Flacco (.): 17.1 pts
#   Aaron Rodgers (): 17.0 pts
#   C.J. Stroud (.): 16.8 pts
#   Baker Mayfield (.): 16.6 pts
#   Jordan Love (.): 16.6 pts
#   Marcus Mariota (.): 16.5 pts
#   Mac Jones (.): 16.3 pts
#   Tua Tagovailoa (.): 16.2 pts
#   Sam Darnold (.): 16.1 pts
#   Jared Goff (): 16.0 pts
#   Bo Nix (): 16.0 pts
#   Geno Smith (.): 15.8 pts
#   Michael Penix (.): 15.1 pts
#   Trevor Lawrence (.): 14.5 pts
#   Davis Mills (.): 14.2 pts
#   Jameis Winston (.): 13.8 pts
#   Justin Fields (.): 13.1 pts
#   Dillon Gabriel (.): 11.4 pts
#   Bryce Young (.): 11.1 pts
#   Cam Ward (.): 10.6 pts
#
# Scraping FLEX tab...
#   Table headers: ['#', 'Player', 'Pos', 'Proj. Pts', 'Rush Yds', 'Rec', 'Rec Yds', 'TDs']
#   Column indices found: {'proj_pts': 3, 'rush_yds': 4, 'rec': 5, 'rec_yds': 6, 'tds': 7}
#   ✓ Will calculate PPR points from component stats for FLEX
#   C. McCaffrey (RB): 23.9 pts (calculated: 72.0 rush + 52.0 rec yds, 5.9 rec, 0.93 TDs)
#   De'Von Achane (RB): 22.4 pts (calculated: 79.5 rush + 37.5 rec yds, 5.5 rec, 0.86 TDs)
#   Bijan Robinson (RB): 20.0 pts (calculated: 73.0 rush + 37.0 rec yds, 4.6 rec, 0.73 TDs)
#   Ja'Marr Chase (WR): 21.9 pts (calculated: 0.9 rush + 93.5 rec yds, 8.7 rec, 0.62 TDs)
#   Josh Jacobs (RB): 18.6 pts (calculated: 79.5 rush + 23.6 rec yds, 2.9 rec, 0.9 TDs)
#   Puka Nacua (WR): 20.9 pts (calculated: 3.4 rush + 87.5 rec yds, 7.8 rec, 0.67 TDs)
#   J. Smith-Njigba (WR): 20.3 pts (calculated: 1.5 rush + 99.0 rec yds, 7.4 rec, 0.48 TDs)
#   Rico Dowdle (RB): 17.7 pts (calculated: 90.5 rush + 15.5 rec yds, 3.1 rec, 0.66 TDs)
#   T. Henderson (RB): 17.1 pts (calculated: 78.0 rush + 16.5 rec yds, 2.6 rec, 0.84 TDs)
#   Jaylen Warren (RB): 17.2 pts (calculated: 72.5 rush + 19.0 rec yds, 3.4 rec, 0.78 TDs)
#   Ashton Jeanty (RB): 16.9 pts (calculated: 73.2 rush + 21.4 rec yds, 2.9 rec, 0.76 TDs)
#   CeeDee Lamb (WR): 19.0 pts (calculated: 1.6 rush + 87.2 rec yds, 7.0 rec, 0.52 TDs)
#   Javonte Williams (RB): 16.3 pts (calculated: 75.6 rush + 13.1 rec yds, 2.6 rec, 0.81 TDs)
#   James Cook (RB): 15.8 pts (calculated: 79.5 rush + 12.5 rec yds, 2.0 rec, 0.76 TDs)
#   Rashee Rice (WR): 18.0 pts (calculated: 9.5 rush + 72.5 rec yds, 6.7 rec, 0.51 TDs)
#   Trey McBride (TE): 18.5 pts (calculated: 0.0 rush + 75.5 rec yds, 7.8 rec, 0.52 TDs)
#   A. St. Brown (WR): 18.1 pts (calculated: 0.5 rush + 77.5 rec yds, 7.3 rec, 0.5 TDs)
#   Jaylen Waddle (WR): 17.1 pts (calculated: 0.4 rush + 77.0 rec yds, 5.8 rec, 0.59 TDs)
#   Drake London (WR): 17.2 pts (calculated: 0.1 rush + 77.0 rec yds, 6.4 rec, 0.52 TDs)
#   Saquon Barkley (RB): 15.2 pts (calculated: 72.0 rush + 16.5 rec yds, 2.8 rec, 0.59 TDs)
#   Jahmyr Gibbs (RB): 15.4 pts (calculated: 61.5 rush + 21.5 rec yds, 3.4 rec, 0.62 TDs)
#   Justin Jefferson (WR): 16.1 pts (calculated: 0.1 rush + 72.0 rec yds, 5.8 rec, 0.52 TDs)
#   Brock Bowers (TE): 16.2 pts (calculated: 0.0 rush + 71.5 rec yds, 6.1 rec, 0.49 TDs)
#   Davante Adams (WR): 15.4 pts (calculated: 0.0 rush + 62.0 rec yds, 5.2 rec, 0.66 TDs)
#   Derrick Henry (RB): 13.0 pts (calculated: 74.5 rush + 9.2 rec yds, 1.1 rec, 0.59 TDs)
#   Woody Marks (RB): 13.8 pts (calculated: 56.0 rush + 18.0 rec yds, 2.7 rec, 0.62 TDs)
#   Quinshon Judkins (RB): 13.1 pts (calculated: 69.5 rush + 11.8 rec yds, 1.6 rec, 0.57 TDs)
#   Chase Brown (RB): 14.4 pts (calculated: 51.5 rush + 24.0 rec yds, 4.0 rec, 0.48 TDs)
#   George Pickens (WR): 14.7 pts (calculated: 0.2 rush + 70.2 rec yds, 5.0 rec, 0.44 TDs)
#   Nico Collins (WR): 14.9 pts (calculated: 0.2 rush + 67.5 rec yds, 5.2 rec, 0.48 TDs)
#   Emeka Egbuka (WR): 14.5 pts (calculated: 0.7 rush + 67.5 rec yds, 5.0 rec, 0.45 TDs)
#   Kyren Williams (RB): 12.9 pts (calculated: 61.0 rush + 13.5 rec yds, 2.3 rec, 0.53 TDs)
#   Aaron Jones (RB): 13.5 pts (calculated: 49.5 rush + 21.5 rec yds, 3.3 rec, 0.51 TDs)
#   Ladd McConkey (WR): 14.5 pts (calculated: 0.1 rush + 64.0 rec yds, 5.6 rec, 0.42 TDs)
#   Travis Etienne (RB): 12.9 pts (calculated: 55.0 rush + 15.5 rec yds, 2.6 rec, 0.54 TDs)
#   Kimani Vidal (RB): 12.2 pts (calculated: 61.0 rush + 10.0 rec yds, 1.9 rec, 0.54 TDs)
#   Breece Hall (RB): 12.5 pts (calculated: 59.0 rush + 16.5 rec yds, 2.4 rec, 0.42 TDs)
#   D'Andre Swift (RB): 12.5 pts (calculated: 55.0 rush + 20.4 rec yds, 2.4 rec, 0.42 TDs)
#   Tee Higgins (WR): 13.4 pts (calculated: 0.1 rush + 59.0 rec yds, 5.0 rec, 0.41 TDs)
#   DeVonta Smith (WR): 13.0 pts (calculated: 0.1 rush + 56.5 rec yds, 4.8 rec, 0.42 TDs)
#   Rome Odunze (WR): 12.9 pts (calculated: 0.2 rush + 59.0 rec yds, 4.6 rec, 0.4 TDs)
#   A.J. Brown (WR): 12.6 pts (calculated: 0.0 rush + 57.5 rec yds, 4.2 rec, 0.44 TDs)
#   Zay Flowers (WR): 12.8 pts (calculated: 2.5 rush + 58.0 rec yds, 4.7 rec, 0.35 TDs)
#   Deebo Samuel (WR): 13.0 pts (calculated: 6.7 rush + 50.5 rec yds, 5.1 rec, 0.37 TDs)
#   W. Robinson (WR): 13.1 pts (calculated: 0.6 rush + 59.0 rec yds, 5.4 rec, 0.29 TDs)
#   Stefon Diggs (WR): 12.8 pts (calculated: 0.4 rush + 53.5 rec yds, 4.8 rec, 0.44 TDs)
#   RJ Harvey (RB): 11.7 pts (calculated: 43.1 rush + 18.2 rec yds, 2.6 rec, 0.49 TDs)
#   DK Metcalf (WR): 12.2 pts (calculated: 0.0 rush + 53.5 rec yds, 4.2 rec, 0.45 TDs)
#   Tyrone Tracy (RB): 10.9 pts (calculated: 46.0 rush + 15.6 rec yds, 2.3 rec, 0.41 TDs)
#   T. McMillan (WR): 12.0 pts (calculated: 0.2 rush + 54.5 rec yds, 4.7 rec, 0.31 TDs)
#   Khalil Shakir (WR): 12.3 pts (calculated: 0.3 rush + 50.5 rec yds, 5.2 rec, 0.34 TDs)
#   Quentin Johnston (WR): 11.6 pts (calculated: 0.7 rush + 51.5 rec yds, 4.0 rec, 0.4 TDs)
#   Brian Thomas (WR): 11.4 pts (calculated: 0.1 rush + 58.2 rec yds, 3.9 rec, 0.28 TDs)
#   Rachaad White (RB): 10.7 pts (calculated: 36.0 rush + 13.5 rec yds, 3.0 rec, 0.46 TDs)
#   George Kittle (TE): 11.6 pts (calculated: 0.0 rush + 46.5 rec yds, 4.8 rec, 0.36 TDs)
#   Tre Tucker (WR): 10.9 pts (calculated: 2.9 rush + 49.8 rec yds, 3.6 rec, 0.34 TDs)
#   Jauan Jennings (WR): 11.1 pts (calculated: 0.1 rush + 51.5 rec yds, 4.1 rec, 0.31 TDs)
#   Courtland Sutton (WR): 11.1 pts (calculated: 0.0 rush + 50.0 rec yds, 4.1 rec, 0.33 TDs)
#   Jake Ferguson (TE): 11.5 pts (calculated: 0.0 rush + 37.4 rec yds, 4.9 rec, 0.47 TDs)
#   Kareem Hunt (RB): 9.6 pts (calculated: 41.5 rush + 6.5 rec yds, 1.7 rec, 0.52 TDs)
#   Cade Otton (TE): 11.0 pts (calculated: 0.0 rush + 46.0 rec yds, 4.5 rec, 0.32 TDs)
#   Romeo Doubs (WR): 10.8 pts (calculated: 0.0 rush + 46.0 rec yds, 4.2 rec, 0.33 TDs)
#   Travis Kelce (TE): 10.8 pts (calculated: 0.0 rush + 45.0 rec yds, 4.3 rec, 0.34 TDs)
#   P. Washington (WR): 10.6 pts (calculated: 1.5 rush + 48.0 rec yds, 3.9 rec, 0.29 TDs)
#   Kyle Pitts (TE): 10.9 pts (calculated: 0.0 rush + 47.0 rec yds, 4.6 rec, 0.27 TDs)
#   Jordan Addison (WR): 10.4 pts (calculated: 0.7 rush + 46.5 rec yds, 3.6 rec, 0.35 TDs)
#   Jameson Williams (WR): 10.3 pts (calculated: 1.5 rush + 47.0 rec yds, 3.5 rec, 0.32 TDs)
#   DJ Moore (WR): 10.2 pts (calculated: 5.2 rush + 40.5 rec yds, 3.7 rec, 0.33 TDs)
#   Emari Demercado (RB): 9.3 pts (calculated: 40.4 rush + 12.3 rec yds, 1.8 rec, 0.37 TDs)
#   David Montgomery (RB): 9.2 pts (calculated: 39.5 rush + 9.0 rec yds, 1.8 rec, 0.43 TDs)
#   Jakobi Meyers (WR): 10.2 pts (calculated: 0.7 rush + 46.0 rec yds, 3.7 rec, 0.3 TDs)
#   Troy Franklin (WR): 10.4 pts (calculated: 0.8 rush + 40.5 rec yds, 4.2 rec, 0.35 TDs)
#   Darius Slayton (WR): 10.1 pts (calculated: 0.1 rush + 50.7 rec yds, 3.5 rec, 0.25 TDs)
#   Tony Pollard (RB): 9.2 pts (calculated: 39.0 rush + 12.0 rec yds, 2.1 rec, 0.34 TDs)
#   Zach Ertz (TE): 10.2 pts (calculated: 0.0 rush + 41.5 rec yds, 4.0 rec, 0.34 TDs)
#   Xavier Worthy (WR): 9.9 pts (calculated: 2.5 rush + 41.0 rec yds, 3.8 rec, 0.29 TDs)
#   Dallas Goedert (TE): 10.1 pts (calculated: 0.0 rush + 37.0 rec yds, 4.2 rec, 0.36 TDs)
#   Kenneth Walker (RB): 8.4 pts (calculated: 45.0 rush + 4.5 rec yds, 1.2 rec, 0.37 TDs)
#   Tyjae Spears (RB): 8.9 pts (calculated: 27.5 rush + 16.5 rec yds, 2.5 rec, 0.34 TDs)
#   Keenan Allen (WR): 9.8 pts (calculated: 0.0 rush + 36.5 rec yds, 4.3 rec, 0.31 TDs)
#   Theo Johnson (TE): 9.6 pts (calculated: 0.0 rush + 41.0 rec yds, 3.9 rec, 0.27 TDs)
#   Oronde Gadsden (TE): 9.3 pts (calculated: 0.0 rush + 37.3 rec yds, 3.1 rec, 0.41 TDs)
#   Sam LaPorta (TE): 9.5 pts (calculated: 0.0 rush + 39.5 rec yds, 3.9 rec, 0.28 TDs)
#   Dalton Schultz (TE): 9.6 pts (calculated: 0.0 rush + 39.5 rec yds, 4.0 rec, 0.28 TDs)
#   Nick Chubb (RB): 8.0 pts (calculated: 44.0 rush + 6.1 rec yds, 0.9 rec, 0.35 TDs)
#   Bam Knight (RB): 7.5 pts (calculated: 35.5 rush + 14.5 rec yds, 0.0 rec, 0.42 TDs)
#   J. Croskey-Merritt (RB): 8.0 pts (calculated: 33.0 rush + 9.3 rec yds, 1.2 rec, 0.43 TDs)
#   Hunter Henry (TE): 9.1 pts (calculated: 0.5 rush + 32.5 rec yds, 3.3 rec, 0.41 TDs)
#   Keon Coleman (WR): 9.0 pts (calculated: 0.0 rush + 42.0 rec yds, 3.1 rec, 0.28 TDs)
#   Kyle Monangai (RB): 7.7 pts (calculated: 38.2 rush + 8.8 rec yds, 1.0 rec, 0.33 TDs)
#   Calvin Ridley (WR): 8.6 pts (calculated: 0.5 rush + 46.5 rec yds, 2.8 rec, 0.19 TDs)
#   Zach Charbonnet (RB): 7.7 pts (calculated: 34.5 rush + 4.5 rec yds, 1.2 rec, 0.44 TDs)
#   Jerry Jeudy (WR): 9.0 pts (calculated: 0.1 rush + 40.5 rec yds, 3.9 rec, 0.18 TDs)
#   Mason Taylor (TE): 9.2 pts (calculated: 0.0 rush + 32.5 rec yds, 4.3 rec, 0.28 TDs)
#   Tez Johnson (WR): 8.7 pts (calculated: 0.3 rush + 39.0 rec yds, 3.3 rec, 0.24 TDs)
#   Christian Watson (WR): 8.4 pts (calculated: 0.6 rush + 38.0 rec yds, 2.9 rec, 0.28 TDs)
#   Mack Hollins (WR): 8.6 pts (calculated: 0.1 rush + 37.5 rec yds, 3.2 rec, 0.27 TDs)
#   Michael Wilson (WR): 8.7 pts (calculated: 0.1 rush + 32.0 rec yds, 3.6 rec, 0.32 TDs)
#   J.K. Dobbins (RB): 7.2 pts (calculated: 32.2 rush + 3.0 rec yds, 0.7 rec, 0.49 TDs)
#   Malik Washington (WR): 8.3 pts (calculated: 8.5 rush + 24.5 rec yds, 3.2 rec, 0.3 TDs)
#   Jordan Mason (RB): 7.0 pts (calculated: 31.0 rush + 5.1 rec yds, 0.9 rec, 0.42 TDs)
#   Greg Dortch (WR): 8.2 pts (calculated: 3.0 rush + 31.7 rec yds, 3.2 rec, 0.25 TDs)
#   Harold Fannin (TE): 8.6 pts (calculated: 0.0 rush + 34.0 rec yds, 4.2 rec, 0.17 TDs)
#   Sean Tucker (RB): 6.9 pts (calculated: 40.8 rush + 5.2 rec yds, 0.8 rec, 0.25 TDs)
#   Christian Kirk (WR): 8.0 pts (calculated: 0.1 rush + 37.9 rec yds, 3.1 rec, 0.19 TDs)
#   Elic Ayomanor (WR): 7.9 pts (calculated: 0.1 rush + 36.5 rec yds, 3.0 rec, 0.21 TDs)
#   David Njoku (TE): 8.2 pts (calculated: 0.0 rush + 35.3 rec yds, 3.7 rec, 0.17 TDs)
#   Mark Andrews (TE): 8.0 pts (calculated: 0.0 rush + 30.5 rec yds, 3.1 rec, 0.3 TDs)
#   Kenneth Gainwell (RB): 7.5 pts (calculated: 25.7 rush + 14.0 rec yds, 2.3 rec, 0.21 TDs)
#   T.J. Hockenson (TE): 7.9 pts (calculated: 0.0 rush + 30.0 rec yds, 3.2 rec, 0.28 TDs)
#   Calvin Austin (WR): 7.8 pts (calculated: 0.4 rush + 32.0 rec yds, 3.1 rec, 0.24 TDs)
#   Colston Loveland (TE): 7.7 pts (calculated: 0.0 rush + 34.2 rec yds, 3.0 rec, 0.22 TDs)
#   Devin Singletary (RB): 6.7 pts (calculated: 34.5 rush + 8.5 rec yds, 1.2 rec, 0.2 TDs)
#   Chris Rodriguez (RB): 6.2 pts (calculated: 36.0 rush + 2.3 rec yds, 0.3 rec, 0.34 TDs)
#   Dawson Knox (TE): 7.3 pts (calculated: 0.0 rush + 32.0 rec yds, 2.6 rec, 0.25 TDs)
#   Rashid Shaheed (WR): 7.2 pts (calculated: 2.2 rush + 31.0 rec yds, 2.3 rec, 0.26 TDs)
#   Chimere Dike (WR): 7.2 pts (calculated: 2.8 rush + 30.5 rec yds, 2.7 rec, 0.19 TDs)
#   Isaiah Likely (TE): 6.9 pts (calculated: 0.0 rush + 31.1 rec yds, 2.5 rec, 0.21 TDs)
#   Cooper Kupp (WR): 6.8 pts (calculated: 0.1 rush + 29.0 rec yds, 2.8 rec, 0.19 TDs)
#   Luke Musgrave (TE): 7.0 pts (calculated: 0.0 rush + 27.5 rec yds, 3.0 rec, 0.21 TDs)
#   Marvin Mims (WR): 6.7 pts (calculated: 2.6 rush + 28.9 rec yds, 2.4 rec, 0.19 TDs)
#   Darnell Mooney (WR): 6.7 pts (calculated: 0.1 rush + 29.0 rec yds, 2.5 rec, 0.21 TDs)
#   Matthew Golden (WR): 6.5 pts (calculated: 2.5 rush + 26.4 rec yds, 2.2 rec, 0.24 TDs)
#   O. Zaccheaus (WR): 6.8 pts (calculated: 1.5 rush + 29.2 rec yds, 2.7 rec, 0.17 TDs)
#   Tyler Allgeier (RB): 5.5 pts (calculated: 27.5 rush + 3.0 rec yds, 0.4 rec, 0.35 TDs)
#   Ricky Pearsall (WR): 6.1 pts (calculated: 0.7 rush + 25.5 rec yds, 1.7 rec, 0.3 TDs)
#   Michael Mayer (TE): 6.7 pts (calculated: 0.0 rush + 28.1 rec yds, 2.9 rec, 0.17 TDs)
#   Tyler Lockett (WR): 6.6 pts (calculated: 0.0 rush + 30.0 rec yds, 2.6 rec, 0.17 TDs)
#   Noah Fant (TE): 6.6 pts (calculated: 0.0 rush + 27.5 rec yds, 2.8 rec, 0.17 TDs)
#   Joshua Palmer (WR): 6.2 pts (calculated: 0.0 rush + 31.8 rec yds, 2.1 rec, 0.16 TDs)
#   Pat Freiermuth (TE): 6.4 pts (calculated: 0.0 rush + 24.5 rec yds, 2.6 rec, 0.23 TDs)
#   Jayden Higgins (WR): 6.3 pts (calculated: 0.1 rush + 29.3 rec yds, 2.5 rec, 0.15 TDs)
#   Isaiah Davis (RB): 6.0 pts (calculated: 22.5 rush + 13.2 rec yds, 1.7 rec, 0.12 TDs)
#   Isiah Pacheco (RB): 5.2 pts (calculated: 12.8 rush + 2.7 rec yds, 0.4 rec, 0.54 TDs)
#   Dontayvion Wicks (WR): 6.1 pts (calculated: 0.0 rush + 26.4 rec yds, 2.1 rec, 0.22 TDs)
#   Jalen Coker (WR): 6.1 pts (calculated: 0.0 rush + 27.0 rec yds, 2.4 rec, 0.16 TDs)
#   Jaylin Lane (WR): 6.1 pts (calculated: 0.2 rush + 25.0 rec yds, 2.4 rec, 0.2 TDs)
#   Jeremy McNichols (RB): 5.7 pts (calculated: 16.1 rush + 13.5 rec yds, 1.7 rec, 0.18 TDs)
#   Greg Dulcich (TE): 6.0 pts (calculated: 0.0 rush + 26.5 rec yds, 2.3 rec, 0.18 TDs)
#   Emanuel Wilson (RB): 5.2 pts (calculated: 26.7 rush + 6.8 rec yds, 0.9 rec, 0.16 TDs)
#   Blake Corum (RB): 5.0 pts (calculated: 30.0 rush + 4.1 rec yds, 0.6 rec, 0.16 TDs)
#   Brashard Smith (RB): 5.4 pts (calculated: 17.1 rush + 12.1 rec yds, 1.5 rec, 0.16 TDs)
#   Chuba Hubbard (RB): 5.1 pts (calculated: 24.3 rush + 6.2 rec yds, 1.0 rec, 0.18 TDs)
#   Samaje Perine (RB): 4.8 pts (calculated: 23.4 rush + 7.6 rec yds, 0.9 rec, 0.13 TDs)
#   Brian Robinson (RB): 4.2 pts (calculated: 24.5 rush + 2.6 rec yds, 0.3 rec, 0.19 TDs)
#
# Total unique players scraped: 176
#
# Saving 176 projections to database...
# ✓ Successfully saved to database!
#   ✓ Complete
#
# 🔵 FanDuel (subprocess)...
#   ✓ Complete
#
# ======================================================================
# SCRAPING SUMMARY
# ======================================================================
#
#   Sleeper         ✅
#   ESPN            ✅
#   FantasyPros     ✅
#   First Down      ✅
#   FanDuel         ✅
#
# ======================================================================

# %% [markdown]
# ## 📊 Database Status & Data Quality

# %%
def show_database_status():
    """Display comprehensive database status and data quality metrics."""
    with ProjectionsDB(db_path=DB_PATH) as db:
        all_projs = db.get_projections()
        
        print(f"{'='*70}")
        print(f"DATABASE STATUS")
        print(f"{'='*70}\n")
        print(f"Total records: {len(all_projs)}\n")
        
        # Count by source
        print(f"📊 Records by Source:")
        print("-" * 70)
        sources = {}
        for p in all_projs:
            source = p['source_website']
            sources[source] = sources.get(source, 0) + 1
        
        for source, count in sorted(sources.items()):
            print(f"  {source:<25} {count:>5} records")
        
        # Count by week
        print(f"\n📅 Records by Week:")
        print("-" * 70)
        weeks = {}
        for p in all_projs:
            week = p['week']
            weeks[week] = weeks.get(week, 0) + 1
        
        for week, count in sorted(weeks.items()):
            print(f"  {week:<25} {count:>5} records")
        
        # Team coverage (data quality check)
        print(f"\n🏈 Team Data Coverage (Quality Check):")
        print("-" * 70)
        for source in sorted(sources.keys()):
            source_projs = [p for p in all_projs if p['source_website'] == source]
            with_team = sum(1 for p in source_projs if p.get('team'))
            total = len(source_projs)
            pct = (with_team / total * 100) if total > 0 else 0
            status = "✅" if pct >= 95 else "⚠️" if pct >= 75 else "❌"
            print(f"  {source:<25} {with_team:>4}/{total:<4} ({pct:>5.1f}%) {status}")
        
        print(f"\n{'='*70}\n")

# Show status
show_database_status()
# Out:
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 3331
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#   espn.com                    472 records
#   fanduel.com                 981 records
#   fantasypros.com             709 records
#   firstdown.studio            337 records
#   sleeper.com                 832 records
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#   Week 10                    1625 records
#   Week 11                    1706 records
#
# 🏈 Team Data Coverage (Quality Check):
# ----------------------------------------------------------------------
#   espn.com                   472/472  (100.0%) ✅
#   fanduel.com                981/981  (100.0%) ✅
#   fantasypros.com            709/709  (100.0%) ✅
#   firstdown.studio           337/337  (100.0%) ✅
#   sleeper.com                832/832  (100.0%) ✅
#
# ======================================================================

# %% [markdown]
# ---
#
# ## 🛠️ Utility Functions
#
# **Use these as needed for database management**

# %%
# ============================================================================
# UTILITY FUNCTIONS - Uncomment to use
# ============================================================================

def clear_week(week_name):
    """Delete all records from a specific week."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    cursor.execute("DELETE FROM projections WHERE week = ?", (week_name,))
    deleted = cursor.rowcount
    conn.commit()
    conn.close()
    print(f"✓ Deleted {deleted} records from {week_name}")

def clear_source(source_name, week=None):
    """Delete records from a specific source."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    if week:
        cursor.execute("DELETE FROM projections WHERE source_website = ? AND week = ?", (source_name, week))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} for {week}")
    else:
        cursor.execute("DELETE FROM projections WHERE source_website = ?", (source_name,))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} (all weeks)")
    conn.commit()
    conn.close()

def clear_entire_database():
    """⚠️ DELETE ALL RECORDS - requires confirmation."""
    confirm = input("⚠️  Type 'DELETE ALL' to confirm: ")
    if confirm == "DELETE ALL":
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("DELETE FROM projections")
        conn.commit()
        deleted = cursor.rowcount
        conn.close()
        print(f"\n✓ Deleted {deleted} records from database")
    else:
        print("\n✗ Cancelled")

def show_week_source_matrix():
    """Display a matrix showing record counts by week and source."""
    import pandas as pd
    conn = sqlite3.connect(DB_PATH)
    query = """
        SELECT week, source_website, COUNT(*) as count
        FROM projections
        GROUP BY week, source_website
        ORDER BY week, source_website
    """
    df = pd.read_sql_query(query, conn)
    conn.close()
    
    if len(df) == 0:
        print("No data in database")
        return
    
    pivot = df.pivot(index='source_website', columns='week', values='count')
    pivot = pivot.fillna(0).astype(int)
    
    print(f"\n{'='*70}")
    print("WEEK × SOURCE MATRIX")
    print("="*70)
    print(pivot.to_string())
    print("="*70 + "\n")

def run_single_scraper(scraper_name):
    """Run a specific scraper by name."""
    scrapers = {
        'sleeper': lambda: SleeperScraper(db_path=DB_PATH),
        'espn': lambda: ESPNScraper(headless=HEADLESS, db_path=DB_PATH),
        'fantasypros': lambda: FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH),
        'firstdown': lambda: FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH)
    }
    
    name_lower = scraper_name.lower()
    if name_lower not in scrapers:
        print(f"Unknown scraper: {scraper_name}")
        print(f"Available: {', '.join(scrapers.keys())}")
        return
    
    print(f"Running {scraper_name}...")
    try:
        with scrapers[name_lower]() as scraper:
            if name_lower == 'sleeper':
                scraper.scrape_and_save(week=WEEK, season=SEASON)
            elif name_lower == 'espn':
                scraper.scrape_and_save(week=WEEK, season=SEASON)
            elif name_lower == 'firstdown':
                scraper.scrape_and_save(week=WEEK, scoring="PPR")
            else:
                scraper.scrape_and_save(week=WEEK)
        print(f"✓ {scraper_name} complete")
    except Exception as e:
        print(f"✗ Error: {e}")

# Uncomment to use:
# clear_week("Week 10")
# clear_source("fantasypros.com", WEEK)
# clear_entire_database()
show_week_source_matrix()
# run_single_scraper("sleeper")

print("✅ Utility functions loaded. Uncomment above to use.")
# Out:
# ======================================================================
# WEEK × SOURCE MATRIX
# ======================================================================
# week              Week 10  Week 11
# source_website
# espn.com              232      240
# fanduel.com           473      508
# fantasypros.com       388      321
# firstdown.studio      161      176
# sleeper.com           371      461
# ======================================================================
#
# ✅ Utility functions loaded. Uncomment above to use.

# %% [markdown]
# ---
#
# ## 📚 Quick Reference
#
# ### Weekly Workflow:
# 1. Update `WEEK` and `SEASON` in cell 2
# 2. **Kernel → Restart & Run All**
# 3. Wait for all scrapers to complete (~5-10 minutes)
# 4. Check database status for data quality
#
# ### Available Functions:
# - `run_all_scrapers()` - Scrape all sources *(runs automatically)*
# - `show_database_status()` - View database contents *(runs automatically)*
# - `run_single_scraper(name)` - Run one scraper
# - `clear_week(week)` - Delete all data for a week
# - `clear_source(source, week)` - Delete data from a source
# - `show_week_source_matrix()` - See week×source grid
# - `clear_entire_database()` - Delete everything ⚠️
#
# ### Source Names:
# - `"fanduel.com"`
# - `"sleeper.com"`
# - `"espn.com"`
# - `"fantasypros.com"`
# - `"firstdown.studio"`
#
# ### Tips:
# - FanDuel uses Playwright and runs in a subprocess (this is normal)
# - Set `HEADLESS = False` to see browser windows for debugging
# - Scrapers typically take 1-3 minutes each
# - Check "Team Data Coverage" to ensure quality (should be ≥95%)
#
# ---
#
# **✅ Ready to use! Update WEEK and run all cells.**
