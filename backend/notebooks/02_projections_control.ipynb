# %% [markdown]
# # 🎮 Fantasy Football Projections - Control Panel
#
# **Scrape and manage player projections from multiple sources.**
#
# ## Quick Start:
# 1. **Update `WEEK` and `SEASON`** in the configuration
# 2. **Run All Cells** to scrape all sources
# 3. View database status and data quality metrics
#
# ## Sources:
# - 🔵 FanDuel
# - 💤 Sleeper
# - 🔴 ESPN
# - 📊 FantasyPros
# - 🎯 First Down Studio
#
# ---

# %% [markdown]
# ## 📦 Setup & Configuration

# %%
import os
import sqlite3
import subprocess
import sys
from datetime import datetime
from pathlib import Path

# Use absolute paths (this notebook is at backend/notebooks/)
NOTEBOOK_DIR = Path(r"C:\Users\Samer Faizi\Documents\Claude Model\backend\notebooks")
BACKEND_DIR = NOTEBOOK_DIR.parent
PROJECT_ROOT = BACKEND_DIR.parent
SCRAPERS_DIR = BACKEND_DIR / "scrapers"

# Add project root to path for package imports
sys.path.insert(0, str(PROJECT_ROOT))

# Import from the backend.scrapers package (uses relative imports internally)
from backend.scrapers.database import ProjectionsDB
from backend.scrapers.scraper_sleeper import SleeperScraper
from backend.scrapers.scraper_espn import ESPNScraper
from backend.scrapers.scraper_fantasypros import FantasyProsScraper
from backend.scrapers.scraper_firstdown import FirstDownStudioScraper

# ==================== CONFIGURATION ====================
# Update these for each scraping session

WEEK = "Week 15"  # ⬅️ UPDATE THIS!
SEASON = "2025"
HEADLESS = False  # Set to False to see browser windows

# Database path
DB_PATH = str(BACKEND_DIR / "data" / "databases" / "projections.db")

# Verify database exists
if not Path(DB_PATH).exists():
    print(f"⚠️ WARNING: Database not found at: {DB_PATH}")
else:
    print(f"✅ Database found: {DB_PATH}")

print("✅ Setup Complete!")
print(f"📅 {WEEK}, Season {SEASON}")
print(f"👁️  Headless mode: {HEADLESS}")
print("\n" + "="*70 + "\n")
# Out:
# ✅ Database found: C:\Users\Samer Faizi\Documents\Claude Model\backend\data\databases\projections.db
# ✅ Setup Complete!
# 📅 Week 15, Season 2025
# 👁️  Headless mode: False
#
# ======================================================================

# %% [markdown]
# ## 🤖 Individual Scrapers
#
# Run each scraper individually for easier debugging. Each cell is independent.

# %%
# 💤 SLEEPER SCRAPER (API-based, fast & reliable)
# ================================================
print(f"{'='*70}")
print(f"💤 SLEEPER SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    with SleeperScraper(db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK, season=SEASON)
    print("\n✅ Sleeper scraping complete!")
except Exception as e:
    print(f"\n❌ Sleeper error: {e}")
# Out:
# ======================================================================
# 💤 SLEEPER SCRAPER - Week 15
# ======================================================================
#
#
# Fetching Sleeper projections for 2025 Week 15...
# Fetching all players from Sleeper API...
#   ✓ Loaded 11402 players
# Fetching from: https://api.sleeper.app/v1/projections/nfl/regular/2025/15
#   ✓ Successfully fetched 8624 player projections
#
# Parsing 8624 projections...
#   Brandon Aubrey (K): 10.9 pts
#   CeeDee Lamb (WR): 17.7 pts
#   Bucky Irving (RB): 15.5 pts
#   Omarion Hampton (RB): 12.7 pts
#   Oronde Gadsden (TE): 10.2 pts
#   Kyle Pitts (TE): 11.8 pts
#   Dak Prescott (QB): 22.1 pts
#   Matthew Stafford (QB): 21.4 pts
#   Khalil Shakir (WR): 12.8 pts
#   James Cook (RB): 16.9 pts
#   Jauan Jennings (WR): 12.3 pts
#   Sam Darnold (QB): 19.9 pts
#   Jaxon Smith-Njigba (WR): 22.7 pts
#   Jaylen Waddle (WR): 14.2 pts
#   TreVeyon Henderson (RB): 15.1 pts
#   D'Andre Swift (RB): 10.8 pts
#   Geno Smith (QB): 17.6 pts
#   Tua Tagovailoa (QB): 17.6 pts
#   Jalen Hurts (QB): 22.3 pts
#   Ladd McConkey (WR): 13.8 pts
#   Michael Wilson (WR): 12.4 pts
#   Jordan Love (QB): 17.4 pts
#   Chris Godwin (WR): 11.7 pts
#   Kirk Cousins (QB): 17.9 pts
#   Jake Ferguson (TE): 10.5 pts
#   Patrick Mahomes (QB): 22.9 pts
#   Shedeur Sanders (QB): 19.6 pts
#   Ja'Marr Chase (WR): 18.8 pts
#   Justin Herbert (QB): 20.6 pts
#   Tee Higgins (WR): 14.4 pts
#   Lamar Jackson (QB): 24.6 pts
#   Davante Adams (WR): 15.7 pts
#   Aaron Rodgers (QB): 18.9 pts
#   Deebo Samuel (WR): 13.4 pts
#   Tyler Shough (QB): 20.3 pts
#   Tyrod Taylor (QB): 17.4 pts
#   Baker Mayfield (QB): 21.8 pts
#   Tyler Warren (TE): 10.4 pts
#   Christian Watson (WR): 10.6 pts
#   Jakobi Meyers (WR): 10.9 pts
#   Ricky Pearsall (WR): 10.7 pts
#   Emeka Egbuka (WR): 11.2 pts
#   Nico Collins (WR): 16.6 pts
#   Bryce Young (QB): 17.7 pts
#   Rico Dowdle (RB): 10.2 pts
#   George Pickens (WR): 16.2 pts
#   Garrett Wilson (WR): 12.7 pts
#   Woody Marks (RB): 14.8 pts
#   Mike Evans (WR): 12.4 pts
#   RJ Harvey (RB): 13.8 pts
#   Derrick Henry (RB): 17.2 pts
#   Cam Ward (QB): 15.0 pts
#   Puka Nacua (WR): 20.9 pts
#   A.J. Brown (WR): 14.5 pts
#   Christian McCaffrey (RB): 26.5 pts
#   Saquon Barkley (RB): 14.1 pts
#   Trey McBride (TE): 17.2 pts
#   Alec Pierce (WR): 10.1 pts
#   Trevor Lawrence (QB): 18.7 pts
#   Jaxson Dart (QB): 22.9 pts
#   J.J. McCarthy (QB): 19.9 pts
#   Ashton Jeanty (RB): 14.4 pts
#   Riley Leonard (QB): 15.7 pts
#   Chris Rodriguez (RB): 11.3 pts
#   Dallas Goedert (TE): 10.5 pts
#   Tyrone Tracy (RB): 11.5 pts
#   Rashee Rice (WR): 16.2 pts
#   De'Von Achane (RB): 17.6 pts
#   Bijan Robinson (RB): 21.4 pts
#   DeVonta Smith (WR): 13.8 pts
#   Joe Burrow (QB): 20.1 pts
#   Jahmyr Gibbs (RB): 21.2 pts
#   Jared Goff (QB): 19.0 pts
#   Jameson Williams (WR): 13.3 pts
#   George Kittle (TE): 14.6 pts
#   Marvin Harrison (WR): 10.8 pts
#   Keenan Allen (WR): 11.2 pts
#   Brock Purdy (QB): 22.9 pts
#   Quinshon Judkins (RB): 14.6 pts
#   Kenneth Walker (RB): 11.9 pts
#   Amon-Ra St. Brown (WR): 18.4 pts
#   Tetairoa McMillan (WR): 13.7 pts
#   Bo Nix (QB): 18.8 pts
#   Stefon Diggs (WR): 13.3 pts
#   Kenneth Gainwell (RB): 12.6 pts
#   Travis Etienne (RB): 14.3 pts
#   Brian Thomas (WR): 10.4 pts
#   Terry McLaurin (WR): 13.7 pts
#   Aaron Jones (RB): 11.0 pts
#   Kyren Williams (RB): 13.2 pts
#   Jaylen Warren (RB): 13.2 pts
#   Chase Brown (RB): 14.7 pts
#   Mark Andrews (TE): 10.6 pts
#   Jayden Higgins (WR): 10.1 pts
#   Justin Jefferson (WR): 14.0 pts
#   Quentin Johnston (WR): 11.5 pts
#   Chris Olave (WR): 15.3 pts
#   Josh Allen (QB): 26.1 pts
#   Zay Flowers (WR): 15.6 pts
#   Harold Fannin (TE): 12.4 pts
#   Wan'Dale Robinson (WR): 14.1 pts
#   Courtland Sutton (WR): 11.2 pts
#   Devaughn Vele (WR): 11.4 pts
#   Kareem Hunt (RB): 10.2 pts
#   Caleb Williams (QB): 17.6 pts
#   Jacoby Brissett (QB): 18.8 pts
#   C.J. Stroud (QB): 19.4 pts
#   Travis Kelce (TE): 10.9 pts
#   Josh Jacobs (RB): 16.7 pts
#   Brock Bowers (TE): 15.4 pts
#   Jayden Daniels (QB): 20.5 pts
#   Michael Pittman (WR): 11.0 pts
#   Juwan Johnson (TE): 10.8 pts
#   DK Metcalf (WR): 12.5 pts
#   Breece Hall (RB): 13.9 pts
#   Jonathan Taylor (RB): 18.2 pts
#   Drake Maye (QB): 23.5 pts
#   Javonte Williams (RB): 17.1 pts
#
# ✓ Projections with data: 8624 out of 8624
# ✓ Total players with valid projections: 490
#
# Saving 490 projections to database...
# ✓ Successfully saved to database!
#
# ✅ Sleeper scraping complete!

# %%
# # DELETE incorrect ESPN data for Week 14
# import sqlite3

# conn = sqlite3.connect(DB_PATH)
# cursor = conn.cursor()

# # See what we're deleting
# cursor.execute("""
#     SELECT COUNT(*) FROM projections 
#     WHERE source_website = 'espn.com' AND week = 'Week 14'
# """)
# count = cursor.fetchone()[0]
# print(f"Found {count} ESPN Week 14 records to delete")

# # Delete them
# cursor.execute("""
#     DELETE FROM projections 
#     WHERE source_website = 'espn.com' AND week = 'Week 14'
# """)
# conn.commit()
# print(f"✅ Deleted {cursor.rowcount} ESPN records for Week 14")
# conn.close()

# %%
# 🔴 ESPN SCRAPER
# ================================================
# Set HEADLESS = False in setup cell to debug visually
print(f"{'='*70}")
print(f"🔴 ESPN SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    with ESPNScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK, season=SEASON)
    print("\n✅ ESPN scraping complete!")
except Exception as e:
    print(f"\n❌ ESPN error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# 🔴 ESPN SCRAPER - Week 15
# ======================================================================
#
#
# Fetching ESPN projections for Week 15...
# Navigating to https://fantasy.espn.com/football/players/projections...
# Clicking 'Sortable Projections' view...
#   ✓ Switched to Sortable Projections view
# Setting scoring to Points PPR...
#   ✓ Set to Points PPR
# Setting to This Week projections...
#   ✓ Set to This Week
#
# Scraping 6 positions (up to 50 players each)...
#
#   [QB] Loading fresh page and applying filter...
#     → Filter attempt 1/5...
#     → Switched to Sortable Projections
#     ✗ Wrong positions: ['RB', 'RB', 'WR']
#     → Filter attempt 2/5...
#     → Switched to Sortable Projections
#     ✓ Filter verified: ['QB', 'QB', 'QB']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. Jaxson Dart (NYG): 22.0 pts
#         2. Drake Maye (NE): 21.4 pts
#         3. Jalen Hurts (PHI): 20.2 pts
#         4. Matthew Stafford (LAR): 19.9 pts
#         5. Josh Allen (BUF): 19.8 pts
#         6. Lamar Jackson (BAL): 19.4 pts
#         7. Brock Purdy (SF): 19.2 pts
#         8. Joe Burrow (CIN): 18.8 pts
#         9. Dak Prescott (DAL): 18.2 pts
#        10. Marcus Mariota (WAS): 18.1 pts
#        11. Trevor Lawrence (JAX): 17.5 pts
#        12. Patrick Mahomes (KC): 17.5 pts
#        13. C.J. Stroud (HOU): 17.2 pts
#        14. Bo Nix (DEN): 17.0 pts
#        15. Caleb Williams (CHI): 16.1 pts
#        16. Jared Goff (DET): 15.8 pts
#        17. Justin Herbert (LAC): 15.8 pts
#        18. J.J. McCarthy (MIN): 15.6 pts
#        19. Baker Mayfield (TB): 15.4 pts
#        20. Sam Darnold (SEA): 15.3 pts
#        21. Tyler Shough (NO): 15.3 pts
#        22. Jordan Love (GB): 14.8 pts
#        23. Cam Ward (TEN): 14.0 pts
#        24. Jacoby Brissett (ARI): 13.9 pts
#        25. Aaron Rodgers (PIT): 13.8 pts
#        26. Bryce Young (CAR): 13.2 pts
#        27. Shedeur Sanders (CLE): 13.1 pts
#        28. Tyrod Taylor (NYJ): 12.6 pts
#        29. Kirk Cousins (ATL): 12.3 pts
#        30. Kenny Pickett (LV): 12.1 pts
#        31. Tua Tagovailoa (MIA): 10.7 pts
#        32. Riley Leonard (IND): 10.4 pts
#        33. Jayden Daniels (WAS): 0.0 pts
#        34. Daniel Jones (IND): 0.0 pts
#        35. Kyler Murray (ARI): 0.0 pts
#        36. Justin Fields (NYJ): 0.0 pts
#        37. Joe Flacco (CIN): 0.0 pts
#        38. Michael Penix Jr. (ATL): 0.0 pts
#        39. Geno Smith (LV): 0.0 pts
#        40. Davis Mills (HOU): 0.0 pts
#        41. Mac Jones (SF): 0.0 pts
#        42. Jameis Winston (NYG): 0.0 pts
#        43. Carson Wentz (MIN): 0.0 pts
#        44. Russell Wilson (NYG): 0.0 pts
#        45. Dillon Gabriel (CLE): 0.0 pts
#        46. Spencer Rattler (NO): 0.0 pts
#        47. Anthony Richardson Sr. (IND): 0.0 pts
#        48. Mason Rudolph (PIT): 0.0 pts
#        49. Trey Lance (LAC): 0.0 pts
#        50. Jake Browning (CIN): 0.0 pts
#     ✓ Total 50 QB projections
#     ✓ Scraped 50 QB projections
#
#   [RB] Loading fresh page and applying filter...
#     → Filter attempt 1/5...
#     → Switched to Sortable Projections
#     ✓ Filter verified: ['RB', 'RB', 'WR']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. Christian McCaffrey (SF): 26.7 pts
#         2. De'Von Achane (MIA): 23.1 pts
#         3. Puka Nacua (LAR): 22.3 pts
#         4. Jaxson Dart (NYG): 22.0 pts
#         5. Jahmyr Gibbs (DET): 21.7 pts
#         6. Bijan Robinson (ATL): 21.5 pts
#         7. Drake Maye (NE): 21.4 pts
#         8. Amon-Ra St. Brown (DET): 20.9 pts
#         9. Jaxon Smith-Njigba (SEA): 20.8 pts
#        10. Ja'Marr Chase (CIN): 20.4 pts
#        11. Jalen Hurts (PHI): 20.2 pts
#        12. Matthew Stafford (LAR): 19.9 pts
#        13. Josh Allen (BUF): 19.8 pts
#        14. Lamar Jackson (BAL): 19.4 pts
#        15. Brock Purdy (SF): 19.2 pts
#        16. Joe Burrow (CIN): 18.8 pts
#        17. Dak Prescott (DAL): 18.2 pts
#        18. Marcus Mariota (WAS): 18.1 pts
#        19. Derrick Henry (BAL): 17.6 pts
#        20. Trevor Lawrence (JAX): 17.5 pts
#        21. Patrick Mahomes (KC): 17.5 pts
#        22. Rashee Rice (KC): 17.2 pts
#        23. C.J. Stroud (HOU): 17.2 pts
#        24. CeeDee Lamb (DAL): 17.2 pts
#        25. Bo Nix (DEN): 17.0 pts
#        26. A.J. Brown (PHI): 16.8 pts
#        27. Jonathan Taylor (IND): 16.7 pts
#        28. Josh Jacobs (GB): 16.6 pts
#        29. Davante Adams (LAR): 16.4 pts
#        30. Saquon Barkley (PHI): 16.4 pts
#        31. Nico Collins (HOU): 16.3 pts
#        32. George Pickens (DAL): 16.3 pts
#        33. James Cook (BUF): 16.3 pts
#        34. Caleb Williams (CHI): 16.1 pts
#        35. Jared Goff (DET): 15.8 pts
#        36. Justin Herbert (LAC): 15.8 pts
#        37. Justin Jefferson (MIN): 15.7 pts
#        38. J.J. McCarthy (MIN): 15.6 pts
#        39. Baker Mayfield (TB): 15.4 pts
#        40. Chase Brown (CIN): 15.3 pts
#        41. Sam Darnold (SEA): 15.3 pts
#        42. Tyler Shough (NO): 15.3 pts
#        43. Quinshon Judkins (CLE): 15.2 pts
#        44. Bucky Irving (TB): 15.2 pts
#        45. Travis Etienne Jr. (JAX): 15.0 pts
#        46. Jordan Love (GB): 14.8 pts
#        47. George Kittle (SF): 14.8 pts
#        48. Woody Marks (HOU): 14.7 pts
#        49. Wan'Dale Robinson (NYG): 14.6 pts
#        50. RJ Harvey (DEN): 14.6 pts
#     ✓ Total 50 RB projections
#     ✓ Scraped 50 RB projections
#
#   [WR] Loading fresh page and applying filter...
#     → Filter attempt 1/5...
#     → Switched to Sortable Projections
#     ✗ Wrong positions: ['RB', 'RB', 'WR']
#     → Filter attempt 2/5...
#     → Switched to Sortable Projections
#     ✓ Filter verified: ['WR', 'WR', 'WR']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. Puka Nacua (LAR): 22.3 pts
#         2. Amon-Ra St. Brown (DET): 20.9 pts
#         3. Jaxon Smith-Njigba (SEA): 20.8 pts
#         4. Ja'Marr Chase (CIN): 20.4 pts
#         5. Rashee Rice (KC): 17.2 pts
#         6. CeeDee Lamb (DAL): 17.2 pts
#         7. A.J. Brown (PHI): 16.8 pts
#         8. Davante Adams (LAR): 16.4 pts
#         9. Nico Collins (HOU): 16.3 pts
#        10. George Pickens (DAL): 16.3 pts
#        11. Justin Jefferson (MIN): 15.7 pts
#        12. Wan'Dale Robinson (NYG): 14.6 pts
#        13. Deebo Samuel (WAS): 14.0 pts
#        14. Jaylen Waddle (MIA): 13.9 pts
#        15. Jameson Williams (DET): 13.9 pts
#        16. DK Metcalf (PIT): 13.9 pts
#        17. Chris Olave (NO): 13.6 pts
#        18. Terry McLaurin (WAS): 13.4 pts
#        19. Stefon Diggs (NE): 13.3 pts
#        20. Courtland Sutton (DEN): 13.2 pts
#        21. Tetairoa McMillan (CAR): 13.2 pts
#        22. Jauan Jennings (SF): 13.1 pts
#        23. Ladd McConkey (LAC): 12.9 pts
#        24. DeVonta Smith (PHI): 12.9 pts
#        25. Zay Flowers (BAL): 12.8 pts
#        26. Marvin Harrison Jr. (ARI): 12.8 pts
#        27. Jordan Addison (MIN): 12.4 pts
#        28. Emeka Egbuka (TB): 12.0 pts
#        29. Jakobi Meyers (JAX): 11.9 pts
#        30. Adonai Mitchell (NYJ): 11.8 pts
#        31. Rome Odunze (CHI): 11.5 pts
#        32. John Metchie (NYJ): 11.3 pts
#        33. Christian Watson (GB): 11.3 pts
#        34. Chris Godwin Jr. (TB): 11.1 pts
#        35. Chimere Dike (TEN): 11.1 pts
#        36. Michael Wilson (ARI): 11.0 pts
#        37. Keenan Allen (LAC): 10.5 pts
#        38. Khalil Shakir (BUF): 10.5 pts
#        39. Michael Pittman Jr. (IND): 10.4 pts
#        40. Jayden Reed (GB): 10.0 pts
#        41. Jayden Higgins (HOU): 9.9 pts
#        42. Darius Slayton (NYG): 9.8 pts
#        43. Brian Thomas Jr. (JAX): 9.7 pts
#        44. Devaughn Vele (NO): 9.7 pts
#        45. Mike Evans (TB): 9.6 pts
#        46. Romeo Doubs (GB): 9.5 pts
#        47. Darnell Mooney (ATL): 9.5 pts
#        48. Jerry Jeudy (CLE): 9.2 pts
#        49. Andrei Iosivas (CIN): 9.1 pts
#        50. Kayshon Boutte (NE): 9.0 pts
#     ✓ Total 50 WR projections
#     ✓ Scraped 50 WR projections
#
#   [TE] Loading fresh page and applying filter...
#     → Filter attempt 1/5...
#     → Switched to Sortable Projections
#     ✗ Wrong positions: ['RB', 'RB', 'WR']
#     → Filter attempt 2/5...
#     → Switched to Sortable Projections
#     ✓ Filter verified: ['TE', 'TE', 'TE']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. George Kittle (SF): 14.8 pts
#         2. Trey McBride (ARI): 13.9 pts
#         3. Brock Bowers (LV): 13.0 pts
#         4. Kyle Pitts Sr. (ATL): 11.9 pts
#         5. Harold Fannin Jr. (CLE): 11.1 pts
#         6. Dallas Goedert (PHI): 10.3 pts
#         7. Hunter Henry (NE): 10.3 pts
#         8. Mark Andrews (BAL): 10.3 pts
#         9. Travis Kelce (KC): 10.0 pts
#        10. Jake Ferguson (DAL): 10.0 pts
#        11. Dalton Kincaid (BUF): 9.9 pts
#        12. Tyler Warren (IND): 9.8 pts
#        13. Theo Johnson (NYG): 9.8 pts
#        14. Juwan Johnson (NO): 9.7 pts
#        15. Isaiah Likely (BAL): 9.5 pts
#        16. Colby Parkinson (LAR): 9.4 pts
#        17. T.J. Hockenson (MIN): 9.0 pts
#        18. Dalton Schultz (HOU): 8.9 pts
#        19. Oronde Gadsden (LAC): 8.6 pts
#        20. AJ Barner (SEA): 8.6 pts
#        21. Brenton Strange (JAX): 8.3 pts
#        22. Colston Loveland (CHI): 8.1 pts
#        23. Mike Gesicki (CIN): 7.8 pts
#        24. Gunnar Helm (TEN): 7.7 pts
#        25. Evan Engram (DEN): 7.5 pts
#        26. Mason Taylor (NYJ): 7.4 pts
#        27. Darren Waller (MIA): 7.0 pts
#        28. Chig Okonkwo (TEN): 6.2 pts
#        29. Darnell Washington (PIT): 6.1 pts
#        30. Michael Mayer (LV): 5.7 pts
#        31. Jonnu Smith (PIT): 5.4 pts
#        32. Pat Freiermuth (PIT): 5.3 pts
#        33. Luke Musgrave (GB): 4.7 pts
#        34. Anthony Firkser (DET): 4.5 pts
#        35. Greg Dulcich (MIA): 4.3 pts
#        36. David Njoku (CLE): 4.1 pts
#        37. John Bates (WAS): 4.0 pts
#        38. Davis Allen (LAR): 3.9 pts
#        39. Dawson Knox (BUF): 3.7 pts
#        40. Taysom Hill (NO): 3.7 pts
#        41. Noah Fant (CIN): 3.7 pts
#        42. Ja'Tavion Sanders (CAR): 3.7 pts
#        43. Elijah Arroyo (SEA): 3.7 pts
#        44. Adam Trautman (DEN): 3.5 pts
#        45. Austin Hooper (NE): 3.5 pts
#        46. Payne Durham (TB): 3.4 pts
#        47. Noah Gray (KC): 3.3 pts
#        48. Daniel Bellinger (NYG): 3.3 pts
#        49. Cole Kmet (CHI): 3.3 pts
#        50. Ben Sinnott (WAS): 3.2 pts
#     ✓ Total 50 TE projections
#     ✓ Scraped 50 TE projections
#
#   [K] Loading fresh page and applying filter...
#     → Filter attempt 1/5...
#     → Switched to Sortable Projections
#     ✓ Filter verified: ['K', 'K', 'K']
#     Found 3 tables
#     Found 50 player rows
#     Found 50 FPTS rows
#         1. Harrison Mevis (LAR): 9.1 pts
#         2. Eddy Pineiro (SF): 8.8 pts
#         3. Brandon Aubrey (DAL): 8.7 pts
#         4. Cam Little (JAX): 8.6 pts
#         5. Jason Myers (SEA): 8.5 pts
#         6. Andy Borregales (NE): 8.4 pts
#         7. Jake Bates (DET): 8.3 pts
#         8. Chris Boswell (PIT): 8.3 pts
#         9. Younghoe Koo (NYG): 8.3 pts
#        10. Evan McPherson (CIN): 8.2 pts
#        11. Tyler Loop (BAL): 8.2 pts
#        12. Matt Prater (BUF): 8.1 pts
#        13. Cairo Santos (CHI): 8.1 pts
#        14. Ka'imi Fairbairn (HOU): 8.1 pts
#        15. Cameron Dicker (LAC): 8.1 pts
#        16. Chase McLaughlin (TB): 8.1 pts
#        17. Wil Lutz (DEN): 8.0 pts
#        18. Harrison Butker (KC): 8.0 pts
#        19. Jake Elliott (PHI): 8.0 pts
#        20. Will Reichard (MIN): 7.9 pts
#        21. Brandon McManus (GB): 7.8 pts
#        22. Riley Patterson (MIA): 7.8 pts
#        23. Zane Gonzalez (ATL): 7.8 pts
#        24. Joey Slye (TEN): 7.4 pts
#        25. Ryan Fitzgerald (CAR): 7.4 pts
#        26. Nick Folk (NYJ): 7.3 pts
#        27. Andre Szmyt (CLE): 7.3 pts
#        28. Jake Moody (WAS): 7.3 pts
#        29. Charlie Smyth (NO): 7.2 pts
#        30. Chad Ryland (ARI): 6.8 pts
#        31. Blake Grupe (IND): 6.7 pts
#        32. Daniel Carlson (LV): 6.7 pts
#        33. Tyler Bass (BUF): 0.0 pts
#        34. Jason Sanders (MIA): 0.0 pts
#        35. Spencer Shrader (IND): 0.0 pts
#        36. Lucas Havrisik (GB): 0.0 pts
#        37. Graham Gano (NYG): 0.0 pts
#     ✓ Total 37 K projections
#     ✓ Scraped 37 K projections
#
#   [D/ST] Loading fresh page and applying filter...
#     → Filter attempt 1/5...
#     → Switched to Sortable Projections
#     ✗ Wrong positions: ['RB', 'RB', 'WR']
#     → Filter attempt 2/5...
#     → Switched to Sortable Projections
#     ✓ Filter verified: ['D/ST', 'D/ST', 'D/ST']
#     Found 3 tables
#     Found 32 player rows
#     Found 32 FPTS rows
#         1. Jaguars Defense (JAX): 8.4 pts
#         2. Seahawks Defense (SEA): 8.2 pts
#         3. Texans Defense (HOU): 7.8 pts
#         4. Eagles Defense (PHI): 7.3 pts
#         5. Cowboys Defense (DAL): 7.1 pts
#         6. Steelers Defense (PIT): 6.8 pts
#         7. Bears Defense (CHI): 6.7 pts
#         8. Chiefs Defense (KC): 6.6 pts
#         9. 49ers Defense (SF): 6.2 pts
#        10. Saints Defense (NO): 5.9 pts
#        11. Dolphins Defense (MIA): 5.7 pts
#        12. Panthers Defense (CAR): 5.3 pts
#        13. Broncos Defense (DEN): 5.2 pts
#        14. Packers Defense (GB): 5.2 pts
#        15. Buccaneers Defense (TB): 5.0 pts
#        16. Chargers Defense (LAC): 5.0 pts
#        17. Falcons Defense (ATL): 5.0 pts
#        18. Raiders Defense (LV): 4.8 pts
#        19. Patriots Defense (NE): 4.6 pts
#        20. Ravens Defense (BAL): 4.6 pts
#        21. Jets Defense (NYJ): 4.5 pts
#        22. Giants Defense (NYG): 4.5 pts
#        23. Cardinals Defense (ARI): 4.2 pts
#        24. Rams Defense (LAR): 4.2 pts
#        25. Browns Defense (CLE): 4.1 pts
#        26. Bills Defense (BUF): 4.0 pts
#        27. Vikings Defense (MIN): 3.9 pts
#        28. Colts Defense (IND): 3.8 pts
#        29. Bengals Defense (CIN): 3.7 pts
#        30. Commanders Defense (WAS): 3.2 pts
#        31. Titans Defense (TEN): 3.1 pts
#        32. Lions Defense (DET): 3.0 pts
#     ✓ Total 32 D/ST projections
#     ✓ Scraped 32 D/ST projections
#
# ✓ Total players with valid projections: 269
#
# Saving 269 projections to database...
# ✓ Successfully saved to database!
#
# ✅ ESPN scraping complete!

# %%
# 📊 FANTASYPROS SCRAPER  
# ================================================
# Set HEADLESS = False in setup cell to debug visually
print(f"{'='*70}")
print(f"📊 FANTASYPROS SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    with FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK)
    print("\n✅ FantasyPros scraping complete!")
except Exception as e:
    print(f"\n❌ FantasyPros error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# 📊 FANTASYPROS SCRAPER - Week 15
# ======================================================================
#
#
# ============================================================
# FANTASYPROS SCRAPER - Week 15
# ============================================================
#
#   [QB] Loading https://www.fantasypros.com/nfl/rankings/qb.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 79 rows
#     → Parsing players...
#         1. Josh Allen (BUF): 21.5
#         2. Matthew Stafford (LAR): 21.3
#         3. Drake Maye (NE): 21.1
#         4. Joe Burrow (CIN): 20.9
#         5. Jalen Hurts (PHI): 20.6
#         6. Lamar Jackson (BAL): 20.2
#         7. Dak Prescott (DAL): 19.9
#         8. Jaxson Dart (NYG): 19.5
#         9. Patrick Mahomes II (KC): 19.2
#        10. Brock Purdy (SF): 18.8
#        11. Trevor Lawrence (JAC): 18.7
#        12. Jared Goff (DET): 18.2
#        13. Marcus Mariota (WAS): 17.8
#        14. Baker Mayfield (TB): 17.4
#        15. Sam Darnold (SEA): 16.9
#        16. Jordan Love (GB): 16.5
#        17. J.J. McCarthy (MIN): 16.3
#        18. Bo Nix (DEN): 16.1
#        19. C.J. Stroud (HOU): 15.9
#        20. Jacoby Brissett (ARI): 15.6
#        21. Justin Herbert (LAC): 15.3
#        22. Caleb Williams (CHI): 15.0
#        23. Bryce Young (CAR): 14.7
#        24. Tyler Shough (NO): 14.3
#        25. Shedeur Sanders (CLE): 14.0
#        26. Aaron Rodgers (PIT): 13.8
#        27. Kirk Cousins (ATL): 13.5
#        28. Tua Tagovailoa (MIA): 13.0
#        29. Cam Ward (TEN): 12.5
#        30. Riley Leonard (IND): 11.8
#        31. Kenny Pickett (LV): 11.1
#        32. Brady Cook (NYJ): 10.2
#        33. Justin Fields (NYJ): 9.4
#        34. Philip Rivers (IND): 1.6
#        35. Geno Smith (LV): 0.6
#        36. Tyrod Taylor (NYJ): 0.5
#        37. Trey Lance (LAC): 0.5
#        38. Teddy Bridgewater (TB): 0.5
#        39. Max Brosmer (MIN): 0.5
#        40. Tyler Huntley (BAL): 0.5
#        41. Joe Flacco (CIN): 0.5
#        42. Davis Mills (HOU): 0.5
#        43. Tyson Bagent (CHI): 0.5
#        44. Mason Rudolph (PIT): 0.5
#        45. Jalen Milroe (SEA): 0.5
#        46. Jimmy Garoppolo (LAR): 0.4
#        47. Joshua Dobbs (NE): 0.4
#        48. Malik Willis (GB): 0.4
#        49. Mitchell Trubisky (BUF): 0.4
#        50. Joe Milton III (DAL): 0.4
#        51. Mac Jones (SF): 0.4
#        52. Jameis Winston (NYG): 0.4
#        53. Brett Rypien (IND): 0.4
#        54. Nick Mullens (JAC): 0.4
#        55. Spencer Rattler (NO): 0.4
#        56. Tanner McKee (PHI): 0.4
#        57. Jarrett Stidham (DEN): 0.3
#        58. Andy Dalton (CAR): 0.3
#        59. Brandon Allen (TEN): 0.2
#        60. Zach Wilson (MIA): 0.2
#        61. Quinn Ewers (MIA): 0.2
#        62. Russell Wilson (NYG): 0.2
#        63. Jake Browning (CIN): 0.1
#     ✓ QB: 63 players scraped
#
#   [RB] Loading https://www.fantasypros.com/nfl/rankings/ppr-rb.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 112 rows
#     → Parsing players...
#         1. Christian McCaffrey (SF): 26.9
#         2. Jahmyr Gibbs (DET): 20.9
#         3. Bijan Robinson (ATL): 20.6
#         4. De'Von Achane (MIA): 19.7
#         5. Bucky Irving (TB): 16.7
#         6. Derrick Henry (BAL): 16.0
#         7. James Cook III (BUF): 16.0
#         8. Travis Etienne Jr. (JAC): 15.6
#         9. Chase Brown (CIN): 15.4
#        10. Saquon Barkley (PHI): 15.4
#        11. Jonathan Taylor (IND): 15.0
#        12. Josh Jacobs (GB): 14.3
#        13. Javonte Williams (DAL): 14.1
#        14. TreVeyon Henderson (NE): 14.0
#        15. Quinshon Judkins (CLE): 13.8
#        16. Kyren Williams (LAR): 13.7
#        17. Woody Marks (HOU): 13.5
#        18. RJ Harvey (DEN): 13.4
#        19. Jaylen Warren (PIT): 13.0
#        20. Breece Hall (NYJ): 13.0
#        21. Ashton Jeanty (LV): 12.8
#        22. Kenneth Walker III (SEA): 12.7
#        23. Rico Dowdle (CAR): 12.0
#        24. Omarion Hampton (LAC): 11.7
#        25. Devin Neal (NO): 11.7
#        26. D'Andre Swift (CHI): 11.6
#        27. Aaron Jones Sr. (MIN): 11.4
#        28. Chris Rodriguez Jr. (WAS): 11.4
#        29. Kyle Monangai (CHI): 11.3
#        30. Tyrone Tracy Jr. (NYG): 10.6
#        31. Tony Pollard (TEN): 10.6
#        32. Chuba Hubbard (CAR): 10.2
#        33. Zonovan Knight (ARI): 10.0
#        34. Devin Singletary (NYG): 9.9
#        35. Kareem Hunt (KC): 9.7
#        36. Blake Corum (LAR): 9.7
#        37. David Montgomery (DET): 9.5
#        38. Kenneth Gainwell (PIT): 9.5
#        39. Zach Charbonnet (SEA): 9.4
#        40. Rhamondre Stevenson (NE): 9.4
#        41. Kimani Vidal (LAC): 8.2
#        42. Tyjae Spears (TEN): 8.0
#        43. Jordan Mason (MIN): 7.5
#        44. Michael Carter (ARI): 7.4
#        45. Tyler Allgeier (ATL): 7.4
#        46. Samaje Perine (CIN): 7.0
#        47. Rachaad White (TB): 6.9
#        48. Bhayshul Tuten (JAC): 6.3
#        49. Isiah Pacheco (KC): 6.3
#        50. Jaleel McLaughlin (DEN): 6.0
#        51. Ty Johnson (BUF): 5.8
#        52. Jaylen Wright (MIA): 5.4
#        53. Sean Tucker (TB): 5.4
#        54. Jeremy McNichols (WAS): 5.4
#        55. Brian Robinson Jr. (SF): 5.2
#        56. Jacory Croskey-Merritt (WAS): 5.1
#        57. Emanuel Wilson (GB): 5.0
#        58. Dylan Sampson (CLE): 4.7
#        59. Ollie Gordon II (MIA): 4.5
#        60. Rasheen Ali (BAL): 4.4
#        61. Malik Davis (DAL): 3.4
#        62. Dare Ogunbowale (HOU): 3.3
#        63. Isaiah Davis (NYJ): 3.2
#        64. Ray Davis (BUF): 3.0
#        65. Brashard Smith (KC): 3.0
#        66. Tyler Badie (DEN): 2.8
#        67. Keaton Mitchell (BAL): 2.5
#        68. Tank Bigsby (PHI): 2.5
#        69. Raheem Mostert (LV): 2.4
#        70. LeQuint Allen Jr. (JAC): 2.4
#        71. Chris Brooks (GB): 2.1
#        72. Will Shipley (PHI): 2.0
#        73. Nick Chubb (HOU): 1.9
#        74. Audric Estime (NO): 1.9
#        75. Jerome Ford (CLE): 1.8
#        76. Evan Hull (NO): 1.7
#        77. Emari Demercado (ARI): 1.6
#        78. Ameer Abdullah (IND): 1.5
#        79. Kaleb Johnson (PIT): 1.3
#        80. Kyle Juszczyk (SF): 1.2
#        81. Hunter Luepke (DAL): 1.1
#        82. Patrick Ricard (BAL): 1.1
#        83. Alec Ingold (MIA): 1.0
#        84. Zavier Scott (MIN): 1.0
#        85. Dylan Laube (LV): 1.0
#        86. Terrell Jennings (NE): 0.9
#        87. Adam Prentice (DEN): 0.9
#        88. British Brooks (HOU): 0.8
#        89. Alvin Kamara (NO): 0.8
#        90. DJ Giddens (IND): 0.8
#        91. Clyde Edwards-Helaire (KC): 0.8
#        92. Kendall Milton (CIN): 0.7
#        93. Trevor Etienne (CAR): 0.7
#        94. Tyler Goodson (IND): 0.7
#        95. Julius Chestnut (TEN): 0.7
#        96. Raheim Sanders (CLE): 0.6
#        97. Tahj Brooks (CIN): 0.5
#        98. Reggie Gilliam (BUF): 0.4
#        99. C.J. Ham (MIN): 0.4
#       100. Jaydon Blue (DAL): 0.4
#       101. Hassan Haskins (LAC): 0.3
#       102. MarShawn Lloyd (GB): 0.2
#       103. Kene Nwangwu (NYJ): 0.1
#     ✓ RB: 103 players scraped
#
#   [WR] Loading https://www.fantasypros.com/nfl/rankings/ppr-wr.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 144 rows
#     → Parsing players...
#         1. Jaxon Smith-Njigba (SEA): 21.0
#         2. Puka Nacua (LAR): 21.0
#         3. Ja'Marr Chase (CIN): 19.1
#         4. Rashee Rice (KC): 18.5
#         5. Amon-Ra St. Brown (DET): 17.1
#         6. Davante Adams (LAR): 17.0
#         7. Nico Collins (HOU): 16.9
#         8. George Pickens (DAL): 16.7
#         9. A.J. Brown (PHI): 16.5
#        10. Jaylen Waddle (MIA): 15.9
#        11. Michael Wilson (ARI): 15.8
#        12. Wan'Dale Robinson (NYG): 14.5
#        13. Chris Olave (NO): 14.5
#        14. Tetairoa McMillan (CAR): 14.3
#        15. Jameson Williams (DET): 14.2
#        16. Terry McLaurin (WAS): 13.5
#        17. Jakobi Meyers (JAC): 13.1
#        18. DeVonta Smith (PHI): 13.0
#        19. Justin Jefferson (MIN): 12.8
#        20. Stefon Diggs (NE): 12.8
#        21. Zay Flowers (BAL): 12.7
#        22. Ladd McConkey (LAC): 12.6
#        23. Jauan Jennings (SF): 12.5
#        24. DK Metcalf (PIT): 12.5
#        25. Chris Godwin Jr. (TB): 12.4
#        26. Emeka Egbuka (TB): 12.3
#        27. Courtland Sutton (DEN): 12.1
#        28. Michael Pittman Jr. (IND): 12.1
#        29. Christian Watson (GB): 11.6
#        30. Brian Thomas Jr. (JAC): 11.4
#        31. Khalil Shakir (BUF): 11.1
#        32. Deebo Samuel Sr. (WAS): 11.0
#        33. Luther Burden III (CHI): 10.8
#        34. DJ Moore (CHI): 10.6
#        35. Jerry Jeudy (CLE): 10.1
#        36. Jordan Addison (MIN): 10.5
#        37. Adonai Mitchell (NYJ): 10.1
#        38. Alec Pierce (IND): 10.0
#        39. Quentin Johnston (LAC): 9.8
#        40. Jayden Reed (GB): 9.8
#        41. Jayden Higgins (HOU): 9.6
#        42. Xavier Worthy (KC): 9.6
#        43. Darnell Mooney (ATL): 9.4
#        44. Devaughn Vele (NO): 9.3
#        45. Kayshon Boutte (NE): 9.2
#        46. Darius Slayton (NYG): 9.0
#        47. Ricky Pearsall (SF): 9.0
#        48. Romeo Doubs (GB): 8.9
#        49. Troy Franklin (DEN): 8.9
#        50. Keenan Allen (LAC): 8.8
#        51. Chimere Dike (TEN): 8.7
#        52. John Metchie III (NYJ): 8.5
#        53. Pat Bryant (DEN): 8.6
#        54. Tre Tucker (LV): 8.5
#        55. Rashid Shaheed (SEA): 8.4
#        56. Cooper Kupp (SEA): 8.2
#        57. Jalen Coker (CAR): 8.1
#        58. Malik Washington (MIA): 8.0
#        59. Josh Downs (IND): 7.9
#        60. Elic Ayomanor (TEN): 7.8
#        61. Andrei Iosivas (CIN): 7.7
#        62. Ryan Flournoy (DAL): 7.7
#        63. Isaac TeSlaa (DET): 7.7
#        64. Olamide Zaccheaus (CHI): 7.5
#        65. Xavier Legette (CAR): 7.5
#        66. Mike Evans (TB): 7.2
#        67. Keon Coleman (BUF): 7.2
#        68. Gabe Davis (BUF): 7.2
#        69. Marquise Brown (KC): 6.8
#        70. Tez Johnson (TB): 6.8
#        71. Christian Kirk (HOU): 6.5
#        72. Rashod Bateman (BAL): 6.3
#        73. Tim Patrick (JAC): 6.3
#        74. David Sills V (ATL): 6.2
#        75. Jack Bech (LV): 6.2
#        76. Calvin Austin III (PIT): 5.7
#        77. Mack Hollins (NE): 5.6
#        78. Dontayvion Wicks (GB): 5.5
#        79. CeeDee Lamb (DAL): 5.4
#        80. Marvin Mims Jr. (DEN): 5.3
#        81. KaVontae Turpin (DAL): 5.2
#        82. Mason Tipton (NO): 5.2
#        83. Noah Brown (WAS): 5.1
#        84. Tyler Lockett (LV): 5.0
#        85. Cedric Tillman (CLE): 4.9
#        86. DeMario Douglas (NE): 4.7
#        87. Van Jefferson (TEN): 4.6
#        88. DeAndre Hopkins (BAL): 4.5
#        89. Kyle Williams (NE): 4.3
#        90. Xavier Hutchinson (HOU): 4.3
#        91. Sterling Shepard (TB): 4.2
#        92. Matthew Golden (GB): 4.2
#        93. Tyquan Thornton (KC): 4.1
#        94. Treylon Burks (WAS): 4.1
#        95. Parker Washington (JAC): 4.0
#        96. Adam Thielen (PIT): 3.9
#        97. Isaiah Bond (CLE): 3.9
#        98. Jaylin Noel (HOU): 3.8
#        99. Jalen Nailor (MIN): 3.5
#       100. Mitch Tinsley (CIN): 3.4
#       101. Isaiah Williams (NYJ): 3.4
#       102. Marvin Harrison Jr. (ARI): 3.3
#       103. Tee Higgins (CIN): 3.3
#       104. Kendrick Bourne (SF): 3.3
#       105. Brandin Cooks (BUF): 3.3
#       106. JuJu Smith-Schuster (KC): 3.2
#       107. Jahan Dotson (PHI): 3.2
#       108. Rome Odunze (CHI): 3.2
#       109. Tre Harris (LAC): 3.2
#       110. Xavier Weaver (ARI): 3.1
#       111. Isaiah Hodgins (NYG): 3.1
#       112. Shedrick Jackson (LV): 3.0
#       113. Dylan Drummond (ATL): 2.8
#       114. Tyrell Shavers (BUF): 2.6
#       115. Andre Baccellia (ARI): 2.5
#       116. Demarcus Robinson (SF): 2.4
#       117. Xavier Smith (LAR): 2.3
#       118. Lil'Jordan Humphrey (DEN): 2.3
#       119. Casey Washington (ATL): 2.1
#       120. Konata Mumpfield (LAR): 2.1
#       121. Gage Larvadain (CLE): 2.1
#       122. Jordan Whittington (LAR): 2.1
#       123. Marquez Valdes-Scantling (PIT): 2.0
#       124. Jalen Brooks (ARI): 2.0
#       125. Bo Melton (GB): 1.9
#       126. Cedrick Wilson Jr. (MIA): 1.9
#       127. Malachi Corley (CLE): 1.8
#       128. Jaylin Lane (WAS): 1.8
#       129. Nick Westbrook-Ikhine (MIA): 1.6
#       130. Dyami Brown (JAC): 1.5
#       131. Allen Lazard (NYJ): 1.4
#       132. Jimmy Horn Jr. (CAR): 1.4
#       133. Kalif Raymond (DET): 1.2
#       134. Devin Duvernay (CHI): 1.2
#       135. Dont'e Thornton Jr. (LV): 1.0
#       136. Arian Smith (NYJ): 1.0
#       137. James Proche II (TEN): 0.9
#       138. Kameron Johnson (TB): 0.7
#       139. Trent Sherfield Sr. (ARI): 0.6
#       140. Jamari Thrash (CLE): 0.6
#       141. Tylan Wallace (BAL): 0.4
#     ✓ WR: 141 players scraped
#
#   [TE] Loading https://www.fantasypros.com/nfl/rankings/ppr-te.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 79 rows
#     → Parsing players...
#         1. Trey McBride (ARI): 15.4
#         2. George Kittle (SF): 13.7
#         3. Brock Bowers (LV): 13.2
#         4. Harold Fannin Jr. (CLE): 10.5
#         5. Kyle Pitts Sr. (ATL): 10.4
#         6. Tyler Warren (IND): 10.4
#         7. Travis Kelce (KC): 10.4
#         8. Brenton Strange (JAC): 10.3
#         9. Jake Ferguson (DAL): 10.3
#        10. Dalton Kincaid (BUF): 10.2
#        11. Mark Andrews (BAL): 9.8
#        12. Theo Johnson (NYG): 9.8
#        13. Colston Loveland (CHI): 9.7
#        14. Hunter Henry (NE): 9.6
#        15. Juwan Johnson (NO): 9.3
#        16. Isaiah Likely (BAL): 9.2
#        17. Dalton Schultz (HOU): 8.9
#        18. Darren Waller (MIA): 8.7
#        19. Dallas Goedert (PHI): 8.6
#        20. AJ Barner (SEA): 8.4
#        21. Oronde Gadsden II (LAC): 8.3
#        22. Mike Gesicki (CIN): 8.2
#        23. Colby Parkinson (LAR): 8.0
#        24. Evan Engram (DEN): 7.9
#        25. Mason Taylor (NYJ): 7.9
#        26. T.J. Hockenson (MIN): 7.4
#        27. Gunnar Helm (TEN): 6.7
#        28. Pat Freiermuth (PIT): 6.5
#        29. Chig Okonkwo (TEN): 6.3
#        30. Dawson Knox (BUF): 5.4
#        31. Jonnu Smith (PIT): 5.2
#        32. Ja'Tavion Sanders (CAR): 5.1
#        33. Cole Kmet (CHI): 5.1
#        34. Darnell Washington (PIT): 4.9
#        35. David Njoku (CLE): 4.8
#        36. John Bates (WAS): 4.5
#        37. Ben Sinnott (WAS): 4.2
#        38. Luke Musgrave (GB): 4.2
#        39. Cade Otton (TB): 4.1
#        40. Taysom Hill (NO): 4.0
#        41. Noah Fant (CIN): 3.9
#        42. Greg Dulcich (MIA): 3.7
#        43. Elijah Higgins (ARI): 3.6
#        44. Josh Oliver (MIN): 3.5
#        45. Davis Allen (LAR): 3.5
#        46. Terrance Ferguson (LAR): 3.5
#        47. Tommy Tremble (CAR): 3.3
#        48. Noah Gray (KC): 3.3
#        49. Elijah Arroyo (SEA): 2.9
#        50. Austin Hooper (NE): 2.9
#        51. Adam Trautman (DEN): 2.8
#        52. Ross Dwelley (FA): 2.8
#        53. Charlie Kolar (BAL): 2.7
#        54. Anthony Firkser (DET): 2.7
#        55. Mitchell Evans (CAR): 2.7
#        56. Michael Mayer (LV): 2.7
#        57. Payne Durham (TB): 2.6
#        58. Tanner Hudson (CIN): 2.5
#        59. Josh Whyle (GB): 2.5
#        60. Cade Stover (HOU): 2.5
#        61. John FitzPatrick (GB): 2.5
#        62. Jackson Hawes (BUF): 2.4
#        63. Luke Schoonmaker (DAL): 2.2
#        64. Daniel Bellinger (NYG): 2.0
#        65. Jeremy Ruckert (NYJ): 2.0
#        66. Grant Calcaterra (PHI): 2.0
#        67. Foster Moreau (NO): 1.9
#        68. Drew Sample (CIN): 1.9
#        69. Ian Thomas (LV): 1.8
#        70. Charlie Woerner (ATL): 1.8
#        71. Mo Alie-Cox (IND): 1.8
#        72. Drew Ogletree (IND): 1.7
#        73. Connor Heyward (PIT): 1.4
#        74. Quintin Morris (JAC): 1.3
#        75. Kylen Granson (PHI): 1.2
#        76. Julian Hill (MIA): 1.0
#        77. Brevyn Spann-Ford (DAL): 1.0
#     ✓ TE: 77 players scraped
#
#   [K] Loading https://www.fantasypros.com/nfl/rankings/k.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 34 rows
#     → Parsing players...
#         1. Brandon Aubrey (DAL): 9.1
#         2. Jason Myers (SEA): 8.8
#         3. Ka'imi Fairbairn (HOU): 8.7
#         4. Tyler Loop (BAL): 8.5
#         5. Chase McLaughlin (TB): 8.4
#         6. Evan McPherson (CIN): 8.0
#         7. Cam Little (JAC): 8.0
#         8. Cameron Dicker (LAC): 7.7
#         9. Harrison Mevis (LAR): 7.6
#        10. Eddy Pineiro (SF): 7.6
#        11. Jake Bates (DET): 7.6
#        12. Andy Borregales (NE): 7.5
#        13. Matt Prater (BUF): 7.4
#        14. Chris Boswell (PIT): 7.4
#        15. Wil Lutz (DEN): 7.3
#        16. Harrison Butker (KC): 7.2
#        17. Cairo Santos (CHI): 7.2
#        18. Jake Elliott (PHI): 7.1
#        19. Riley Patterson (MIA): 7.0
#        20. Brandon McManus (GB): 7.0
#        21. Will Reichard (MIN): 7.0
#        22. Jake Moody (WAS): 6.9
#        23. Ryan Fitzgerald (CAR): 6.8
#        24. Zane Gonzalez (ATL): 6.8
#        25. Charlie Smyth (NO): 6.7
#        26. Nick Folk (NYJ): 6.6
#        27. Chad Ryland (ARI): 6.5
#        28. Joey Slye (TEN): 6.3
#        29. Andre Szmyt (CLE): 6.3
#        30. Blake Grupe (IND): 5.8
#        31. Younghoe Koo (NYG): 5.6
#        32. Matt Gay (FA): 5.4
#        33. Daniel Carlson (LV): 4.7
#     ✓ K: 33 players scraped
#
#   [DST] Loading https://www.fantasypros.com/nfl/rankings/dst.php
#     → Loading page (attempt 1)... OK
#     → Waiting for table... OK
#     → Scrolling to load all players... found 33 rows
#     → Parsing players...
#         1. Seattle Seahawks Defense (SEA): 12.4
#         2. Houston Texans Defense (HOU): 10.2
#         3. Philadelphia Eagles Defense (PHI): 8.3
#         4. Jacksonville Jaguars Defense (JAC): 8.3
#         5. San Francisco 49ers Defense (SF): 8.1
#         6. Chicago Bears Defense (CHI): 7.9
#         7. Dallas Cowboys Defense (DAL): 7.9
#         8. Tampa Bay Buccaneers Defense (TB): 7.7
#         9. Denver Broncos Defense (DEN): 7.3
#        10. Pittsburgh Steelers Defense (PIT): 7.0
#        11. Green Bay Packers Defense (GB): 7.0
#        12. Carolina Panthers Defense (CAR): 6.9
#        13. Cleveland Browns Defense (CLE): 6.6
#        14. Kansas City Chiefs Defense (KC): 6.6
#        15. Miami Dolphins Defense (MIA): 6.3
#        16. Los Angeles Rams Defense (LAR): 6.0
#        17. New Orleans Saints Defense (NO): 5.9
#        18. Baltimore Ravens Defense (BAL): 5.9
#        19. Los Angeles Chargers Defense (LAC): 5.8
#        20. Washington Commanders Defense (WAS): 5.8
#        21. New York Giants Defense (NYG): 5.7
#        22. Minnesota Vikings Defense (MIN): 5.7
#        23. New England Patriots Defense (NE): 5.7
#        24. Buffalo Bills Defense (BUF): 5.6
#        25. New York Jets Defense (NYJ): 5.6
#        26. Arizona Cardinals Defense (ARI): 5.6
#        27. Detroit Lions Defense (DET): 5.5
#        28. Indianapolis Colts Defense (IND): 5.4
#        29. Tennessee Titans Defense (TEN): 5.3
#        30. Atlanta Falcons Defense (ATL): 4.9
#        31. Cincinnati Bengals Defense (CIN): 4.9
#        32. Las Vegas Raiders Defense (LV): 4.9
#     ✓ DST: 32 players scraped
#
# ============================================================
# Total: 449 players scraped
# ============================================================
#
# Saving 449 projections to database...
# ✓ Successfully saved to database!
#
# ✅ FantasyPros scraping complete!

# %%
# 🎯 FIRST DOWN STUDIO SCRAPER
# ================================================
# Set HEADLESS = False in setup cell to debug visually
print(f"{'='*70}")
print(f"🎯 FIRST DOWN STUDIO SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    with FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
        scraper.scrape_and_save(week=WEEK, scoring="PPR")
    print("\n✅ First Down Studio scraping complete!")
except Exception as e:
    print(f"\n❌ First Down Studio error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# 🎯 FIRST DOWN STUDIO SCRAPER - Week 15
# ======================================================================
#
#
# Scraping QB from https://www.firstdown.studio/rankings/qb...
#   Headers: ['# (vs. ecr)', 'Player', 'Proj. Pts', 'Pass Yds', 'Pass TDs', 'INTs', 'Rush Yds']
#   Found points column at index 2
#   Found 31 player rows
#     Josh Allen (BUF): 21.5 pts
#     Matthew Stafford (LA): 20.4 pts
#     Lamar Jackson (BAL): 20.4 pts
#     Dak Prescott (DAL): 19.9 pts
#     Jalen Hurts (PHI): 19.2 pts
#     Joe Burrow (CIN): 19.1 pts
#     Patrick Mahomes (KC): 18.9 pts
#     Drake Maye (NE): 18.6 pts
#     Jaxson Dart (NYG): 18.5 pts
#     Brock Purdy (SF): 17.8 pts
#     C.J. Stroud (HOU): 17.1 pts
#     Baker Mayfield (TB): 17.1 pts
#     Trevor Lawrence (JAC): 17.1 pts
#     Jared Goff (DET): 16.9 pts
#     Sam Darnold (SEA): 16.6 pts
#     Marcus Mariota (WAS): 16.4 pts
#     Bo Nix (DEN): 15.6 pts
#     Caleb Williams (CHI): 15.6 pts
#     Justin Herbert (LAC): 15.1 pts
#     Jordan Love (GB): 14.9 pts
#     Aaron Rodgers (PIT): 14.1 pts
#     Jacoby Brissett (ARI): 14.0 pts
#     Bryce Young (CAR): 14.0 pts
#     Tyler Shough (NO): 13.9 pts
#     J.J. McCarthy (MIN): 13.6 pts
#     Tua Tagovailoa (MIA): 12.6 pts
#     Cam Ward (TEN): 11.9 pts
#     Kirk Cousins (ATL): 11.7 pts
#     Shedeur Sanders (CLE): 11.2 pts
#     Geno Smith (LV): 10.7 pts
#     Riley Leonard (IND): 9.5 pts
#   ✓ Scraped 31 QB projections
#
# Scraping RB from https://www.firstdown.studio/rankings/rb...
#   Headers: ['# (vs. ecr)', 'Player', 'Proj. Pts', 'Rush Yds', 'Rec', 'Rec Yds', 'TDs']
#   Found points column at index 2
#   Found 55 player rows
#     C. McCaffrey (SF): 21.0 pts
#     Bijan Robinson (ATL): 17.9 pts
#     Jahmyr Gibbs (DET): 17.6 pts
#     De'Von Achane (MIA): 16.7 pts
#     Derrick Henry (BAL): 15.6 pts
#     Jonathan Taylor (IND): 15.6 pts
#     James Cook (BUF): 14.7 pts
#     Saquon Barkley (PHI): 14.3 pts
#     Javonte Williams (DAL): 14.1 pts
#     Travis Etienne (JAC): 13.9 pts
#     Woody Marks (HOU): 13.8 pts
#     Josh Jacobs (GB): 13.6 pts
#     Breece Hall (NYJ): 12.7 pts
#     Bucky Irving (TB): 12.7 pts
#     Quinshon Judkins (CLE): 12.3 pts
#     Ashton Jeanty (LV): 12.2 pts
#     RJ Harvey (DEN): 12.1 pts
#     Kyren Williams (LA): 12.0 pts
#     Kenneth Walker (SEA): 11.6 pts
#     Rico Dowdle (CAR): 11.6 pts
#     Chase Brown (CIN): 11.3 pts
#     T. Henderson (NE): 11.3 pts
#     Aaron Jones (MIN): 11.0 pts
#     D'Andre Swift (CHI): 10.6 pts
#     Tyrone Tracy (NYG): 10.6 pts
#     Omarion Hampton (LAC): 10.5 pts
#     Jaylen Warren (PIT): 10.3 pts
#     Kenneth Gainwell (PIT): 9.5 pts
#     Kyle Monangai (CHI): 9.3 pts
#     Kareem Hunt (KC): 9.0 pts
#     Devin Neal (NO): 8.9 pts
#     Zach Charbonnet (SEA): 8.5 pts
#     Devin Singletary (NYG): 8.4 pts
#     David Montgomery (DET): 8.3 pts
#     Chuba Hubbard (CAR): 8.1 pts
#     Chris Rodriguez (WAS): 7.8 pts
#     R. Stevenson (NE): 7.5 pts
#     Tony Pollard (TEN): 7.1 pts
#     Jordan Mason (MIN): 7.0 pts
#     Blake Corum (LA): 7.0 pts
#     Tyjae Spears (TEN): 6.9 pts
#     Tyler Allgeier (ATL): 6.0 pts
#     Samaje Perine (CIN): 5.9 pts
#     Kimani Vidal (LAC): 5.8 pts
#     Isiah Pacheco (KC): 5.7 pts
#     J. Croskey-Merritt (WAS): 5.5 pts
#     Nick Chubb (HOU): 5.4 pts
#     Emari Demercado (ARI): 5.4 pts
#     Keaton Mitchell (BAL): 5.3 pts
#     Dylan Sampson (CLE): 5.3 pts
#     Bhayshul Tuten (JAC): 5.2 pts
#     Brian Robinson (SF): 5.1 pts
#     Rachaad White (TB): 5.0 pts
#     Michael Carter (ARI): 4.6 pts
#     Emanuel Wilson (GB): 4.2 pts
#   ✓ Scraped 55 RB projections
#
# Scraping WR from https://www.firstdown.studio/rankings/wr...
#   Headers: ['# (vs. ecr)', 'Player', 'Proj. Pts', 'Rec', 'Rec Yds', 'TDs']
#   Found points column at index 2
#   Found 69 player rows
#     J. Smith-Njigba (SEA): 18.2 pts
#     Puka Nacua (LA): 17.7 pts
#     Ja'Marr Chase (CIN): 17.3 pts
#     A. St. Brown (DET): 15.0 pts
#     George Pickens (DAL): 14.1 pts
#     Davante Adams (LA): 13.5 pts
#     Nico Collins (HOU): 13.3 pts
#     Rashee Rice (KC): 12.7 pts
#     Zay Flowers (BAL): 11.9 pts
#     Chris Olave (NO): 11.6 pts
#     Jameson Williams (DET): 11.2 pts
#     A.J. Brown (PHI): 10.9 pts
#     T. McMillan (CAR): 10.8 pts
#     W. Robinson (NYG): 10.7 pts
#     Terry McLaurin (WAS): 10.4 pts
#     Justin Jefferson (MIN): 10.2 pts
#     DK Metcalf (PIT): 10.1 pts
#     Jaylen Waddle (MIA): 10.0 pts
#     Christian Watson (GB): 9.9 pts
#     DeVonta Smith (PHI): 9.9 pts
#     Ladd McConkey (LAC): 9.9 pts
#     Jakobi Meyers (JAC): 9.8 pts
#     Mike Evans (TB): 9.7 pts
#     Stefon Diggs (NE): 9.4 pts
#     Deebo Samuel (WAS): 9.2 pts
#     Jauan Jennings (SF): 9.0 pts
#     Brian Thomas (JAC): 8.8 pts
#     Michael Wilson (ARI): 8.8 pts
#     Emeka Egbuka (TB): 8.6 pts
#     Courtland Sutton (DEN): 8.5 pts
#     Luther Burden (CHI): 8.2 pts
#     Jordan Addison (MIN): 8.2 pts
#     Chris Godwin (TB): 8.0 pts
#     Ricky Pearsall (SF): 7.9 pts
#     Michael Pittman (IND): 7.8 pts
#     Khalil Shakir (BUF): 7.8 pts
#     Jayden Higgins (HOU): 7.7 pts
#     Xavier Worthy (KC): 7.5 pts
#     Keenan Allen (LAC): 7.5 pts
#     Adonai Mitchell (NYJ): 7.4 pts
#     Romeo Doubs (GB): 7.3 pts
#     Devaughn Vele (NO): 7.3 pts
#     Quentin Johnston (LAC): 7.2 pts
#     Alec Pierce (IND): 7.1 pts
#     Tee Higgins (CIN): 7.0 pts
#     Rashid Shaheed (SEA): 6.8 pts
#     Jayden Reed (GB): 6.7 pts
#     Cooper Kupp (SEA): 6.7 pts
#     Darnell Mooney (ATL): 6.6 pts
#     DJ Moore (CHI): 6.6 pts
#     Chimere Dike (TEN): 6.6 pts
#     P. Washington (JAC): 6.5 pts
#     Darius Slayton (NYG): 6.4 pts
#     John Metchie (NYJ): 6.4 pts
#     Jerry Jeudy (CLE): 6.3 pts
#     Troy Franklin (DEN): 6.2 pts
#     Pat Bryant (DEN): 6.1 pts
#     Andrei Iosivas (CIN): 6.1 pts
#     Jalen Coker (CAR): 6.1 pts
#     Kayshon Boutte (NE): 5.9 pts
#     Elic Ayomanor (TEN): 5.8 pts
#     Tre Tucker (LV): 5.6 pts
#     Malik Washington (MIA): 5.5 pts
#     Mack Hollins (NE): 5.4 pts
#     Josh Downs (IND): 5.4 pts
#     Christian Kirk (HOU): 5.0 pts
#     Xavier Legette (CAR): 4.9 pts
#     Noah Brown (WAS): 4.9 pts
#     Ryan Flournoy (DAL): 4.8 pts
#   ✓ Scraped 69 WR projections
#
# Scraping TE from https://www.firstdown.studio/rankings/te...
#   Headers: ['# (vs. ecr)', 'Player', 'Proj. Pts', 'Rec', 'Rec Yds', 'TDs']
#   Found points column at index 2
#   Found 27 player rows
#     Trey McBride (ARI): 12.5 pts
#     Kyle Pitts (ATL): 10.6 pts
#     George Kittle (SF): 10.2 pts
#     Brock Bowers (LV): 9.4 pts
#     Harold Fannin (CLE): 8.7 pts
#     Jake Ferguson (DAL): 8.6 pts
#     Travis Kelce (KC): 8.5 pts
#     Juwan Johnson (NO): 8.3 pts
#     Mark Andrews (BAL): 8.1 pts
#     Hunter Henry (NE): 7.9 pts
#     Brenton Strange (JAC): 7.7 pts
#     Tyler Warren (IND): 7.6 pts
#     Dalton Kincaid (BUF): 7.5 pts
#     Theo Johnson (NYG): 7.4 pts
#     Dallas Goedert (PHI): 7.4 pts
#     Oronde Gadsden (LAC): 7.4 pts
#     Dalton Schultz (HOU): 7.3 pts
#     Colston Loveland (CHI): 6.9 pts
#     Isaiah Likely (BAL): 6.5 pts
#     Mike Gesicki (CIN): 6.4 pts
#     AJ Barner (SEA): 6.2 pts
#     Colby Parkinson (LA): 6.2 pts
#     Darren Waller (MIA): 6.2 pts
#     Mason Taylor (NYJ): 5.9 pts
#     T.J. Hockenson (MIN): 5.7 pts
#     Cade Otton (TB): 5.6 pts
#     Pat Freiermuth (PIT): 5.0 pts
#   ✓ Scraped 27 TE projections
#
# Scraping K from https://www.firstdown.studio/rankings/k...
#   Headers: ['#', 'Player', 'Kicking Pts']
#   Found points column at index 2
#   Found 25 player rows
#     Cam Little (JAC): 9.5 pts
#     Brandon Aubrey (DAL): 9.0 pts
#     Jason Myers (SEA): 8.4 pts
#     Harrison Mevis (LA): 8.0 pts
#     Chase McLaughlin (TB): 7.9 pts
#     Ka'imi Fairbairn (HOU): 7.9 pts
#     Cairo Santos (CHI): 7.7 pts
#     Chris Boswell (PIT): 7.7 pts
#     Jake Elliott (PHI): 7.7 pts
#     Tyler Loop (BAL): 7.7 pts
#     Will Reichard (MIN): 7.7 pts
#     Cameron Dicker (LAC): 7.5 pts
#     Evan McPherson (CIN): 7.4 pts
#     Harrison Butker (KC): 6.9 pts
#     Andy Borregales (NE): 6.9 pts
#     Jake Bates (DET): 6.9 pts
#     Riley Patterson (MIA): 6.9 pts
#     Wil Lutz (DEN): 6.9 pts
#     Brandon McManus (GB): 6.9 pts
#     Younghoe Koo (NYG): 6.7 pts
#     Jake Moody (WAS): 6.7 pts
#     Andre Szmyt (CLE): 5.7 pts
#     Chad Ryland (ARI): 5.7 pts
#     Nick Folk (NYJ): 5.6 pts
#     Joey Slye (TEN): 5.5 pts
#   ✓ Scraped 25 K projections
#
# Total unique players scraped: 207
#
# Saving 207 projections to database...
# ✓ Successfully saved to database!
#
# ✅ First Down Studio scraping complete!

# %%
# 🔵 FANDUEL SCRAPER (runs in subprocess due to Playwright)
# ================================================
print(f"{'='*70}")
print(f"🔵 FANDUEL SCRAPER - {WEEK}")
print(f"{'='*70}\n")

try:
    temp_script = NOTEBOOK_DIR / "_temp_fanduel.py"
    script_content = f'''
import sys
sys.path.insert(0, r"{PROJECT_ROOT}")
from backend.scrapers.scraper_fanduel import FanDuelScraper

try:
    with FanDuelScraper(headless={HEADLESS}, db_path=r"{DB_PATH}") as scraper:
        scraper.scrape_and_save(week="{WEEK}")
    print("FanDuel complete")
except Exception as e:
    print(f"Error: {{e}}")
    import traceback
    traceback.print_exc()
    raise
'''
    temp_script.write_text(script_content, encoding='utf-8')
    
    result = subprocess.run(
        [sys.executable, str(temp_script)],
        capture_output=True,
        text=True,
        cwd=str(PROJECT_ROOT),
        timeout=300
    )
    
    print(result.stdout)
    if result.stderr:
        print("STDERR:", result.stderr)
    
    if result.returncode == 0:
        print("\n✅ FanDuel scraping complete!")
    else:
        print(f"\n❌ FanDuel failed with code {result.returncode}")
    
    temp_script.unlink(missing_ok=True)
except Exception as e:
    print(f"\n❌ FanDuel error: {e}")
    import traceback
    traceback.print_exc()
    if temp_script.exists():
        temp_script.unlink()
# Out:
# ======================================================================
# 🔵 FANDUEL SCRAPER - Week 15
# ======================================================================
#
# Navigating to https://www.fanduel.com/research/nfl/fantasy/ppr...
#   Intercepted data from https://fdresearch-api.fanduel.com/graphql
#   âœ“ Found 552 projections in response
#
# Parsing 552 projections...
#   Christian McCaffrey (RB): 27.2 pts
#   Puka Nacua (WR): 22.1 pts
#   Lamar Jackson (QB): 21.6 pts
#   Ja'Marr Chase (WR): 21.2 pts
#   Jaxon Smith-Njigba (WR): 21.1 pts
#   De'Von Achane (RB): 21.1 pts
#   Dak Prescott (QB): 20.9 pts
#   Matthew Stafford (QB): 20.7 pts
#   Jalen Hurts (QB): 20.3 pts
#   Drake Maye (QB): 20.2 pts
#   Amon-Ra St. Brown (WR): 20.1 pts
#   Josh Allen (QB): 20.1 pts
#   Brock Purdy (QB): 19.1 pts
#   Patrick Mahomes (QB): 18.9 pts
#   Jaxson Dart (QB): 18.7 pts
#   Bijan Robinson (RB): 18.7 pts
#   Jahmyr Gibbs (RB): 18.4 pts
#   Joe Burrow (QB): 18.4 pts
#   Jayden Daniels (QB): 17.9 pts
#   C.J. Stroud (QB): 17.8 pts
#   Trevor Lawrence (QB): 17.8 pts
#   Baker Mayfield (QB): 17.4 pts
#   Jonathan Taylor (RB): 17.2 pts
#   Sam Darnold (QB): 17.2 pts
#   Jared Goff (QB): 17.0 pts
#   Chase Brown (RB): 16.9 pts
#   George Pickens (WR): 16.7 pts
#   Saquon Barkley (RB): 16.6 pts
#   Derrick Henry (RB): 16.6 pts
#   Justin Herbert (QB): 16.3 pts
#   J.J. McCarthy (QB): 16.1 pts
#   James Cook (RB): 16.0 pts
#   Davante Adams (WR): 15.9 pts
#   Chris Olave (WR): 15.8 pts
#   Justin Jefferson (WR): 15.8 pts
#   Caleb Williams (QB): 15.7 pts
#   Bo Nix (QB): 15.6 pts
#   Breece Hall (RB): 15.6 pts
#   Trey McBride (TE): 15.5 pts
#   Rashee Rice (WR): 15.5 pts
#   Woody Marks (RB): 15.3 pts
#   Ashton Jeanty (RB): 15.3 pts
#   Aaron Rodgers (QB): 15.0 pts
#   Kirk Cousins (QB): 14.8 pts
#   Jordan Love (QB): 14.8 pts
#   Josh Jacobs (RB): 14.7 pts
#   Nico Collins (WR): 14.6 pts
#   Zay Flowers (WR): 14.5 pts
#   Tyrone Tracy Jr. (RB): 14.5 pts
#   Rico Dowdle (RB): 14.4 pts
#   Javonte Williams (RB): 14.4 pts
#   Tyler Shough (QB): 14.2 pts
#   Jacoby Brissett (QB): 14.1 pts
#   Quinshon Judkins (RB): 14.1 pts
#   A.J. Brown (WR): 14.0 pts
#   Shedeur Sanders (QB): 13.9 pts
#   Jaylen Waddle (WR): 13.8 pts
#   Bryce Young (QB): 13.4 pts
#   Kyren Williams (RB): 13.3 pts
#   DeVonta Smith (WR): 13.3 pts
#   Stefon Diggs (WR): 13.2 pts
#   Bucky Irving (RB): 13.0 pts
#   Deebo Samuel (WR): 12.9 pts
#   Kenneth Walker III (RB): 12.9 pts
#   Travis Etienne (RB): 12.9 pts
#   Jauan Jennings (WR): 12.7 pts
#   Cameron Ward (QB): 12.7 pts
#   D.K. Metcalf (WR): 12.6 pts
#   Jakobi Meyers (WR): 12.6 pts
#   Tetairoa McMillan (WR): 12.6 pts
#   Harold Fannin Jr. (TE): 12.6 pts
#   Tua Tagovailoa (QB): 12.6 pts
#   Jameson Williams (WR): 12.5 pts
#   Wan'Dale Robinson (WR): 12.5 pts
#   D'Andre Swift (RB): 12.4 pts
#   Juwan Johnson (TE): 12.4 pts
#   Jaylen Warren (RB): 12.4 pts
#   Kenneth Gainwell (RB): 12.3 pts
#   Brian Thomas Jr. (WR): 12.2 pts
#   Tyler Warren (TE): 12.2 pts
#   Kenny Pickett (QB): 12.1 pts
#   David Montgomery (RB): 12.0 pts
#   Khalil Shakir (WR): 11.9 pts
#   George Kittle (TE): 11.7 pts
#   TreVeyon Henderson (RB): 11.6 pts
#   Omarion Hampton (RB): 11.4 pts
#   Tony Pollard (RB): 11.4 pts
#   Ladd McConkey (WR): 11.4 pts
#   RJ Harvey (RB): 11.3 pts
#   Mike Evans (WR): 11.3 pts
#   Terry McLaurin (WR): 11.2 pts
#   Mark Andrews (TE): 11.1 pts
#   Brock Bowers (TE): 10.9 pts
#   Courtland Sutton (WR): 10.9 pts
#   Jordan Addison (WR): 10.8 pts
#   Aaron Jones (RB): 10.7 pts
#   Chris Godwin (WR): 10.5 pts
#   Brenton Strange (TE): 10.5 pts
#   Kyle Pitts (TE): 10.4 pts
#   Jake Ferguson (TE): 10.4 pts
#   Kareem Hunt (RB): 10.1 pts
#   Christian Watson (WR): 10.0 pts
#   Travis Kelce (TE): 10.0 pts
#   Alec Pierce (WR): 9.9 pts
#   Keenan Allen (WR): 9.9 pts
#   Oronde Gadsden (TE): 9.8 pts
#   Emeka Egbuka (WR): 9.8 pts
#   Michael Pittman Jr. (WR): 9.8 pts
#   Jayden Reed (WR): 9.8 pts
#   Zonovan Knight (RB): 9.8 pts
#   Hunter Henry (TE): 9.7 pts
#   Jerry Jeudy (WR): 9.7 pts
#   Dalton Schultz (TE): 9.7 pts
#   Michael Wilson (WR): 9.7 pts
#   Rome Odunze (WR): 9.5 pts
#   Romeo Doubs (WR): 9.3 pts
#   Jayden Higgins (WR): 9.2 pts
#   Zach Charbonnet (RB): 9.1 pts
#   Ricky Pearsall (WR): 8.8 pts
#   Alvin Kamara (RB): 8.8 pts
#   Dalton Kincaid (TE): 8.8 pts
#   Xavier Worthy (WR): 8.7 pts
#   Tyjae Spears (RB): 8.7 pts
#   CeeDee Lamb (WR): 8.7 pts
#   Theo Johnson (TE): 8.6 pts
#   Devin Neal (RB): 8.6 pts
#   Darius Slayton (WR): 8.6 pts
#   Kayshon Boutte (WR): 8.5 pts
#   Parker Washington (WR): 8.4 pts
#   Troy Franklin (WR): 8.4 pts
#   D.J. Moore (WR): 8.4 pts
#   Dallas Goedert (TE): 8.4 pts
#   T.J. Hockenson (TE): 8.3 pts
#   Drake London (WR): 8.3 pts
#   Quentin Johnston (WR): 8.3 pts
#   Chuba Hubbard (RB): 8.3 pts
#   Devin Singletary (RB): 8.2 pts
#   Kyle Monangai (RB): 8.2 pts
#   Elic Ayomanor (WR): 8.2 pts
#   Adonai Mitchell (WR): 8.2 pts
#   Darnell Mooney (WR): 8.2 pts
#   Jordan Mason (RB): 8.1 pts
#   Mack Hollins (WR): 8.1 pts
#   Mason Taylor (TE): 8.0 pts
#   Rashid Shaheed (WR): 7.8 pts
#   Darren Waller (TE): 7.8 pts
#   Isaiah Hodgins (WR): 7.8 pts
#   Devaughn Vele (WR): 7.8 pts
#   Josh Downs (WR): 7.7 pts
#   Marvin Harrison Jr. (WR): 7.6 pts
#   Malik Washington (WR): 7.6 pts
#   Rachaad White (RB): 7.5 pts
#   Tre Tucker (WR): 7.4 pts
#   David Sills V (WR): 7.4 pts
#   Isaiah Likely (TE): 7.4 pts
#   Chimere Dike (WR): 7.3 pts
#   AJ Barner (TE): 7.3 pts
#   Luther Burden III (WR): 7.2 pts
#   Blake Corum (RB): 7.1 pts
#   Cooper Kupp (WR): 7.0 pts
#   Colby Parkinson (TE): 7.0 pts
#   Pat Freiermuth (TE): 7.0 pts
#   Evan Engram (TE): 7.0 pts
#   Colston Loveland (TE): 7.0 pts
#   Xavier Legette (WR): 7.0 pts
#   Michael Carter (RB): 6.9 pts
#   Rashod Bateman (WR): 6.9 pts
#   Rhamondre Stevenson (RB): 6.8 pts
#   Jalen Nailor (WR): 6.8 pts
#   Keon Coleman (WR): 6.7 pts
#   Calvin Austin III (WR): 6.7 pts
#   Bhayshul Tuten (RB): 6.7 pts
#   Mike Gesicki (TE): 6.7 pts
#   Tyrod Taylor (QB): 6.6 pts
#   Chris Rodriguez Jr. (RB): 6.6 pts
#   Chigoziem Okonkwo (TE): 6.5 pts
#   Brady Cook (QB): 6.4 pts
#   Ryan Flournoy (WR): 6.4 pts
#   Jalen Coker (WR): 6.4 pts
#   Marvin Mims (WR): 6.3 pts
#   Pat Bryant (WR): 6.3 pts
#   Andrei Iosivas (WR): 6.3 pts
#   Ross Dwelley (TE): 6.3 pts
#   Noah Brown (WR): 6.2 pts
#   Jacory Croskey-Merritt (RB): 6.2 pts
#   Dylan Sampson (RB): 6.2 pts
#   Isaac TeSlaa (WR): 6.0 pts
#   Samaje Perine (RB): 6.0 pts
#   Isiah Pacheco (RB): 5.9 pts
#   Kimani Vidal (RB): 5.9 pts
#   Van Jefferson (WR): 5.8 pts
#   Jonnu Smith (TE): 5.8 pts
#   Demario Douglas (WR): 5.7 pts
#   Emanuel Wilson (RB): 5.7 pts
#   John Metchie III (WR): 5.7 pts
#   Isaiah Bond (WR): 5.5 pts
#   Isaiah Davis (RB): 5.4 pts
#   Christian Kirk (WR): 5.3 pts
#   Gunnar Helm (TE): 5.3 pts
#   Brandin Cooks (WR): 5.2 pts
#   Gabriel Davis (WR): 5.2 pts
#   Michael Mayer (TE): 5.2 pts
#   Daniel Bellinger (TE): 5.2 pts
#   Noah Fant (TE): 5.1 pts
#   Taysom Hill (TE): 5.1 pts
#   Cade Otton (TE): 5.0 pts
#   Dawson Knox (TE): 5.0 pts
#   Ja'Tavion Sanders (TE): 4.8 pts
#   Brian Robinson (RB): 4.8 pts
#   Kyle Juszczyk (RB): 4.8 pts
#   Tyler Lockett (WR): 4.7 pts
#   David Njoku (TE): 4.7 pts
#   Marquise Brown (WR): 4.6 pts
#   Dylan Drummond (WR): 4.5 pts
#   KaVontae Turpin (WR): 4.5 pts
#   Tommy Tremble (TE): 4.4 pts
#   Xavier Smith (WR): 4.3 pts
#   Demarcus Robinson (WR): 4.2 pts
#   Mitchell Tinsley (WR): 4.2 pts
#   Philip Rivers (QB): 4.1 pts
#   Riley Leonard (QB): 3.9 pts
#   Emari Demercado (RB): 3.9 pts
#   DeAndre Hopkins (WR): 3.9 pts
#   Lil'Jordan Humphrey (WR): 3.9 pts
#   Luke Musgrave (TE): 3.9 pts
#   Cole Kmet (TE): 3.9 pts
#   Xavier Restrepo (WR): 3.9 pts
#   Brett Rypien (QB): 3.8 pts
#   Davis Allen (TE): 3.8 pts
#   Jeremy McNichols (RB): 3.8 pts
#   Kyle Williams (WR): 3.7 pts
#   Treylon Burks (WR): 3.7 pts
#   Gage Larvadain (WR): 3.7 pts
#   Tyler Allgeier (RB): 3.7 pts
#   JuJu Smith-Schuster (WR): 3.7 pts
#   Jaleel McLaughlin (RB): 3.6 pts
#   Nick Chubb (RB): 3.6 pts
#   Austin Hooper (TE): 3.5 pts
#   Xavier Hutchinson (WR): 3.5 pts
#   Dont'e Thornton Jr. (WR): 3.4 pts
#   Greg Dulcich (TE): 3.4 pts
#   Olamide Zaccheaus (WR): 3.3 pts
#   John Bates (TE): 3.3 pts
#   Jordan Whittington (WR): 3.3 pts
#   Jaylin Lane (WR): 3.3 pts
#   Terrance Ferguson (TE): 3.2 pts
#   Elijah Arroyo (TE): 3.2 pts
#   LeQuint Allen Jr. (RB): 3.1 pts
#   Tre Harris (WR): 3.1 pts
#   Ty Johnson (RB): 3.1 pts
#   Sterling Shepard (WR): 3.0 pts
#   Jahan Dotson (WR): 3.0 pts
#   Darnell Washington (TE): 3.0 pts
#   Malik Davis (RB): 3.0 pts
#   Brashard Smith (RB): 3.0 pts
#   Charlie Kolar (TE): 3.0 pts
#   Ben Sinnott (TE): 3.0 pts
#   Luke Schoonmaker (TE): 2.9 pts
#   Jaylin Noel (WR): 2.9 pts
#   Raheem Mostert (RB): 2.9 pts
#   Jimmy Horn Jr. (WR): 2.8 pts
#   Matthew Golden (WR): 2.8 pts
#   Tyrell Shavers (WR): 2.8 pts
#   Foster Moreau (TE): 2.8 pts
#   Tez Johnson (WR): 2.8 pts
#   Ollie Gordon II (RB): 2.8 pts
#   Ray Davis (RB): 2.7 pts
#   Cedric Tillman (WR): 2.7 pts
#   Jeremy Ruckert (TE): 2.7 pts
#   Rasheen Ali (RB): 2.7 pts
#   Jack Bech (WR): 2.6 pts
#   Elijah Higgins (TE): 2.6 pts
#   Trevor Etienne (RB): 2.6 pts
#   Jonathan Mingo (WR): 2.5 pts
#   Tylan Wallace (WR): 2.5 pts
#   Tanner Hudson (TE): 2.5 pts
#   John FitzPatrick (TE): 2.4 pts
#   Xavier Weaver (WR): 2.4 pts
#   Adam Thielen (WR): 2.3 pts
#   Mason Tipton (WR): 2.3 pts
#   Devontez Walker (WR): 2.3 pts
#   Jaylen Wright (RB): 2.3 pts
#   Jerome Ford (RB): 2.2 pts
#   Jackson Hawes (TE): 2.2 pts
#   Cade Stover (TE): 2.1 pts
#   Isaiah Williams (WR): 2.1 pts
#   Will Dissly (TE): 2.1 pts
#   Marquez Valdes-Scantling (WR): 2.0 pts
#   Sean Tucker (RB): 1.9 pts
#   Tyquan Thornton (WR): 1.9 pts
#   Tank Bigsby (RB): 1.9 pts
#   Nick Westbrook-Ikhine (WR): 1.9 pts
#   Andre Baccellia (WR): 1.9 pts
#   Adam Trautman (TE): 1.9 pts
#   Trent Sherfield (WR): 1.9 pts
#   Will Shipley (RB): 1.9 pts
#   Konata Mumpfield (WR): 1.8 pts
#   Blake Whiteheart (TE): 1.8 pts
#   Dontayvion Wicks (WR): 1.8 pts
#   Brevyn Spann-Ford (TE): 1.8 pts
#   Drew Sample (TE): 1.8 pts
#   Charlie Jones (WR): 1.8 pts
#   Allen Lazard (WR): 1.7 pts
#   Devin Duvernay (WR): 1.7 pts
#   Kaleb Johnson (RB): 1.7 pts
#   Cam Akers (RB): 1.6 pts
#   Elijah Moore (WR): 1.6 pts
#   Tim Patrick (WR): 1.6 pts
#   Charlie Woerner (TE): 1.6 pts
#   Gunner Olszewski (WR): 1.5 pts
#   Ameer Abdullah (RB): 1.5 pts
#   Cody White (WR): 1.5 pts
#   Cody Schrader (RB): 1.5 pts
#   Chris Brooks (RB): 1.5 pts
#   Adam Prentice (RB): 1.5 pts
#   Tai Felton (WR): 1.5 pts
#   Dylan Laube (RB): 1.5 pts
#   Ben Skowronek (WR): 1.5 pts
#   Durham Smythe (TE): 1.4 pts
#   Ben Sims (TE): 1.4 pts
#   Grant Calcaterra (TE): 1.4 pts
#   Tyler Badie (RB): 1.4 pts
#   Julian Hill (TE): 1.4 pts
#   Noah Gray (TE): 1.4 pts
#   Jelani Woods (TE): 1.4 pts
#   Malik Heath (WR): 1.4 pts
#   Dare Ogunbowale (RB): 1.3 pts
#   Kendrick Bourne (WR): 1.3 pts
#   Travis Homer (RB): 1.2 pts
#   Tahj Brooks (RB): 1.2 pts
#   Jalen Tolbert (WR): 1.2 pts
#   Deven Thompkins (WR): 1.1 pts
#   Shane Zylstra (TE): 1.1 pts
#   Stone Smartt (TE): 1.1 pts
#   Khadarel Hodge (WR): 1.1 pts
#   Tyler Conklin (TE): 1.0 pts
#   Chris Moore (WR): 1.0 pts
#   Mitchell Evans (TE): 1.0 pts
#   Jalin Hyatt (WR): 1.0 pts
#   Josh Oliver (TE): 1.0 pts
#   Kendall Milton (RB): 1.0 pts
#   Brycen Tremayne (WR): 0.9 pts
#   Andrew Beck (RB): 0.9 pts
#   Patrick Ricard (RB): 0.9 pts
#   Julius Chestnut (RB): 0.9 pts
#   Isaac Guerendo (RB): 0.8 pts
#   Hunter Luepke (RB): 0.8 pts
#   Feleipe Franks (TE): 0.8 pts
#   Ian Thomas (TE): 0.8 pts
#   Dyami Brown (WR): 0.8 pts
#   British Brooks (RB): 0.7 pts
#   Jeff Wilson (RB): 0.7 pts
#   Mo Alie-Cox (TE): 0.7 pts
#   Connor Heyward (TE): 0.7 pts
#   Jaret Patterson (RB): 0.7 pts
#   Derius Davis (WR): 0.7 pts
#   Reggie Gilliam (RB): 0.7 pts
#   Nyheim Hines (RB): 0.6 pts
#   A.J. Dillon (RB): 0.6 pts
#   Alec Ingold (RB): 0.6 pts
#   Keleki Latu (TE): 0.6 pts
#   Chris Manhertz (TE): 0.6 pts
#   Luke Farrell (TE): 0.6 pts
#   Skyy Moore (WR): 0.6 pts
#   Jake Tonges (TE): 0.6 pts
#   Payne Durham (TE): 0.5 pts
#   Devin Culp (TE): 0.5 pts
#   Tyler Goodson (RB): 0.5 pts
#   Scotty Miller (WR): 0.5 pts
#   Nick Kallerup (TE): 0.5 pts
#   Ryan Miller (WR): 0.5 pts
#   Hunter Long (TE): 0.5 pts
#   Eric Saubert (TE): 0.5 pts
#   Dareke Young (WR): 0.5 pts
#   Kameron Johnson (WR): 0.5 pts
#   Tay Martin (WR): 0.5 pts
#   Jake Bobo (WR): 0.5 pts
#   KeAndre Lambert-Smith (WR): 0.5 pts
#   Andrew Ogletree (TE): 0.5 pts
#   Zamir White (RB): 0.5 pts
#   David Martin-Robinson (TE): 0.5 pts
#   Cedrick Wilson (WR): 0.5 pts
#   Alex Bachman (WR): 0.5 pts
#   Carter Runyon (TE): 0.5 pts
#   Jamal Agnew (WR): 0.5 pts
#   Kylen Granson (TE): 0.5 pts
#   DJ Turner (WR): 0.5 pts
#   Anthony Gould (WR): 0.5 pts
#   Zavier Scott (RB): 0.5 pts
#   DJ Giddens (RB): 0.4 pts
#   Arian Smith (WR): 0.4 pts
#   Darius Cooper (WR): 0.4 pts
#   Xavier Gipson (WR): 0.4 pts
#   Jameis Winston (QB): 0.3 pts
#   Mac Jones (QB): 0.3 pts
#   Nick Mullens (QB): 0.3 pts
#   Joe Flacco (QB): 0.3 pts
#   Joe Milton III (QB): 0.3 pts
#   Mason Rudolph (QB): 0.3 pts
#   Joshua Dobbs (QB): 0.3 pts
#   Davis Mills (QB): 0.3 pts
#   Andy Dalton (QB): 0.3 pts
#   Tyson Bagent (QB): 0.3 pts
#   Easton Stick (QB): 0.2 pts
#   Trey Lance (QB): 0.2 pts
#   Dee Eskridge (WR): 0.2 pts
#   Kedon Slovis (QB): 0.2 pts
#   Gardner Minshew (QB): 0.2 pts
#   Jarrett Stidham (QB): 0.2 pts
#   Kyle Allen (QB): 0.2 pts
#   Max Brosmer (QB): 0.2 pts
#   Mitchell Trubisky (QB): 0.2 pts
#   Aidan O'Connell (QB): 0.2 pts
#   Tyler Huntley (QB): 0.2 pts
#   Dillon Gabriel (QB): 0.2 pts
#   Spencer Rattler (QB): 0.2 pts
#   Malik Willis (QB): 0.2 pts
#   Tyler Johnson (WR): 0.2 pts
#   Owen Wright (RB): 0.2 pts
#   Zach Wilson (QB): 0.2 pts
#   Nathan Carter (RB): 0.2 pts
#   Terrell Jennings (RB): 0.2 pts
#   Trayveon Williams (RB): 0.2 pts
#   Amar Johnson (RB): 0.2 pts
#   Teddy Bridgewater (QB): 0.0 pts
#   Teagan Quitoriano (TE): 0.0 pts
#   Jalen McMillan (WR): 0.0 pts
#   Casey Washington (WR): 0.0 pts
#   Josh Williams (RB): 0.0 pts
#   Mecole Hardman (WR): 0.0 pts
#   D'Ernest Johnson (RB): 0.0 pts
#   Josh Palmer (WR): 0.0 pts
#   Tommy DeVito (QB): 0.0 pts
#   Jack Westover (RB): 0.0 pts
#   Efton Chism III (WR): 0.0 pts
#   Josh Reynolds (WR): 0.0 pts
#   Johnny Mundt (TE): 0.0 pts
#   Justin Fields (QB): 0.0 pts
#   Garrett Wilson (WR): 0.0 pts
#   Quintin Morris (TE): 0.0 pts
#   Irvin Charles (WR): 0.0 pts
#   Braelon Allen (RB): 0.0 pts
#   Josh Johnson (QB): 0.0 pts
#   Russell Wilson (QB): 0.0 pts
#   Marcus Mariota (QB): 0.0 pts
#   Ray-Ray McCloud (WR): 0.0 pts
#   Eric Gray (RB): 0.0 pts
#   Cam Skattebo (RB): 0.0 pts
#   Beaux Collins (WR): 0.0 pts
#   Thomas Fidone II (TE): 0.0 pts
#   Ja'Corey Brooks (WR): 0.0 pts
#   Geno Smith (QB): 0.0 pts
#   Sam Howell (QB): 0.0 pts
#   Justin Shorter (TE): 0.0 pts
#   Tanner McKee (QB): 0.0 pts
#   Cameron Latu (TE): 0.0 pts
#   Joe Mixon (RB): 0.0 pts
#   Justin Watson (WR): 0.0 pts
#   Kyler Murray (QB): 0.0 pts
#   Irv Smith Jr. (TE): 0.0 pts
#   Braxton Berrios (WR): 0.0 pts
#   Jakob Johnson (RB): 0.0 pts
#   Harrison Bryant (TE): 0.0 pts
#   Simi Fehoko (WR): 0.0 pts
#   Tank Dell (WR): 0.0 pts
#   Trishton Jackson (WR): 0.0 pts
#   Jared Wayne (WR): 0.0 pts
#   Travis Vokolek (TE): 0.0 pts
#   Corey Kiner (RB): 0.0 pts
#   Cooper Rush (QB): 0.0 pts
#   Tee Higgins (WR): 0.0 pts
#   Jake Browning (QB): 0.0 pts
#   Keaton Mitchell (RB): 0.0 pts
#   Erick All Jr. (TE): 0.0 pts
#   Cam Grandy (TE): 0.0 pts
#   LaJohntay Wester (WR): 0.0 pts
#   Clyde Edwards-Helaire (RB): 0.0 pts
#   Elijah Mitchell (RB): 0.0 pts
#   Hassan Haskins (RB): 0.0 pts
#   Jason Brownlee (WR): 0.0 pts
#   Tucker Fisk (TE): 0.0 pts
#   Jared Wiley (TE): 0.0 pts
#   Nikko Remigio (WR): 0.0 pts
#   Jalen Royals (WR): 0.0 pts
#   Case Keenum (QB): 0.0 pts
#   Bailey Zappe (QB): 0.0 pts
#   Brittain Brown (RB): 0.0 pts
#   Roschon Johnson (RB): 0.0 pts
#   Malachi Corley (WR): 0.0 pts
#   Jamari Thrash (WR): 0.0 pts
#   Raheim Sanders (RB): 0.0 pts
#   Jahdae Walker (WR): 0.0 pts
#   Cade McDonald (WR): 0.0 pts
#   J.K. Dobbins (RB): 0.0 pts
#   Nate Adkins (TE): 0.0 pts
#   Lucas Krull (TE): 0.0 pts
#   MarShawn Lloyd (RB): 0.0 pts
#   Savion Williams (WR): 0.0 pts
#   Brandon Allen (QB): 0.0 pts
#   Brandon Aiyuk (WR): 0.0 pts
#   Jacob Cowing (WR): 0.0 pts
#   Bryce Oliver (WR): 0.0 pts
#   Kalel Mullings (RB): 0.0 pts
#   Adrian Martinez (QB): 0.0 pts
#   Jordan James (RB): 0.0 pts
#   Jordan Watkins (WR): 0.0 pts
#   Drew Lock (QB): 0.0 pts
#   Ashton Dulin (WR): 0.0 pts
#   Anthony Richardson (QB): 0.0 pts
#   Will Mallory (TE): 0.0 pts
#   Brady Russell (RB): 0.0 pts
#   George Holani (RB): 0.0 pts
#   Tory Horton (WR): 0.0 pts
#   Robbie Ouzts (RB): 0.0 pts
#   Jalen Milroe (QB): 0.0 pts
#   Ricky White III (WR): 0.0 pts
#   David Moore (WR): 0.0 pts
#   Hunter Renfrow (WR): 0.0 pts
#   Jack Stoll (TE): 0.0 pts
#   James Mitchell (TE): 0.0 pts
#   Trey Palmer (WR): 0.0 pts
#   Evan Hull (RB): 0.0 pts
#   Audric Estime (RB): 0.0 pts
#   Zaire Mitchell-Paden (TE): 0.0 pts
#   Moliki Matavao (TE): 0.0 pts
#   Dalevon Campbell (WR): 0.0 pts
#   Jimmy Garoppolo (QB): 0.0 pts
#   Kalif Raymond (WR): 0.0 pts
#   Craig Reynolds (RB): 0.0 pts
#   Tutu Atwell (WR): 0.0 pts
#   Sam LaPorta (TE): 0.0 pts
#   Sione Vaki (RB): 0.0 pts
#   Dominic Lovett (WR): 0.0 pts
#   Jacob Saylors (RB): 0.0 pts
#   Jarquez Hunter (RB): 0.0 pts
#   Jackson Meeks (WR): 0.0 pts
#   Hayden Rucci (TE): 0.0 pts
#   Stetson Bennett (QB): 0.0 pts
#   Brennan Presley (WR): 0.0 pts
#   Zach Horton (TE): 0.0 pts
#   C.J. Ham (RB): 0.0 pts
#   Ty Chandler (RB): 0.0 pts
#   Jaydon Blue (RB): 0.0 pts
#   Ben Yurosek (TE): 0.0 pts
#   Myles Price (WR): 0.0 pts
#   Jalen Cropper (WR): 0.0 pts
#   Skylar Thompson (QB): 0.0 pts
#   Tanner Conner (TE): 0.0 pts
#   Roman Wilson (WR): 0.0 pts
#   Tahj Washington (WR): 0.0 pts
#   Ke'Shawn Williams (WR): 0.0 pts
#   Quinn Ewers (QB): 0.0 pts
#
# Total players scraped: 552
#
# Saving 552 projections to database...
# Using database: C:\Users\Samer Faizi\Documents\Claude Model\backend\data\databases\projections.db
# âœ“ Successfully saved to database!
# FanDuel complete
#
#
# ✅ FanDuel scraping complete!

# %% [markdown]
# ### 🚀 Run All Scrapers (Convenience Cell)
#
# Run this cell to execute all scrapers in sequence:

# %%
# 🚀 RUN ALL SCRAPERS
# ================================================
def run_all_scrapers():
    """Run all scrapers for the configured week."""
    print(f"{'='*70}")
    print(f"RUNNING ALL SCRAPERS - {WEEK}")
    print(f"{'='*70}\n")
    
    results = {}
    
    # 1. Sleeper
    print("💤 Sleeper...")
    try:
        with SleeperScraper(db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, season=SEASON)
        results['Sleeper'] = '✅'
    except Exception as e:
        results['Sleeper'] = f'❌ {str(e)[:40]}'
        print(f"  Error: {e}")
    
    # 2. ESPN
    print("\n🔴 ESPN...")
    try:
        with ESPNScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, season=SEASON)
        results['ESPN'] = '✅'
    except Exception as e:
        results['ESPN'] = f'❌ {str(e)[:40]}'
        print(f"  Error: {e}")
    
    # 3. FantasyPros
    print("\n📊 FantasyPros...")
    try:
        with FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK)
        results['FantasyPros'] = '✅'
    except Exception as e:
        results['FantasyPros'] = f'❌ {str(e)[:40]}'
        print(f"  Error: {e}")
    
    # 4. First Down Studio
    print("\n🎯 First Down Studio...")
    try:
        with FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH) as scraper:
            scraper.scrape_and_save(week=WEEK, scoring="PPR")
        results['First Down'] = '✅'
    except Exception as e:
        results['First Down'] = f'❌ {str(e)[:40]}'
        print(f"  Error: {e}")
    
    # 5. FanDuel (subprocess)
    print("\n🔵 FanDuel...")
    try:
        temp_script = NOTEBOOK_DIR / "_temp_fanduel.py"
        script_content = f'''
import sys
sys.path.insert(0, r"{PROJECT_ROOT}")
from backend.scrapers.scraper_fanduel import FanDuelScraper
with FanDuelScraper(headless={HEADLESS}, db_path=r"{DB_PATH}") as scraper:
    scraper.scrape_and_save(week="{WEEK}")
'''
        temp_script.write_text(script_content, encoding='utf-8')
        result = subprocess.run([sys.executable, str(temp_script)], capture_output=True, text=True, cwd=str(PROJECT_ROOT), timeout=300)
        temp_script.unlink(missing_ok=True)
        results['FanDuel'] = '✅' if result.returncode == 0 else f'❌ Exit {result.returncode}'
    except Exception as e:
        results['FanDuel'] = f'❌ {str(e)[:40]}'
    
    # Summary
    print(f"\n{'='*70}")
    print("SCRAPING SUMMARY")
    print(f"{'='*70}")
    for source, status in results.items():
        print(f"  {source:<15} {status}")
    print(f"{'='*70}\n")

# Uncomment to run all:
# run_all_scrapers()

# %% [markdown]
# ## 📊 Database Status & Data Quality

# %%
def show_database_status():
    """Display comprehensive database status and data quality metrics."""
    with ProjectionsDB(db_path=DB_PATH) as db:
        all_projs = db.get_projections()
        
        print(f"{'='*70}")
        print(f"DATABASE STATUS")
        print(f"{'='*70}\n")
        print(f"Total records: {len(all_projs)}\n")
        
        # Count by source
        print(f"📊 Records by Source:")
        print("-" * 70)
        sources = {}
        for p in all_projs:
            source = p['source_website']
            sources[source] = sources.get(source, 0) + 1
        
        for source, count in sorted(sources.items()):
            print(f"  {source:<25} {count:>5} records")
        
        # Count by week
        print(f"\n📅 Records by Week:")
        print("-" * 70)
        weeks = {}
        for p in all_projs:
            week = p['week']
            weeks[week] = weeks.get(week, 0) + 1
        
        for week, count in sorted(weeks.items()):
            print(f"  {week:<25} {count:>5} records")
        
        # Team coverage (data quality check)
        print(f"\n🏈 Team Data Coverage (Quality Check):")
        print("-" * 70)
        for source in sorted(sources.keys()):
            source_projs = [p for p in all_projs if p['source_website'] == source]
            with_team = sum(1 for p in source_projs if p.get('team'))
            total = len(source_projs)
            pct = (with_team / total * 100) if total > 0 else 0
            status = "✅" if pct >= 95 else "⚠️" if pct >= 75 else "❌"
            print(f"  {source:<25} {with_team:>4}/{total:<4} ({pct:>5.1f}%) {status}")
        
        print(f"\n{'='*70}\n")

# Show status
show_database_status()
# Out:
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 9767
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#   espn.com                   1442 records
#   fanduel.com                3030 records
#   fantasypros.com            2304 records
#   firstdown.studio            544 records
#   sleeper.com                2447 records
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#   Week 10                    1625 records
#   Week 11                    1649 records
#   Week 12                    1519 records
#   Week 13                    1578 records
#   Week 14                    1424 records
#   Week 15                    1972 records
#
# 🏈 Team Data Coverage (Quality Check):
# ----------------------------------------------------------------------
#   espn.com                  1442/1442 (100.0%) ✅
#   fanduel.com               3030/3030 (100.0%) ✅
#   fantasypros.com           2304/2304 (100.0%) ✅
#   firstdown.studio           544/544  (100.0%) ✅
#   sleeper.com               2447/2447 (100.0%) ✅
#
# ======================================================================

# %% [markdown]
# ---
#
# ## 🛠️ Utility Functions
#
# **Use these as needed for database management**

# %%
# ============================================================================
# UTILITY FUNCTIONS - Uncomment to use
# ============================================================================

def clear_week(week_name):
    """Delete all records from a specific week."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    cursor.execute("DELETE FROM projections WHERE week = ?", (week_name,))
    deleted = cursor.rowcount
    conn.commit()
    conn.close()
    print(f"✓ Deleted {deleted} records from {week_name}")

def clear_source(source_name, week=None):
    """Delete records from a specific source."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    if week:
        cursor.execute("DELETE FROM projections WHERE source_website = ? AND week = ?", (source_name, week))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} for {week}")
    else:
        cursor.execute("DELETE FROM projections WHERE source_website = ?", (source_name,))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} (all weeks)")
    conn.commit()
    conn.close()

def clear_entire_database():
    """⚠️ DELETE ALL RECORDS - requires confirmation."""
    confirm = input("⚠️  Type 'DELETE ALL' to confirm: ")
    if confirm == "DELETE ALL":
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()
        cursor.execute("DELETE FROM projections")
        conn.commit()
        deleted = cursor.rowcount
        conn.close()
        print(f"\n✓ Deleted {deleted} records from database")
    else:
        print("\n✗ Cancelled")

def show_week_source_matrix():
    """Display a matrix showing record counts by week and source."""
    import pandas as pd
    conn = sqlite3.connect(DB_PATH)
    query = """
        SELECT week, source_website, COUNT(*) as count
        FROM projections
        GROUP BY week, source_website
        ORDER BY week, source_website
    """
    df = pd.read_sql_query(query, conn)
    conn.close()
    
    if len(df) == 0:
        print("No data in database")
        return
    
    pivot = df.pivot(index='source_website', columns='week', values='count')
    pivot = pivot.fillna(0).astype(int)
    
    print(f"\n{'='*70}")
    print("WEEK × SOURCE MATRIX")
    print("="*70)
    print(pivot.to_string())
    print("="*70 + "\n")

def run_single_scraper(scraper_name):
    """Run a specific scraper by name."""
    scrapers = {
        'sleeper': lambda: SleeperScraper(db_path=DB_PATH),
        'espn': lambda: ESPNScraper(headless=HEADLESS, db_path=DB_PATH),
        'fantasypros': lambda: FantasyProsScraper(headless=HEADLESS, db_path=DB_PATH),
        'firstdown': lambda: FirstDownStudioScraper(headless=HEADLESS, db_path=DB_PATH)
    }
    
    name_lower = scraper_name.lower()
    if name_lower not in scrapers:
        print(f"Unknown scraper: {scraper_name}")
        print(f"Available: {', '.join(scrapers.keys())}")
        return
    
    print(f"Running {scraper_name}...")
    try:
        with scrapers[name_lower]() as scraper:
            if name_lower == 'sleeper':
                scraper.scrape_and_save(week=WEEK, season=SEASON)
            elif name_lower == 'espn':
                scraper.scrape_and_save(week=WEEK, season=SEASON)
            elif name_lower == 'firstdown':
                scraper.scrape_and_save(week=WEEK, scoring="PPR")
            else:
                scraper.scrape_and_save(week=WEEK)
        print(f"✓ {scraper_name} complete")
    except Exception as e:
        print(f"✗ Error: {e}")

# Uncomment to use:
# clear_week("Week 10")
# clear_source("fantasypros.com", WEEK)
# clear_entire_database()
show_week_source_matrix()
# run_single_scraper("sleeper")

print("✅ Utility functions loaded. Uncomment above to use.")
# Out:
# ======================================================================
# WEEK × SOURCE MATRIX
# ======================================================================
# week              Week 10  Week 11  Week 12  Week 13  Week 14  Week 15
# source_website
# espn.com              232      240      234      246      216      274
# fanduel.com           473      508      471      546      480      552
# fantasypros.com       388      321      437      362      347      449
# firstdown.studio      161      176        0        0        0      207
# sleeper.com           371      404      377      424      381      490
# ======================================================================
#
# ✅ Utility functions loaded. Uncomment above to use.

# %% [markdown]
# ---
#
# ## 📚 Quick Reference
#
# ### Weekly Workflow:
# 1. Update `WEEK` and `SEASON` in cell 2
# 2. **Kernel → Restart & Run All**
# 3. Wait for all scrapers to complete (~5-10 minutes)
# 4. Check database status for data quality
#
# ### Available Functions:
# - `run_all_scrapers()` - Scrape all sources *(runs automatically)*
# - `show_database_status()` - View database contents *(runs automatically)*
# - `run_single_scraper(name)` - Run one scraper
# - `clear_week(week)` - Delete all data for a week
# - `clear_source(source, week)` - Delete data from a source
# - `show_week_source_matrix()` - See week×source grid
# - `clear_entire_database()` - Delete everything ⚠️
#
# ### Source Names:
# - `"fanduel.com"`
# - `"sleeper.com"`
# - `"espn.com"`
# - `"fantasypros.com"`
# - `"firstdown.studio"`
#
# ### Tips:
# - FanDuel uses Playwright and runs in a subprocess (this is normal)
# - Set `HEADLESS = False` to see browser windows for debugging
# - Scrapers typically take 1-3 minutes each
# - Check "Team Data Coverage" to ensure quality (should be ≥95%)
#
# ---
#
# **✅ Ready to use! Update WEEK and run all cells.**
