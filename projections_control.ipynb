# %% [markdown]
# # 🎮 Fantasy Football Database - Master Control Panel
#
# This notebook provides complete control over your fantasy football projections database.
#
# **Features:**
# - 🗑️ Database management (view, clear, reset)
# - 📊 Run scrapers individually or all at once
# - 📈 View data quality metrics
# - 🔍 Check team coverage by source

# %% [markdown]
# ## 📦 Setup & Imports
#
# **Note:** The FanDuel scraper (Playwright-based) runs via subprocess to avoid conflicts with Jupyter's event loop. All other scrapers run directly in the notebook.

# %%
import os
import sqlite3
import subprocess
import sys
from datetime import datetime
from database import ProjectionsDB

# Don't import Playwright-based scrapers directly - they conflict with Jupyter
# We'll import Selenium-based scrapers normally
from scraper_sleeper import SleeperScraper
from scraper_espn import ESPNScraper
from scraper_fantasypros import FantasyProsScraper
from scraper_firstdown import FirstDownStudioScraper

# Configuration
WEEK = "Week 9"
SEASON = "2024"
HEADLESS = True  # Set to False to see browser

print(f"✓ Imports successful")
print(f"Configuration: {WEEK}, Season {SEASON}")
print(f"Headless mode: {HEADLESS}")
print(f"\n⚠️  Note: FanDuel scraper must be run via subprocess (Playwright limitation in Jupyter)")
# Out:
# ✓ Imports successful
# Configuration: Week 9, Season 2024
# Headless mode: True
#
# ⚠️  Note: FanDuel scraper must be run via subprocess (Playwright limitation in Jupyter)

# %% [markdown]
# ## 📊 Database Status & Overview

# %%
def show_database_status():
    """Display current database status."""
    with ProjectionsDB() as db:
        all_projs = db.get_projections()
        
        print(f"\n{'='*70}")
        print(f"DATABASE STATUS")
        print(f"{'='*70}\n")
        print(f"Total records: {len(all_projs)}")
        
        # Count by source
        print(f"\n📊 Records by Source:")
        print("-" * 70)
        sources = {}
        for p in all_projs:
            source = p['source_website']
            sources[source] = sources.get(source, 0) + 1
        
        for source, count in sorted(sources.items()):
            print(f"  {source:<25} {count:>5} records")
        
        # Count by week
        print(f"\n📅 Records by Week:")
        print("-" * 70)
        weeks = {}
        for p in all_projs:
            week = p['week']
            weeks[week] = weeks.get(week, 0) + 1
        
        for week, count in sorted(weeks.items()):
            print(f"  {week:<25} {count:>5} records")
        
        # Team coverage
        print(f"\n🏈 Team Data Coverage:")
        print("-" * 70)
        for source in sorted(sources.keys()):
            source_projs = [p for p in all_projs if p['source_website'] == source]
            with_team = sum(1 for p in source_projs if p.get('team'))
            total = len(source_projs)
            pct = (with_team / total * 100) if total > 0 else 0
            status = "✅" if pct >= 95 else "⚠️" if pct >= 75 else "❌"
            print(f"  {source:<25} {with_team:>4}/{total:<4} ({pct:>5.1f}%) {status}")

show_database_status()
# Out:
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 804
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#   espn.com                    233 records
#   fantasypros.com             182 records
#   sleeper.com                 389 records
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#   Week 8                      182 records
#   Week 9                      622 records
#
# 🏈 Team Data Coverage:
# ----------------------------------------------------------------------
#   espn.com                   233/233  (100.0%) ✅
#   fantasypros.com            182/182  (100.0%) ✅
#   sleeper.com                389/389  (100.0%) ✅

# %% [markdown]
# ## 🗑️ Database Management
#
# ### ⚠️ Clear Entire Database
# **WARNING:** This will delete ALL records from the database!

# %%
def clear_entire_database():
    """Delete all records from the database."""
    confirm = input("⚠️  Are you sure you want to delete ALL records? Type 'DELETE ALL' to confirm: ")
    
    if confirm == "DELETE ALL":
        conn = sqlite3.connect("projections.db")
        cursor = conn.cursor()
        cursor.execute("DELETE FROM projections")
        conn.commit()
        deleted = cursor.rowcount
        conn.close()
        print(f"\n✓ Deleted {deleted} records from database")
        print("Database is now empty.")
    else:
        print("\n✗ Cancelled. Database unchanged.")

# Uncomment to run:
clear_entire_database()
show_database_status()

# %% [markdown]
# ### 🗑️ Clear Specific Source

# %%
def clear_source(source_name, week=None):
    """Delete records from a specific source."""
    conn = sqlite3.connect("projections.db")
    cursor = conn.cursor()
    
    if week:
        cursor.execute("DELETE FROM projections WHERE source_website = ? AND week = ?", (source_name, week))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} for {week}")
    else:
        cursor.execute("DELETE FROM projections WHERE source_website = ?", (source_name,))
        print(f"✓ Deleted {cursor.rowcount} records from {source_name} (all weeks)")
    
    conn.commit()
    conn.close()

# Examples:
# clear_source("fantasypros.com", WEEK)
clear_source("fanduel.com")
# show_database_status()
# Out:
# ✓ Deleted 465 records from fanduel.com (all weeks)

# %% [markdown]
# ## 🤖 Run Scrapers Individually
#
# **Note:** FanDuel uses Playwright which conflicts with Jupyter's event loop, so it runs via subprocess (separate process). The other scrapers run directly in the notebook.
#
# ### 1️⃣ FanDuel Scraper

# %%
print(f"\n{'='*70}")
print(f"🔵 FANDUEL SCRAPER (via subprocess)")
print(f"{'='*70}\n")
print(f"Using configuration: {WEEK}, Headless={HEADLESS}\n")

# FanDuel uses Playwright which doesn't work in Jupyter's event loop
# Run it as a subprocess instead
try:
    # Create a temporary script to run FanDuel scraper
    # Use proper string formatting to pass variables
    script_content = f'''from scraper_fanduel import FanDuelScraper

print("Starting FanDuel scraper...")
print(f"Week: {WEEK}")
print(f"Headless: {HEADLESS}")

with FanDuelScraper(headless={HEADLESS}) as scraper:
    scraper.scrape_and_save(week="{WEEK}")
'''
    
    # Write to temp file
    with open("_temp_fanduel.py", "w") as f:
        f.write(script_content)
    
    # Debug: Show what we're running
    print(f"Running FanDuel scraper for {WEEK}...\n")
    
    # Run as subprocess
    result = subprocess.run(
        [sys.executable, "_temp_fanduel.py"],
        capture_output=True,
        text=True
    )
    
    # Print output
    print(result.stdout)
    
    if result.returncode == 0:
        print("\n✅ FanDuel scraping complete!")
    else:
        print(f"\n❌ Error: {result.stderr}")
    
    # Clean up temp file
    if os.path.exists("_temp_fanduel.py"):
        os.remove("_temp_fanduel.py")
        
except Exception as e:
    print(f"\n❌ Error: {e}")
    # Clean up temp file if error
    if os.path.exists("_temp_fanduel.py"):
        os.remove("_temp_fanduel.py")

show_database_status()
# Out:
# ======================================================================
# 🔵 FANDUEL SCRAPER (via subprocess)
# ======================================================================
#
# Using configuration: Week 9, Headless=True
#
# Running FanDuel scraper for Week 9...
#
# Starting FanDuel scraper...
# Week: Week 9
# Headless: True
# Navigating to https://www.fanduel.com/research/nfl/fantasy/ppr...
#   Intercepted data from https://fdresearch-api.fanduel.com/graphql
#   âœ“ Found 465 projections in response
#
# Parsing 465 projections...
#   Lamar Jackson (QB): 24.7 pts
#   Christian McCaffrey (RB): 22.8 pts
#   Josh Allen (QB): 21.6 pts
#   Jonathan Taylor (RB): 21.3 pts
#   Patrick Mahomes (QB): 21.0 pts
#   Kyler Murray (QB): 20.8 pts
#   Jahmyr Gibbs (RB): 20.6 pts
#   Justin Herbert (QB): 20.6 pts
#   Drake Maye (QB): 20.5 pts
#   Puka Nacua (WR): 20.0 pts
#   Ja'Marr Chase (WR): 19.8 pts
#   Dak Prescott (QB): 19.7 pts
#   Bijan Robinson (RB): 19.5 pts
#   Jordan Love (QB): 19.3 pts
#   Caleb Williams (QB): 19.2 pts
#   De'Von Achane (RB): 19.1 pts
#   CeeDee Lamb (WR): 18.5 pts
#   James Cook (RB): 18.2 pts
#   Jaxson Dart (QB): 18.2 pts
#   Zay Flowers (WR): 18.1 pts
#   Trey McBride (TE): 18.1 pts
#   Amon-Ra St. Brown (WR): 18.1 pts
#   Matthew Stafford (QB): 17.9 pts
#   Daniel Jones (QB): 17.8 pts
#   Jared Goff (QB): 17.4 pts
#   Jaxon Smith-Njigba (WR): 17.4 pts
#   Justin Jefferson (WR): 17.3 pts
#   Trevor Lawrence (QB): 17.0 pts
#   Aaron Rodgers (QB): 16.9 pts
#   Javonte Williams (RB): 16.7 pts
#   Sam Darnold (QB): 16.6 pts
#   J.J. McCarthy (QB): 16.6 pts
#   Rashee Rice (WR): 16.5 pts
#   D'Andre Swift (RB): 16.4 pts
#   Josh Jacobs (RB): 16.2 pts
#   Kyren Williams (RB): 16.1 pts
#   Joe Flacco (QB): 16.1 pts
#   Bo Nix (QB): 16.0 pts
#   Davante Adams (WR): 15.7 pts
#   C.J. Stroud (QB): 15.7 pts
#   Marvin Harrison Jr. (WR): 15.6 pts
#   Jaylen Waddle (WR): 15.6 pts
#   Chase Brown (RB): 15.4 pts
#   Travis Etienne (RB): 15.0 pts
#   Drake London (WR): 14.9 pts
#   Tyler Warren (TE): 14.6 pts
#   George Pickens (WR): 14.6 pts
#   Tua Tagovailoa (QB): 14.4 pts
#   Tetairoa McMillan (WR): 14.4 pts
#   Geno Smith (QB): 14.4 pts
#   Keenan Allen (WR): 14.3 pts
#   Nico Collins (WR): 14.2 pts
#   Derrick Henry (RB): 14.2 pts
#   Ashton Jeanty (RB): 14.2 pts
#   Michael Pittman Jr. (WR): 14.1 pts
#   Tyrone Tracy Jr. (RB): 14.0 pts
#   Brian Thomas Jr. (WR): 13.7 pts
#   Stefon Diggs (WR): 13.7 pts
#   Quentin Johnston (WR): 13.6 pts
#   D.K. Metcalf (WR): 13.6 pts
#   Tucker Kraft (TE): 13.4 pts
#   Ladd McConkey (WR): 13.3 pts
#   Courtland Sutton (WR): 13.2 pts
#   Terry McLaurin (WR): 13.1 pts
#   Alvin Kamara (RB): 13.1 pts
#   Cameron Ward (QB): 13.1 pts
#   Rome Odunze (WR): 13.1 pts
#   Cooper Kupp (WR): 12.9 pts
#   J.K. Dobbins (RB): 12.8 pts
#   Brock Bowers (TE): 12.7 pts
#   Chris Olave (WR): 12.6 pts
#   Tyler Shough (QB): 12.5 pts
#   Brandon Aiyuk (WR): 12.3 pts
#   Woody Marks (RB): 12.1 pts
#   Deebo Samuel (WR): 11.8 pts
#   Travis Kelce (TE): 11.8 pts
#   Kenneth Walker III (RB): 11.8 pts
#   Jaylen Warren (RB): 11.7 pts
#   Keon Coleman (WR): 11.6 pts
#   Jameson Williams (WR): 11.6 pts
#   TreVeyon Henderson (RB): 11.5 pts
#   Xavier Worthy (WR): 11.5 pts
#   Khalil Shakir (WR): 11.5 pts
#   George Kittle (TE): 11.3 pts
#   Tee Higgins (WR): 11.3 pts
#   Jacory Croskey-Merritt (RB): 11.2 pts
#   Tony Pollard (RB): 11.0 pts
#   Brock Purdy (QB): 11.0 pts
#   Romeo Doubs (WR): 11.0 pts
#   David Montgomery (RB): 10.9 pts
#   Wan'Dale Robinson (WR): 10.9 pts
#   Kimani Vidal (RB): 10.8 pts
#   Theo Johnson (TE): 10.6 pts
#   Sam LaPorta (TE): 10.6 pts
#   Rico Dowdle (RB): 10.6 pts
#   Hunter Henry (TE): 10.5 pts
#   Jordan Addison (WR): 10.4 pts
#   Jake Ferguson (TE): 10.4 pts
#   Rashid Shaheed (WR): 10.4 pts
#   Aaron Jones (RB): 10.3 pts
#   Rhamondre Stevenson (RB): 10.3 pts
#   Kenneth Gainwell (RB): 10.1 pts
#   Juwan Johnson (TE): 9.9 pts
#   Oronde Gadsden (TE): 9.8 pts
#   Dalton Kincaid (TE): 9.8 pts
#   Marcus Mariota (QB): 9.8 pts
#   D.J. Moore (WR): 9.7 pts
#   Jayden Daniels (QB): 9.7 pts
#   Kyle Pitts (TE): 9.5 pts
#   Jakobi Meyers (WR): 9.4 pts
#   Rashod Bateman (WR): 9.3 pts
#   Malik Washington (WR): 9.3 pts
#   Calvin Austin III (WR): 9.3 pts
#   Christian Kirk (WR): 9.1 pts
#   Josh Downs (WR): 9.1 pts
#   Mark Andrews (TE): 8.9 pts
#   Marquise Brown (WR): 8.9 pts
#   Troy Franklin (WR): 8.8 pts
#   T.J. Hockenson (TE): 8.8 pts
#   Justice Hill (RB): 8.7 pts
#   Kayshon Boutte (WR): 8.7 pts
#   Blake Corum (RB): 8.7 pts
#   Elic Ayomanor (WR): 8.6 pts
#   Tre Tucker (WR): 8.6 pts
#   Travis Hunter (WR): 8.6 pts
#   Christian Watson (WR): 8.5 pts
#   Chigoziem Okonkwo (TE): 8.4 pts
#   Dalton Schultz (TE): 8.4 pts
#   Zach Ertz (TE): 8.3 pts
#   Darnell Mooney (WR): 8.3 pts
#   Emari Demercado (RB): 8.2 pts
#   Isiah Pacheco (RB): 8.2 pts
#   Pat Freiermuth (TE): 8.2 pts
#   Jonnu Smith (TE): 8.2 pts
#   Nick Chubb (RB): 8.2 pts
#   Matthew Golden (WR): 8.1 pts
#   Ricky Pearsall (WR): 8.1 pts
#   Alec Pierce (WR): 8.1 pts
#   Zach Charbonnet (RB): 8.1 pts
#   Xavier Legette (WR): 7.9 pts
#   Kirk Cousins (QB): 7.8 pts
#   Mac Jones (QB): 7.8 pts
#   Michael Penix Jr. (QB): 7.8 pts
#   Darius Slayton (WR): 7.6 pts
#   Michael Wilson (WR): 7.6 pts
#   Noah Fant (TE): 7.5 pts
#   Parker Washington (WR): 7.5 pts
#   Ollie Gordon II (RB): 7.3 pts
#   Evan Engram (TE): 7.3 pts
#   Tyjae Spears (RB): 7.3 pts
#   Ja'Tavion Sanders (TE): 7.2 pts
#   AJ Barner (TE): 7.2 pts
#   Andy Dalton (QB): 7.1 pts
#   Tyler Higbee (TE): 7.1 pts
#   Zonovan Knight (RB): 6.9 pts
#   Julian Hill (TE): 6.7 pts
#   Isaiah Likely (TE): 6.4 pts
#   Tory Horton (WR): 6.4 pts
#   Casey Washington (WR): 6.4 pts
#   Bryce Young (QB): 6.3 pts
#   Luther Burden III (WR): 6.1 pts
#   RJ Harvey (RB): 6.1 pts
#   Devin Singletary (RB): 6.1 pts
#   Colston Loveland (TE): 5.9 pts
#   Zay Jones (WR): 5.9 pts
#   Jordan Mason (RB): 5.9 pts
#   Demarcus Robinson (WR): 5.8 pts
#   Chimere Dike (WR): 5.7 pts
#   Elijah Arroyo (TE): 5.6 pts
#   Marvin Mims (WR): 5.6 pts
#   Lil'Jordan Humphrey (WR): 5.5 pts
#   Andrei Iosivas (WR): 5.4 pts
#   Dyami Brown (WR): 5.4 pts
#   Jauan Jennings (WR): 5.4 pts
#   Mack Hollins (WR): 5.4 pts
#   Tyler Allgeier (RB): 5.3 pts
#   Jalen Nailor (WR): 5.3 pts
#   Kalif Raymond (WR): 5.1 pts
#   Curtis Samuel (WR): 5.1 pts
#   Jeremy McNichols (RB): 5.1 pts
#   Calvin Ridley (WR): 5.1 pts
#   Bhayshul Tuten (RB): 5.1 pts
#   Jalen Tolbert (WR): 5.1 pts
#   Chuba Hubbard (RB): 5.0 pts
#   Samaje Perine (RB): 4.9 pts
#   Brandin Cooks (WR): 4.9 pts
#   Daniel Bellinger (TE): 4.8 pts
#   Greg Dortch (WR): 4.8 pts
#   Jimmy Horn Jr. (WR): 4.8 pts
#   Cole Kmet (TE): 4.8 pts
#   Hunter Renfrow (WR): 4.8 pts
#   Jordan Whittington (WR): 4.7 pts
#   Dont'e Thornton Jr. (WR): 4.7 pts
#   Austin Hooper (TE): 4.6 pts
#   Pat Bryant (WR): 4.6 pts
#   Kareem Hunt (RB): 4.6 pts
#   Emanuel Wilson (RB): 4.6 pts
#   Dawson Knox (TE): 4.5 pts
#   Brashard Smith (RB): 4.5 pts
#   Xavier Hutchinson (WR): 4.4 pts
#   Hunter Long (TE): 4.3 pts
#   Gunnar Helm (TE): 4.3 pts
#   Kyle Monangai (RB): 4.2 pts
#   Brian Robinson (RB): 4.2 pts
#   KaVontae Turpin (WR): 4.1 pts
#   Tyler Lockett (WR): 4.1 pts
#   Michael Mayer (TE): 4.0 pts
#   Hassan Haskins (RB): 4.0 pts
#   Olamide Zaccheaus (WR): 3.9 pts
#   MarShawn Lloyd (RB): 3.9 pts
#   Luke McCaffrey (WR): 3.9 pts
#   Devin Duvernay (WR): 3.8 pts
#   Johnny Mundt (TE): 3.8 pts
#   Nick Westbrook-Ikhine (WR): 3.7 pts
#   DeAndre Hopkins (WR): 3.6 pts
#   Josh Palmer (WR): 3.6 pts
#   Jaydon Blue (RB): 3.5 pts
#   Tanner Conner (TE): 3.4 pts
#   Demario Douglas (WR): 3.3 pts
#   Tim Patrick (WR): 3.3 pts
#   Dontayvion Wicks (WR): 3.2 pts
#   Raheem Mostert (RB): 3.2 pts
#   Tyquan Thornton (WR): 3.2 pts
#   Will Dissly (TE): 3.1 pts
#   Chris Moore (WR): 3.1 pts
#   Drew Sample (TE): 3.1 pts
#   Jalin Hyatt (WR): 3.0 pts
#   Adonai Mitchell (WR): 3.0 pts
#   Adam Thielen (WR): 2.9 pts
#   Jaylin Lane (WR): 2.7 pts
#   Ty Johnson (RB): 2.7 pts
#   Roman Wilson (WR): 2.7 pts
#   Luke Schoonmaker (TE): 2.7 pts
#   Isaac TeSlaa (WR): 2.6 pts
#   George Holani (RB): 2.6 pts
#   Colby Parkinson (TE): 2.5 pts
#   Chris Manhertz (TE): 2.5 pts
#   JuJu Smith-Schuster (WR): 2.5 pts
#   Jaylin Noel (WR): 2.4 pts
#   Kaleb Johnson (RB): 2.4 pts
#   Robbie Chosen (WR): 2.4 pts
#   Taysom Hill (TE): 2.4 pts
#   Tommy Tremble (TE): 2.4 pts
#   Devin Neal (RB): 2.3 pts
#   Darnell Washington (TE): 2.3 pts
#   Josh Oliver (TE): 2.2 pts
#   Kyle Williams (WR): 2.2 pts
#   Chris Brooks (RB): 2.1 pts
#   Jonathan Mingo (WR): 2.1 pts
#   Savion Williams (WR): 2.0 pts
#   Jayden Higgins (WR): 2.0 pts
#   Jack Bech (WR): 1.9 pts
#   Zavier Scott (RB): 1.9 pts
#   Trevor Etienne (RB): 1.9 pts
#   Nate Adkins (TE): 1.9 pts
#   Devaughn Vele (WR): 1.8 pts
#   Jaret Patterson (RB): 1.8 pts
#   Ray Davis (RB): 1.7 pts
#   Elijah Higgins (TE): 1.7 pts
#   Chris Rodriguez Jr. (RB): 1.6 pts
#   Jake Bobo (WR): 1.5 pts
#   Isaac Guerendo (RB): 1.5 pts
#   Dylan Laube (RB): 1.5 pts
#   Tyler Conklin (TE): 1.4 pts
#   Jackson Hawes (TE): 1.4 pts
#   Kyle Juszczyk (RB): 1.4 pts
#   Tre Harris (WR): 1.4 pts
#   Keaton Mitchell (RB): 1.4 pts
#   Noah Gray (TE): 1.4 pts
#   Terrance Ferguson (TE): 1.3 pts
#   Davis Allen (TE): 1.2 pts
#   Charlie Kolar (TE): 1.2 pts
#   Brock Wright (TE): 1.2 pts
#   Kendrick Bourne (WR): 1.2 pts
#   Greg Dulcich (TE): 1.2 pts
#   Luke Musgrave (TE): 1.1 pts
#   Charlie Woerner (TE): 1.1 pts
#   Cedrick Wilson (WR): 1.1 pts
#   Tylan Wallace (WR): 1.1 pts
#   Malik Heath (WR): 1.1 pts
#   Mitchell Evans (TE): 1.1 pts
#   Julius Chestnut (RB): 1.1 pts
#   Beaux Collins (WR): 1.0 pts
#   Tyrell Shavers (WR): 1.0 pts
#   Alec Ingold (RB): 1.0 pts
#   LeQuint Allen Jr. (RB): 1.0 pts
#   Xavier Smith (WR): 1.0 pts
#   David Martin-Robinson (TE): 1.0 pts
#   Tyler Badie (RB): 0.9 pts
#   Trent Sherfield (WR): 0.9 pts
#   Ashton Dulin (WR): 0.9 pts
#   Braxton Berrios (WR): 0.8 pts
#   Van Jefferson (WR): 0.8 pts
#   Ameer Abdullah (RB): 0.8 pts
#   Zamir White (RB): 0.8 pts
#   Jack Stoll (TE): 0.7 pts
#   Tay Martin (WR): 0.7 pts
#   Hunter Luepke (RB): 0.7 pts
#   Brevyn Spann-Ford (TE): 0.7 pts
#   Travis Homer (RB): 0.7 pts
#   DJ Giddens (RB): 0.7 pts
#   Riley Leonard (QB): 0.7 pts
#   Brycen Tremayne (WR): 0.7 pts
#   Jeff Wilson (RB): 0.6 pts
#   Jaylen Wright (RB): 0.6 pts
#   Patrick Ricard (RB): 0.6 pts
#   Cam Akers (RB): 0.6 pts
#   Jacob Saylors (RB): 0.6 pts
#   Roschon Johnson (RB): 0.6 pts
#   Reggie Gilliam (RB): 0.6 pts
#   Jared Wiley (TE): 0.6 pts
#   Rasheen Ali (RB): 0.6 pts
#   Tahj Brooks (RB): 0.6 pts
#   British Brooks (RB): 0.6 pts
#   Adam Trautman (TE): 0.6 pts
#   Mo Alie-Cox (TE): 0.6 pts
#   Will Mallory (TE): 0.6 pts
#   Ryan Flournoy (WR): 0.6 pts
#   Durham Smythe (TE): 0.6 pts
#   Andrew Ogletree (TE): 0.6 pts
#   Teagan Quitoriano (TE): 0.6 pts
#   Nikko Remigio (WR): 0.6 pts
#   John FitzPatrick (TE): 0.6 pts
#   Ben Sims (TE): 0.6 pts
#   Feleipe Franks (TE): 0.6 pts
#   Dee Eskridge (WR): 0.6 pts
#   Erick All Jr. (TE): 0.6 pts
#   Devontez Walker (WR): 0.6 pts
#   Luke Farrell (TE): 0.6 pts
#   Jake Tonges (TE): 0.6 pts
#   Connor Heyward (TE): 0.6 pts
#   Ben Yurosek (TE): 0.6 pts
#   Eric Saubert (TE): 0.6 pts
#   Marquez Valdes-Scantling (WR): 0.5 pts
#   Nathan Carter (RB): 0.5 pts
#   Justin Shorter (TE): 0.5 pts
#   Ben Sinnott (TE): 0.5 pts
#   Irv Smith Jr. (TE): 0.5 pts
#   Harrison Bryant (TE): 0.5 pts
#   Khadarel Hodge (WR): 0.5 pts
#   Mitchell Tinsley (WR): 0.5 pts
#   Skyy Moore (WR): 0.5 pts
#   James Mitchell (TE): 0.5 pts
#   Charlie Jones (WR): 0.5 pts
#   Lucas Krull (TE): 0.5 pts
#   Jalen Coker (WR): 0.5 pts
#   Anthony Gould (WR): 0.5 pts
#   Dareke Young (WR): 0.5 pts
#   Dameon Pierce (RB): 0.5 pts
#   Ben Skowronek (WR): 0.5 pts
#   Jamal Agnew (WR): 0.5 pts
#   David Sills V (WR): 0.5 pts
#   Jared Wayne (WR): 0.4 pts
#   Dare Ogunbowale (RB): 0.4 pts
#   Jake Browning (QB): 0.3 pts
#   Jimmy Garoppolo (QB): 0.3 pts
#   Nyheim Hines (RB): 0.3 pts
#   Nick Mullens (QB): 0.3 pts
#   Russell Wilson (QB): 0.3 pts
#   Tucker Fisk (TE): 0.3 pts
#   Jacoby Brissett (QB): 0.3 pts
#   Joe Milton III (QB): 0.3 pts
#   Mason Rudolph (QB): 0.3 pts
#   Trey Lance (QB): 0.3 pts
#   Gardner Minshew (QB): 0.3 pts
#   KeAndre Lambert-Smith (WR): 0.3 pts
#   Tyson Bagent (QB): 0.3 pts
#   Max Brosmer (QB): 0.2 pts
#   Ian Thomas (TE): 0.2 pts
#   Jarrett Stidham (QB): 0.2 pts
#   Mitchell Trubisky (QB): 0.2 pts
#   Malik Willis (QB): 0.2 pts
#   Kyle Allen (QB): 0.2 pts
#   Spencer Rattler (QB): 0.2 pts
#   Drew Lock (QB): 0.2 pts
#   Davis Mills (QB): 0.2 pts
#   Brandon Allen (QB): 0.2 pts
#   Joshua Dobbs (QB): 0.2 pts
#   Kenny Pickett (QB): 0.2 pts
#   Cooper Rush (QB): 0.2 pts
#   Zach Wilson (QB): 0.2 pts
#   Mason Tipton (WR): 0.2 pts
#   Elijah Mitchell (RB): 0.2 pts
#   Darren Waller (TE): 0.0 pts
#   Tyler Huntley (QB): 0.0 pts
#   LaJohntay Wester (WR): 0.0 pts
#   Tahj Washington (WR): 0.0 pts
#   Quinn Ewers (QB): 0.0 pts
#   Hayden Rucci (TE): 0.0 pts
#   Case Keenum (QB): 0.0 pts
#   Mike Gesicki (TE): 0.0 pts
#   Tanner Hudson (TE): 0.0 pts
#   Joe Burrow (QB): 0.0 pts
#   Jermaine Burton (WR): 0.0 pts
#   Cam Grandy (TE): 0.0 pts
#   Jahdae Walker (WR): 0.0 pts
#   Joe Mixon (RB): 0.0 pts
#   Justin Watson (WR): 0.0 pts
#   Tank Dell (WR): 0.0 pts
#   Jaleel McLaughlin (RB): 0.0 pts
#   Cade Stover (TE): 0.0 pts
#   Jameis Winston (QB): 0.0 pts
#   Trent Taylor (WR): 0.0 pts
#   Eric Gray (RB): 0.0 pts
#   Jacob Cowing (WR): 0.0 pts
#   Cam Skattebo (RB): 0.0 pts
#   Adrian Martinez (QB): 0.0 pts
#   Jordan James (RB): 0.0 pts
#   Thomas Fidone II (TE): 0.0 pts
#   Jordan Watkins (WR): 0.0 pts
#   Skylar Thompson (QB): 0.0 pts
#   Anthony Richardson (QB): 0.0 pts
#   Tyler Goodson (RB): 0.0 pts
#   Ke'Shawn Williams (WR): 0.0 pts
#   David Moore (WR): 0.0 pts
#   Jayden Reed (WR): 0.0 pts
#   Hendon Hooker (QB): 0.0 pts
#   Dalevon Campbell (WR): 0.0 pts
#   C.J. Ham (RB): 0.0 pts
#   Craig Reynolds (RB): 0.0 pts
#   Shane Zylstra (TE): 0.0 pts
#   Ty Chandler (RB): 0.0 pts
#   Sione Vaki (RB): 0.0 pts
#   Tai Felton (WR): 0.0 pts
#   Dominic Lovett (WR): 0.0 pts
#   Myles Price (WR): 0.0 pts
#   Jackson Meeks (WR): 0.0 pts
#   Trayveon Williams (RB): 0.0 pts
#   Derius Davis (WR): 0.0 pts
#   Bryce Oliver (WR): 0.0 pts
#   Omarion Hampton (RB): 0.0 pts
#   Kalel Mullings (RB): 0.0 pts
#   Easton Stick (QB): 0.0 pts
#   Jack Westover (RB): 0.0 pts
#   Efton Chism III (WR): 0.0 pts
#   Dylan Drummond (WR): 0.0 pts
#   Alex Bachman (WR): 0.0 pts
#   Brenton Strange (TE): 0.0 pts
#   Aidan O'Connell (QB): 0.0 pts
#   Carter Runyon (TE): 0.0 pts
#   Foster Moreau (TE): 0.0 pts
#   Tutu Atwell (WR): 0.0 pts
#   Trey Palmer (WR): 0.0 pts
#   Zaire Mitchell-Paden (TE): 0.0 pts
#   Konata Mumpfield (WR): 0.0 pts
#   Moliki Matavao (TE): 0.0 pts
#   Jarquez Hunter (RB): 0.0 pts
#   Elijah Moore (WR): 0.0 pts
#   Jason Brownlee (WR): 0.0 pts
#   Jalen Royals (WR): 0.0 pts
#   Josh Johnson (QB): 0.0 pts
#   Noah Brown (WR): 0.0 pts
#   Cody White (WR): 0.0 pts
#   John Bates (TE): 0.0 pts
#   Brady Russell (RB): 0.0 pts
#   Robbie Ouzts (RB): 0.0 pts
#   Jalen Milroe (QB): 0.0 pts
#   Ja'Corey Brooks (WR): 0.0 pts
#   Trishton Jackson (WR): 0.0 pts
#   Trey Benson (RB): 0.0 pts
#   Tip Reiman (TE): 0.0 pts
#   Xavier Weaver (WR): 0.0 pts
#   Travis Vokolek (TE): 0.0 pts
#   Jalen Cropper (WR): 0.0 pts
#   Kedon Slovis (QB): 0.0 pts
#
# Total players scraped: 465
#
# Saving 465 projections to database...
# âœ“ Successfully saved to database!
#
#
# ✅ FanDuel scraping complete!
#
# ======================================================================
# DATABASE STATUS
# ======================================================================
#
# Total records: 1269
#
# 📊 Records by Source:
# ----------------------------------------------------------------------
#   espn.com                    233 records
#   fanduel.com                 465 records
#   fantasypros.com             182 records
#   sleeper.com                 389 records
#
# 📅 Records by Week:
# ----------------------------------------------------------------------
#   Week 8                      182 records
#   Week 9                     1087 records
#
# 🏈 Team Data Coverage:
# ----------------------------------------------------------------------
#   espn.com                   233/233  (100.0%) ✅
#   fanduel.com                465/465  (100.0%) ✅
#   fantasypros.com            182/182  (100.0%) ✅
#   sleeper.com                389/389  (100.0%) ✅

# %% [markdown]
# ### 2️⃣ Sleeper Scraper

# %%
print(f"\n{'='*70}")
print(f"💤 SLEEPER SCRAPER")
print(f"{'='*70}\n")

try:
    with SleeperScraper() as scraper:
        scraper.scrape_and_save(week=WEEK, season=SEASON)
    print("\n✅ Sleeper scraping complete!")
except Exception as e:
    print(f"\n❌ Error: {e}")

show_database_status()

# %% [markdown]
# ### 3️⃣ ESPN Scraper

# %%
print(f"\n{'='*70}")
print(f"🔴 ESPN SCRAPER")
print(f"{'='*70}\n")

try:
    with ESPNScraper(headless=HEADLESS) as scraper:
        scraper.scrape_and_save(week=WEEK, season=SEASON)
    print("\n✅ ESPN scraping complete!")
except Exception as e:
    print(f"\n❌ Error: {e}")

show_database_status()

# %% [markdown]
# ### 4️⃣ FantasyPros Scraper

# %%
print(f"\n{'='*70}")
print(f"📊 FANTASYPROS SCRAPER")
print(f"{'='*70}\n")

try:
    with FantasyProsScraper(headless=HEADLESS) as scraper:
        scraper.scrape_and_save(week=WEEK)
    print("\n✅ FantasyPros scraping complete!")
except Exception as e:
    print(f"\n❌ Error: {e}")

show_database_status()

# %% [markdown]
# ### 5️⃣ First Down Studio Scraper

# %%
print(f"\n{'='*70}")
print(f"🎯 FIRST DOWN STUDIO SCRAPER")
print(f"{'='*70}\n")

try:
    with FirstDownStudioScraper(headless=HEADLESS) as scraper:
        scraper.scrape_and_save(week=WEEK, scoring="PPR")
    print("\n✅ First Down Studio scraping complete!")
except Exception as e:
    print(f"\n❌ Error: {e}")

show_database_status()

# %% [markdown]
# ## 🎯 Quick Reference
#
# ### Useful Commands
#
# ```python
# # View current database status
# show_database_status()
#
# # Clear entire database (requires confirmation)
# clear_entire_database()
#
# # Clear specific source
# clear_source("fantasypros.com", WEEK)  # Clear specific week
# clear_source("fanduel.com")            # Clear all weeks
#
# # Change configuration
# WEEK = "Week 9"
# SEASON = "2024"
# HEADLESS = False  # Show browser
# ```
#
# ### Source Names
# - `"fanduel.com"`
# - `"sleeper.com"`
# - `"espn.com"`
# - `"fantasypros.com"`
# - `"firstdown.studio"`
